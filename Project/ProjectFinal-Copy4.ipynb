# %%
# %pylab inline

from scipy.ndimage.filters import convolve

import theano
import theano.tensor.signal.downsample
import skimage.io
print theano.config.floatX

from common.plotting import plot_mat

from fuel.datasets.cifar10 import CIFAR10
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme
# Out:
# Populating the interactive namespace from numpy and matplotlib
# float32
# Using gpu device 0: GeForce GTX 780 (CNMeM is enabled)

# %%
CIFAR10.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'})
)

cifar10_train = CIFAR10(("train",), subset=slice(None,40000))
cifar10_valid = CIFAR10(("train",), subset=slice(40000, None))
cifar10_testt  = CIFAR10(("test",))

minibatch_train = 100
minibatch_valid = 100
minibatch_testt = 100

cifar10_train_stream = DataStream.default_stream(
    cifar10_train,
    iteration_scheme=ShuffledScheme(cifar10_train.num_examples, minibatch_train)
)
cifar10_valid_stream = DataStream.default_stream(
    cifar10_valid, 
    iteration_scheme=SequentialScheme(cifar10_valid.num_examples, minibatch_valid)
)
cifar10_testt_stream = DataStream.default_stream(
    cifar10_testt, 
    iteration_scheme=SequentialScheme(cifar10_testt.num_examples, minibatch_testt)
)

print "Each trainin batch consits of a tuple containing:"
for element in next(cifar10_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(cifar10_testt_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    

plot_mat(cifar10_train.data_sources[0][:20], cmap='gray')

asd = 0
for x in cifar10_train_stream.get_epoch_iterator():
    asd += 1
print asd
# Out:
# Each trainin batch consits of a tuple containing:
#  - an array of size (100, 3, 32, 32) containing float32
#  - an array of size (100, 1) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (100, 3, 32, 32) containing float32
#  - an array of size (100, 1) containing uint8
# 400

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
def print_warn(s, X):
    print "after_%s shape: %s" % (s, X.tag.test_value.shape,)

class Layer_Conv():
    def __init__(self, in_chan, out_chan, size):
        self.in_chan = in_chan
        self.out_chan = out_chan
        self.size = size
    def make(self, X, n):
        CWn = theano.shared(np.zeros((self.out_chan, self.in_chan, self.size, self.size), dtype='float32'), name=('CW%d'%n))
        CBn = theano.shared(np.zeros((self.out_chan,), dtype='float32'), name=('CB%d'%n))
        
        CWn.tag.initializer = IsotropicGaussian(0.05)
        CBn.tag.initializer = Constant(0.0)
        
        after_Cn = theano.tensor.maximum(
            0.0,
            theano.tensor.nnet.conv2d(X, CWn) + CBn.dimshuffle('x',0,'x','x')
        )
        print_warn(("C%d"%n), after_Cn)
        
        return after_Cn, [CWn, CBn], [("C%d"%n)]
    
class Layer_Pool():
    def __init__(self, size):
        self.size = size        
    def make(self, X, n):
        after_Pn = theano.tensor.signal.downsample.max_pool_2d(X, (self.size, self.size), ignore_border=True)
        print_warn(("P%d"%n), after_Pn)
        
        return after_Pn, [], [("P%d"%n)]
    
class Layer_Filt():
    def __init__(self, in_chan, out_chan):
        self.in_chan = in_chan
        self.out_chan = out_chan
    def make(self, X, n):
        num_fw4_hidden=10
        FWn = theano.shared(np.zeros((self.in_chan, self.out_chan), dtype='float32'), name=('FW%d'%n))
        FBn = theano.shared(np.zeros((self.out_chan,), dtype='float32'), name=('FB%d'%n))
        
        FWn.tag.initializer = IsotropicGaussian(0.05)
        FBn.tag.initializer = Constant(0.0)

        after_Fn = theano.tensor.dot(X.flatten(2), FWn) + FBn.dimshuffle('x',0)
        print_warn(("F%d"%n), after_Fn)
        
        return after_Fn, [FWn, FBn], [("F%d"%n)]
    
class Layer_Soft():
    def __init__(self):
        pass
    def make(self, X, n):
        after_Sn = theano.tensor.nnet.softmax(X)
        print_warn(("S%d"%n), after_Sn)
        
        return after_Sn, [], [("S%d"%n)]

# %%
class NetworkBuilder():
    def __init__(self, layerlist):
        self.layers = layerlist
    def make(self, X):
        model_parameters = []
        self.model_names = ["X"]
        self.model_layers = [X] 
        i = 1
        after = X
        for layer in self.layers:
            after, param, name = layer.make(after, i)
            self.model_layers += [after]
            model_parameters += param
            self.model_names += name
            i += 1
            
        return after, model_parameters

# %%
theano.config.compute_test_value = 'warn'
X_test_value, Y_test_value = next(cifar10_train_stream.get_epoch_iterator())

X = theano.tensor.tensor4('X')
Y = theano.tensor.matrix('Y', dtype='uint8')
X.tag.test_value = X_test_value[:3]
Y.tag.test_value = Y_test_value[:3]
print "X shape: %s" % (X.tag.test_value.shape,)

network = NetworkBuilder([
        Layer_Conv(3, 32, 3),
        Layer_Pool(2),
        Layer_Conv(32, 50, 4),
        Layer_Pool(2),
        Layer_Conv(50, 64, 3),
        Layer_Filt(64*4*4, 1500),
        Layer_Filt(1500, 600),
        Layer_Filt(600, 10),
        Layer_Soft()
    ])

output, parameters = network.make(X)

predictions = theano.tensor.argmax(output, axis=1)

error_rate = theano.tensor.neq(predictions,Y.ravel()).mean()

nll = - theano.tensor.log(output[theano.tensor.arange(Y.shape[0]), Y.ravel()]).mean()

alpha = 4e-3
weight_decay = 0.0
for p in parameters:
    if p.name[1]=='W':
        weight_decay = weight_decay + alpha * (p**2).sum()

cost = nll + weight_decay

theano.config.compute_test_value = 'off'
# Out:
# X shape: (3, 3, 32, 32)
# after_C1 shape: (3, 32, 30, 30)
# after_P2 shape: (3, 32, 15, 15)
# after_C3 shape: (3, 50, 12, 12)
# after_P4 shape: (3, 50, 6, 6)
# after_C5 shape: (3, 64, 4, 4)
# after_F6 shape: (3, 1500)
# after_F7 shape: (3, 600)
# after_F8 shape: (3, 10)
# after_S9 shape: (3, 10)

# %%
updates = []

lrate = theano.tensor.scalar('lrate',dtype='float32')
momentum = theano.tensor.scalar('momentum',dtype='float32')
gradients = theano.grad(cost, parameters)
velocities = [theano.shared(np.zeros_like(p.get_value()), name='V_%s' %(p.name, )) for p in parameters]

for p,g,v in zip(parameters, gradients, velocities):
    v_new = momentum * v - lrate * g
    p_new = p + v_new
    updates += [(v,v_new), (p, p_new)]

# %%
train_step = theano.function(
    [X, Y, lrate, momentum],
    [cost, error_rate, nll, weight_decay],
    updates=updates
)

predict = theano.function(
    [X], 
    predictions
)

# %%
def compute_error_rate(stream):
    errs = 0.0
    num_samples = 0.0
    for X, Y in stream.get_epoch_iterator():
        errs += (predict(X)!=Y.ravel()).sum()
        num_samples += Y.shape[0]
    return errs/num_samples

def init_parameters():
    rng = np.random.RandomState(1234)
    for p in parameters:
        p.set_value(p.tag.initializer.generate(rng, p.get_value().shape))

def snapshot_parameters():
    return [p.get_value(borrow=False) for p in parameters]

def load_parameters(snapshot):
    for p, s in zip(parameters, snapshot):
        p.set_value(s, borrow=False)

# %%
i=0
e=0

init_parameters()
for v in velocities:
    v.set_value(np.zeros_like(v.get_value()))

best_valid_error_rate = np.inf
best_params = snapshot_parameters()
best_params_epoch = 0

train_erros = []
train_loss = []
train_nll = []
validation_errors = []

number_of_epochs = 3
patience_expansion = 1.5

while e<number_of_epochs:
    e += 1
    epoch_start_i = i
    
    for X_batch, Y_batch in cifar10_train_stream.get_epoch_iterator(): 
        i += 1
        
        K = 4000
        lrate = 7e-3 * K / np.maximum(K, i)
        momentum=0.9
        
        L, err_rate, nll, wdec = train_step(X_batch, Y_batch, lrate, momentum)
        
        train_loss.append((i,L))
        train_erros.append((i,err_rate))
        train_nll.append((i,nll))
        
        if i % 100 == 0:
            print "At minibatch %d, batch loss %f, batch nll %f, batch error rate %f%%" % (i, L, nll, err_rate*100)
        
    
    val_error_rate = compute_error_rate(cifar10_valid_stream)
    if val_error_rate < best_valid_error_rate:
        number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
        best_valid_error_rate = val_error_rate
        best_params = snapshot_parameters()
        best_params_epoch = e
        
    validation_errors.append((i,val_error_rate))
    print "After epoch %d: valid_err_rate: %f%% currently going to do %d epochs" %(
        e, val_error_rate*100, number_of_epochs)
    
    print "After epoch %d: averaged train_err_rate: %f%% averaged train nll: %f averaged train loss: %f" %(
        e, 
        np.mean(np.asarray(train_erros)[epoch_start_i:,1])*100, 
        np.mean(np.asarray(train_nll)[epoch_start_i:,1]),
        np.mean(np.asarray(train_loss)[epoch_start_i:,1])
    )
# Out:
# At minibatch 100, batch loss 24.377111, batch nll 1.753822, batch error rate 75.000000%
# At minibatch 200, batch loss 21.904369, batch nll 1.668158, batch error rate 59.000000%
# At minibatch 300, batch loss 19.526388, batch nll 1.424558, batch error rate 56.000000%
# At minibatch 400, batch loss 17.439568, batch nll 1.244112, batch error rate 45.000000%
# After epoch 1: valid_err_rate: 48.590000% currently going to do 3 epochs
# After epoch 1: averaged train_err_rate: 56.992500% averaged train nll: 1.564813 averaged train loss: 21.952376
# At minibatch 500, batch loss 15.475135, batch nll 0.979425, batch error rate 32.000000%
# At minibatch 600, batch loss 14.233560, batch nll 1.254299, batch error rate 47.000000%
# At minibatch 700, batch loss 12.654534, batch nll 1.031156, batch error rate 37.000000%
# At minibatch 800, batch loss 11.597654, batch nll 1.183596, batch error rate 40.000000%
# After epoch 2: valid_err_rate: 42.180000% currently going to do 4 epochs
# After epoch 2: averaged train_err_rate: 44.210000% averaged train nll: 1.243716 averaged train loss: 14.323840
# At minibatch 900, batch loss 10.343377, batch nll 1.005058, batch error rate 36.000000%
# At minibatch 1000, batch loss 9.299478, batch nll 0.921677, batch error rate 33.000000%
# At minibatch 1100, batch loss 8.675255, batch nll 1.160013, batch error rate 41.000000%
# At minibatch 1200, batch loss 7.662499, batch nll 0.915787, batch error rate 28.000000%
# After epoch 3: valid_err_rate: 38.540000% currently going to do 5 epochs
# After epoch 3: averaged train_err_rate: 39.272500% averaged train nll: 1.112754 averaged train loss: 9.552577
# At minibatch 1300, batch loss 7.112775, batch nll 1.047744, batch error rate 36.000000%
# At minibatch 1400, batch loss 6.391049, batch nll 0.934755, batch error rate 36.000000%
# At minibatch 1500, batch loss 5.815645, batch nll 0.906513, batch error rate 32.000000%
# At minibatch 1600, batch loss 5.309970, batch nll 0.887582, batch error rate 30.000000%
# After epoch 4: valid_err_rate: 34.540000% currently going to do 7 epochs
# After epoch 4: averaged train_err_rate: 36.582500% averaged train nll: 1.040107 averaged train loss: 6.535562
# At minibatch 1700, batch loss 4.941545, batch nll 0.952328, batch error rate 30.000000%
# At minibatch 1800, batch loss 4.581633, batch nll 0.978874, batch error rate 38.000000%
# At minibatch 1900, batch loss 4.242560, batch nll 0.985551, batch error rate 31.000000%
# At minibatch 2000, batch loss 3.895086, batch nll 0.948295, batch error rate 27.000000%
# After epoch 5: valid_err_rate: 34.820000% currently going to do 7 epochs
# After epoch 5: averaged train_err_rate: 34.752500% averaged train nll: 0.987855 averaged train loss: 4.615785
# At minibatch 2100, batch loss 3.536963, batch nll 0.864810, batch error rate 29.000000%
# At minibatch 2200, batch loss 3.252203, batch nll 0.826197, batch error rate 30.000000%
# At minibatch 2300, batch loss 3.231459, batch nll 1.024744, batch error rate 25.000000%
# At minibatch 2400, batch loss 2.910969, batch nll 0.901518, batch error rate 35.000000%
# After epoch 6: valid_err_rate: 33.890000% currently going to do 10 epochs
# After epoch 6: averaged train_err_rate: 32.842500% averaged train nll: 0.939218 averaged train loss: 3.381595
# At minibatch 2500, batch loss 2.686493, batch nll 0.849796, batch error rate 29.000000%
# At minibatch 2600, batch loss 2.722886, batch nll 1.043077, batch error rate 34.000000%
# At minibatch 2700, batch loss 2.396876, batch nll 0.855842, batch error rate 27.000000%
# At minibatch 2800, batch loss 2.164779, batch nll 0.748417, batch error rate 27.000000%
# After epoch 7: valid_err_rate: 32.360000% currently going to do 11 epochs
# After epoch 7: averaged train_err_rate: 31.717500% averaged train nll: 0.909358 averaged train loss: 2.600015
# At minibatch 2900, batch loss 2.010974, batch nll 0.702779, batch error rate 25.000000%
# At minibatch 3000, batch loss 2.018235, batch nll 0.809192, batch error rate 27.000000%
# At minibatch 3100, batch loss 1.890622, batch nll 0.770449, batch error rate 26.000000%
# At minibatch 3200, batch loss 1.707750, batch nll 0.667614, batch error rate 22.000000%
# After epoch 8: valid_err_rate: 32.790000% currently going to do 11 epochs
# After epoch 8: averaged train_err_rate: 30.915000% averaged train nll: 0.887924 averaged train loss: 2.102993
# At minibatch 3300, batch loss 2.006928, batch nll 1.035663, batch error rate 28.000000%
# At minibatch 3400, batch loss 1.772914, batch nll 0.864371, batch error rate 34.000000%
# At minibatch 3500, batch loss 1.658830, batch nll 0.803348, batch error rate 36.000000%
# At minibatch 3600, batch loss 1.527248, batch nll 0.724469, batch error rate 21.000000%
# After epoch 9: valid_err_rate: 31.220000% currently going to do 14 epochs
# After epoch 9: averaged train_err_rate: 30.325000% averaged train nll: 0.871541 averaged train loss: 1.785901
# At minibatch 3700, batch loss 1.588861, batch nll 0.826400, batch error rate 30.000000%
# At minibatch 3800, batch loss 1.528874, batch nll 0.806571, batch error rate 27.000000%
# At minibatch 3900, batch loss 1.553109, batch nll 0.865635, batch error rate 29.000000%
# At minibatch 4000, batch loss 1.501525, batch nll 0.846943, batch error rate 25.000000%
# After epoch 10: valid_err_rate: 30.840000% currently going to do 16 epochs
# After epoch 10: averaged train_err_rate: 29.235000% averaged train nll: 0.841499 averaged train loss: 1.566074
# At minibatch 4100, batch loss 1.553189, batch nll 0.924241, batch error rate 35.000000%
# At minibatch 4200, batch loss 1.464336, batch nll 0.857879, batch error rate 32.000000%
# At minibatch 4300, batch loss 1.365595, batch nll 0.779974, batch error rate 26.000000%
# At minibatch 4400, batch loss 1.468697, batch nll 0.901867, batch error rate 32.000000%
# After epoch 11: valid_err_rate: 31.510000% currently going to do 16 epochs
# After epoch 11: averaged train_err_rate: 29.035000% averaged train nll: 0.835484 averaged train loss: 1.443104
# At minibatch 4500, batch loss 1.355427, batch nll 0.802632, batch error rate 25.000000%
# At minibatch 4600, batch loss 1.481913, batch nll 0.944823, batch error rate 28.000000%
# At minibatch 4700, batch loss 1.321971, batch nll 0.796771, batch error rate 27.000000%
# At minibatch 4800, batch loss 1.678744, batch nll 1.165427, batch error rate 39.000000%
# After epoch 12: valid_err_rate: 31.700000% currently going to do 16 epochs
# After epoch 12: averaged train_err_rate: 28.227500% averaged train nll: 0.811419 averaged train loss: 1.349722
# At minibatch 4900, batch loss 1.256637, batch nll 0.751686, batch error rate 26.000000%
# At minibatch 5000, batch loss 1.281644, batch nll 0.785047, batch error rate 25.000000%
# At minibatch 5100, batch loss 1.214251, batch nll 0.726630, batch error rate 30.000000%
# At minibatch 5200, batch loss 1.259959, batch nll 0.778880, batch error rate 25.000000%
# After epoch 13: valid_err_rate: 29.210000% currently going to do 20 epochs
# After epoch 13: averaged train_err_rate: 27.222500% averaged train nll: 0.787154 averaged train loss: 1.283349
# At minibatch 5300, batch loss 1.188571, batch nll 0.712148, batch error rate 26.000000%
# At minibatch 5400, batch loss 1.163516, batch nll 0.690454, batch error rate 28.000000%
# At minibatch 5500, batch loss 1.316819, batch nll 0.850727, batch error rate 26.000000%
# At minibatch 5600, batch loss 1.257750, batch nll 0.796723, batch error rate 22.000000%
# After epoch 14: valid_err_rate: 28.440000% currently going to do 22 epochs
# After epoch 14: averaged train_err_rate: 26.817500% averaged train nll: 0.772136 averaged train loss: 1.243441
# At minibatch 5700, batch loss 1.012575, batch nll 0.552703, batch error rate 20.000000%
# At minibatch 5800, batch loss 1.242165, batch nll 0.786055, batch error rate 25.000000%
# At minibatch 5900, batch loss 1.031014, batch nll 0.577611, batch error rate 19.000000%
# At minibatch 6000, batch loss 1.300900, batch nll 0.851289, batch error rate 28.000000%
# After epoch 15: valid_err_rate: 29.890000% currently going to do 22 epochs
# After epoch 15: averaged train_err_rate: 26.325000% averaged train nll: 0.756948 averaged train loss: 1.213303
# At minibatch 6100, batch loss 1.248295, batch nll 0.799769, batch error rate 29.000000%
# At minibatch 6200, batch loss 1.256751, batch nll 0.808875, batch error rate 28.000000%
# At minibatch 6300, batch loss 1.345160, batch nll 0.900280, batch error rate 32.000000%
# At minibatch 6400, batch loss 1.120330, batch nll 0.677265, batch error rate 23.000000%
# After epoch 16: valid_err_rate: 27.990000% currently going to do 25 epochs
# After epoch 16: averaged train_err_rate: 25.625000% averaged train nll: 0.743074 averaged train loss: 1.190199
# At minibatch 6500, batch loss 1.065072, batch nll 0.621696, batch error rate 21.000000%
# At minibatch 6600, batch loss 1.176648, batch nll 0.734599, batch error rate 24.000000%
# At minibatch 6700, batch loss 1.237070, batch nll 0.796508, batch error rate 31.000000%
# At minibatch 6800, batch loss 1.159942, batch nll 0.722402, batch error rate 26.000000%
# After epoch 17: valid_err_rate: 28.470000% currently going to do 25 epochs
# After epoch 17: averaged train_err_rate: 25.332500% averaged train nll: 0.728331 averaged train loss: 1.170007
# At minibatch 6900, batch loss 1.366794, batch nll 0.928331, batch error rate 33.000000%
# At minibatch 7000, batch loss 1.174625, batch nll 0.736991, batch error rate 20.000000%
# At minibatch 7100, batch loss 1.371343, batch nll 0.934720, batch error rate 35.000000%
# At minibatch 7200, batch loss 1.253625, batch nll 0.818289, batch error rate 28.000000%
# After epoch 18: valid_err_rate: 28.420000% currently going to do 25 epochs
# After epoch 18: averaged train_err_rate: 25.040000% averaged train nll: 0.725145 averaged train loss: 1.162392
# At minibatch 7300, batch loss 1.173083, batch nll 0.737037, batch error rate 26.000000%
# At minibatch 7400, batch loss 1.122210, batch nll 0.685962, batch error rate 28.000000%
# At minibatch 7500, batch loss 1.090122, batch nll 0.655264, batch error rate 19.000000%
# At minibatch 7600, batch loss 1.103945, batch nll 0.670173, batch error rate 24.000000%
# After epoch 19: valid_err_rate: 27.890000% currently going to do 29 epochs
# After epoch 19: averaged train_err_rate: 24.850000% averaged train nll: 0.715141 averaged train loss: 1.150510
# At minibatch 7700, batch loss 1.154524, batch nll 0.719264, batch error rate 25.000000%
# At minibatch 7800, batch loss 1.172438, batch nll 0.736472, batch error rate 27.000000%
# At minibatch 7900, batch loss 1.223826, batch nll 0.788652, batch error rate 25.000000%
# At minibatch 8000, batch loss 1.222133, batch nll 0.788973, batch error rate 26.000000%
# After epoch 20: valid_err_rate: 27.980000% currently going to do 29 epochs
# After epoch 20: averaged train_err_rate: 24.382500% averaged train nll: 0.696280 averaged train loss: 1.131097
# At minibatch 8100, batch loss 1.105127, batch nll 0.670507, batch error rate 22.000000%
# At minibatch 8200, batch loss 1.020448, batch nll 0.585231, batch error rate 17.000000%
# At minibatch 8300, batch loss 1.177274, batch nll 0.742707, batch error rate 19.000000%
# At minibatch 8400, batch loss 1.164761, batch nll 0.731433, batch error rate 23.000000%
# After epoch 21: valid_err_rate: 28.420000% currently going to do 29 epochs
# After epoch 21: averaged train_err_rate: 23.762500% averaged train nll: 0.692249 averaged train loss: 1.126735
# At minibatch 8500, batch loss 1.103575, batch nll 0.668635, batch error rate 22.000000%
# At minibatch 8600, batch loss 1.060151, batch nll 0.624662, batch error rate 21.000000%
# At minibatch 8700, batch loss 1.053579, batch nll 0.618992, batch error rate 24.000000%
# At minibatch 8800, batch loss 1.229079, batch nll 0.794928, batch error rate 25.000000%
# After epoch 22: valid_err_rate: 26.990000% currently going to do 34 epochs
# After epoch 22: averaged train_err_rate: 23.427500% averaged train nll: 0.675987 averaged train loss: 1.110682
# At minibatch 8900, batch loss 1.128441, batch nll 0.692792, batch error rate 26.000000%
# At minibatch 9000, batch loss 1.140759, batch nll 0.704313, batch error rate 28.000000%
# At minibatch 9100, batch loss 1.109293, batch nll 0.673674, batch error rate 27.000000%
# At minibatch 9200, batch loss 1.016958, batch nll 0.581936, batch error rate 20.000000%
# After epoch 23: valid_err_rate: 26.870000% currently going to do 35 epochs
# After epoch 23: averaged train_err_rate: 22.875000% averaged train nll: 0.664423 averaged train loss: 1.100033
# At minibatch 9300, batch loss 1.232630, batch nll 0.797129, batch error rate 23.000000%
# At minibatch 9400, batch loss 1.013112, batch nll 0.576400, batch error rate 16.000000%
# At minibatch 9500, batch loss 1.244734, batch nll 0.807924, batch error rate 30.000000%
# At minibatch 9600, batch loss 1.301548, batch nll 0.864599, batch error rate 30.000000%
# After epoch 24: valid_err_rate: 27.140000% currently going to do 35 epochs
# After epoch 24: averaged train_err_rate: 22.792500% averaged train nll: 0.666150 averaged train loss: 1.102470
# At minibatch 9700, batch loss 1.032217, batch nll 0.594475, batch error rate 22.000000%
# At minibatch 9800, batch loss 1.171025, batch nll 0.732578, batch error rate 25.000000%
# At minibatch 9900, batch loss 1.116894, batch nll 0.678070, batch error rate 24.000000%
# At minibatch 10000, batch loss 1.037059, batch nll 0.598846, batch error rate 24.000000%
# After epoch 25: valid_err_rate: 27.770000% currently going to do 35 epochs
# After epoch 25: averaged train_err_rate: 22.740000% averaged train nll: 0.660827 averaged train loss: 1.098932
# At minibatch 10100, batch loss 0.980586, batch nll 0.541461, batch error rate 16.000000%
# At minibatch 10200, batch loss 1.076898, batch nll 0.637072, batch error rate 18.000000%
# At minibatch 10300, batch loss 0.985691, batch nll 0.546220, batch error rate 20.000000%
# At minibatch 10400, batch loss 1.056305, batch nll 0.616785, batch error rate 20.000000%
# After epoch 26: valid_err_rate: 26.700000% currently going to do 40 epochs
# After epoch 26: averaged train_err_rate: 22.250000% averaged train nll: 0.647501 averaged train loss: 1.086739
# At minibatch 10500, batch loss 1.120721, batch nll 0.680330, batch error rate 17.000000%
# At minibatch 10600, batch loss 1.029927, batch nll 0.588620, batch error rate 17.000000%
# At minibatch 10700, batch loss 1.083103, batch nll 0.641971, batch error rate 25.000000%
# At minibatch 10800, batch loss 1.071581, batch nll 0.630815, batch error rate 22.000000%
# After epoch 27: valid_err_rate: 26.630000% currently going to do 41 epochs
# After epoch 27: averaged train_err_rate: 22.142500% averaged train nll: 0.642101 averaged train loss: 1.082959
# At minibatch 10900, batch loss 1.101986, batch nll 0.658991, batch error rate 28.000000%
# At minibatch 11000, batch loss 1.055724, batch nll 0.612703, batch error rate 23.000000%
# At minibatch 11100, batch loss 1.183137, batch nll 0.740233, batch error rate 26.000000%
# At minibatch 11200, batch loss 0.947476, batch nll 0.505285, batch error rate 16.000000%
# After epoch 28: valid_err_rate: 26.880000% currently going to do 41 epochs
# After epoch 28: averaged train_err_rate: 21.945000% averaged train nll: 0.639777 averaged train loss: 1.082414
# At minibatch 11300, batch loss 1.197455, batch nll 0.754035, batch error rate 24.000000%
# At minibatch 11400, batch loss 1.218975, batch nll 0.774872, batch error rate 28.000000%
# At minibatch 11500, batch loss 1.144939, batch nll 0.700856, batch error rate 23.000000%
# At minibatch 11600, batch loss 1.191555, batch nll 0.747340, batch error rate 28.000000%
# After epoch 29: valid_err_rate: 26.620000% currently going to do 44 epochs
# After epoch 29: averaged train_err_rate: 21.552500% averaged train nll: 0.632704 averaged train loss: 1.076440
# At minibatch 11700, batch loss 1.028111, batch nll 0.582873, batch error rate 25.000000%
# At minibatch 11800, batch loss 1.000703, batch nll 0.555456, batch error rate 14.000000%
# At minibatch 11900, batch loss 1.083887, batch nll 0.638249, batch error rate 25.000000%
# At minibatch 12000, batch loss 1.022741, batch nll 0.576904, batch error rate 25.000000%
# After epoch 30: valid_err_rate: 26.060000% currently going to do 46 epochs
# After epoch 30: averaged train_err_rate: 21.372500% averaged train nll: 0.626174 averaged train loss: 1.071534
# At minibatch 12100, batch loss 1.136410, batch nll 0.689641, batch error rate 23.000000%
# At minibatch 12200, batch loss 1.125634, batch nll 0.678477, batch error rate 23.000000%
# At minibatch 12300, batch loss 1.130816, batch nll 0.683655, batch error rate 24.000000%
# At minibatch 12400, batch loss 0.942811, batch nll 0.495330, batch error rate 17.000000%
# After epoch 31: valid_err_rate: 25.580000% currently going to do 47 epochs
# After epoch 31: averaged train_err_rate: 21.197500% averaged train nll: 0.620750 averaged train loss: 1.067657
# At minibatch 12500, batch loss 0.887499, batch nll 0.438804, batch error rate 14.000000%
# At minibatch 12600, batch loss 1.085722, batch nll 0.636592, batch error rate 17.000000%
# At minibatch 12700, batch loss 1.043694, batch nll 0.594381, batch error rate 22.000000%
# At minibatch 12800, batch loss 0.968576, batch nll 0.519824, batch error rate 18.000000%
# After epoch 32: valid_err_rate: 25.860000% currently going to do 47 epochs
# After epoch 32: averaged train_err_rate: 20.945000% averaged train nll: 0.611205 averaged train loss: 1.060114
# At minibatch 12900, batch loss 1.115373, batch nll 0.665180, batch error rate 20.000000%
# At minibatch 13000, batch loss 0.931780, batch nll 0.481118, batch error rate 14.000000%
# At minibatch 13100, batch loss 0.960295, batch nll 0.508946, batch error rate 16.000000%
# At minibatch 13200, batch loss 0.980940, batch nll 0.531076, batch error rate 16.000000%
# After epoch 33: valid_err_rate: 27.520000% currently going to do 47 epochs
# After epoch 33: averaged train_err_rate: 20.857500% averaged train nll: 0.608117 averaged train loss: 1.058556
# At minibatch 13300, batch loss 1.121984, batch nll 0.670626, batch error rate 22.000000%
# At minibatch 13400, batch loss 1.148260, batch nll 0.696098, batch error rate 24.000000%
# At minibatch 13500, batch loss 0.998813, batch nll 0.546800, batch error rate 20.000000%
# At minibatch 13600, batch loss 1.116368, batch nll 0.664492, batch error rate 22.000000%
# After epoch 34: valid_err_rate: 27.490000% currently going to do 47 epochs
# After epoch 34: averaged train_err_rate: 20.912500% averaged train nll: 0.609476 averaged train loss: 1.061107
# At minibatch 13700, batch loss 1.069247, batch nll 0.616284, batch error rate 22.000000%
# At minibatch 13800, batch loss 1.060787, batch nll 0.607074, batch error rate 22.000000%
# At minibatch 13900, batch loss 1.044029, batch nll 0.590143, batch error rate 21.000000%
# At minibatch 14000, batch loss 1.034308, batch nll 0.580547, batch error rate 23.000000%
# After epoch 35: valid_err_rate: 26.110000% currently going to do 47 epochs
# After epoch 35: averaged train_err_rate: 20.417500% averaged train nll: 0.598212 averaged train loss: 1.051491
# At minibatch 14100, batch loss 1.136161, batch nll 0.681398, batch error rate 21.000000%
# At minibatch 14200, batch loss 1.000576, batch nll 0.545088, batch error rate 23.000000%
# At minibatch 14300, batch loss 0.986843, batch nll 0.532058, batch error rate 15.000000%
# At minibatch 14400, batch loss 0.989154, batch nll 0.534029, batch error rate 16.000000%
# After epoch 36: valid_err_rate: 26.870000% currently going to do 47 epochs
# After epoch 36: averaged train_err_rate: 20.330000% averaged train nll: 0.593517 averaged train loss: 1.048545
# At minibatch 14500, batch loss 1.157951, batch nll 0.701178, batch error rate 23.000000%
# At minibatch 14600, batch loss 1.141050, batch nll 0.684283, batch error rate 20.000000%
# At minibatch 14700, batch loss 1.165724, batch nll 0.709145, batch error rate 28.000000%
# At minibatch 14800, batch loss 0.981573, batch nll 0.524717, batch error rate 15.000000%
# After epoch 37: valid_err_rate: 26.650000% currently going to do 47 epochs
# After epoch 37: averaged train_err_rate: 20.040000% averaged train nll: 0.588658 averaged train loss: 1.045109
# At minibatch 14900, batch loss 0.986192, batch nll 0.528440, batch error rate 17.000000%
# At minibatch 15000, batch loss 1.104367, batch nll 0.646352, batch error rate 24.000000%
# At minibatch 15100, batch loss 0.826835, batch nll 0.368717, batch error rate 8.000000%
# At minibatch 15200, batch loss 0.961611, batch nll 0.502909, batch error rate 16.000000%
# After epoch 38: valid_err_rate: 25.710000% currently going to do 47 epochs
# After epoch 38: averaged train_err_rate: 19.852500% averaged train nll: 0.585705 averaged train loss: 1.043597
# At minibatch 15300, batch loss 1.117266, batch nll 0.657526, batch error rate 23.000000%
# At minibatch 15400, batch loss 1.063430, batch nll 0.603769, batch error rate 23.000000%
# At minibatch 15500, batch loss 1.220379, batch nll 0.760117, batch error rate 23.000000%
# At minibatch 15600, batch loss 1.065258, batch nll 0.605518, batch error rate 19.000000%
# After epoch 39: valid_err_rate: 25.910000% currently going to do 47 epochs
# After epoch 39: averaged train_err_rate: 19.680000% averaged train nll: 0.577158 averaged train loss: 1.036850
# At minibatch 15700, batch loss 0.950290, batch nll 0.489792, batch error rate 13.000000%
# At minibatch 15800, batch loss 1.215563, batch nll 0.754511, batch error rate 27.000000%
# At minibatch 15900, batch loss 1.102493, batch nll 0.641172, batch error rate 19.000000%
# At minibatch 16000, batch loss 1.063102, batch nll 0.601923, batch error rate 23.000000%
# After epoch 40: valid_err_rate: 26.000000% currently going to do 47 epochs
# After epoch 40: averaged train_err_rate: 19.640000% averaged train nll: 0.579596 averaged train loss: 1.040448
# At minibatch 16100, batch loss 1.042643, batch nll 0.580357, batch error rate 16.000000%
# At minibatch 16200, batch loss 1.129168, batch nll 0.666886, batch error rate 19.000000%
# At minibatch 16300, batch loss 1.010025, batch nll 0.547551, batch error rate 18.000000%
# At minibatch 16400, batch loss 0.955886, batch nll 0.492886, batch error rate 20.000000%
# After epoch 41: valid_err_rate: 26.310000% currently going to do 47 epochs
# After epoch 41: averaged train_err_rate: 19.457500% averaged train nll: 0.573687 averaged train loss: 1.035953
# At minibatch 16500, batch loss 1.002196, batch nll 0.538126, batch error rate 17.000000%
# At minibatch 16600, batch loss 1.043011, batch nll 0.578485, batch error rate 26.000000%
# At minibatch 16700, batch loss 1.000805, batch nll 0.536546, batch error rate 19.000000%
# At minibatch 16800, batch loss 1.069793, batch nll 0.605691, batch error rate 20.000000%
# After epoch 42: valid_err_rate: 25.800000% currently going to do 47 epochs
# After epoch 42: averaged train_err_rate: 19.410000% averaged train nll: 0.570341 averaged train loss: 1.034437
# At minibatch 16900, batch loss 1.069283, batch nll 0.604219, batch error rate 21.000000%
# At minibatch 17000, batch loss 0.958495, batch nll 0.493421, batch error rate 17.000000%
# At minibatch 17100, batch loss 1.067433, batch nll 0.602323, batch error rate 23.000000%
# At minibatch 17200, batch loss 1.148922, batch nll 0.683733, batch error rate 24.000000%
# After epoch 43: valid_err_rate: 25.350000% currently going to do 65 epochs
# After epoch 43: averaged train_err_rate: 19.242500% averaged train nll: 0.566873 averaged train loss: 1.031853
# At minibatch 17300, batch loss 0.978040, batch nll 0.511699, batch error rate 21.000000%
# At minibatch 17400, batch loss 1.087051, batch nll 0.620639, batch error rate 24.000000%
# At minibatch 17500, batch loss 0.997890, batch nll 0.531118, batch error rate 21.000000%
# At minibatch 17600, batch loss 0.903812, batch nll 0.437209, batch error rate 14.000000%
# After epoch 44: valid_err_rate: 25.830000% currently going to do 65 epochs
# After epoch 44: averaged train_err_rate: 19.142500% averaged train nll: 0.562729 averaged train loss: 1.029141
# At minibatch 17700, batch loss 0.992278, batch nll 0.525054, batch error rate 20.000000%
# At minibatch 17800, batch loss 0.995315, batch nll 0.527753, batch error rate 16.000000%
# At minibatch 17900, batch loss 0.985273, batch nll 0.517324, batch error rate 17.000000%
# At minibatch 18000, batch loss 1.053037, batch nll 0.585035, batch error rate 20.000000%
# After epoch 45: valid_err_rate: 24.680000% currently going to do 68 epochs
# After epoch 45: averaged train_err_rate: 18.952500% averaged train nll: 0.560355 averaged train loss: 1.027924
# At minibatch 18100, batch loss 0.983910, batch nll 0.515403, batch error rate 20.000000%
# At minibatch 18200, batch loss 1.013150, batch nll 0.543961, batch error rate 15.000000%
# At minibatch 18300, batch loss 0.950594, batch nll 0.480960, batch error rate 21.000000%
# At minibatch 18400, batch loss 0.993279, batch nll 0.523605, batch error rate 18.000000%
# After epoch 46: valid_err_rate: 26.050000% currently going to do 68 epochs
# After epoch 46: averaged train_err_rate: 19.012500% averaged train nll: 0.556712 averaged train loss: 1.025804
# At minibatch 18500, batch loss 1.004462, batch nll 0.533898, batch error rate 16.000000%
# At minibatch 18600, batch loss 1.116845, batch nll 0.646026, batch error rate 22.000000%
# At minibatch 18700, batch loss 0.970017, batch nll 0.498829, batch error rate 18.000000%
# At minibatch 18800, batch loss 1.062420, batch nll 0.591218, batch error rate 25.000000%
# After epoch 47: valid_err_rate: 25.440000% currently going to do 68 epochs
# After epoch 47: averaged train_err_rate: 18.820000% averaged train nll: 0.553770 averaged train loss: 1.024504
# At minibatch 18900, batch loss 0.995178, batch nll 0.522700, batch error rate 17.000000%
# At minibatch 19000, batch loss 1.126027, batch nll 0.653187, batch error rate 25.000000%
# At minibatch 19100, batch loss 1.006304, batch nll 0.533507, batch error rate 18.000000%
# At minibatch 19200, batch loss 0.957208, batch nll 0.484572, batch error rate 14.000000%
# After epoch 48: valid_err_rate: 25.590000% currently going to do 68 epochs
# After epoch 48: averaged train_err_rate: 18.645000% averaged train nll: 0.548583 averaged train loss: 1.021111
# At minibatch 19300, batch loss 0.955585, batch nll 0.482171, batch error rate 15.000000%
# At minibatch 19400, batch loss 0.944443, batch nll 0.470685, batch error rate 17.000000%
# At minibatch 19500, batch loss 0.976222, batch nll 0.502188, batch error rate 17.000000%
# At minibatch 19600, batch loss 0.960835, batch nll 0.486935, batch error rate 15.000000%
# After epoch 49: valid_err_rate: 25.420000% currently going to do 68 epochs
# After epoch 49: averaged train_err_rate: 18.482500% averaged train nll: 0.545067 averaged train loss: 1.018714
# At minibatch 19700, batch loss 1.024736, batch nll 0.550194, batch error rate 16.000000%
# At minibatch 19800, batch loss 1.023837, batch nll 0.549015, batch error rate 17.000000%
# At minibatch 19900, batch loss 0.914436, batch nll 0.439670, batch error rate 13.000000%
# At minibatch 20000, batch loss 1.084983, batch nll 0.610135, batch error rate 20.000000%
# After epoch 50: valid_err_rate: 24.770000% currently going to do 68 epochs
# After epoch 50: averaged train_err_rate: 18.430000% averaged train nll: 0.544882 averaged train loss: 1.019519
# At minibatch 20100, batch loss 1.051084, batch nll 0.575595, batch error rate 18.000000%
# At minibatch 20200, batch loss 1.075825, batch nll 0.599480, batch error rate 18.000000%
# At minibatch 20300, batch loss 0.894950, batch nll 0.418952, batch error rate 15.000000%
# At minibatch 20400, batch loss 1.053806, batch nll 0.577845, batch error rate 20.000000%
# After epoch 51: valid_err_rate: 24.950000% currently going to do 68 epochs
# After epoch 51: averaged train_err_rate: 18.075000% averaged train nll: 0.534994 averaged train loss: 1.010795
# At minibatch 20500, batch loss 1.017397, batch nll 0.541018, batch error rate 15.000000%
# At minibatch 20600, batch loss 0.957272, batch nll 0.480562, batch error rate 17.000000%
# At minibatch 20700, batch loss 1.143186, batch nll 0.666061, batch error rate 28.000000%
# At minibatch 20800, batch loss 1.002735, batch nll 0.525536, batch error rate 18.000000%
# After epoch 52: valid_err_rate: 25.590000% currently going to do 68 epochs
# After epoch 52: averaged train_err_rate: 18.142500% averaged train nll: 0.541692 averaged train loss: 1.018312
# At minibatch 20900, batch loss 0.852522, batch nll 0.374273, batch error rate 9.000000%
# At minibatch 21000, batch loss 1.040647, batch nll 0.562600, batch error rate 19.000000%
# At minibatch 21100, batch loss 1.046816, batch nll 0.568518, batch error rate 22.000000%
# At minibatch 21200, batch loss 0.837751, batch nll 0.358982, batch error rate 14.000000%
# After epoch 53: valid_err_rate: 24.550000% currently going to do 80 epochs
# After epoch 53: averaged train_err_rate: 18.007500% averaged train nll: 0.534014 averaged train loss: 1.012258
# At minibatch 21300, batch loss 1.057584, batch nll 0.578305, batch error rate 22.000000%
# At minibatch 21400, batch loss 0.871294, batch nll 0.391856, batch error rate 9.000000%
# At minibatch 21500, batch loss 1.099102, batch nll 0.619398, batch error rate 25.000000%
# At minibatch 21600, batch loss 0.970968, batch nll 0.491078, batch error rate 16.000000%
# After epoch 54: valid_err_rate: 25.620000% currently going to do 80 epochs
# After epoch 54: averaged train_err_rate: 17.855000% averaged train nll: 0.529383 averaged train loss: 1.008759
# At minibatch 21700, batch loss 0.997916, batch nll 0.517880, batch error rate 17.000000%
# At minibatch 21800, batch loss 0.829144, batch nll 0.348923, batch error rate 8.000000%
# At minibatch 21900, batch loss 1.113734, batch nll 0.633272, batch error rate 23.000000%
# At minibatch 22000, batch loss 0.982013, batch nll 0.501197, batch error rate 17.000000%
# After epoch 55: valid_err_rate: 24.340000% currently going to do 83 epochs
# After epoch 55: averaged train_err_rate: 17.845000% averaged train nll: 0.528375 averaged train loss: 1.008652
# At minibatch 22100, batch loss 1.050325, batch nll 0.569039, batch error rate 23.000000%
# At minibatch 22200, batch loss 1.009156, batch nll 0.527571, batch error rate 18.000000%
# At minibatch 22300, batch loss 1.009350, batch nll 0.527263, batch error rate 16.000000%
# At minibatch 22400, batch loss 1.093522, batch nll 0.611514, batch error rate 20.000000%
# After epoch 56: valid_err_rate: 24.620000% currently going to do 83 epochs
# After epoch 56: averaged train_err_rate: 17.782500% averaged train nll: 0.525483 averaged train loss: 1.007090
# At minibatch 22500, batch loss 0.921438, batch nll 0.438874, batch error rate 15.000000%
# At minibatch 22600, batch loss 0.939091, batch nll 0.456234, batch error rate 13.000000%
# At minibatch 22700, batch loss 0.873481, batch nll 0.390541, batch error rate 14.000000%
# At minibatch 22800, batch loss 1.018163, batch nll 0.535338, batch error rate 22.000000%
# After epoch 57: valid_err_rate: 25.010000% currently going to do 83 epochs
# After epoch 57: averaged train_err_rate: 17.640000% averaged train nll: 0.522244 averaged train loss: 1.004959
# At minibatch 22900, batch loss 0.976371, batch nll 0.492545, batch error rate 15.000000%
# At minibatch 23000, batch loss 0.915025, batch nll 0.431078, batch error rate 16.000000%
# At minibatch 23100, batch loss 1.042361, batch nll 0.558007, batch error rate 15.000000%
# At minibatch 23200, batch loss 1.062699, batch nll 0.578583, batch error rate 24.000000%
# After epoch 58: valid_err_rate: 25.400000% currently going to do 83 epochs
# After epoch 58: averaged train_err_rate: 17.412500% averaged train nll: 0.519775 averaged train loss: 1.003714
# At minibatch 23300, batch loss 1.058418, batch nll 0.573853, batch error rate 24.000000%
# At minibatch 23400, batch loss 0.910732, batch nll 0.426142, batch error rate 13.000000%
# At minibatch 23500, batch loss 1.157322, batch nll 0.672688, batch error rate 21.000000%
# At minibatch 23600, batch loss 0.984354, batch nll 0.499382, batch error rate 18.000000%
# After epoch 59: valid_err_rate: 25.360000% currently going to do 83 epochs
# After epoch 59: averaged train_err_rate: 17.407500% averaged train nll: 0.516580 averaged train loss: 1.001188
# At minibatch 23700, batch loss 1.091068, batch nll 0.605549, batch error rate 27.000000%
# At minibatch 23800, batch loss 0.947517, batch nll 0.461658, batch error rate 17.000000%
# At minibatch 23900, batch loss 0.949619, batch nll 0.463384, batch error rate 16.000000%
# At minibatch 24000, batch loss 0.999332, batch nll 0.513348, batch error rate 18.000000%
# After epoch 60: valid_err_rate: 25.040000% currently going to do 83 epochs
# After epoch 60: averaged train_err_rate: 17.392500% averaged train nll: 0.515484 averaged train loss: 1.001305
# At minibatch 24100, batch loss 0.899315, batch nll 0.412432, batch error rate 13.000000%
# At minibatch 24200, batch loss 1.108207, batch nll 0.621078, batch error rate 22.000000%
# At minibatch 24300, batch loss 1.028702, batch nll 0.541238, batch error rate 21.000000%
# At minibatch 24400, batch loss 0.934958, batch nll 0.447818, batch error rate 13.000000%
# After epoch 61: valid_err_rate: 25.680000% currently going to do 83 epochs
# After epoch 61: averaged train_err_rate: 17.120000% averaged train nll: 0.511884 averaged train loss: 0.998875
# At minibatch 24500, batch loss 0.987675, batch nll 0.499846, batch error rate 17.000000%
# At minibatch 24600, batch loss 1.099058, batch nll 0.610808, batch error rate 20.000000%
# At minibatch 24700, batch loss 1.087626, batch nll 0.599352, batch error rate 23.000000%
# At minibatch 24800, batch loss 1.038277, batch nll 0.550059, batch error rate 22.000000%
# After epoch 62: valid_err_rate: 26.050000% currently going to do 83 epochs
# After epoch 62: averaged train_err_rate: 17.230000% averaged train nll: 0.510302 averaged train loss: 0.998356
# At minibatch 24900, batch loss 0.913498, batch nll 0.424680, batch error rate 12.000000%
# At minibatch 25000, batch loss 1.012915, batch nll 0.523773, batch error rate 22.000000%
# At minibatch 25100, batch loss 0.897479, batch nll 0.408184, batch error rate 11.000000%
# At minibatch 25200, batch loss 0.927846, batch nll 0.438479, batch error rate 10.000000%
# After epoch 63: valid_err_rate: 24.880000% currently going to do 83 epochs
# After epoch 63: averaged train_err_rate: 16.892500% averaged train nll: 0.506944 averaged train loss: 0.995972
# At minibatch 25300, batch loss 1.068725, batch nll 0.578590, batch error rate 22.000000%
# At minibatch 25400, batch loss 1.011952, batch nll 0.521621, batch error rate 17.000000%
# At minibatch 25500, batch loss 0.930803, batch nll 0.440387, batch error rate 13.000000%
# At minibatch 25600, batch loss 1.116299, batch nll 0.625813, batch error rate 22.000000%
# After epoch 64: valid_err_rate: 25.360000% currently going to do 83 epochs
# After epoch 64: averaged train_err_rate: 16.647500% averaged train nll: 0.503163 averaged train loss: 0.993343
# At minibatch 25700, batch loss 0.947031, batch nll 0.455909, batch error rate 13.000000%
# At minibatch 25800, batch loss 0.941919, batch nll 0.450505, batch error rate 14.000000%
# At minibatch 25900, batch loss 0.966013, batch nll 0.474413, batch error rate 14.000000%
# At minibatch 26000, batch loss 1.171559, batch nll 0.680100, batch error rate 25.000000%
# After epoch 65: valid_err_rate: 24.370000% currently going to do 83 epochs
# After epoch 65: averaged train_err_rate: 16.632500% averaged train nll: 0.501815 averaged train loss: 0.993075
# At minibatch 26100, batch loss 1.142193, batch nll 0.650218, batch error rate 22.000000%
# At minibatch 26200, batch loss 0.966014, batch nll 0.473731, batch error rate 18.000000%
# At minibatch 26300, batch loss 0.978481, batch nll 0.486244, batch error rate 16.000000%
# At minibatch 26400, batch loss 1.020105, batch nll 0.527826, batch error rate 17.000000%
# After epoch 66: valid_err_rate: 25.100000% currently going to do 83 epochs
# After epoch 66: averaged train_err_rate: 16.797500% averaged train nll: 0.501074 averaged train loss: 0.993176
# At minibatch 26500, batch loss 0.913118, batch nll 0.420395, batch error rate 16.000000%
# At minibatch 26600, batch loss 1.080172, batch nll 0.586960, batch error rate 22.000000%
# At minibatch 26700, batch loss 1.039915, batch nll 0.546575, batch error rate 17.000000%
# At minibatch 26800, batch loss 0.971816, batch nll 0.478387, batch error rate 16.000000%
# After epoch 67: valid_err_rate: 25.540000% currently going to do 83 epochs
# After epoch 67: averaged train_err_rate: 16.455000% averaged train nll: 0.497285 averaged train loss: 0.990352
# At minibatch 26900, batch loss 1.064072, batch nll 0.570016, batch error rate 18.000000%
# At minibatch 27000, batch loss 0.979834, batch nll 0.485479, batch error rate 18.000000%
# At minibatch 27100, batch loss 0.923212, batch nll 0.428923, batch error rate 14.000000%
# At minibatch 27200, batch loss 1.054629, batch nll 0.560340, batch error rate 16.000000%
# After epoch 68: valid_err_rate: 25.440000% currently going to do 83 epochs
# After epoch 68: averaged train_err_rate: 16.480000% averaged train nll: 0.494832 averaged train loss: 0.988979
# At minibatch 27300, batch loss 1.024756, batch nll 0.530008, batch error rate 18.000000%
# At minibatch 27400, batch loss 0.921398, batch nll 0.426171, batch error rate 14.000000%
# At minibatch 27500, batch loss 0.980724, batch nll 0.485408, batch error rate 16.000000%
# At minibatch 27600, batch loss 0.965661, batch nll 0.470371, batch error rate 14.000000%
# After epoch 69: valid_err_rate: 24.970000% currently going to do 83 epochs
# After epoch 69: averaged train_err_rate: 16.452500% averaged train nll: 0.493683 averaged train loss: 0.988762
# At minibatch 27700, batch loss 0.902476, batch nll 0.406654, batch error rate 11.000000%
# At minibatch 27800, batch loss 1.068903, batch nll 0.572985, batch error rate 20.000000%
# At minibatch 27900, batch loss 0.980211, batch nll 0.484155, batch error rate 13.000000%
# At minibatch 28000, batch loss 1.087425, batch nll 0.591245, batch error rate 25.000000%
# After epoch 70: valid_err_rate: 25.340000% currently going to do 83 epochs
# After epoch 70: averaged train_err_rate: 16.515000% averaged train nll: 0.494182 averaged train loss: 0.990141
# At minibatch 28100, batch loss 0.868393, batch nll 0.371758, batch error rate 13.000000%
# At minibatch 28200, batch loss 0.945983, batch nll 0.448963, batch error rate 16.000000%
# At minibatch 28300, batch loss 1.047013, batch nll 0.550073, batch error rate 17.000000%
# At minibatch 28400, batch loss 1.041314, batch nll 0.544129, batch error rate 22.000000%
# After epoch 71: valid_err_rate: 25.590000% currently going to do 83 epochs
# After epoch 71: averaged train_err_rate: 16.475000% averaged train nll: 0.490376 averaged train loss: 0.987179
# At minibatch 28500, batch loss 0.997990, batch nll 0.500411, batch error rate 18.000000%
# At minibatch 28600, batch loss 1.089019, batch nll 0.591296, batch error rate 20.000000%
# At minibatch 28700, batch loss 0.999940, batch nll 0.501890, batch error rate 19.000000%
# At minibatch 28800, batch loss 1.055552, batch nll 0.557387, batch error rate 19.000000%
# After epoch 72: valid_err_rate: 24.920000% currently going to do 83 epochs
# After epoch 72: averaged train_err_rate: 16.212500% averaged train nll: 0.487930 averaged train loss: 0.985695
# At minibatch 28900, batch loss 1.062513, batch nll 0.563949, batch error rate 22.000000%
# At minibatch 29000, batch loss 1.143519, batch nll 0.644203, batch error rate 22.000000%
# At minibatch 29100, batch loss 0.969580, batch nll 0.470216, batch error rate 12.000000%
# At minibatch 29200, batch loss 0.984761, batch nll 0.485600, batch error rate 17.000000%
# After epoch 73: valid_err_rate: 24.680000% currently going to do 83 epochs
# After epoch 73: averaged train_err_rate: 15.945000% averaged train nll: 0.485483 averaged train loss: 0.984448
# At minibatch 29300, batch loss 0.921007, batch nll 0.421251, batch error rate 10.000000%
# At minibatch 29400, batch loss 0.846838, batch nll 0.346764, batch error rate 9.000000%
# At minibatch 29500, batch loss 1.056629, batch nll 0.556450, batch error rate 19.000000%
# At minibatch 29600, batch loss 1.001130, batch nll 0.501078, batch error rate 19.000000%
# After epoch 74: valid_err_rate: 25.070000% currently going to do 83 epochs
# After epoch 74: averaged train_err_rate: 16.017500% averaged train nll: 0.482639 averaged train loss: 0.982587
# At minibatch 29700, batch loss 1.023416, batch nll 0.522821, batch error rate 16.000000%
# At minibatch 29800, batch loss 0.886206, batch nll 0.385450, batch error rate 13.000000%
# At minibatch 29900, batch loss 0.959525, batch nll 0.458658, batch error rate 16.000000%
# At minibatch 30000, batch loss 0.838356, batch nll 0.337189, batch error rate 12.000000%
# After epoch 75: valid_err_rate: 24.630000% currently going to do 83 epochs
# After epoch 75: averaged train_err_rate: 15.822500% averaged train nll: 0.479401 averaged train loss: 0.980137
# At minibatch 30100, batch loss 1.053841, batch nll 0.552339, batch error rate 21.000000%
# At minibatch 30200, batch loss 0.940781, batch nll 0.439109, batch error rate 16.000000%
# At minibatch 30300, batch loss 0.951959, batch nll 0.449994, batch error rate 15.000000%
# At minibatch 30400, batch loss 1.072639, batch nll 0.570699, batch error rate 18.000000%
# After epoch 76: valid_err_rate: 24.540000% currently going to do 83 epochs
# After epoch 76: averaged train_err_rate: 16.052500% averaged train nll: 0.482004 averaged train loss: 0.983709
# At minibatch 30500, batch loss 0.902031, batch nll 0.399764, batch error rate 14.000000%
# At minibatch 30600, batch loss 0.930502, batch nll 0.427809, batch error rate 11.000000%
# At minibatch 30700, batch loss 0.856022, batch nll 0.353147, batch error rate 9.000000%
# At minibatch 30800, batch loss 1.010743, batch nll 0.508115, batch error rate 17.000000%
# After epoch 77: valid_err_rate: 24.800000% currently going to do 83 epochs
# After epoch 77: averaged train_err_rate: 15.905000% averaged train nll: 0.480511 averaged train loss: 0.983090
# At minibatch 30900, batch loss 0.899220, batch nll 0.395937, batch error rate 13.000000%
# At minibatch 31000, batch loss 0.941062, batch nll 0.437513, batch error rate 15.000000%
# At minibatch 31100, batch loss 0.978161, batch nll 0.474567, batch error rate 16.000000%
# At minibatch 31200, batch loss 0.939057, batch nll 0.435504, batch error rate 12.000000%
# After epoch 78: valid_err_rate: 25.100000% currently going to do 83 epochs
# After epoch 78: averaged train_err_rate: 15.622500% averaged train nll: 0.475386 averaged train loss: 0.978752
# At minibatch 31300, batch loss 0.931244, batch nll 0.427320, batch error rate 14.000000%
# At minibatch 31400, batch loss 1.005936, batch nll 0.501794, batch error rate 16.000000%
# At minibatch 31500, batch loss 1.052061, batch nll 0.547750, batch error rate 16.000000%
# At minibatch 31600, batch loss 1.078556, batch nll 0.574091, batch error rate 20.000000%
# After epoch 79: valid_err_rate: 25.300000% currently going to do 83 epochs
# After epoch 79: averaged train_err_rate: 15.752500% averaged train nll: 0.474162 averaged train loss: 0.978250
# At minibatch 31700, batch loss 1.016579, batch nll 0.511817, batch error rate 20.000000%
# At minibatch 31800, batch loss 1.052294, batch nll 0.547239, batch error rate 15.000000%
# At minibatch 31900, batch loss 0.991354, batch nll 0.486137, batch error rate 18.000000%
# At minibatch 32000, batch loss 0.974747, batch nll 0.469645, batch error rate 19.000000%
# After epoch 80: valid_err_rate: 24.430000% currently going to do 83 epochs
# After epoch 80: averaged train_err_rate: 15.662500% averaged train nll: 0.472649 averaged train loss: 0.977586
# At minibatch 32100, batch loss 0.913330, batch nll 0.407888, batch error rate 12.000000%
# At minibatch 32200, batch loss 1.016800, batch nll 0.511099, batch error rate 21.000000%
# At minibatch 32300, batch loss 1.073047, batch nll 0.567234, batch error rate 19.000000%
# At minibatch 32400, batch loss 0.907395, batch nll 0.401412, batch error rate 13.000000%
# After epoch 81: valid_err_rate: 25.600000% currently going to do 83 epochs
# After epoch 81: averaged train_err_rate: 15.585000% averaged train nll: 0.470311 averaged train loss: 0.975966
# At minibatch 32500, batch loss 0.854668, batch nll 0.348259, batch error rate 13.000000%
# At minibatch 32600, batch loss 1.159292, batch nll 0.652579, batch error rate 25.000000%
# At minibatch 32700, batch loss 0.878570, batch nll 0.371876, batch error rate 9.000000%
# At minibatch 32800, batch loss 0.920480, batch nll 0.413470, batch error rate 12.000000%
# After epoch 82: valid_err_rate: 24.610000% currently going to do 83 epochs
# After epoch 82: averaged train_err_rate: 15.455000% averaged train nll: 0.465711 averaged train loss: 0.972278
# At minibatch 32900, batch loss 0.881578, batch nll 0.374193, batch error rate 10.000000%
# At minibatch 33000, batch loss 1.016467, batch nll 0.508973, batch error rate 19.000000%
# At minibatch 33100, batch loss 0.964073, batch nll 0.456472, batch error rate 12.000000%
# At minibatch 33200, batch loss 0.869577, batch nll 0.361764, batch error rate 9.000000%
# After epoch 83: valid_err_rate: 24.470000% currently going to do 83 epochs
# After epoch 83: averaged train_err_rate: 15.382500% averaged train nll: 0.465648 averaged train loss: 0.973119
# At minibatch 33300, batch loss 0.983787, batch nll 0.475649, batch error rate 16.000000%
# At minibatch 33400, batch loss 1.198503, batch nll 0.690203, batch error rate 22.000000%
# At minibatch 33500, batch loss 0.941186, batch nll 0.432743, batch error rate 15.000000%
# At minibatch 33600, batch loss 1.003937, batch nll 0.495561, batch error rate 17.000000%
# After epoch 84: valid_err_rate: 24.920000% currently going to do 83 epochs
# After epoch 84: averaged train_err_rate: 15.152500% averaged train nll: 0.464138 averaged train loss: 0.972354

# %%
print "Setting network parameters from after epoch %d" %(best_params_epoch)
load_parameters(best_params)

print "Success rate is %f%%" %(100.0-compute_error_rate(cifar10_testt_stream)*100.0,)
print "Error rate is %f%%" %(compute_error_rate(cifar10_testt_stream)*100.0,)

figure(figsize=(16,14))

subplot(2,1,1)
train_nll_a = np.array(train_nll)
semilogy(train_nll_a[:,0], train_nll_a[:,1], label='batch train nll')
legend()

subplot(2,1,2)
train_erros_a = np.array(train_erros)
plot(train_erros_a[:,0], train_erros_a[:,1], label='batch train error rate')
validation_errors_a = np.array(validation_errors)
plot(validation_errors_a[:,0], validation_errors_a[:,1], label='validation error rate', color='r')
ylim(0,1.2)
legend()
# Out:
# Setting network parameters from after epoch 55
# Success rate is 75.500000%
# Error rate is 24.500000%

# %%
middle_layers_computer = theano.function([X], network.model_layers)

img_num=11

middle_layers = middle_layers_computer(X_test_value[img_num:img_num+1])
print middle_layers[0].shape
print middle_layers[1].shape
print middle_layers[2].shape
print middle_layers[3].shape
print middle_layers[4].shape


plot_mat(middle_layers[0])
title(network.model_names[0])
show()

for ml, name in zip(middle_layers[1:], network.model_names[1:]):
    try:
        #print ml#.transpose(1,0,2,3).shape
        plot_mat(ml.transpose(1,0,2,3), cmap='gray')
        title(name)
        show()
    except ValueError:
        pass
# Out:
# (1, 3, 32, 32)
# (1, 16, 30, 30)
# (1, 16, 15, 15)
# (1, 25, 12, 12)
# (1, 25, 6, 6)
