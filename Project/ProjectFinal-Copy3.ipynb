# %%
# %pylab inline

from scipy.ndimage.filters import convolve

import theano
import theano.tensor.signal.downsample
import skimage.io
print theano.config.floatX

from common.plotting import plot_mat

from fuel.datasets.cifar10 import CIFAR10
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme
# Out:
# Populating the interactive namespace from numpy and matplotlib
# float32
# Using gpu device 0: GeForce GTX 780 (CNMeM is enabled)

# %%
CIFAR10.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'})
)

cifar10_train = CIFAR10(("train",), subset=slice(None,40000))
cifar10_valid = CIFAR10(("train",), subset=slice(40000, None))
cifar10_testt  = CIFAR10(("test",))

minibatch_train = 100
minibatch_valid = 100
minibatch_testt = 100

cifar10_train_stream = DataStream.default_stream(
    cifar10_train,
    iteration_scheme=ShuffledScheme(cifar10_train.num_examples, minibatch_train)
)
cifar10_valid_stream = DataStream.default_stream(
    cifar10_valid, 
    iteration_scheme=SequentialScheme(cifar10_valid.num_examples, minibatch_valid)
)
cifar10_testt_stream = DataStream.default_stream(
    cifar10_testt, 
    iteration_scheme=SequentialScheme(cifar10_testt.num_examples, minibatch_testt)
)

print "Each trainin batch consits of a tuple containing:"
for element in next(cifar10_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(cifar10_testt_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    

plot_mat(cifar10_train.data_sources[0][:20], cmap='gray')

asd = 0
for x in cifar10_train_stream.get_epoch_iterator():
    asd += 1
print asd
# Out:
# Each trainin batch consits of a tuple containing:
#  - an array of size (100, 3, 32, 32) containing float32
#  - an array of size (100, 1) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (100, 3, 32, 32) containing float32
#  - an array of size (100, 1) containing uint8
# 400

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
def print_warn(s, X):
    print "after_%s shape: %s" % (s, X.tag.test_value.shape,)

class Layer_Conv():
    def __init__(self, in_chan, out_chan, size):
        self.in_chan = in_chan
        self.out_chan = out_chan
        self.size = size
    def make(self, X, n):
        CWn = theano.shared(np.zeros((self.out_chan, self.in_chan, self.size, self.size), dtype='float32'), name=('CW%d'%n))
        CBn = theano.shared(np.zeros((self.out_chan,), dtype='float32'), name=('CB%d'%n))
        
        CWn.tag.initializer = IsotropicGaussian(0.05)
        CBn.tag.initializer = Constant(0.0)
        
        after_Cn = theano.tensor.maximum(
            0.0,
            theano.tensor.nnet.conv2d(X, CWn) + CBn.dimshuffle('x',0,'x','x')
        )
        print_warn(("C%d"%n), after_Cn)
        
        return after_Cn, [CWn, CBn], [("C%d"%n)]
    
class Layer_Pool():
    def __init__(self, size):
        self.size = size        
    def make(self, X, n):
        after_Pn = theano.tensor.signal.downsample.max_pool_2d(X, (self.size, self.size), ignore_border=True)
        print_warn(("P%d"%n), after_Pn)
        
        return after_Pn, [], [("P%d"%n)]
    
class Layer_Filt():
    def __init__(self, in_chan, out_chan):
        self.in_chan = in_chan
        self.out_chan = out_chan
    def make(self, X, n):
        num_fw4_hidden=10
        FWn = theano.shared(np.zeros((self.in_chan, self.out_chan), dtype='float32'), name=('FW%d'%n))
        FBn = theano.shared(np.zeros((self.out_chan,), dtype='float32'), name=('FB%d'%n))
        
        FWn.tag.initializer = IsotropicGaussian(0.05)
        FBn.tag.initializer = Constant(0.0)

        after_Fn = theano.tensor.dot(X.flatten(2), FWn) + FBn.dimshuffle('x',0)
        print_warn(("F%d"%n), after_Fn)
        
        return after_Fn, [FWn, FBn], [("F%d"%n)]
    
class Layer_Soft():
    def __init__(self):
        pass
    def make(self, X, n):
        after_Sn = theano.tensor.nnet.softmax(X)
        print_warn(("S%d"%n), after_Sn)
        
        return after_Sn, [], [("S%d"%n)]

# %%
class NetworkBuilder():
    def __init__(self, layerlist):
        self.layers = layerlist
    def make(self, X):
        model_parameters = []
        self.model_names = ["X"]
        self.model_layers = [X] 
        i = 1
        after = X
        for layer in self.layers:
            after, param, name = layer.make(after, i)
            self.model_layers += [after]
            model_parameters += param
            self.model_names += name
            i += 1
            
        return after, model_parameters

# %%
theano.config.compute_test_value = 'warn'
X_test_value, Y_test_value = next(cifar10_train_stream.get_epoch_iterator())

X = theano.tensor.tensor4('X')
Y = theano.tensor.matrix('Y', dtype='uint8')
X.tag.test_value = X_test_value[:3]
Y.tag.test_value = Y_test_value[:3]
print "X shape: %s" % (X.tag.test_value.shape,)

network = NetworkBuilder([
        Layer_Conv(3, 16, 3),
        Layer_Pool(2),
        Layer_Conv(16, 25, 4),
        Layer_Pool(2),
        Layer_Conv(25, 32, 3),
        Layer_Filt(32*4*4, 850),
        Layer_Filt(850, 10),
        Layer_Soft()
    ])

output, parameters = network.make(X)

predictions = theano.tensor.argmax(output, axis=1)

error_rate = theano.tensor.neq(predictions,Y.ravel()).mean()

nll = - theano.tensor.log(output[theano.tensor.arange(Y.shape[0]), Y.ravel()]).mean()

alpha = 3e-3
weight_decay = 0.0
for p in parameters:
    if p.name[1]=='W':
        weight_decay = weight_decay + alpha * (p**2).sum()

cost = nll + weight_decay

theano.config.compute_test_value = 'off'
# Out:
# X shape: (3, 3, 32, 32)
# after_C1 shape: (3, 16, 30, 30)
# after_P2 shape: (3, 16, 15, 15)
# after_C3 shape: (3, 25, 12, 12)
# after_P4 shape: (3, 25, 6, 6)
# after_C5 shape: (3, 32, 4, 4)
# after_F6 shape: (3, 850)
# after_F7 shape: (3, 10)
# after_S8 shape: (3, 10)

# %%
updates = []

lrate = theano.tensor.scalar('lrate',dtype='float32')
momentum = theano.tensor.scalar('momentum',dtype='float32')
gradients = theano.grad(cost, parameters)
velocities = [theano.shared(np.zeros_like(p.get_value()), name='V_%s' %(p.name, )) for p in parameters]

for p,g,v in zip(parameters, gradients, velocities):
    v_new = momentum * v - lrate * g
    p_new = p + v_new
    updates += [(v,v_new), (p, p_new)]

# %%
train_step = theano.function(
    [X, Y, lrate, momentum],
    [cost, error_rate, nll, weight_decay],
    updates=updates
)

predict = theano.function(
    [X], 
    predictions
)

# %%
def compute_error_rate(stream):
    errs = 0.0
    num_samples = 0.0
    for X, Y in stream.get_epoch_iterator():
        errs += (predict(X)!=Y.ravel()).sum()
        num_samples += Y.shape[0]
    return errs/num_samples

def init_parameters():
    rng = np.random.RandomState(1234)
    for p in parameters:
        p.set_value(p.tag.initializer.generate(rng, p.get_value().shape))

def snapshot_parameters():
    return [p.get_value(borrow=False) for p in parameters]

def load_parameters(snapshot):
    for p, s in zip(parameters, snapshot):
        p.set_value(s, borrow=False)

# %%
i=0
e=0

init_parameters()
for v in velocities:
    v.set_value(np.zeros_like(v.get_value()))

best_valid_error_rate = np.inf
best_params = snapshot_parameters()
best_params_epoch = 0

train_erros = []
train_loss = []
train_nll = []
validation_errors = []

number_of_epochs = 3
patience_expansion = 1.5

while e<number_of_epochs:
    e += 1
    epoch_start_i = i
    
    for X_batch, Y_batch in cifar10_train_stream.get_epoch_iterator(): 
        i += 1
        
        K = 4000
        lrate = 5e-3 * K / np.maximum(K, i)
        momentum=0.9
        
        L, err_rate, nll, wdec = train_step(X_batch, Y_batch, lrate, momentum)
        
        train_loss.append((i,L))
        train_erros.append((i,err_rate))
        train_nll.append((i,nll))
        
        if i % 100 == 0:
            print "At minibatch %d, batch loss %f, batch nll %f, batch error rate %f%%" % (i, L, nll, err_rate*100)
        
    
    val_error_rate = compute_error_rate(cifar10_valid_stream)
    if val_error_rate < best_valid_error_rate:
        number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
        best_valid_error_rate = val_error_rate
        best_params = snapshot_parameters()
        best_params_epoch = e
        
    validation_errors.append((i,val_error_rate))
    print "After epoch %d: valid_err_rate: %f%% currently going to do %d epochs" %(
        e, val_error_rate*100, number_of_epochs)
    
    print "After epoch %d: averaged train_err_rate: %f%% averaged train nll: %f averaged train loss: %f" %(
        e, 
        np.mean(np.asarray(train_erros)[epoch_start_i:,1])*100, 
        np.mean(np.asarray(train_nll)[epoch_start_i:,1]),
        np.mean(np.asarray(train_loss)[epoch_start_i:,1])
    )
# Out:
# At minibatch 100, batch loss 5.318232, batch nll 2.055914, batch error rate 75.000000%
# At minibatch 200, batch loss 4.929622, batch nll 1.849429, batch error rate 63.000000%
# At minibatch 300, batch loss 4.617818, batch nll 1.706795, batch error rate 64.000000%
# At minibatch 400, batch loss 4.227404, batch nll 1.476084, batch error rate 53.000000%
# After epoch 1: valid_err_rate: 55.830000% currently going to do 3 epochs
# After epoch 1: averaged train_err_rate: 68.430000% averaged train nll: 1.855527 averaged train loss: 4.942390
# At minibatch 500, batch loss 4.182035, batch nll 1.580918, batch error rate 57.000000%
# At minibatch 600, batch loss 3.904267, batch nll 1.445944, batch error rate 52.000000%
# At minibatch 700, batch loss 3.652890, batch nll 1.329449, batch error rate 50.000000%
# At minibatch 800, batch loss 3.619598, batch nll 1.422521, batch error rate 55.000000%
# After epoch 2: valid_err_rate: 49.570000% currently going to do 4 epochs
# After epoch 2: averaged train_err_rate: 51.707500% averaged train nll: 1.434941 averaged train loss: 3.897772
# At minibatch 900, batch loss 3.514676, batch nll 1.436743, batch error rate 50.000000%
# At minibatch 1000, batch loss 3.421450, batch nll 1.454596, batch error rate 48.000000%
# At minibatch 1100, batch loss 3.246598, batch nll 1.384846, batch error rate 52.000000%
# At minibatch 1200, batch loss 3.241005, batch nll 1.478390, batch error rate 48.000000%
# After epoch 3: valid_err_rate: 48.100000% currently going to do 5 epochs
# After epoch 3: averaged train_err_rate: 46.987500% averaged train nll: 1.317098 averaged train loss: 3.287631
# At minibatch 1300, batch loss 2.866616, batch nll 1.195472, batch error rate 35.000000%
# At minibatch 1400, batch loss 2.695820, batch nll 1.110999, batch error rate 38.000000%
# At minibatch 1500, batch loss 2.661771, batch nll 1.159100, batch error rate 37.000000%
# At minibatch 1600, batch loss 2.608097, batch nll 1.183043, batch error rate 44.000000%
# After epoch 4: valid_err_rate: 41.930000% currently going to do 7 epochs
# After epoch 4: averaged train_err_rate: 43.800000% averaged train nll: 1.235634 averaged train loss: 2.822828
# At minibatch 1700, batch loss 2.489244, batch nll 1.134884, batch error rate 40.000000%
# At minibatch 1800, batch loss 2.465352, batch nll 1.177901, batch error rate 40.000000%
# At minibatch 1900, batch loss 2.378896, batch nll 1.154942, batch error rate 49.000000%
# At minibatch 2000, batch loss 2.247936, batch nll 1.084334, batch error rate 38.000000%
# After epoch 5: valid_err_rate: 40.640000% currently going to do 8 epochs
# After epoch 5: averaged train_err_rate: 41.557500% averaged train nll: 1.178164 averaged train loss: 2.467367
# At minibatch 2100, batch loss 2.264005, batch nll 1.154639, batch error rate 40.000000%
# At minibatch 2200, batch loss 2.081867, batch nll 1.025010, batch error rate 32.000000%
# At minibatch 2300, batch loss 2.119656, batch nll 1.111849, batch error rate 40.000000%
# At minibatch 2400, batch loss 1.837764, batch nll 0.875890, batch error rate 31.000000%
# After epoch 6: valid_err_rate: 39.250000% currently going to do 10 epochs
# After epoch 6: averaged train_err_rate: 39.965000% averaged train nll: 1.134809 averaged train loss: 2.193459
# At minibatch 2500, batch loss 2.236697, batch nll 1.317442, batch error rate 50.000000%
# At minibatch 2600, batch loss 2.048087, batch nll 1.169608, batch error rate 43.000000%
# At minibatch 2700, batch loss 1.921848, batch nll 1.081274, batch error rate 40.000000%
# At minibatch 2800, batch loss 2.017176, batch nll 1.212567, batch error rate 43.000000%
# After epoch 7: valid_err_rate: 38.250000% currently going to do 11 epochs
# After epoch 7: averaged train_err_rate: 37.962500% averaged train nll: 1.083641 averaged train loss: 1.963645
# At minibatch 2900, batch loss 1.744695, batch nll 0.973227, batch error rate 36.000000%
# At minibatch 3000, batch loss 1.752480, batch nll 1.011443, batch error rate 37.000000%
# At minibatch 3100, batch loss 1.490906, batch nll 0.780425, batch error rate 24.000000%
# At minibatch 3200, batch loss 1.735487, batch nll 1.053118, batch error rate 36.000000%
# After epoch 8: valid_err_rate: 37.930000% currently going to do 13 epochs
# After epoch 8: averaged train_err_rate: 36.970000% averaged train nll: 1.052407 averaged train loss: 1.793763
# At minibatch 3300, batch loss 1.748396, batch nll 1.091032, batch error rate 38.000000%
# At minibatch 3400, batch loss 1.834195, batch nll 1.201651, batch error rate 47.000000%
# At minibatch 3500, batch loss 1.513967, batch nll 0.904313, batch error rate 30.000000%
# At minibatch 3600, batch loss 1.736499, batch nll 1.149270, batch error rate 41.000000%
# After epoch 9: valid_err_rate: 38.610000% currently going to do 13 epochs
# After epoch 9: averaged train_err_rate: 35.670000% averaged train nll: 1.025358 averaged train loss: 1.658708
# At minibatch 3700, batch loss 1.694525, batch nll 1.126109, batch error rate 39.000000%
# At minibatch 3800, batch loss 1.560310, batch nll 1.010795, batch error rate 39.000000%
# At minibatch 3900, batch loss 1.556724, batch nll 1.025573, batch error rate 33.000000%
# At minibatch 4000, batch loss 1.405577, batch nll 0.890634, batch error rate 27.000000%
# After epoch 10: valid_err_rate: 35.530000% currently going to do 16 epochs
# After epoch 10: averaged train_err_rate: 34.985000% averaged train nll: 1.000470 averaged train loss: 1.550230
# At minibatch 4100, batch loss 1.366016, batch nll 0.866337, batch error rate 28.000000%
# At minibatch 4200, batch loss 1.448575, batch nll 0.962406, batch error rate 41.000000%
# At minibatch 4300, batch loss 1.282307, batch nll 0.808950, batch error rate 28.000000%
# At minibatch 4400, batch loss 1.333279, batch nll 0.872286, batch error rate 27.000000%
# After epoch 11: valid_err_rate: 34.490000% currently going to do 17 epochs
# After epoch 11: averaged train_err_rate: 33.960000% averaged train nll: 0.973962 averaged train loss: 1.460818
# At minibatch 4500, batch loss 1.557193, batch nll 1.107311, batch error rate 38.000000%
# At minibatch 4600, batch loss 1.364387, batch nll 0.924111, batch error rate 29.000000%
# At minibatch 4700, batch loss 1.260439, batch nll 0.828923, batch error rate 25.000000%
# At minibatch 4800, batch loss 1.447690, batch nll 1.025083, batch error rate 38.000000%
# After epoch 12: valid_err_rate: 35.940000% currently going to do 17 epochs
# After epoch 12: averaged train_err_rate: 32.995000% averaged train nll: 0.947153 averaged train loss: 1.387957
# At minibatch 4900, batch loss 1.344487, batch nll 0.929361, batch error rate 27.000000%
# At minibatch 5000, batch loss 1.357169, batch nll 0.948878, batch error rate 32.000000%
# At minibatch 5100, batch loss 1.342451, batch nll 0.942143, batch error rate 33.000000%
# At minibatch 5200, batch loss 1.377224, batch nll 0.983061, batch error rate 31.000000%
# After epoch 13: valid_err_rate: 33.300000% currently going to do 20 epochs
# After epoch 13: averaged train_err_rate: 32.380000% averaged train nll: 0.933734 averaged train loss: 1.341685
# At minibatch 5300, batch loss 1.311838, batch nll 0.922885, batch error rate 34.000000%
# At minibatch 5400, batch loss 1.133234, batch nll 0.750137, batch error rate 24.000000%
# At minibatch 5500, batch loss 1.283633, batch nll 0.906217, batch error rate 33.000000%
# At minibatch 5600, batch loss 1.137699, batch nll 0.764606, batch error rate 24.000000%
# After epoch 14: valid_err_rate: 33.010000% currently going to do 22 epochs
# After epoch 14: averaged train_err_rate: 31.332500% averaged train nll: 0.909249 averaged train loss: 1.292414
# At minibatch 5700, batch loss 1.248581, batch nll 0.879342, batch error rate 30.000000%
# At minibatch 5800, batch loss 1.055450, batch nll 0.690247, batch error rate 27.000000%
# At minibatch 5900, batch loss 1.365212, batch nll 1.004473, batch error rate 40.000000%
# At minibatch 6000, batch loss 1.119439, batch nll 0.762511, batch error rate 27.000000%
# After epoch 15: valid_err_rate: 31.750000% currently going to do 23 epochs
# After epoch 15: averaged train_err_rate: 30.942500% averaged train nll: 0.887210 averaged train loss: 1.252033
# At minibatch 6100, batch loss 1.302400, batch nll 0.948400, batch error rate 33.000000%
# At minibatch 6200, batch loss 1.241328, batch nll 0.891320, batch error rate 30.000000%
# At minibatch 6300, batch loss 1.194283, batch nll 0.847420, batch error rate 30.000000%
# At minibatch 6400, batch loss 1.216479, batch nll 0.872488, batch error rate 33.000000%
# After epoch 16: valid_err_rate: 32.070000% currently going to do 23 epochs
# After epoch 16: averaged train_err_rate: 30.265000% averaged train nll: 0.872923 averaged train loss: 1.223342
# At minibatch 6500, batch loss 1.198677, batch nll 0.856827, batch error rate 32.000000%
# At minibatch 6600, batch loss 1.103479, batch nll 0.764378, batch error rate 20.000000%
# At minibatch 6700, batch loss 1.170834, batch nll 0.833955, batch error rate 29.000000%
# At minibatch 6800, batch loss 1.216890, batch nll 0.882426, batch error rate 34.000000%
# After epoch 17: valid_err_rate: 33.250000% currently going to do 23 epochs
# After epoch 17: averaged train_err_rate: 29.877500% averaged train nll: 0.863716 averaged train loss: 1.202890
# At minibatch 6900, batch loss 1.164696, batch nll 0.832348, batch error rate 30.000000%
# At minibatch 7000, batch loss 1.237231, batch nll 0.906801, batch error rate 30.000000%
# At minibatch 7100, batch loss 1.064640, batch nll 0.735975, batch error rate 24.000000%
# At minibatch 7200, batch loss 1.177698, batch nll 0.851584, batch error rate 24.000000%
# After epoch 18: valid_err_rate: 31.370000% currently going to do 28 epochs
# After epoch 18: averaged train_err_rate: 29.452500% averaged train nll: 0.847900 averaged train loss: 1.178447
# At minibatch 7300, batch loss 1.224864, batch nll 0.899984, batch error rate 36.000000%
# At minibatch 7400, batch loss 1.139487, batch nll 0.816454, batch error rate 30.000000%
# At minibatch 7500, batch loss 1.162112, batch nll 0.840215, batch error rate 34.000000%
# At minibatch 7600, batch loss 1.156164, batch nll 0.836111, batch error rate 31.000000%
# After epoch 19: valid_err_rate: 31.170000% currently going to do 29 epochs
# After epoch 19: averaged train_err_rate: 28.905000% averaged train nll: 0.839173 averaged train loss: 1.162332
# At minibatch 7700, batch loss 1.147986, batch nll 0.828713, batch error rate 32.000000%
# At minibatch 7800, batch loss 1.202714, batch nll 0.885081, batch error rate 27.000000%
# At minibatch 7900, batch loss 1.265696, batch nll 0.949518, batch error rate 33.000000%
# At minibatch 8000, batch loss 1.107816, batch nll 0.792925, batch error rate 27.000000%
# After epoch 20: valid_err_rate: 31.630000% currently going to do 29 epochs
# After epoch 20: averaged train_err_rate: 28.685000% averaged train nll: 0.830520 averaged train loss: 1.148162
# At minibatch 8100, batch loss 1.107920, batch nll 0.794109, batch error rate 28.000000%
# At minibatch 8200, batch loss 1.096684, batch nll 0.783490, batch error rate 33.000000%
# At minibatch 8300, batch loss 1.264619, batch nll 0.952705, batch error rate 32.000000%
# At minibatch 8400, batch loss 1.091519, batch nll 0.780601, batch error rate 27.000000%
# After epoch 21: valid_err_rate: 31.050000% currently going to do 32 epochs
# After epoch 21: averaged train_err_rate: 28.167500% averaged train nll: 0.819855 averaged train loss: 1.132845
# At minibatch 8500, batch loss 1.124246, batch nll 0.813445, batch error rate 27.000000%
# At minibatch 8600, batch loss 1.092198, batch nll 0.781833, batch error rate 26.000000%
# At minibatch 8700, batch loss 1.025357, batch nll 0.716095, batch error rate 22.000000%
# At minibatch 8800, batch loss 1.030637, batch nll 0.723234, batch error rate 19.000000%
# After epoch 22: valid_err_rate: 30.990000% currently going to do 34 epochs
# After epoch 22: averaged train_err_rate: 27.975000% averaged train nll: 0.810877 averaged train loss: 1.120699
# At minibatch 8900, batch loss 1.091595, batch nll 0.784422, batch error rate 25.000000%
# At minibatch 9000, batch loss 1.330890, batch nll 1.024111, batch error rate 37.000000%
# At minibatch 9100, batch loss 0.844207, batch nll 0.537897, batch error rate 16.000000%
# At minibatch 9200, batch loss 1.097140, batch nll 0.791876, batch error rate 22.000000%
# After epoch 23: valid_err_rate: 30.900000% currently going to do 35 epochs
# After epoch 23: averaged train_err_rate: 27.585000% averaged train nll: 0.804979 averaged train loss: 1.111735
# At minibatch 9300, batch loss 1.038106, batch nll 0.733099, batch error rate 25.000000%
# At minibatch 9400, batch loss 1.056104, batch nll 0.751466, batch error rate 29.000000%
# At minibatch 9500, batch loss 1.155033, batch nll 0.851125, batch error rate 29.000000%
# At minibatch 9600, batch loss 1.114630, batch nll 0.811618, batch error rate 32.000000%
# After epoch 24: valid_err_rate: 29.750000% currently going to do 37 epochs
# After epoch 24: averaged train_err_rate: 27.545000% averaged train nll: 0.798906 averaged train loss: 1.103367
# At minibatch 9700, batch loss 0.961157, batch nll 0.658620, batch error rate 20.000000%
# At minibatch 9800, batch loss 1.115854, batch nll 0.813546, batch error rate 30.000000%
# At minibatch 9900, batch loss 1.295158, batch nll 0.992696, batch error rate 35.000000%
# At minibatch 10000, batch loss 1.017189, batch nll 0.715615, batch error rate 27.000000%
# After epoch 25: valid_err_rate: 29.660000% currently going to do 38 epochs
# After epoch 25: averaged train_err_rate: 27.372500% averaged train nll: 0.792123 averaged train loss: 1.094604
# At minibatch 10100, batch loss 1.069542, batch nll 0.767721, batch error rate 27.000000%
# At minibatch 10200, batch loss 1.007874, batch nll 0.706813, batch error rate 24.000000%
# At minibatch 10300, batch loss 1.092963, batch nll 0.792009, batch error rate 29.000000%
# At minibatch 10400, batch loss 1.200418, batch nll 0.899874, batch error rate 33.000000%
# After epoch 26: valid_err_rate: 30.000000% currently going to do 38 epochs
# After epoch 26: averaged train_err_rate: 26.965000% averaged train nll: 0.783033 averaged train loss: 1.084323
# At minibatch 10500, batch loss 1.017847, batch nll 0.717300, batch error rate 26.000000%
# At minibatch 10600, batch loss 1.170174, batch nll 0.869998, batch error rate 33.000000%
# At minibatch 10700, batch loss 0.979065, batch nll 0.678982, batch error rate 24.000000%
# At minibatch 10800, batch loss 1.015596, batch nll 0.716418, batch error rate 26.000000%
# After epoch 27: valid_err_rate: 30.140000% currently going to do 38 epochs
# After epoch 27: averaged train_err_rate: 26.742500% averaged train nll: 0.776122 averaged train loss: 1.076308
# At minibatch 10900, batch loss 1.104591, batch nll 0.805040, batch error rate 25.000000%
# At minibatch 11000, batch loss 1.016058, batch nll 0.716461, batch error rate 26.000000%
# At minibatch 11100, batch loss 1.030102, batch nll 0.731288, batch error rate 27.000000%
# At minibatch 11200, batch loss 0.995859, batch nll 0.696979, batch error rate 24.000000%
# After epoch 28: valid_err_rate: 31.330000% currently going to do 38 epochs
# After epoch 28: averaged train_err_rate: 26.557500% averaged train nll: 0.771976 averaged train loss: 1.071201
# At minibatch 11300, batch loss 0.936478, batch nll 0.637656, batch error rate 24.000000%
# At minibatch 11400, batch loss 1.188876, batch nll 0.890243, batch error rate 30.000000%
# At minibatch 11500, batch loss 0.994882, batch nll 0.696678, batch error rate 24.000000%
# At minibatch 11600, batch loss 1.017216, batch nll 0.719121, batch error rate 22.000000%
# After epoch 29: valid_err_rate: 30.360000% currently going to do 38 epochs
# After epoch 29: averaged train_err_rate: 26.347500% averaged train nll: 0.767455 averaged train loss: 1.066028
# At minibatch 11700, batch loss 0.976596, batch nll 0.678447, batch error rate 24.000000%
# At minibatch 11800, batch loss 1.037135, batch nll 0.739408, batch error rate 24.000000%
# At minibatch 11900, batch loss 1.194751, batch nll 0.897164, batch error rate 31.000000%
# At minibatch 12000, batch loss 1.134019, batch nll 0.836630, batch error rate 29.000000%
# After epoch 30: valid_err_rate: 29.640000% currently going to do 46 epochs
# After epoch 30: averaged train_err_rate: 26.427500% averaged train nll: 0.765570 averaged train loss: 1.063370
# At minibatch 12100, batch loss 1.052150, batch nll 0.754536, batch error rate 27.000000%
# At minibatch 12200, batch loss 1.016616, batch nll 0.719009, batch error rate 28.000000%
# At minibatch 12300, batch loss 0.984503, batch nll 0.687035, batch error rate 25.000000%
# At minibatch 12400, batch loss 1.099564, batch nll 0.802350, batch error rate 24.000000%
# After epoch 31: valid_err_rate: 29.410000% currently going to do 47 epochs
# After epoch 31: averaged train_err_rate: 26.205000% averaged train nll: 0.760743 averaged train loss: 1.058310
# At minibatch 12500, batch loss 0.956296, batch nll 0.658816, batch error rate 22.000000%
# At minibatch 12600, batch loss 0.968491, batch nll 0.671150, batch error rate 22.000000%
# At minibatch 12700, batch loss 0.918901, batch nll 0.621541, batch error rate 20.000000%
# At minibatch 12800, batch loss 1.131267, batch nll 0.834567, batch error rate 29.000000%
# After epoch 32: valid_err_rate: 29.600000% currently going to do 47 epochs
# After epoch 32: averaged train_err_rate: 26.072500% averaged train nll: 0.758749 averaged train loss: 1.056013
# At minibatch 12900, batch loss 0.993209, batch nll 0.696001, batch error rate 21.000000%
# At minibatch 13000, batch loss 1.044935, batch nll 0.747569, batch error rate 24.000000%
# At minibatch 13100, batch loss 1.203895, batch nll 0.906939, batch error rate 36.000000%
# At minibatch 13200, batch loss 1.159992, batch nll 0.863105, batch error rate 26.000000%
# After epoch 33: valid_err_rate: 29.240000% currently going to do 50 epochs
# After epoch 33: averaged train_err_rate: 25.975000% averaged train nll: 0.750169 averaged train loss: 1.047195
# At minibatch 13300, batch loss 1.093490, batch nll 0.796298, batch error rate 31.000000%
# At minibatch 13400, batch loss 1.162477, batch nll 0.865232, batch error rate 31.000000%
# At minibatch 13500, batch loss 1.048576, batch nll 0.751443, batch error rate 19.000000%
# At minibatch 13600, batch loss 1.092124, batch nll 0.795059, batch error rate 26.000000%
# After epoch 34: valid_err_rate: 29.240000% currently going to do 50 epochs
# After epoch 34: averaged train_err_rate: 25.477500% averaged train nll: 0.746090 averaged train loss: 1.043209
# At minibatch 13700, batch loss 0.845263, batch nll 0.548470, batch error rate 20.000000%
# At minibatch 13800, batch loss 1.087298, batch nll 0.790436, batch error rate 35.000000%
# At minibatch 13900, batch loss 1.049469, batch nll 0.752456, batch error rate 23.000000%
# At minibatch 14000, batch loss 1.040497, batch nll 0.743434, batch error rate 28.000000%
# After epoch 35: valid_err_rate: 29.190000% currently going to do 53 epochs
# After epoch 35: averaged train_err_rate: 25.655000% averaged train nll: 0.747647 averaged train loss: 1.044530
# At minibatch 14100, batch loss 1.088078, batch nll 0.790699, batch error rate 28.000000%
# At minibatch 14200, batch loss 0.960780, batch nll 0.663381, batch error rate 28.000000%
# At minibatch 14300, batch loss 0.898486, batch nll 0.601316, batch error rate 21.000000%
# At minibatch 14400, batch loss 1.029339, batch nll 0.732312, batch error rate 27.000000%
# After epoch 36: valid_err_rate: 29.640000% currently going to do 53 epochs
# After epoch 36: averaged train_err_rate: 25.360000% averaged train nll: 0.738600 averaged train loss: 1.035864
# At minibatch 14500, batch loss 1.106742, batch nll 0.809217, batch error rate 26.000000%
# At minibatch 14600, batch loss 0.981966, batch nll 0.684478, batch error rate 22.000000%
# At minibatch 14700, batch loss 1.060037, batch nll 0.762858, batch error rate 32.000000%
# At minibatch 14800, batch loss 0.994768, batch nll 0.697783, batch error rate 18.000000%
# After epoch 37: valid_err_rate: 28.630000% currently going to do 56 epochs
# After epoch 37: averaged train_err_rate: 25.410000% averaged train nll: 0.734256 averaged train loss: 1.031543
# At minibatch 14900, batch loss 0.854845, batch nll 0.557612, batch error rate 22.000000%
# At minibatch 15000, batch loss 1.219709, batch nll 0.922313, batch error rate 33.000000%
# At minibatch 15100, batch loss 1.121138, batch nll 0.823560, batch error rate 25.000000%
# At minibatch 15200, batch loss 0.996491, batch nll 0.699397, batch error rate 24.000000%
# After epoch 38: valid_err_rate: 28.670000% currently going to do 56 epochs
# After epoch 38: averaged train_err_rate: 25.257500% averaged train nll: 0.732244 averaged train loss: 1.029546
# At minibatch 15300, batch loss 0.951535, batch nll 0.654118, batch error rate 22.000000%
# At minibatch 15400, batch loss 0.983249, batch nll 0.685688, batch error rate 27.000000%
# At minibatch 15500, batch loss 1.126947, batch nll 0.829460, batch error rate 24.000000%
# At minibatch 15600, batch loss 1.013105, batch nll 0.715640, batch error rate 27.000000%
# After epoch 39: valid_err_rate: 28.530000% currently going to do 59 epochs
# After epoch 39: averaged train_err_rate: 25.077500% averaged train nll: 0.728848 averaged train loss: 1.026283
# At minibatch 15700, batch loss 0.994864, batch nll 0.696843, batch error rate 22.000000%
# At minibatch 15800, batch loss 1.070763, batch nll 0.772793, batch error rate 29.000000%
# At minibatch 15900, batch loss 1.077988, batch nll 0.780349, batch error rate 20.000000%
# At minibatch 16000, batch loss 0.981874, batch nll 0.684138, batch error rate 22.000000%
# After epoch 40: valid_err_rate: 29.560000% currently going to do 59 epochs
# After epoch 40: averaged train_err_rate: 24.940000% averaged train nll: 0.724143 averaged train loss: 1.021922
# At minibatch 16100, batch loss 1.141605, batch nll 0.843701, batch error rate 24.000000%
# At minibatch 16200, batch loss 0.973553, batch nll 0.675520, batch error rate 22.000000%
# At minibatch 16300, batch loss 0.928100, batch nll 0.630252, batch error rate 25.000000%
# At minibatch 16400, batch loss 1.009238, batch nll 0.711401, batch error rate 24.000000%
# After epoch 41: valid_err_rate: 28.710000% currently going to do 59 epochs
# After epoch 41: averaged train_err_rate: 24.792500% averaged train nll: 0.726558 averaged train loss: 1.024474
# At minibatch 16500, batch loss 0.975856, batch nll 0.677859, batch error rate 22.000000%
# At minibatch 16600, batch loss 1.185068, batch nll 0.886832, batch error rate 30.000000%
# At minibatch 16700, batch loss 0.985251, batch nll 0.687426, batch error rate 22.000000%
# At minibatch 16800, batch loss 0.960174, batch nll 0.661940, batch error rate 20.000000%
# After epoch 42: valid_err_rate: 28.970000% currently going to do 59 epochs
# After epoch 42: averaged train_err_rate: 24.815000% averaged train nll: 0.721873 averaged train loss: 1.019956
# At minibatch 16900, batch loss 1.009243, batch nll 0.710704, batch error rate 25.000000%
# At minibatch 17000, batch loss 0.920039, batch nll 0.621463, batch error rate 19.000000%
# At minibatch 17100, batch loss 1.123706, batch nll 0.825305, batch error rate 28.000000%
# At minibatch 17200, batch loss 0.937564, batch nll 0.639163, batch error rate 27.000000%
# After epoch 43: valid_err_rate: 28.510000% currently going to do 65 epochs
# After epoch 43: averaged train_err_rate: 24.840000% averaged train nll: 0.720444 averaged train loss: 1.018895
# At minibatch 17300, batch loss 1.102885, batch nll 0.804059, batch error rate 30.000000%
# At minibatch 17400, batch loss 0.984730, batch nll 0.685879, batch error rate 25.000000%
# At minibatch 17500, batch loss 0.932569, batch nll 0.633767, batch error rate 20.000000%
# At minibatch 17600, batch loss 0.883819, batch nll 0.585198, batch error rate 21.000000%
# After epoch 44: valid_err_rate: 27.980000% currently going to do 67 epochs
# After epoch 44: averaged train_err_rate: 24.575000% averaged train nll: 0.716185 averaged train loss: 1.014976
# At minibatch 17700, batch loss 1.105212, batch nll 0.806548, batch error rate 25.000000%
# At minibatch 17800, batch loss 1.004140, batch nll 0.705205, batch error rate 26.000000%
# At minibatch 17900, batch loss 1.038822, batch nll 0.740047, batch error rate 29.000000%
# At minibatch 18000, batch loss 0.927916, batch nll 0.628876, batch error rate 17.000000%
# After epoch 45: valid_err_rate: 28.550000% currently going to do 67 epochs
# After epoch 45: averaged train_err_rate: 24.297500% averaged train nll: 0.711972 averaged train loss: 1.010770
# At minibatch 18100, batch loss 1.024441, batch nll 0.725160, batch error rate 25.000000%
# At minibatch 18200, batch loss 0.906718, batch nll 0.607235, batch error rate 20.000000%
# At minibatch 18300, batch loss 1.215113, batch nll 0.915680, batch error rate 32.000000%
# At minibatch 18400, batch loss 1.182419, batch nll 0.883161, batch error rate 31.000000%
# After epoch 46: valid_err_rate: 28.450000% currently going to do 67 epochs
# After epoch 46: averaged train_err_rate: 24.277500% averaged train nll: 0.710077 averaged train loss: 1.009373
# At minibatch 18500, batch loss 1.058009, batch nll 0.758533, batch error rate 31.000000%
# At minibatch 18600, batch loss 0.996053, batch nll 0.696630, batch error rate 26.000000%
# At minibatch 18700, batch loss 0.945033, batch nll 0.645191, batch error rate 19.000000%
# At minibatch 18800, batch loss 0.944788, batch nll 0.645061, batch error rate 16.000000%
# After epoch 47: valid_err_rate: 28.340000% currently going to do 67 epochs
# After epoch 47: averaged train_err_rate: 24.242500% averaged train nll: 0.707846 averaged train loss: 1.007421
# At minibatch 18900, batch loss 0.985989, batch nll 0.685988, batch error rate 25.000000%
# At minibatch 19000, batch loss 1.057507, batch nll 0.757559, batch error rate 27.000000%
# At minibatch 19100, batch loss 1.162769, batch nll 0.862672, batch error rate 29.000000%
# At minibatch 19200, batch loss 1.049933, batch nll 0.750079, batch error rate 23.000000%
# After epoch 48: valid_err_rate: 28.010000% currently going to do 67 epochs
# After epoch 48: averaged train_err_rate: 24.027500% averaged train nll: 0.706261 averaged train loss: 1.006221
# At minibatch 19300, batch loss 0.962035, batch nll 0.662020, batch error rate 22.000000%
# At minibatch 19400, batch loss 1.017888, batch nll 0.717543, batch error rate 26.000000%
# At minibatch 19500, batch loss 0.994964, batch nll 0.694579, batch error rate 29.000000%
# At minibatch 19600, batch loss 0.916330, batch nll 0.615986, batch error rate 20.000000%
# After epoch 49: valid_err_rate: 28.420000% currently going to do 67 epochs
# After epoch 49: averaged train_err_rate: 24.082500% averaged train nll: 0.704344 averaged train loss: 1.004543
# At minibatch 19700, batch loss 0.971169, batch nll 0.670618, batch error rate 27.000000%
# At minibatch 19800, batch loss 1.064384, batch nll 0.763892, batch error rate 29.000000%
# At minibatch 19900, batch loss 0.918384, batch nll 0.617615, batch error rate 25.000000%
# At minibatch 20000, batch loss 1.066320, batch nll 0.765574, batch error rate 26.000000%
# After epoch 50: valid_err_rate: 27.700000% currently going to do 76 epochs
# After epoch 50: averaged train_err_rate: 23.770000% averaged train nll: 0.700183 averaged train loss: 1.000783
# At minibatch 20100, batch loss 1.100214, batch nll 0.799466, batch error rate 31.000000%
# At minibatch 20200, batch loss 0.966850, batch nll 0.665800, batch error rate 24.000000%
# At minibatch 20300, batch loss 1.023030, batch nll 0.722036, batch error rate 26.000000%
# At minibatch 20400, batch loss 1.058084, batch nll 0.757073, batch error rate 22.000000%
# After epoch 51: valid_err_rate: 28.240000% currently going to do 76 epochs
# After epoch 51: averaged train_err_rate: 23.937500% averaged train nll: 0.698183 averaged train loss: 0.999097
# At minibatch 20500, batch loss 1.096349, batch nll 0.795100, batch error rate 27.000000%
# At minibatch 20600, batch loss 0.878080, batch nll 0.576789, batch error rate 22.000000%
# At minibatch 20700, batch loss 0.971310, batch nll 0.670186, batch error rate 22.000000%
# At minibatch 20800, batch loss 0.902583, batch nll 0.601391, batch error rate 17.000000%
# After epoch 52: valid_err_rate: 27.950000% currently going to do 76 epochs
# After epoch 52: averaged train_err_rate: 23.882500% averaged train nll: 0.699640 averaged train loss: 1.000874
# At minibatch 20900, batch loss 1.039138, batch nll 0.737699, batch error rate 29.000000%
# At minibatch 21000, batch loss 1.045711, batch nll 0.744052, batch error rate 26.000000%
# At minibatch 21100, batch loss 0.954962, batch nll 0.653215, batch error rate 22.000000%
# At minibatch 21200, batch loss 1.127857, batch nll 0.826155, batch error rate 35.000000%
# After epoch 53: valid_err_rate: 27.840000% currently going to do 76 epochs
# After epoch 53: averaged train_err_rate: 23.690000% averaged train nll: 0.694341 averaged train loss: 0.995917
# At minibatch 21300, batch loss 1.026276, batch nll 0.724689, batch error rate 28.000000%
# At minibatch 21400, batch loss 0.990271, batch nll 0.688319, batch error rate 25.000000%
# At minibatch 21500, batch loss 0.959524, batch nll 0.657321, batch error rate 20.000000%
# At minibatch 21600, batch loss 0.925814, batch nll 0.623537, batch error rate 16.000000%
# After epoch 54: valid_err_rate: 28.420000% currently going to do 76 epochs
# After epoch 54: averaged train_err_rate: 23.690000% averaged train nll: 0.692769 averaged train loss: 0.994681
# At minibatch 21700, batch loss 0.960579, batch nll 0.658164, batch error rate 24.000000%
# At minibatch 21800, batch loss 1.015515, batch nll 0.713291, batch error rate 22.000000%
# At minibatch 21900, batch loss 1.037683, batch nll 0.735250, batch error rate 29.000000%
# At minibatch 22000, batch loss 1.032297, batch nll 0.729767, batch error rate 27.000000%
# After epoch 55: valid_err_rate: 27.670000% currently going to do 83 epochs
# After epoch 55: averaged train_err_rate: 23.707500% averaged train nll: 0.693150 averaged train loss: 0.995548
# At minibatch 22100, batch loss 1.072684, batch nll 0.769729, batch error rate 26.000000%
# At minibatch 22200, batch loss 0.984666, batch nll 0.681981, batch error rate 19.000000%
# At minibatch 22300, batch loss 1.054461, batch nll 0.751771, batch error rate 25.000000%
# At minibatch 22400, batch loss 0.983203, batch nll 0.680488, batch error rate 23.000000%
# After epoch 56: valid_err_rate: 27.710000% currently going to do 83 epochs
# After epoch 56: averaged train_err_rate: 23.812500% averaged train nll: 0.691325 averaged train loss: 0.994077
# At minibatch 22500, batch loss 1.026201, batch nll 0.723323, batch error rate 27.000000%
# At minibatch 22600, batch loss 1.107169, batch nll 0.804098, batch error rate 27.000000%
# At minibatch 22700, batch loss 0.960266, batch nll 0.657184, batch error rate 27.000000%
# At minibatch 22800, batch loss 0.940160, batch nll 0.637005, batch error rate 22.000000%
# After epoch 57: valid_err_rate: 27.990000% currently going to do 83 epochs
# After epoch 57: averaged train_err_rate: 23.482500% averaged train nll: 0.686408 averaged train loss: 0.989375
# At minibatch 22900, batch loss 1.183796, batch nll 0.880481, batch error rate 30.000000%
# At minibatch 23000, batch loss 0.941676, batch nll 0.638352, batch error rate 19.000000%
# At minibatch 23100, batch loss 0.941749, batch nll 0.638418, batch error rate 22.000000%
# At minibatch 23200, batch loss 1.021432, batch nll 0.717907, batch error rate 27.000000%
# After epoch 58: valid_err_rate: 27.760000% currently going to do 83 epochs
# After epoch 58: averaged train_err_rate: 23.657500% averaged train nll: 0.687178 averaged train loss: 0.990491
# At minibatch 23300, batch loss 0.836573, batch nll 0.532678, batch error rate 20.000000%
# At minibatch 23400, batch loss 0.968451, batch nll 0.664357, batch error rate 20.000000%
# At minibatch 23500, batch loss 0.989010, batch nll 0.684814, batch error rate 22.000000%
# At minibatch 23600, batch loss 0.948394, batch nll 0.644507, batch error rate 24.000000%
# After epoch 59: valid_err_rate: 28.150000% currently going to do 83 epochs
# After epoch 59: averaged train_err_rate: 23.397500% averaged train nll: 0.683893 averaged train loss: 0.987878
# At minibatch 23700, batch loss 0.998799, batch nll 0.694510, batch error rate 20.000000%
# At minibatch 23800, batch loss 1.004929, batch nll 0.700549, batch error rate 20.000000%
# At minibatch 23900, batch loss 0.986202, batch nll 0.681861, batch error rate 27.000000%
# At minibatch 24000, batch loss 1.142467, batch nll 0.838231, batch error rate 30.000000%
# After epoch 60: valid_err_rate: 28.090000% currently going to do 83 epochs
# After epoch 60: averaged train_err_rate: 23.282500% averaged train nll: 0.680687 averaged train loss: 0.984940
# At minibatch 24100, batch loss 0.942205, batch nll 0.637832, batch error rate 23.000000%
# At minibatch 24200, batch loss 1.057688, batch nll 0.752951, batch error rate 24.000000%
# At minibatch 24300, batch loss 1.176914, batch nll 0.872229, batch error rate 34.000000%
# At minibatch 24400, batch loss 0.954419, batch nll 0.649774, batch error rate 23.000000%
# After epoch 61: valid_err_rate: 27.830000% currently going to do 83 epochs
# After epoch 61: averaged train_err_rate: 23.310000% averaged train nll: 0.682405 averaged train loss: 0.986952
# At minibatch 24500, batch loss 1.006970, batch nll 0.702370, batch error rate 23.000000%
# At minibatch 24600, batch loss 0.860166, batch nll 0.555305, batch error rate 19.000000%
# At minibatch 24700, batch loss 0.982829, batch nll 0.677841, batch error rate 25.000000%
# At minibatch 24800, batch loss 1.070730, batch nll 0.765735, batch error rate 26.000000%
# After epoch 62: valid_err_rate: 27.560000% currently going to do 94 epochs
# After epoch 62: averaged train_err_rate: 23.235000% averaged train nll: 0.681434 averaged train loss: 0.986220
# At minibatch 24900, batch loss 0.957897, batch nll 0.652878, batch error rate 25.000000%
# At minibatch 25000, batch loss 1.084478, batch nll 0.779035, batch error rate 25.000000%
# At minibatch 25100, batch loss 0.991459, batch nll 0.686008, batch error rate 24.000000%
# At minibatch 25200, batch loss 0.965191, batch nll 0.659882, batch error rate 22.000000%
# After epoch 63: valid_err_rate: 27.960000% currently going to do 94 epochs
# After epoch 63: averaged train_err_rate: 23.162500% averaged train nll: 0.677571 averaged train loss: 0.982842
# At minibatch 25300, batch loss 0.938916, batch nll 0.633384, batch error rate 24.000000%
# At minibatch 25400, batch loss 0.908296, batch nll 0.602723, batch error rate 24.000000%
# At minibatch 25500, batch loss 0.954567, batch nll 0.648984, batch error rate 23.000000%
# At minibatch 25600, batch loss 1.013416, batch nll 0.707736, batch error rate 23.000000%
# After epoch 64: valid_err_rate: 27.750000% currently going to do 94 epochs
# After epoch 64: averaged train_err_rate: 23.072500% averaged train nll: 0.677427 averaged train loss: 0.982958
# At minibatch 25700, batch loss 1.071679, batch nll 0.765911, batch error rate 28.000000%
# At minibatch 25800, batch loss 1.070376, batch nll 0.764562, batch error rate 29.000000%
# At minibatch 25900, batch loss 0.895185, batch nll 0.589144, batch error rate 21.000000%
# At minibatch 26000, batch loss 1.000185, batch nll 0.694208, batch error rate 23.000000%
# After epoch 65: valid_err_rate: 28.130000% currently going to do 94 epochs
# After epoch 65: averaged train_err_rate: 23.187500% averaged train nll: 0.676482 averaged train loss: 0.982353
# At minibatch 26100, batch loss 1.165845, batch nll 0.859770, batch error rate 26.000000%
# At minibatch 26200, batch loss 0.907265, batch nll 0.601044, batch error rate 19.000000%
# At minibatch 26300, batch loss 0.867354, batch nll 0.561033, batch error rate 18.000000%
# At minibatch 26400, batch loss 1.081374, batch nll 0.774971, batch error rate 31.000000%
# After epoch 66: valid_err_rate: 27.840000% currently going to do 94 epochs
# After epoch 66: averaged train_err_rate: 23.140000% averaged train nll: 0.672936 averaged train loss: 0.979137
# At minibatch 26500, batch loss 1.142700, batch nll 0.836262, batch error rate 32.000000%
# At minibatch 26600, batch loss 1.028850, batch nll 0.722297, batch error rate 24.000000%
# At minibatch 26700, batch loss 1.068409, batch nll 0.761745, batch error rate 26.000000%
# At minibatch 26800, batch loss 1.007725, batch nll 0.700989, batch error rate 27.000000%
# After epoch 67: valid_err_rate: 27.780000% currently going to do 94 epochs
# After epoch 67: averaged train_err_rate: 23.002500% averaged train nll: 0.670888 averaged train loss: 0.977413
# At minibatch 26900, batch loss 0.944909, batch nll 0.637987, batch error rate 21.000000%
# At minibatch 27000, batch loss 0.949578, batch nll 0.642641, batch error rate 24.000000%
# At minibatch 27100, batch loss 1.086422, batch nll 0.779391, batch error rate 28.000000%
# At minibatch 27200, batch loss 0.862498, batch nll 0.555563, batch error rate 16.000000%
# After epoch 68: valid_err_rate: 28.080000% currently going to do 94 epochs
# After epoch 68: averaged train_err_rate: 23.030000% averaged train nll: 0.670244 averaged train loss: 0.977171
# At minibatch 27300, batch loss 1.065489, batch nll 0.758368, batch error rate 23.000000%
# At minibatch 27400, batch loss 1.055253, batch nll 0.748010, batch error rate 25.000000%
# At minibatch 27500, batch loss 1.157078, batch nll 0.849921, batch error rate 27.000000%
# At minibatch 27600, batch loss 0.835402, batch nll 0.528257, batch error rate 15.000000%
# After epoch 69: valid_err_rate: 27.600000% currently going to do 94 epochs
# After epoch 69: averaged train_err_rate: 22.992500% averaged train nll: 0.673022 averaged train loss: 0.980171
# At minibatch 27700, batch loss 0.995153, batch nll 0.687828, batch error rate 26.000000%
# At minibatch 27800, batch loss 0.980868, batch nll 0.673299, batch error rate 27.000000%
# At minibatch 27900, batch loss 0.952389, batch nll 0.644676, batch error rate 24.000000%
# At minibatch 28000, batch loss 1.028967, batch nll 0.721451, batch error rate 29.000000%
# After epoch 70: valid_err_rate: 27.600000% currently going to do 94 epochs
# After epoch 70: averaged train_err_rate: 22.857500% averaged train nll: 0.670288 averaged train loss: 0.977776
# At minibatch 28100, batch loss 0.889602, batch nll 0.581870, batch error rate 18.000000%
# At minibatch 28200, batch loss 0.907124, batch nll 0.599251, batch error rate 23.000000%
# At minibatch 28300, batch loss 0.884428, batch nll 0.576386, batch error rate 18.000000%
# At minibatch 28400, batch loss 1.117663, batch nll 0.809699, batch error rate 29.000000%
# After epoch 71: valid_err_rate: 28.130000% currently going to do 94 epochs
# After epoch 71: averaged train_err_rate: 22.727500% averaged train nll: 0.666205 averaged train loss: 0.974058
# At minibatch 28500, batch loss 1.084781, batch nll 0.776800, batch error rate 27.000000%
# At minibatch 28600, batch loss 0.987197, batch nll 0.678955, batch error rate 20.000000%
# At minibatch 28700, batch loss 0.928781, batch nll 0.620517, batch error rate 15.000000%
# At minibatch 28800, batch loss 1.048858, batch nll 0.740598, batch error rate 27.000000%
# After epoch 72: valid_err_rate: 28.240000% currently going to do 94 epochs
# After epoch 72: averaged train_err_rate: 22.890000% averaged train nll: 0.667825 averaged train loss: 0.975996
# At minibatch 28900, batch loss 0.925825, batch nll 0.617342, batch error rate 18.000000%
# At minibatch 29000, batch loss 0.863871, batch nll 0.555413, batch error rate 18.000000%
# At minibatch 29100, batch loss 1.069119, batch nll 0.760430, batch error rate 23.000000%
# At minibatch 29200, batch loss 1.078980, batch nll 0.770247, batch error rate 24.000000%
# After epoch 73: valid_err_rate: 28.290000% currently going to do 94 epochs
# After epoch 73: averaged train_err_rate: 22.642500% averaged train nll: 0.664538 averaged train loss: 0.973070
# At minibatch 29300, batch loss 0.870129, batch nll 0.561235, batch error rate 22.000000%
# At minibatch 29400, batch loss 0.882620, batch nll 0.573520, batch error rate 18.000000%
# At minibatch 29500, batch loss 1.018966, batch nll 0.709898, batch error rate 24.000000%
# At minibatch 29600, batch loss 1.031346, batch nll 0.722572, batch error rate 23.000000%
# After epoch 74: valid_err_rate: 27.680000% currently going to do 94 epochs
# After epoch 74: averaged train_err_rate: 22.707500% averaged train nll: 0.664658 averaged train loss: 0.973625
# At minibatch 29700, batch loss 0.902677, batch nll 0.593676, batch error rate 19.000000%
# At minibatch 29800, batch loss 0.958753, batch nll 0.649845, batch error rate 26.000000%
# At minibatch 29900, batch loss 0.999864, batch nll 0.690880, batch error rate 29.000000%
# At minibatch 30000, batch loss 0.899914, batch nll 0.590875, batch error rate 18.000000%
# After epoch 75: valid_err_rate: 27.770000% currently going to do 94 epochs
# After epoch 75: averaged train_err_rate: 22.697500% averaged train nll: 0.663763 averaged train loss: 0.972734
# At minibatch 30100, batch loss 0.882786, batch nll 0.573532, batch error rate 16.000000%
# At minibatch 30200, batch loss 0.966403, batch nll 0.656940, batch error rate 18.000000%
# At minibatch 30300, batch loss 0.923927, batch nll 0.614587, batch error rate 19.000000%
# At minibatch 30400, batch loss 0.883096, batch nll 0.573735, batch error rate 19.000000%
# After epoch 76: valid_err_rate: 27.790000% currently going to do 94 epochs
# After epoch 76: averaged train_err_rate: 22.767500% averaged train nll: 0.665014 averaged train loss: 0.974337
# At minibatch 30500, batch loss 1.099638, batch nll 0.790086, batch error rate 25.000000%
# At minibatch 30600, batch loss 1.061191, batch nll 0.751536, batch error rate 24.000000%
# At minibatch 30700, batch loss 0.891630, batch nll 0.581989, batch error rate 19.000000%
# At minibatch 30800, batch loss 0.858638, batch nll 0.548890, batch error rate 19.000000%
# After epoch 77: valid_err_rate: 27.750000% currently going to do 94 epochs
# After epoch 77: averaged train_err_rate: 22.587500% averaged train nll: 0.661187 averaged train loss: 0.970791
# At minibatch 30900, batch loss 0.857717, batch nll 0.547848, batch error rate 15.000000%
# At minibatch 31000, batch loss 0.918824, batch nll 0.609013, batch error rate 27.000000%
# At minibatch 31100, batch loss 0.974897, batch nll 0.664883, batch error rate 27.000000%
# At minibatch 31200, batch loss 0.940365, batch nll 0.630297, batch error rate 19.000000%
# After epoch 78: valid_err_rate: 27.540000% currently going to do 118 epochs
# After epoch 78: averaged train_err_rate: 22.717500% averaged train nll: 0.660908 averaged train loss: 0.970810
# At minibatch 31300, batch loss 1.101557, batch nll 0.791355, batch error rate 30.000000%
# At minibatch 31400, batch loss 0.846912, batch nll 0.536616, batch error rate 15.000000%
# At minibatch 31500, batch loss 1.026821, batch nll 0.716338, batch error rate 29.000000%
# At minibatch 31600, batch loss 1.038413, batch nll 0.727990, batch error rate 27.000000%
# After epoch 79: valid_err_rate: 27.890000% currently going to do 118 epochs
# After epoch 79: averaged train_err_rate: 22.475000% averaged train nll: 0.657155 averaged train loss: 0.967437
# At minibatch 31700, batch loss 1.043997, batch nll 0.733567, batch error rate 27.000000%
# At minibatch 31800, batch loss 0.956051, batch nll 0.645540, batch error rate 19.000000%
# At minibatch 31900, batch loss 1.122258, batch nll 0.811646, batch error rate 27.000000%
# At minibatch 32000, batch loss 0.937314, batch nll 0.626660, batch error rate 20.000000%
# After epoch 80: valid_err_rate: 27.990000% currently going to do 118 epochs
# After epoch 80: averaged train_err_rate: 22.555000% averaged train nll: 0.656712 averaged train loss: 0.967219
# At minibatch 32100, batch loss 1.004690, batch nll 0.693800, batch error rate 22.000000%
# At minibatch 32200, batch loss 0.891519, batch nll 0.580649, batch error rate 19.000000%
# At minibatch 32300, batch loss 0.984141, batch nll 0.673067, batch error rate 16.000000%
# At minibatch 32400, batch loss 0.996442, batch nll 0.685449, batch error rate 19.000000%
# After epoch 81: valid_err_rate: 27.870000% currently going to do 118 epochs
# After epoch 81: averaged train_err_rate: 22.430000% averaged train nll: 0.656886 averaged train loss: 0.967796
# At minibatch 32500, batch loss 1.127090, batch nll 0.815923, batch error rate 29.000000%
# At minibatch 32600, batch loss 0.877769, batch nll 0.566550, batch error rate 19.000000%
# At minibatch 32700, batch loss 0.875926, batch nll 0.564611, batch error rate 14.000000%
# At minibatch 32800, batch loss 1.136411, batch nll 0.825139, batch error rate 27.000000%
# After epoch 82: valid_err_rate: 27.790000% currently going to do 118 epochs
# After epoch 82: averaged train_err_rate: 22.542500% averaged train nll: 0.656356 averaged train loss: 0.967567
# At minibatch 32900, batch loss 0.868281, batch nll 0.556889, batch error rate 17.000000%
# At minibatch 33000, batch loss 1.216722, batch nll 0.905173, batch error rate 30.000000%
# At minibatch 33100, batch loss 0.990950, batch nll 0.679440, batch error rate 22.000000%
# At minibatch 33200, batch loss 0.987573, batch nll 0.676096, batch error rate 22.000000%
# After epoch 83: valid_err_rate: 27.360000% currently going to do 125 epochs
# After epoch 83: averaged train_err_rate: 22.235000% averaged train nll: 0.654411 averaged train loss: 0.965846
# At minibatch 33300, batch loss 0.983631, batch nll 0.672013, batch error rate 25.000000%
# At minibatch 33400, batch loss 1.199640, batch nll 0.887871, batch error rate 28.000000%
# At minibatch 33500, batch loss 0.951031, batch nll 0.639291, batch error rate 22.000000%
# At minibatch 33600, batch loss 0.930504, batch nll 0.618736, batch error rate 22.000000%
# After epoch 84: valid_err_rate: 27.240000% currently going to do 127 epochs
# After epoch 84: averaged train_err_rate: 22.272500% averaged train nll: 0.655274 averaged train loss: 0.966963
# At minibatch 33700, batch loss 0.976451, batch nll 0.664614, batch error rate 22.000000%
# At minibatch 33800, batch loss 1.091813, batch nll 0.780018, batch error rate 33.000000%
# At minibatch 33900, batch loss 0.908950, batch nll 0.597043, batch error rate 23.000000%
# At minibatch 34000, batch loss 1.009289, batch nll 0.697293, batch error rate 22.000000%
# After epoch 85: valid_err_rate: 27.700000% currently going to do 127 epochs
# After epoch 85: averaged train_err_rate: 22.057500% averaged train nll: 0.652406 averaged train loss: 0.964273
# At minibatch 34100, batch loss 1.019936, batch nll 0.707877, batch error rate 21.000000%
# At minibatch 34200, batch loss 1.011351, batch nll 0.699268, batch error rate 25.000000%
# At minibatch 34300, batch loss 0.849653, batch nll 0.537651, batch error rate 19.000000%
# At minibatch 34400, batch loss 0.906018, batch nll 0.593833, batch error rate 21.000000%
# After epoch 86: valid_err_rate: 27.460000% currently going to do 127 epochs
# After epoch 86: averaged train_err_rate: 22.245000% averaged train nll: 0.651917 averaged train loss: 0.963960
# At minibatch 34500, batch loss 0.842908, batch nll 0.530527, batch error rate 24.000000%
# At minibatch 34600, batch loss 1.195846, batch nll 0.883449, batch error rate 29.000000%
# At minibatch 34700, batch loss 1.011537, batch nll 0.699049, batch error rate 26.000000%
# At minibatch 34800, batch loss 0.983013, batch nll 0.670603, batch error rate 23.000000%
# After epoch 87: valid_err_rate: 27.570000% currently going to do 127 epochs
# After epoch 87: averaged train_err_rate: 22.260000% averaged train nll: 0.649079 averaged train loss: 0.961483
# At minibatch 34900, batch loss 0.906405, batch nll 0.593911, batch error rate 22.000000%
# At minibatch 35000, batch loss 0.938123, batch nll 0.625486, batch error rate 20.000000%
# At minibatch 35100, batch loss 0.922366, batch nll 0.609793, batch error rate 18.000000%
# At minibatch 35200, batch loss 0.930060, batch nll 0.617324, batch error rate 20.000000%
# After epoch 88: valid_err_rate: 27.530000% currently going to do 127 epochs
# After epoch 88: averaged train_err_rate: 22.327500% averaged train nll: 0.652345 averaged train loss: 0.964916
# At minibatch 35300, batch loss 1.033211, batch nll 0.720311, batch error rate 26.000000%
# At minibatch 35400, batch loss 0.904295, batch nll 0.591325, batch error rate 21.000000%
# At minibatch 35500, batch loss 0.944284, batch nll 0.631310, batch error rate 24.000000%
# At minibatch 35600, batch loss 0.907187, batch nll 0.594267, batch error rate 22.000000%
# ...
# At minibatch 156400, batch loss 0.975896, batch nll 0.633006, batch error rate 21.000000%
# After epoch 391: valid_err_rate: 26.740000% currently going to do 526 epochs
# After epoch 391: averaged train_err_rate: 19.022500% averaged train nll: 0.566233 averaged train loss: 0.909116
# At minibatch 156500, batch loss 0.896170, batch nll 0.553257, batch error rate 22.000000%
# At minibatch 156600, batch loss 0.852646, batch nll 0.509723, batch error rate 11.000000%
# At minibatch 156700, batch loss 0.991110, batch nll 0.648176, batch error rate 16.000000%
# At minibatch 156800, batch loss 0.896319, batch nll 0.553377, batch error rate 20.000000%
# After epoch 392: valid_err_rate: 26.420000% currently going to do 526 epochs
# After epoch 392: averaged train_err_rate: 19.007500% averaged train nll: 0.566592 averaged train loss: 0.909516
# At minibatch 156900, batch loss 0.777081, batch nll 0.434098, batch error rate 10.000000%
# At minibatch 157000, batch loss 0.956414, batch nll 0.613434, batch error rate 20.000000%
# At minibatch 157100, batch loss 0.927919, batch nll 0.584977, batch error rate 21.000000%
# At minibatch 157200, batch loss 0.762291, batch nll 0.419321, batch error rate 15.000000%
# After epoch 393: valid_err_rate: 26.580000% currently going to do 526 epochs
# After epoch 393: averaged train_err_rate: 19.037500% averaged train nll: 0.566442 averaged train loss: 0.909404
# At minibatch 157300, batch loss 0.926058, batch nll 0.583058, batch error rate 20.000000%
# At minibatch 157400, batch loss 0.866404, batch nll 0.523390, batch error rate 19.000000%
# At minibatch 157500, batch loss 0.902705, batch nll 0.559682, batch error rate 22.000000%
# At minibatch 157600, batch loss 0.903998, batch nll 0.560991, batch error rate 20.000000%
# After epoch 394: valid_err_rate: 26.580000% currently going to do 526 epochs
# After epoch 394: averaged train_err_rate: 19.090000% averaged train nll: 0.566289 averaged train loss: 0.909294
# At minibatch 157700, batch loss 0.837802, batch nll 0.494791, batch error rate 16.000000%
# At minibatch 157800, batch loss 0.924488, batch nll 0.581446, batch error rate 20.000000%
# At minibatch 157900, batch loss 1.099990, batch nll 0.756935, batch error rate 27.000000%
# At minibatch 158000, batch loss 0.790305, batch nll 0.447264, batch error rate 16.000000%
# After epoch 395: valid_err_rate: 26.760000% currently going to do 526 epochs
# After epoch 395: averaged train_err_rate: 19.017500% averaged train nll: 0.565818 averaged train loss: 0.908847
# At minibatch 158100, batch loss 0.963411, batch nll 0.620354, batch error rate 22.000000%
# At minibatch 158200, batch loss 0.897979, batch nll 0.554873, batch error rate 19.000000%
# At minibatch 158300, batch loss 0.937723, batch nll 0.594617, batch error rate 23.000000%
# At minibatch 158400, batch loss 0.940656, batch nll 0.597574, batch error rate 16.000000%
# After epoch 396: valid_err_rate: 27.050000% currently going to do 526 epochs
# After epoch 396: averaged train_err_rate: 19.002500% averaged train nll: 0.566874 averaged train loss: 0.909958
# At minibatch 158500, batch loss 0.838482, batch nll 0.495362, batch error rate 15.000000%
# At minibatch 158600, batch loss 0.939230, batch nll 0.596122, batch error rate 20.000000%
# At minibatch 158700, batch loss 1.020344, batch nll 0.677226, batch error rate 27.000000%
# At minibatch 158800, batch loss 0.966779, batch nll 0.623668, batch error rate 19.000000%
# After epoch 397: valid_err_rate: 26.530000% currently going to do 526 epochs
# After epoch 397: averaged train_err_rate: 19.067500% averaged train nll: 0.565902 averaged train loss: 0.909013
# At minibatch 158900, batch loss 0.936026, batch nll 0.592906, batch error rate 22.000000%
# At minibatch 159000, batch loss 0.867616, batch nll 0.524456, batch error rate 17.000000%
# At minibatch 159100, batch loss 0.863966, batch nll 0.520844, batch error rate 19.000000%
# At minibatch 159200, batch loss 0.959609, batch nll 0.616451, batch error rate 19.000000%
# After epoch 398: valid_err_rate: 26.850000% currently going to do 526 epochs
# After epoch 398: averaged train_err_rate: 19.107500% averaged train nll: 0.566032 averaged train loss: 0.909165
# At minibatch 159300, batch loss 0.989065, batch nll 0.645880, batch error rate 22.000000%
# At minibatch 159400, batch loss 1.039028, batch nll 0.695825, batch error rate 21.000000%
# At minibatch 159500, batch loss 0.835859, batch nll 0.492643, batch error rate 15.000000%
# At minibatch 159600, batch loss 0.786850, batch nll 0.443661, batch error rate 16.000000%
# After epoch 399: valid_err_rate: 26.880000% currently going to do 526 epochs
# After epoch 399: averaged train_err_rate: 18.927500% averaged train nll: 0.566416 averaged train loss: 0.909610
# At minibatch 159700, batch loss 0.911534, batch nll 0.568359, batch error rate 13.000000%
# At minibatch 159800, batch loss 0.983057, batch nll 0.639860, batch error rate 24.000000%
# At minibatch 159900, batch loss 0.834815, batch nll 0.491619, batch error rate 15.000000%
# At minibatch 160000, batch loss 0.904807, batch nll 0.561579, batch error rate 20.000000%
# After epoch 400: valid_err_rate: 26.600000% currently going to do 526 epochs
# After epoch 400: averaged train_err_rate: 18.920000% averaged train nll: 0.566010 averaged train loss: 0.909206
# At minibatch 160100, batch loss 0.951704, batch nll 0.608430, batch error rate 21.000000%
# At minibatch 160200, batch loss 1.109427, batch nll 0.766193, batch error rate 23.000000%
# At minibatch 160300, batch loss 0.965720, batch nll 0.622470, batch error rate 21.000000%
# At minibatch 160400, batch loss 0.752117, batch nll 0.408852, batch error rate 13.000000%
# After epoch 401: valid_err_rate: 26.570000% currently going to do 526 epochs
# After epoch 401: averaged train_err_rate: 19.052500% averaged train nll: 0.565957 averaged train loss: 0.909203
# At minibatch 160500, batch loss 0.964818, batch nll 0.621516, batch error rate 18.000000%
# At minibatch 160600, batch loss 0.901563, batch nll 0.558245, batch error rate 20.000000%
# At minibatch 160700, batch loss 0.817879, batch nll 0.474563, batch error rate 16.000000%
# At minibatch 160800, batch loss 0.852642, batch nll 0.509315, batch error rate 16.000000%
# After epoch 402: valid_err_rate: 26.510000% currently going to do 526 epochs
# After epoch 402: averaged train_err_rate: 18.997500% averaged train nll: 0.566286 averaged train loss: 0.909593
# At minibatch 160900, batch loss 0.858418, batch nll 0.515053, batch error rate 16.000000%
# At minibatch 161000, batch loss 0.978867, batch nll 0.635517, batch error rate 18.000000%
# At minibatch 161100, batch loss 0.700896, batch nll 0.357529, batch error rate 10.000000%
# At minibatch 161200, batch loss 1.051901, batch nll 0.708536, batch error rate 17.000000%
# After epoch 403: valid_err_rate: 26.770000% currently going to do 526 epochs
# After epoch 403: averaged train_err_rate: 18.892500% averaged train nll: 0.564609 averaged train loss: 0.907962
# At minibatch 161300, batch loss 0.860937, batch nll 0.517522, batch error rate 14.000000%
# At minibatch 161400, batch loss 0.836687, batch nll 0.493259, batch error rate 15.000000%
# At minibatch 161500, batch loss 0.864324, batch nll 0.520906, batch error rate 21.000000%
# At minibatch 161600, batch loss 0.928306, batch nll 0.584922, batch error rate 23.000000%
# After epoch 404: valid_err_rate: 26.870000% currently going to do 526 epochs
# After epoch 404: averaged train_err_rate: 18.840000% averaged train nll: 0.564915 averaged train loss: 0.908320
# At minibatch 161700, batch loss 0.787150, batch nll 0.443769, batch error rate 13.000000%
# At minibatch 161800, batch loss 0.861236, batch nll 0.517836, batch error rate 15.000000%
# At minibatch 161900, batch loss 1.050457, batch nll 0.707053, batch error rate 26.000000%
# At minibatch 162000, batch loss 0.891750, batch nll 0.548322, batch error rate 24.000000%
# After epoch 405: valid_err_rate: 26.850000% currently going to do 526 epochs
# After epoch 405: averaged train_err_rate: 18.975000% averaged train nll: 0.565665 averaged train loss: 0.909064
# At minibatch 162100, batch loss 0.812183, batch nll 0.468797, batch error rate 15.000000%
# At minibatch 162200, batch loss 0.806819, batch nll 0.463409, batch error rate 12.000000%
# At minibatch 162300, batch loss 0.824852, batch nll 0.481404, batch error rate 14.000000%
# At minibatch 162400, batch loss 0.873622, batch nll 0.530176, batch error rate 15.000000%
# After epoch 406: valid_err_rate: 26.790000% currently going to do 526 epochs
# After epoch 406: averaged train_err_rate: 18.905000% averaged train nll: 0.565772 averaged train loss: 0.909196
# At minibatch 162500, batch loss 0.947276, batch nll 0.603816, batch error rate 20.000000%
# At minibatch 162600, batch loss 0.989029, batch nll 0.645588, batch error rate 21.000000%
# At minibatch 162700, batch loss 0.880946, batch nll 0.537468, batch error rate 22.000000%
# At minibatch 162800, batch loss 0.985155, batch nll 0.641648, batch error rate 23.000000%
# After epoch 407: valid_err_rate: 26.710000% currently going to do 526 epochs
# After epoch 407: averaged train_err_rate: 19.017500% averaged train nll: 0.565284 averaged train loss: 0.908753
# At minibatch 162900, batch loss 0.940228, batch nll 0.596707, batch error rate 23.000000%
# At minibatch 163000, batch loss 0.838736, batch nll 0.495206, batch error rate 20.000000%
# At minibatch 163100, batch loss 0.806524, batch nll 0.462973, batch error rate 18.000000%
# At minibatch 163200, batch loss 0.843319, batch nll 0.499767, batch error rate 15.000000%
# After epoch 408: valid_err_rate: 26.570000% currently going to do 526 epochs
# After epoch 408: averaged train_err_rate: 18.987500% averaged train nll: 0.565133 averaged train loss: 0.908663
# At minibatch 163300, batch loss 0.887902, batch nll 0.544345, batch error rate 18.000000%
# At minibatch 163400, batch loss 1.088465, batch nll 0.744883, batch error rate 23.000000%
# At minibatch 163500, batch loss 0.935109, batch nll 0.591514, batch error rate 18.000000%
# At minibatch 163600, batch loss 0.886369, batch nll 0.542771, batch error rate 13.000000%
# After epoch 409: valid_err_rate: 26.920000% currently going to do 526 epochs
# After epoch 409: averaged train_err_rate: 18.965000% averaged train nll: 0.564279 averaged train loss: 0.907856
# At minibatch 163700, batch loss 0.844380, batch nll 0.500783, batch error rate 15.000000%
# At minibatch 163800, batch loss 0.910784, batch nll 0.567174, batch error rate 23.000000%
# At minibatch 163900, batch loss 0.797198, batch nll 0.453590, batch error rate 14.000000%
# At minibatch 164000, batch loss 0.904308, batch nll 0.560690, batch error rate 17.000000%
# After epoch 410: valid_err_rate: 26.450000% currently going to do 526 epochs
# After epoch 410: averaged train_err_rate: 18.970000% averaged train nll: 0.564814 averaged train loss: 0.908422
# At minibatch 164100, batch loss 1.163172, batch nll 0.819548, batch error rate 21.000000%
# At minibatch 164200, batch loss 0.864854, batch nll 0.521214, batch error rate 20.000000%
# At minibatch 164300, batch loss 0.857108, batch nll 0.513445, batch error rate 17.000000%
# At minibatch 164400, batch loss 0.922793, batch nll 0.579145, batch error rate 18.000000%
# After epoch 411: valid_err_rate: 26.690000% currently going to do 526 epochs
# After epoch 411: averaged train_err_rate: 18.970000% averaged train nll: 0.565115 averaged train loss: 0.908756
# At minibatch 164500, batch loss 0.965413, batch nll 0.621750, batch error rate 21.000000%
# At minibatch 164600, batch loss 0.861079, batch nll 0.517424, batch error rate 16.000000%
# At minibatch 164700, batch loss 0.888766, batch nll 0.545081, batch error rate 19.000000%
# At minibatch 164800, batch loss 0.970873, batch nll 0.627166, batch error rate 26.000000%
# After epoch 412: valid_err_rate: 26.530000% currently going to do 526 epochs
# After epoch 412: averaged train_err_rate: 18.892500% averaged train nll: 0.564150 averaged train loss: 0.907821
# At minibatch 164900, batch loss 0.919826, batch nll 0.576115, batch error rate 21.000000%
# At minibatch 165000, batch loss 0.935106, batch nll 0.591401, batch error rate 24.000000%
# At minibatch 165100, batch loss 0.828414, batch nll 0.484705, batch error rate 20.000000%
# At minibatch 165200, batch loss 0.927461, batch nll 0.583721, batch error rate 22.000000%
# After epoch 413: valid_err_rate: 26.690000% currently going to do 526 epochs
# After epoch 413: averaged train_err_rate: 18.892500% averaged train nll: 0.564472 averaged train loss: 0.908184
# At minibatch 165300, batch loss 0.822007, batch nll 0.478236, batch error rate 17.000000%
# At minibatch 165400, batch loss 0.788674, batch nll 0.444907, batch error rate 12.000000%
# At minibatch 165500, batch loss 0.885467, batch nll 0.541716, batch error rate 18.000000%
# At minibatch 165600, batch loss 1.037119, batch nll 0.693354, batch error rate 26.000000%
# After epoch 414: valid_err_rate: 27.010000% currently going to do 526 epochs
# After epoch 414: averaged train_err_rate: 19.092500% averaged train nll: 0.564303 averaged train loss: 0.908059
# At minibatch 165700, batch loss 0.893848, batch nll 0.550070, batch error rate 18.000000%
# At minibatch 165800, batch loss 0.944090, batch nll 0.600315, batch error rate 24.000000%
# At minibatch 165900, batch loss 0.968636, batch nll 0.624857, batch error rate 24.000000%
# At minibatch 166000, batch loss 0.837488, batch nll 0.493684, batch error rate 14.000000%
# After epoch 415: valid_err_rate: 26.460000% currently going to do 526 epochs
# After epoch 415: averaged train_err_rate: 18.927500% averaged train nll: 0.565088 averaged train loss: 0.908865
# At minibatch 166100, batch loss 0.864478, batch nll 0.520672, batch error rate 15.000000%
# At minibatch 166200, batch loss 0.933409, batch nll 0.589595, batch error rate 20.000000%
# At minibatch 166300, batch loss 0.854311, batch nll 0.510471, batch error rate 20.000000%
# At minibatch 166400, batch loss 0.937239, batch nll 0.593402, batch error rate 25.000000%
# After epoch 416: valid_err_rate: 26.700000% currently going to do 526 epochs
# After epoch 416: averaged train_err_rate: 19.007500% averaged train nll: 0.564099 averaged train loss: 0.907921
# At minibatch 166500, batch loss 0.834126, batch nll 0.490270, batch error rate 14.000000%
# At minibatch 166600, batch loss 0.969452, batch nll 0.625565, batch error rate 22.000000%
# At minibatch 166700, batch loss 0.834197, batch nll 0.490302, batch error rate 12.000000%
# At minibatch 166800, batch loss 0.910270, batch nll 0.566391, batch error rate 20.000000%
# After epoch 417: valid_err_rate: 26.640000% currently going to do 526 epochs
# After epoch 417: averaged train_err_rate: 18.957500% averaged train nll: 0.564542 averaged train loss: 0.908417
# At minibatch 166900, batch loss 0.920714, batch nll 0.576827, batch error rate 20.000000%
# At minibatch 167000, batch loss 0.908090, batch nll 0.564199, batch error rate 20.000000%
# At minibatch 167100, batch loss 1.096278, batch nll 0.752378, batch error rate 27.000000%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-0f3390dd1d00> in <module>()
#      29         momentum=0.9
#      30
# ---> 31         L, err_rate, nll, wdec = train_step(X_batch, Y_batch, lrate, momentum)
#      32
#      33         train_loss.append((i,L))
#
# /home/i258324/Dokumenty/SN/tempNN/nn_assignments/libs/Theano/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# /home/i258324/Dokumenty/SN/tempNN/nn_assignments/libs/Theano/theano/gof/op.pyc in rval(p, i, o, n)
#     862         if ctx is graph.NoContext:
#     863             # default arguments are stored in the closure of `rval`
# --> 864             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
#     865                 r = p(n, [x[0] for x in i], o)
#     866                 for o in node.outputs:
#
# KeyboardInterrupt:

# %%
print "Setting network parameters from after epoch %d" %(best_params_epoch)
load_parameters(best_params)

print "Success rate is %f%%" %(100.0-compute_error_rate(cifar10_testt_stream)*100.0,)
print "Error rate is %f%%" %(compute_error_rate(cifar10_testt_stream)*100.0,)

figure(figsize=(16,14))

subplot(2,1,1)
train_nll_a = np.array(train_nll)
semilogy(train_nll_a[:,0], train_nll_a[:,1], label='batch train nll')
legend()

subplot(2,1,2)
train_erros_a = np.array(train_erros)
plot(train_erros_a[:,0], train_erros_a[:,1], label='batch train error rate')
validation_errors_a = np.array(validation_errors)
plot(validation_errors_a[:,0], validation_errors_a[:,1], label='validation error rate', color='r')
ylim(0,1.2)
legend()
# Out:
# Setting network parameters from after epoch 190
# Success rate is 69.090000%
# Error rate is 30.910000%

# %%
middle_layers_computer = theano.function([X], network.model_layers)

img_num=11

middle_layers = middle_layers_computer(X_test_value[img_num:img_num+1])
print middle_layers[0].shape
print middle_layers[1].shape
print middle_layers[2].shape
print middle_layers[3].shape
print middle_layers[4].shape


plot_mat(middle_layers[0])
title(network.model_names[0])
show()

for ml, name in zip(middle_layers[1:], network.model_names[1:]):
    try:
        #print ml#.transpose(1,0,2,3).shape
        plot_mat(ml.transpose(1,0,2,3), cmap='gray')
        title(name)
        show()
    except ValueError:
        pass
# Out:
# (1, 3, 32, 32)
# (1, 16, 30, 30)
# (1, 16, 15, 15)
# (1, 25, 12, 12)
# (1, 25, 6, 6)
