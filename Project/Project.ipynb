# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
print theano.__file__
# Out:
# /home/i258324/Dokumenty/SN/tempNN/nn_assignments/libs/Theano/theano/__init__.pyc

# %%
import theano
import theano.tensor.signal.downsample
import skimage.io
from scipy.ndimage.filters import convolve

#note: this requires the starter code for the assignments!
from common.plotting import plot_mat

theano.config.floatX = 'float32'
print theano.config.floatX
# Out:
# float32
# Using gpu device 0: GeForce GTX 780 (CNMeM is enabled)

# %%
from fuel.datasets.cifar10 import CIFAR10
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme
from common.plotting import plot_mat

CIFAR10.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'}))

cifar10_train = CIFAR10(("train",), subset=slice(None,40000))
#this stream will shuffle the MNIST set and return us batches of 100 examples
cifar10_train_stream = DataStream.default_stream(
    cifar10_train,
    iteration_scheme=ShuffledScheme(cifar10_train.num_examples, 25))
                                               
cifar10_validation = CIFAR10(("train",), subset=slice(40000, None))

# We will use larger portions for testing and validation
# as these dont do a backward pass and reauire less RAM.
cifar10_validation_stream = DataStream.default_stream(
    cifar10_validation, iteration_scheme=SequentialScheme(cifar10_validation.num_examples, 100))
cifar10_test = CIFAR10(("test",))
cifar10_test_stream = DataStream.default_stream(
    cifar10_test, iteration_scheme=SequentialScheme(cifar10_test.num_examples, 100))

# %%
print "The streams return batches containing %s" % (cifar10_train_stream.sources,)

print "Each trainin batch consits of a tuple containing:"
for element in next(cifar10_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(cifar10_test_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    

plot_mat(cifar10_train.data_sources[0][:20], cmap='gray')
# Out:
# The streams return batches containing (u'features', u'targets')
# Each trainin batch consits of a tuple containing:
#  - an array of size (25, 3, 32, 32) containing float32
#  - an array of size (25, 1) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (100, 3, 32, 32) containing float32
#  - an array of size (100, 1) containing uint8

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
# A theano variable is an entry to the cmputational graph
# We will need to provide its value during function call
# X is batch_size x num_channels x img_rows x img_columns
X = theano.tensor.tensor4('X')

# Y is 1D, it lists the targets for all examples
Y = theano.tensor.matrix('Y', dtype='uint8')

#The tag values are useful during debugging the creation of Theano graphs

X_test_value, Y_test_value = next(cifar10_train_stream.get_epoch_iterator())
#
# Unfortunately, test tags don't work with convolutions with newest Theano :(
#
theano.config.compute_test_value = 'warn' # Enable the computation of test values


X.tag.test_value = X_test_value[:3]
Y.tag.test_value = Y_test_value[:3]

print "X shape: %s" % (X.tag.test_value.shape,)

# this list will hold all parameters of the network
model_parameters = []

#The first convolutional layer
#The shape is: num_out_filters x num_in_filters x filter_height x filter_width
num_filters_1 = 10 #we will apply that many convolution filters in the first layer
CW1 = theano.shared(np.zeros((num_filters_1,3,5,5), dtype='float32'), name='CW1')
#please note - this is somewhat non-standard
CW1.tag.initializer = IsotropicGaussian(0.05)

CB1 = theano.shared(np.zeros((num_filters_1,), dtype='float32'), name='CB1')
CB1.tag.initializer = Constant(0.0)
model_parameters += [CW1, CB1]

after_C1 = theano.tensor.maximum(
    0.0,
    theano.tensor.nnet.conv2d(X, CW1) + CB1.dimshuffle('x',0,'x','x'))
print "after_C1 shape: %s" % (after_C1.tag.test_value.shape,)
after_P1 = theano.tensor.signal.downsample.max_pool_2d(after_C1, (2,2), ignore_border=True)
print "after_P1 shape: %s" % (after_P1.tag.test_value.shape,)


num_filters_2 = 25 #we will compute ten convolution filters in the first layer
CW2 = theano.shared(np.zeros((num_filters_2,num_filters_1,5,5), dtype='float32'), name='CW2')
CW2.tag.initializer = IsotropicGaussian(0.05)

CB2 = theano.shared(np.zeros((num_filters_2,), dtype='float32'), name='CB2')
CB2.tag.initializer = Constant(0.0)
model_parameters += [CW2, CB2]

after_C2 = theano.tensor.maximum(
    0.0,
    theano.tensor.nnet.conv2d(after_P1, CW2) + CB2.dimshuffle('x',0,'x','x'))
print "after_C2 shape: %s" % (after_C2.tag.test_value.shape,)
after_P2 = theano.tensor.signal.downsample.max_pool_2d(after_C2, (2,2), ignore_border=True)
print "after_P2 shape: %s" % (after_P2.tag.test_value.shape,)

#Fully connected layers - we just flatten all filter maps
num_fw3_hidden=1000
FW3 = theano.shared(np.zeros((num_filters_2 * 5 * 5, num_fw3_hidden), dtype='float32'), name='FW3')
#FW3 = theano.shared(np.zeros(( num_fw3_hidden,num_filters_2), dtype='float32'), name='FW3')
FW3.tag.initializer = IsotropicGaussian(0.05)
    
FB3 = theano.shared(np.zeros((num_fw3_hidden,), dtype='float32'), name='FB3')
FB3.tag.initializer = Constant(0.0)
model_parameters += [FW3, FB3]

after_F3 = theano.tensor.maximum(
    0.0, 
    theano.tensor.dot(after_P2.flatten(2), FW3) + FB3.dimshuffle('x',0))
print "after_F3 shape: %s" % (after_F3.tag.test_value.shape,)



num_fw5_hidden=400
FW5 = theano.shared(np.zeros((num_fw3_hidden,num_fw5_hidden), dtype='float32'), name='FW5')
#FW3 = theano.shared(np.zeros(( num_fw3_hidden,num_filters_2), dtype='float32'), name='FW3')
FW5.tag.initializer = IsotropicGaussian(0.05)
    
FB5 = theano.shared(np.zeros((num_fw5_hidden,), dtype='float32'), name='FB5')
FB5.tag.initializer = Constant(0.0)
model_parameters += [FW5, FB5]

after_F5 = theano.tensor.maximum(
    0.0, 
    theano.tensor.dot(after_F3, FW5) + FB5.dimshuffle('x',0))
print "after_F5 shape: %s" % (after_F5.tag.test_value.shape,)




num_fw4_hidden=10
FW4 = theano.shared(np.zeros((num_fw5_hidden, num_fw4_hidden), dtype='float32'), name='FW4')
FW4.tag.initializer = IsotropicGaussian(0.05)

FB4 = theano.shared(np.zeros((num_fw4_hidden,), dtype='float32'), name='FB4')
FB4.tag.initializer = Constant(0.0)
model_parameters += [FW4, FB4]

after_F4 = theano.tensor.dot(after_F5, FW4) + FB4.dimshuffle('x',0)
print "after_F4 shape: %s" % (after_F4.tag.test_value.shape,)

log_probs = theano.tensor.nnet.softmax(after_F4)

predictions = theano.tensor.argmax(log_probs, axis=1)

error_rate = theano.tensor.neq(predictions,Y.ravel()).mean()
nll = - theano.tensor.log(log_probs[theano.tensor.arange(Y.shape[0]), Y.ravel()]).mean()

weight_decay = 0.0
for p in model_parameters:
    if p.name[1]=='W':
        weight_decay = weight_decay + 1e-3 * (p**2).sum()

cost = nll + weight_decay

#At this point stop computing test values
theano.config.compute_test_value = 'off' # Enable the computation of test values
# Out:
# X shape: (3, 3, 32, 32)
# after_C1 shape: (3, 10, 28, 28)
# after_P1 shape: (3, 10, 14, 14)
# after_C2 shape: (3, 25, 10, 10)
# after_P2 shape: (3, 25, 5, 5)
# after_F3 shape: (3, 1000)
# after_F5 shape: (3, 400)
# after_F4 shape: (3, 10)

# %%
updates = []

lrate = theano.tensor.scalar('lrate',dtype='float32')
momentum = theano.tensor.scalar('momentum',dtype='float32')

# Theano will compute the gradients for us
gradients = theano.grad(cost, model_parameters)

#initialize storage for momentum
velocities = [theano.shared(np.zeros_like(p.get_value()), name='V_%s' %(p.name, )) for p in model_parameters]

for p,g,v in zip(model_parameters, gradients, velocities):
    v_new = momentum * v - lrate * g
    p_new = p + v_new
    updates += [(v,v_new), (p, p_new)]
    
updates
# Out:
# [(V_CW1, Elemwise{sub,no_inplace}.0),
#  (CW1, Elemwise{add,no_inplace}.0),
#  (V_CB1, Elemwise{sub,no_inplace}.0),
#  (CB1, Elemwise{add,no_inplace}.0),
#  (V_CW2, Elemwise{sub,no_inplace}.0),
#  (CW2, Elemwise{add,no_inplace}.0),
#  (V_CB2, Elemwise{sub,no_inplace}.0),
#  (CB2, Elemwise{add,no_inplace}.0),
#  (V_FW3, Elemwise{sub,no_inplace}.0),
#  (FW3, Elemwise{add,no_inplace}.0),
#  (V_FB3, Elemwise{sub,no_inplace}.0),
#  (FB3, Elemwise{add,no_inplace}.0),
#  (V_FW5, Elemwise{sub,no_inplace}.0),
#  (FW5, Elemwise{add,no_inplace}.0),
#  (V_FB5, Elemwise{sub,no_inplace}.0),
#  (FB5, Elemwise{add,no_inplace}.0),
#  (V_FW4, Elemwise{sub,no_inplace}.0),
#  (FW4, Elemwise{add,no_inplace}.0),
#  (V_FB4, Elemwise{sub,no_inplace}.0),
#  (FB4, Elemwise{add,no_inplace}.0)]

# %%
#compile theano functions

#each call to train step will make one SGD step
train_step = theano.function([X,Y,lrate,momentum],[cost, error_rate, nll, weight_decay],updates=updates)
#each call to predict will return predictions on a batch of data
predict = theano.function([X], predictions)

# %%
def compute_error_rate(stream):
    errs = 0.0
    num_samples = 0.0
    for X, Y in stream.get_epoch_iterator():
        errs += (predict(X)!=Y.ravel()).sum()
        num_samples += Y.shape[0]
    return errs/num_samples

#utilities to save values of parameters and to load them

def init_parameters():
    rng = np.random.RandomState(1234)
    for p in model_parameters:
        p.set_value(p.tag.initializer.generate(rng, p.get_value().shape))

def snapshot_parameters():
    return [p.get_value(borrow=False) for p in model_parameters]

def load_parameters(snapshot):
    for p, s in zip(model_parameters, snapshot):
        p.set_value(s, borrow=False)

# %%
# init training

i=0
e=0

init_parameters()
for v in velocities:
    v.set_value(np.zeros_like(v.get_value()))

best_valid_error_rate = np.inf
best_params = snapshot_parameters()
best_params_epoch = 0

train_erros = []
train_loss = []
train_nll = []
validation_errors = []

number_of_epochs = 3
patience_expansion = 1.5

# training loop

while e<number_of_epochs: #This loop goes over epochs
    e += 1
    #First train on all data from this batch
    epoch_start_i = i
    for X_batch, Y_batch in cifar10_train_stream.get_epoch_iterator(): 
        i += 1
        
        K = 2000
        lrate = 5e-3 * K / np.maximum(K, i)
        momentum=0.9
        #print X_batch.shape
        #print Y_batch.shape
        #print lrate
        #print momentum
        #print momentum
        L, err_rate, nll, wdec = train_step(X_batch, Y_batch, lrate, momentum)
        
        #print [p.get_value().ravel()[:10] for p in model_parameters]
        #print [p.get_value().ravel()[:10] for p in velocities]
        
        
        train_loss.append((i,L))
        train_erros.append((i,err_rate))
        train_nll.append((i,nll))
        if i % 100 == 0:
            print "At minibatch %d, batch loss %f, batch nll %f, batch error rate %f%%" % (i, L, nll, err_rate*100)
        
    # After an epoch compute validation error
    val_error_rate = compute_error_rate(cifar10_validation_stream)
    if val_error_rate < best_valid_error_rate:
        number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
        best_valid_error_rate = val_error_rate
        best_params = snapshot_parameters()
        best_params_epoch = e
    validation_errors.append((i,val_error_rate))
    print "After epoch %d: valid_err_rate: %f%% currently going to do %d epochs" %(
        e, val_error_rate*100, number_of_epochs)
    print "After epoch %d: averaged train_err_rate: %f%% averaged train nll: %f averaged train loss: %f" %(
        e, np.mean(np.asarray(train_erros)[epoch_start_i:,1])*100, 
        np.mean(np.asarray(train_nll)[epoch_start_i:,1]),
        np.mean(np.asarray(train_loss)[epoch_start_i:,1]))
# Out:
# At minibatch 100, batch loss 4.591718, batch nll 2.043113, batch error rate 72.000000%
# At minibatch 200, batch loss 4.512855, batch nll 2.012073, batch error rate 64.000000%
# At minibatch 300, batch loss 4.502734, batch nll 2.048320, batch error rate 60.000000%
# At minibatch 400, batch loss 4.046394, batch nll 1.637667, batch error rate 64.000000%
# At minibatch 500, batch loss 3.892393, batch nll 1.528685, batch error rate 56.000000%
# At minibatch 600, batch loss 3.917149, batch nll 1.597457, batch error rate 72.000000%
# At minibatch 700, batch loss 4.185088, batch nll 1.908289, batch error rate 72.000000%
# At minibatch 800, batch loss 3.650327, batch nll 1.415781, batch error rate 44.000000%
# At minibatch 900, batch loss 3.549161, batch nll 1.355793, batch error rate 52.000000%
# At minibatch 1000, batch loss 3.430752, batch nll 1.277703, batch error rate 48.000000%
# At minibatch 1100, batch loss 3.654861, batch nll 1.540811, batch error rate 56.000000%
# At minibatch 1200, batch loss 3.449028, batch nll 1.373421, batch error rate 52.000000%
# At minibatch 1300, batch loss 3.501590, batch nll 1.464409, batch error rate 48.000000%
# At minibatch 1400, batch loss 3.213478, batch nll 1.212783, batch error rate 28.000000%
# At minibatch 1500, batch loss 3.498403, batch nll 1.533614, batch error rate 56.000000%
# At minibatch 1600, batch loss 3.417620, batch nll 1.488962, batch error rate 44.000000%
# After epoch 1: valid_err_rate: 46.810000% currently going to do 3 epochs
# After epoch 1: averaged train_err_rate: 57.630000% averaged train nll: 1.579878 averaged train loss: 3.823912
# At minibatch 1700, batch loss 2.843457, batch nll 0.948194, batch error rate 32.000000%
# At minibatch 1800, batch loss 2.904321, batch nll 1.042402, batch error rate 36.000000%
# At minibatch 1900, batch loss 3.239429, batch nll 1.410084, batch error rate 64.000000%
# At minibatch 2000, batch loss 3.039845, batch nll 1.242880, batch error rate 48.000000%
# At minibatch 2100, batch loss 3.239881, batch nll 1.473731, batch error rate 56.000000%
# At minibatch 2200, batch loss 2.862338, batch nll 1.125589, batch error rate 28.000000%
# At minibatch 2300, batch loss 2.697172, batch nll 0.987569, batch error rate 20.000000%
# At minibatch 2400, batch loss 2.809819, batch nll 1.125577, batch error rate 36.000000%
# At minibatch 2500, batch loss 2.965482, batch nll 1.305649, batch error rate 40.000000%
# At minibatch 2600, batch loss 2.712575, batch nll 1.075508, batch error rate 32.000000%
# At minibatch 2700, batch loss 3.088114, batch nll 1.472700, batch error rate 56.000000%
# At minibatch 2800, batch loss 2.911745, batch nll 1.316916, batch error rate 60.000000%
# At minibatch 2900, batch loss 2.587681, batch nll 1.012794, batch error rate 32.000000%
# At minibatch 3000, batch loss 2.571847, batch nll 1.015338, batch error rate 32.000000%
# At minibatch 3100, batch loss 2.977754, batch nll 1.439578, batch error rate 36.000000%
# At minibatch 3200, batch loss 2.086659, batch nll 0.565330, batch error rate 16.000000%
# After epoch 2: valid_err_rate: 40.860000% currently going to do 4 epochs
# After epoch 2: averaged train_err_rate: 42.720000% averaged train nll: 1.203845 averaged train loss: 2.902503
# At minibatch 3300, batch loss 2.452553, batch nll 0.946517, batch error rate 20.000000%
# At minibatch 3400, batch loss 2.279764, batch nll 0.788847, batch error rate 28.000000%
# At minibatch 3500, batch loss 2.402555, batch nll 0.926105, batch error rate 28.000000%
# At minibatch 3600, batch loss 2.167143, batch nll 0.704417, batch error rate 20.000000%
# At minibatch 3700, batch loss 2.283277, batch nll 0.834588, batch error rate 28.000000%
# At minibatch 3800, batch loss 2.000133, batch nll 0.563894, batch error rate 28.000000%
# At minibatch 3900, batch loss 2.686632, batch nll 1.263404, batch error rate 52.000000%
# At minibatch 4000, batch loss 2.703133, batch nll 1.292138, batch error rate 36.000000%
# At minibatch 4100, batch loss 2.388217, batch nll 0.988798, batch error rate 32.000000%
# At minibatch 4200, batch loss 2.255310, batch nll 0.867238, batch error rate 36.000000%
# At minibatch 4300, batch loss 2.305444, batch nll 0.928318, batch error rate 36.000000%
# At minibatch 4400, batch loss 2.538668, batch nll 1.172098, batch error rate 40.000000%
# At minibatch 4500, batch loss 2.304462, batch nll 0.948367, batch error rate 28.000000%
# At minibatch 4600, batch loss 2.140516, batch nll 0.794151, batch error rate 24.000000%
# At minibatch 4700, batch loss 2.469324, batch nll 1.133133, batch error rate 48.000000%
# At minibatch 4800, batch loss 2.169449, batch nll 0.842665, batch error rate 24.000000%
# After epoch 3: valid_err_rate: 35.440000% currently going to do 5 epochs
# After epoch 3: averaged train_err_rate: 35.220000% averaged train nll: 0.994385 averaged train loss: 2.409872
# At minibatch 4900, batch loss 1.993334, batch nll 0.674792, batch error rate 20.000000%
# At minibatch 5000, batch loss 2.081793, batch nll 0.771561, batch error rate 36.000000%
# At minibatch 5100, batch loss 2.254529, batch nll 0.952289, batch error rate 36.000000%
# At minibatch 5200, batch loss 2.187197, batch nll 0.893206, batch error rate 40.000000%
# At minibatch 5300, batch loss 1.663710, batch nll 0.377199, batch error rate 12.000000%
# At minibatch 5400, batch loss 2.207044, batch nll 0.928048, batch error rate 28.000000%
# At minibatch 5500, batch loss 2.172437, batch nll 0.900958, batch error rate 32.000000%
# At minibatch 5600, batch loss 2.416024, batch nll 1.151766, batch error rate 36.000000%
# At minibatch 5700, batch loss 1.945707, batch nll 0.688713, batch error rate 28.000000%
# At minibatch 5800, batch loss 2.180852, batch nll 0.930674, batch error rate 36.000000%
# At minibatch 5900, batch loss 2.449288, batch nll 1.205928, batch error rate 36.000000%
# At minibatch 6000, batch loss 2.153827, batch nll 0.917189, batch error rate 40.000000%
# At minibatch 6100, batch loss 2.399402, batch nll 1.168973, batch error rate 32.000000%
# At minibatch 6200, batch loss 2.410129, batch nll 1.186173, batch error rate 36.000000%
# At minibatch 6300, batch loss 1.971194, batch nll 0.753617, batch error rate 20.000000%
# At minibatch 6400, batch loss 2.030111, batch nll 0.818557, batch error rate 28.000000%
# After epoch 4: valid_err_rate: 34.200000% currently going to do 7 epochs
# After epoch 4: averaged train_err_rate: 30.267500% averaged train nll: 0.860992 averaged train loss: 2.126844
# At minibatch 6500, batch loss 2.127050, batch nll 0.920858, batch error rate 40.000000%
# At minibatch 6600, batch loss 1.918889, batch nll 0.717936, batch error rate 24.000000%
# At minibatch 6700, batch loss 1.780543, batch nll 0.584770, batch error rate 32.000000%
# At minibatch 6800, batch loss 1.874051, batch nll 0.683408, batch error rate 20.000000%
# At minibatch 6900, batch loss 1.857499, batch nll 0.672352, batch error rate 20.000000%
# At minibatch 7000, batch loss 1.958923, batch nll 0.778785, batch error rate 28.000000%
# At minibatch 7100, batch loss 1.767192, batch nll 0.591800, batch error rate 24.000000%
# At minibatch 7200, batch loss 1.644951, batch nll 0.474664, batch error rate 20.000000%
# At minibatch 7300, batch loss 2.074042, batch nll 0.908563, batch error rate 32.000000%
# At minibatch 7400, batch loss 1.773043, batch nll 0.612429, batch error rate 20.000000%
# At minibatch 7500, batch loss 1.898399, batch nll 0.742446, batch error rate 16.000000%
# At minibatch 7600, batch loss 1.778175, batch nll 0.626916, batch error rate 24.000000%
# At minibatch 7700, batch loss 1.811152, batch nll 0.664461, batch error rate 24.000000%
# At minibatch 7800, batch loss 1.910553, batch nll 0.768394, batch error rate 16.000000%
# At minibatch 7900, batch loss 1.921762, batch nll 0.784040, batch error rate 28.000000%
# At minibatch 8000, batch loss 1.804806, batch nll 0.671550, batch error rate 16.000000%
# After epoch 5: valid_err_rate: 31.740000% currently going to do 8 epochs
# After epoch 5: averaged train_err_rate: 26.312500% averaged train nll: 0.757033 averaged train loss: 1.928056
# At minibatch 8100, batch loss 2.157882, batch nll 1.028289, batch error rate 36.000000%
# At minibatch 8200, batch loss 2.184570, batch nll 1.058761, batch error rate 48.000000%
# At minibatch 8300, batch loss 1.531121, batch nll 0.408975, batch error rate 12.000000%
# At minibatch 8400, batch loss 1.805531, batch nll 0.687028, batch error rate 24.000000%
# At minibatch 8500, batch loss 2.246665, batch nll 1.131699, batch error rate 32.000000%
# At minibatch 8600, batch loss 1.917678, batch nll 0.806438, batch error rate 24.000000%
# At minibatch 8700, batch loss 1.667830, batch nll 0.560221, batch error rate 24.000000%
# At minibatch 8800, batch loss 1.790826, batch nll 0.686761, batch error rate 28.000000%
# At minibatch 8900, batch loss 2.104203, batch nll 1.003786, batch error rate 24.000000%
# At minibatch 9000, batch loss 1.552893, batch nll 0.456140, batch error rate 12.000000%
# At minibatch 9100, batch loss 1.477448, batch nll 0.384132, batch error rate 16.000000%
# At minibatch 9200, batch loss 1.915769, batch nll 0.825899, batch error rate 32.000000%
# At minibatch 9300, batch loss 1.828009, batch nll 0.741347, batch error rate 24.000000%
# At minibatch 9400, batch loss 2.156893, batch nll 1.073403, batch error rate 44.000000%
# At minibatch 9500, batch loss 1.863080, batch nll 0.783118, batch error rate 16.000000%
# At minibatch 9600, batch loss 1.527534, batch nll 0.450925, batch error rate 24.000000%
# After epoch 6: valid_err_rate: 31.840000% currently going to do 8 epochs
# After epoch 6: averaged train_err_rate: 23.217500% averaged train nll: 0.674440 averaged train loss: 1.778750
# At minibatch 9700, batch loss 1.735024, batch nll 0.661131, batch error rate 24.000000%
# At minibatch 9800, batch loss 1.591169, batch nll 0.519933, batch error rate 12.000000%
# At minibatch 9900, batch loss 1.844216, batch nll 0.775768, batch error rate 32.000000%
# At minibatch 10000, batch loss 1.676973, batch nll 0.611224, batch error rate 24.000000%
# At minibatch 10100, batch loss 1.933259, batch nll 0.870288, batch error rate 24.000000%
# At minibatch 10200, batch loss 1.454698, batch nll 0.394560, batch error rate 8.000000%
# At minibatch 10300, batch loss 1.848968, batch nll 0.791551, batch error rate 28.000000%
# At minibatch 10400, batch loss 1.647500, batch nll 0.592935, batch error rate 24.000000%
# At minibatch 10500, batch loss 1.554171, batch nll 0.502236, batch error rate 16.000000%
# At minibatch 10600, batch loss 1.860726, batch nll 0.811478, batch error rate 32.000000%
# At minibatch 10700, batch loss 1.949540, batch nll 0.902941, batch error rate 32.000000%
# At minibatch 10800, batch loss 1.600986, batch nll 0.556901, batch error rate 12.000000%
# At minibatch 10900, batch loss 1.688237, batch nll 0.646703, batch error rate 20.000000%
# At minibatch 11000, batch loss 1.731967, batch nll 0.693090, batch error rate 24.000000%
# At minibatch 11100, batch loss 1.408049, batch nll 0.371691, batch error rate 4.000000%
# At minibatch 11200, batch loss 1.956609, batch nll 0.922680, batch error rate 28.000000%
# After epoch 7: valid_err_rate: 31.340000% currently going to do 11 epochs
# After epoch 7: averaged train_err_rate: 20.552500% averaged train nll: 0.601260 averaged train loss: 1.656139
# At minibatch 11300, batch loss 1.694518, batch nll 0.662681, batch error rate 32.000000%
# At minibatch 11400, batch loss 1.692924, batch nll 0.663137, batch error rate 28.000000%
# At minibatch 11500, batch loss 1.459093, batch nll 0.431462, batch error rate 12.000000%
# At minibatch 11600, batch loss 1.468883, batch nll 0.443520, batch error rate 20.000000%
# At minibatch 11700, batch loss 1.509279, batch nll 0.486062, batch error rate 16.000000%
# At minibatch 11800, batch loss 1.542736, batch nll 0.521695, batch error rate 20.000000%
# At minibatch 11900, batch loss 1.418918, batch nll 0.400137, batch error rate 12.000000%
# At minibatch 12000, batch loss 1.554896, batch nll 0.538206, batch error rate 20.000000%
# At minibatch 12100, batch loss 1.561666, batch nll 0.547234, batch error rate 20.000000%
# At minibatch 12200, batch loss 1.590478, batch nll 0.578050, batch error rate 20.000000%
# At minibatch 12300, batch loss 1.513961, batch nll 0.503453, batch error rate 20.000000%
# At minibatch 12400, batch loss 1.431980, batch nll 0.423592, batch error rate 12.000000%
# At minibatch 12500, batch loss 1.714013, batch nll 0.707677, batch error rate 32.000000%
# At minibatch 12600, batch loss 1.600668, batch nll 0.596291, batch error rate 28.000000%
# At minibatch 12700, batch loss 1.519913, batch nll 0.517594, batch error rate 24.000000%
# At minibatch 12800, batch loss 1.797005, batch nll 0.796694, batch error rate 24.000000%
# After epoch 8: valid_err_rate: 32.130000% currently going to do 11 epochs
# After epoch 8: averaged train_err_rate: 18.085000% averaged train nll: 0.535720 averaged train loss: 1.552596
# At minibatch 12900, batch loss 1.385101, batch nll 0.386475, batch error rate 12.000000%
# At minibatch 13000, batch loss 1.349517, batch nll 0.352551, batch error rate 12.000000%
# At minibatch 13100, batch loss 1.603953, batch nll 0.608736, batch error rate 16.000000%
# At minibatch 13200, batch loss 1.548983, batch nll 0.555517, batch error rate 24.000000%
# At minibatch 13300, batch loss 1.556068, batch nll 0.564373, batch error rate 12.000000%
# At minibatch 13400, batch loss 1.530172, batch nll 0.540127, batch error rate 28.000000%
# At minibatch 13500, batch loss 1.388440, batch nll 0.400094, batch error rate 12.000000%
# At minibatch 13600, batch loss 1.400872, batch nll 0.414405, batch error rate 12.000000%
# At minibatch 13700, batch loss 1.347595, batch nll 0.362797, batch error rate 8.000000%
# At minibatch 13800, batch loss 1.604357, batch nll 0.621267, batch error rate 24.000000%
# At minibatch 13900, batch loss 1.576241, batch nll 0.594822, batch error rate 16.000000%
# At minibatch 14000, batch loss 1.412984, batch nll 0.433173, batch error rate 16.000000%
# At minibatch 14100, batch loss 1.792733, batch nll 0.814586, batch error rate 32.000000%
# At minibatch 14200, batch loss 1.370838, batch nll 0.394360, batch error rate 16.000000%
# At minibatch 14300, batch loss 1.528290, batch nll 0.553423, batch error rate 20.000000%
# At minibatch 14400, batch loss 1.316802, batch nll 0.343582, batch error rate 8.000000%
# After epoch 9: valid_err_rate: 30.910000% currently going to do 14 epochs
# After epoch 9: averaged train_err_rate: 15.817500% averaged train nll: 0.473505 averaged train loss: 1.460131
# At minibatch 14500, batch loss 1.416616, batch nll 0.444707, batch error rate 8.000000%
# At minibatch 14600, batch loss 1.491292, batch nll 0.520790, batch error rate 12.000000%
# At minibatch 14700, batch loss 1.478391, batch nll 0.509261, batch error rate 16.000000%
# At minibatch 14800, batch loss 1.292302, batch nll 0.324592, batch error rate 8.000000%
# At minibatch 14900, batch loss 1.431409, batch nll 0.465142, batch error rate 20.000000%
# At minibatch 15000, batch loss 1.305663, batch nll 0.340867, batch error rate 8.000000%
# At minibatch 15100, batch loss 1.449425, batch nll 0.486008, batch error rate 24.000000%
# At minibatch 15200, batch loss 1.337980, batch nll 0.375970, batch error rate 12.000000%
# At minibatch 15300, batch loss 1.626053, batch nll 0.665483, batch error rate 28.000000%
# At minibatch 15400, batch loss 1.345004, batch nll 0.385861, batch error rate 16.000000%
# At minibatch 15500, batch loss 1.253273, batch nll 0.295543, batch error rate 8.000000%
# At minibatch 15600, batch loss 1.375851, batch nll 0.419499, batch error rate 20.000000%
# At minibatch 15700, batch loss 1.414606, batch nll 0.459567, batch error rate 20.000000%
# At minibatch 15800, batch loss 1.468229, batch nll 0.514579, batch error rate 20.000000%
# At minibatch 15900, batch loss 1.230754, batch nll 0.278510, batch error rate 12.000000%
# At minibatch 16000, batch loss 1.298303, batch nll 0.347510, batch error rate 12.000000%
# After epoch 10: valid_err_rate: 30.670000% currently going to do 16 epochs
# After epoch 10: averaged train_err_rate: 13.555000% averaged train nll: 0.416078 averaged train loss: 1.378101
# At minibatch 16100, batch loss 1.098294, batch nll 0.148602, batch error rate 0.000000%
# At minibatch 16200, batch loss 1.226762, batch nll 0.278226, batch error rate 4.000000%
# At minibatch 16300, batch loss 1.532201, batch nll 0.584844, batch error rate 16.000000%
# At minibatch 16400, batch loss 1.170191, batch nll 0.224079, batch error rate 4.000000%
# At minibatch 16500, batch loss 1.240224, batch nll 0.295344, batch error rate 16.000000%
# At minibatch 16600, batch loss 1.228023, batch nll 0.284313, batch error rate 8.000000%
# At minibatch 16700, batch loss 1.511160, batch nll 0.568706, batch error rate 16.000000%
# At minibatch 16800, batch loss 1.541662, batch nll 0.600384, batch error rate 20.000000%
# At minibatch 16900, batch loss 1.282625, batch nll 0.342544, batch error rate 8.000000%
# At minibatch 17000, batch loss 1.196740, batch nll 0.257804, batch error rate 12.000000%
# At minibatch 17100, batch loss 1.192053, batch nll 0.254302, batch error rate 8.000000%
# At minibatch 17200, batch loss 1.440800, batch nll 0.504111, batch error rate 16.000000%
# At minibatch 17300, batch loss 1.182609, batch nll 0.247128, batch error rate 4.000000%
# At minibatch 17400, batch loss 1.245950, batch nll 0.311697, batch error rate 8.000000%
# At minibatch 17500, batch loss 1.209300, batch nll 0.276147, batch error rate 8.000000%
# At minibatch 17600, batch loss 1.379511, batch nll 0.447540, batch error rate 16.000000%
# After epoch 11: valid_err_rate: 31.080000% currently going to do 16 epochs
# After epoch 11: averaged train_err_rate: 11.525000% averaged train nll: 0.365677 averaged train loss: 1.307032
# At minibatch 17700, batch loss 1.283600, batch nll 0.352573, batch error rate 8.000000%
# At minibatch 17800, batch loss 1.106302, batch nll 0.176270, batch error rate 4.000000%
# At minibatch 17900, batch loss 1.288880, batch nll 0.359865, batch error rate 12.000000%
# At minibatch 18000, batch loss 1.292540, batch nll 0.364534, batch error rate 12.000000%
# At minibatch 18100, batch loss 1.226318, batch nll 0.299309, batch error rate 8.000000%
# At minibatch 18200, batch loss 1.359731, batch nll 0.433740, batch error rate 20.000000%
# At minibatch 18300, batch loss 1.079934, batch nll 0.154932, batch error rate 4.000000%
# At minibatch 18400, batch loss 1.207141, batch nll 0.283191, batch error rate 16.000000%
# At minibatch 18500, batch loss 1.153350, batch nll 0.230464, batch error rate 8.000000%
# At minibatch 18600, batch loss 1.188736, batch nll 0.266896, batch error rate 4.000000%
# At minibatch 18700, batch loss 1.286517, batch nll 0.365759, batch error rate 8.000000%
# At minibatch 18800, batch loss 1.390466, batch nll 0.470744, batch error rate 20.000000%
# At minibatch 18900, batch loss 1.309286, batch nll 0.390583, batch error rate 12.000000%
# At minibatch 19000, batch loss 1.179848, batch nll 0.262187, batch error rate 4.000000%
# At minibatch 19100, batch loss 1.356442, batch nll 0.439779, batch error rate 16.000000%
# At minibatch 19200, batch loss 1.317506, batch nll 0.401789, batch error rate 20.000000%
# After epoch 12: valid_err_rate: 30.980000% currently going to do 16 epochs
# After epoch 12: averaged train_err_rate: 9.770000% averaged train nll: 0.319743 averaged train loss: 1.243619
# At minibatch 19300, batch loss 1.361866, batch nll 0.447020, batch error rate 16.000000%
# At minibatch 19400, batch loss 1.329832, batch nll 0.415864, batch error rate 12.000000%
# At minibatch 19500, batch loss 1.086175, batch nll 0.173136, batch error rate 0.000000%
# At minibatch 19600, batch loss 1.254834, batch nll 0.342647, batch error rate 8.000000%
# At minibatch 19700, batch loss 1.150842, batch nll 0.239561, batch error rate 4.000000%
# At minibatch 19800, batch loss 1.136856, batch nll 0.226494, batch error rate 0.000000%
# At minibatch 19900, batch loss 1.125469, batch nll 0.215990, batch error rate 8.000000%
# At minibatch 20000, batch loss 1.284785, batch nll 0.376207, batch error rate 8.000000%
# At minibatch 20100, batch loss 1.219605, batch nll 0.311920, batch error rate 12.000000%
# At minibatch 20200, batch loss 1.227162, batch nll 0.320375, batch error rate 12.000000%
# At minibatch 20300, batch loss 1.103984, batch nll 0.198122, batch error rate 4.000000%
# At minibatch 20400, batch loss 1.235264, batch nll 0.330283, batch error rate 8.000000%
# At minibatch 20500, batch loss 1.104009, batch nll 0.199907, batch error rate 4.000000%
# At minibatch 20600, batch loss 1.197928, batch nll 0.294730, batch error rate 8.000000%
# At minibatch 20700, batch loss 1.349025, batch nll 0.446707, batch error rate 16.000000%
# At minibatch 20800, batch loss 1.258936, batch nll 0.357554, batch error rate 8.000000%
# After epoch 13: valid_err_rate: 31.170000% currently going to do 16 epochs
# After epoch 13: averaged train_err_rate: 8.007500% averaged train nll: 0.275309 averaged train loss: 1.183882
# At minibatch 20900, batch loss 1.112347, batch nll 0.211768, batch error rate 4.000000%
# At minibatch 21000, batch loss 1.250964, batch nll 0.351165, batch error rate 8.000000%
# At minibatch 21100, batch loss 0.994205, batch nll 0.095231, batch error rate 0.000000%
# At minibatch 21200, batch loss 1.206612, batch nll 0.308452, batch error rate 12.000000%
# At minibatch 21300, batch loss 1.091286, batch nll 0.193947, batch error rate 4.000000%
# At minibatch 21400, batch loss 1.154087, batch nll 0.257592, batch error rate 12.000000%
# At minibatch 21500, batch loss 1.276256, batch nll 0.380601, batch error rate 12.000000%
# At minibatch 21600, batch loss 1.012017, batch nll 0.117145, batch error rate 0.000000%
# At minibatch 21700, batch loss 1.007027, batch nll 0.112944, batch error rate 4.000000%
# At minibatch 21800, batch loss 1.126900, batch nll 0.233627, batch error rate 4.000000%
# At minibatch 21900, batch loss 0.971379, batch nll 0.078884, batch error rate 0.000000%
# At minibatch 22000, batch loss 1.166980, batch nll 0.275308, batch error rate 12.000000%
# At minibatch 22100, batch loss 1.292230, batch nll 0.401392, batch error rate 16.000000%
# At minibatch 22200, batch loss 1.028218, batch nll 0.138155, batch error rate 0.000000%
# At minibatch 22300, batch loss 1.276568, batch nll 0.387241, batch error rate 12.000000%
# At minibatch 22400, batch loss 1.003198, batch nll 0.114665, batch error rate 4.000000%
# After epoch 14: valid_err_rate: 31.260000% currently going to do 16 epochs
# After epoch 14: averaged train_err_rate: 6.390000% averaged train nll: 0.236480 averaged train loss: 1.131387
# At minibatch 22500, batch loss 0.998489, batch nll 0.110626, batch error rate 4.000000%
# At minibatch 22600, batch loss 1.018480, batch nll 0.131306, batch error rate 4.000000%
# At minibatch 22700, batch loss 1.060107, batch nll 0.173699, batch error rate 4.000000%
# At minibatch 22800, batch loss 0.971027, batch nll 0.085399, batch error rate 0.000000%
# At minibatch 22900, batch loss 0.999807, batch nll 0.114936, batch error rate 0.000000%
# At minibatch 23000, batch loss 0.957268, batch nll 0.073135, batch error rate 0.000000%
# At minibatch 23100, batch loss 1.157537, batch nll 0.274149, batch error rate 8.000000%
# At minibatch 23200, batch loss 1.106031, batch nll 0.223418, batch error rate 4.000000%
# At minibatch 23300, batch loss 1.062258, batch nll 0.180370, batch error rate 8.000000%
# At minibatch 23400, batch loss 0.992266, batch nll 0.111164, batch error rate 0.000000%
# At minibatch 23500, batch loss 1.115322, batch nll 0.234953, batch error rate 8.000000%
# At minibatch 23600, batch loss 1.041684, batch nll 0.162039, batch error rate 4.000000%
# At minibatch 23700, batch loss 1.069068, batch nll 0.190178, batch error rate 4.000000%
# At minibatch 23800, batch loss 1.014659, batch nll 0.136517, batch error rate 0.000000%
# At minibatch 23900, batch loss 0.970172, batch nll 0.092738, batch error rate 0.000000%
# At minibatch 24000, batch loss 1.113055, batch nll 0.236364, batch error rate 8.000000%
# After epoch 15: valid_err_rate: 31.380000% currently going to do 16 epochs
# After epoch 15: averaged train_err_rate: 5.245000% averaged train nll: 0.204042 averaged train loss: 1.086675
# At minibatch 24100, batch loss 0.981058, batch nll 0.105056, batch error rate 4.000000%
# At minibatch 24200, batch loss 1.080066, batch nll 0.204761, batch error rate 4.000000%
# At minibatch 24300, batch loss 0.963390, batch nll 0.088761, batch error rate 4.000000%
# At minibatch 24400, batch loss 1.131006, batch nll 0.257052, batch error rate 8.000000%
# At minibatch 24500, batch loss 0.980650, batch nll 0.107371, batch error rate 0.000000%
# At minibatch 24600, batch loss 0.996819, batch nll 0.124226, batch error rate 4.000000%
# At minibatch 24700, batch loss 1.022262, batch nll 0.150369, batch error rate 4.000000%
# At minibatch 24800, batch loss 1.090740, batch nll 0.219557, batch error rate 4.000000%
# At minibatch 24900, batch loss 1.239320, batch nll 0.368792, batch error rate 8.000000%
# At minibatch 25000, batch loss 1.246676, batch nll 0.376821, batch error rate 12.000000%
# At minibatch 25100, batch loss 1.056930, batch nll 0.187808, batch error rate 4.000000%
# At minibatch 25200, batch loss 1.096988, batch nll 0.228535, batch error rate 8.000000%
# At minibatch 25300, batch loss 0.980470, batch nll 0.112691, batch error rate 0.000000%
# At minibatch 25400, batch loss 0.978864, batch nll 0.111767, batch error rate 0.000000%
# At minibatch 25500, batch loss 1.091979, batch nll 0.225570, batch error rate 8.000000%
# At minibatch 25600, batch loss 1.087003, batch nll 0.221275, batch error rate 4.000000%
# After epoch 16: valid_err_rate: 31.280000% currently going to do 16 epochs
# After epoch 16: averaged train_err_rate: 4.000000% averaged train nll: 0.174359 averaged train loss: 1.045562

# %%
print "Setting network parameters from after epoch %d" %(best_params_epoch)
load_parameters(best_params)

print "Success rate is %f%%" %(100.0-compute_error_rate(cifar10_test_stream)*100.0,)
print "Error rate is %f%%" %(compute_error_rate(cifar10_test_stream)*100.0,)

figure(figsize=(16,14))

subplot(2,1,1)
train_nll_a = np.array(train_nll)
semilogy(train_nll_a[:,0], train_nll_a[:,1], label='batch train nll')
legend()

subplot(2,1,2)
train_erros_a = np.array(train_erros)
plot(train_erros_a[:,0], train_erros_a[:,1], label='batch train error rate')
validation_errors_a = np.array(validation_errors)
plot(validation_errors_a[:,0], validation_errors_a[:,1], label='validation error rate', color='r')
ylim(0,0.8)
legend()
# Out:
# Setting network parameters from after epoch 10
# Success rate is 69.130000%
# Error rate is 30.870000%

# %%
iii = predict.maker.inputs[0]
X = iii.variable

# %%
# build a function that shows how the network processes an image

middle_layers_computer = theano.function([X], [
        X,
        after_C1,
        after_P1,
        after_C2,
        after_P2
        ])

# %%
img_num=11

middle_layers = middle_layers_computer(X_test_value[img_num:img_num+1])
print middle_layers[0].transpose(1,0,2,3).shape
print middle_layers[1].shape
print middle_layers[2].shape
print middle_layers[3].shape
print middle_layers[4].shape

for ml, name in zip(middle_layers, ['X', 'C1', 'P1', 'C2', 'P2']):
    plot_mat(ml.transpose(1,0,2,3), cmap='gray')
    title(name)
    show()
# Out:
# (3, 1, 32, 32)
# (1, 10, 28, 28)
# (1, 10, 14, 14)
# (1, 25, 10, 10)
# (1, 25, 5, 5)
