# %%
# %pylab inline

from scipy.ndimage.filters import convolve

import theano
import theano.tensor.signal.downsample
import skimage.io
print theano.config.floatX

from common.plotting import plot_mat

from fuel.datasets.cifar10 import CIFAR10
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme
# Out:
# Populating the interactive namespace from numpy and matplotlib
# float32
# Using gpu device 0: GeForce GTX 780 (CNMeM is enabled)

# %%
CIFAR10.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'})
)

cifar10_train = CIFAR10(("train",), subset=slice(None,40000))
cifar10_valid = CIFAR10(("train",), subset=slice(40000, None))
cifar10_testt  = CIFAR10(("test",))

minibatch_train = 100
minibatch_valid = 100
minibatch_testt = 100

cifar10_train_stream = DataStream.default_stream(
    cifar10_train,
    iteration_scheme=ShuffledScheme(cifar10_train.num_examples, minibatch_train)
)
cifar10_valid_stream = DataStream.default_stream(
    cifar10_valid, 
    iteration_scheme=SequentialScheme(cifar10_valid.num_examples, minibatch_valid)
)
cifar10_testt_stream = DataStream.default_stream(
    cifar10_testt, 
    iteration_scheme=SequentialScheme(cifar10_testt.num_examples, minibatch_testt)
)

print "Each trainin batch consits of a tuple containing:"
for element in next(cifar10_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(cifar10_testt_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    

plot_mat(cifar10_train.data_sources[0][:20], cmap='gray')

asd = 0
for x in cifar10_train_stream.get_epoch_iterator():
    asd += 1
print asd
# Out:
# Each trainin batch consits of a tuple containing:
#  - an array of size (100, 3, 32, 32) containing float32
#  - an array of size (100, 1) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (100, 3, 32, 32) containing float32
#  - an array of size (100, 1) containing uint8
# 400

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
def print_warn(s, X):
    print "after_%s shape: %s" % (s, X.tag.test_value.shape,)

class Layer_Conv():
    def __init__(self, in_chan, out_chan, size):
        self.in_chan = in_chan
        self.out_chan = out_chan
        self.size = size
    def make(self, X, n):
        CWn = theano.shared(np.zeros((self.out_chan, self.in_chan, self.size, self.size), dtype='float32'), name=('CW%d'%n))
        CBn = theano.shared(np.zeros((self.out_chan,), dtype='float32'), name=('CB%d'%n))
        
        CWn.tag.initializer = IsotropicGaussian(0.05)
        CBn.tag.initializer = Constant(0.0)
        
        after_Cn = theano.tensor.maximum(
            0.0,
            theano.tensor.nnet.conv2d(X, CWn) + CBn.dimshuffle('x',0,'x','x')
        )
        print_warn(("C%d"%n), after_Cn)
        
        return after_Cn, [CWn, CBn], [("C%d"%n)]
    
class Layer_Pool():
    def __init__(self, size):
        self.size = size        
    def make(self, X, n):
        after_Pn = theano.tensor.signal.downsample.max_pool_2d(X, (self.size, self.size), ignore_border=True)
        print_warn(("P%d"%n), after_Pn)
        
        return after_Pn, [], [("P%d"%n)]
    
class Layer_Filt():
    def __init__(self, in_chan, out_chan):
        self.in_chan = in_chan
        self.out_chan = out_chan
    def make(self, X, n):
        num_fw4_hidden=10
        FWn = theano.shared(np.zeros((self.in_chan, self.out_chan), dtype='float32'), name=('FW%d'%n))
        FBn = theano.shared(np.zeros((self.out_chan,), dtype='float32'), name=('FB%d'%n))
        
        FWn.tag.initializer = IsotropicGaussian(0.05)
        FBn.tag.initializer = Constant(0.0)

        after_Fn = theano.tensor.dot(X.flatten(2), FWn) + FBn.dimshuffle('x',0)
        print_warn(("F%d"%n), after_Fn)
        
        return after_Fn, [FWn, FBn], [("F%d"%n)]
    
class Layer_Soft():
    def __init__(self):
        pass
    def make(self, X, n):
        after_Sn = theano.tensor.nnet.softmax(X)
        print_warn(("S%d"%n), after_Sn)
        
        return after_Sn, [], [("S%d"%n)]

# %%
class NetworkBuilder():
    def __init__(self, layerlist):
        self.layers = layerlist
    def make(self, X):
        model_parameters = []
        self.model_names = ["X"]
        self.model_layers = [X] 
        i = 1
        after = X
        for layer in self.layers:
            after, param, name = layer.make(after, i)
            self.model_layers += [after]
            model_parameters += param
            self.model_names += name
            i += 1
            
        return after, model_parameters

# %%
theano.config.compute_test_value = 'warn'
X_test_value, Y_test_value = next(cifar10_train_stream.get_epoch_iterator())

X = theano.tensor.tensor4('X')
Y = theano.tensor.matrix('Y', dtype='uint8')
X.tag.test_value = X_test_value[:3]
Y.tag.test_value = Y_test_value[:3]
print "X shape: %s" % (X.tag.test_value.shape,)

network = NetworkBuilder([
        Layer_Conv(3, 32, 3),
        Layer_Pool(2),
        Layer_Conv(32, 50, 4),
        Layer_Pool(2),
        Layer_Conv(50, 64, 3),
        Layer_Filt(64*4*4, 1000),
        Layer_Filt(1000, 300),
        Layer_Filt(300, 10),
        Layer_Soft()
    ])

output, parameters = network.make(X)

predictions = theano.tensor.argmax(output, axis=1)

error_rate = theano.tensor.neq(predictions,Y.ravel()).mean()

nll = - theano.tensor.log(output[theano.tensor.arange(Y.shape[0]), Y.ravel()]).mean()

alpha = 3e-3
weight_decay = 0.0
for p in parameters:
    if p.name[1]=='W':
        weight_decay = weight_decay + alpha * (p**2).sum()

cost = nll + weight_decay

theano.config.compute_test_value = 'off'
# Out:
# X shape: (3, 3, 32, 32)
# after_C1 shape: (3, 32, 30, 30)
# after_P2 shape: (3, 32, 15, 15)
# after_C3 shape: (3, 50, 12, 12)
# after_P4 shape: (3, 50, 6, 6)
# after_C5 shape: (3, 64, 4, 4)
# after_F6 shape: (3, 1000)
# after_F7 shape: (3, 300)
# after_F8 shape: (3, 10)
# after_S9 shape: (3, 10)

# %%
updates = []

lrate = theano.tensor.scalar('lrate',dtype='float32')
momentum = theano.tensor.scalar('momentum',dtype='float32')
gradients = theano.grad(cost, parameters)
velocities = [theano.shared(np.zeros_like(p.get_value()), name='V_%s' %(p.name, )) for p in parameters]

for p,g,v in zip(parameters, gradients, velocities):
    v_new = momentum * v - lrate * g
    p_new = p + v_new
    updates += [(v,v_new), (p, p_new)]

# %%
train_step = theano.function(
    [X, Y, lrate, momentum],
    [cost, error_rate, nll, weight_decay],
    updates=updates
)

predict = theano.function(
    [X], 
    predictions
)

# %%
def compute_error_rate(stream):
    errs = 0.0
    num_samples = 0.0
    for X, Y in stream.get_epoch_iterator():
        errs += (predict(X)!=Y.ravel()).sum()
        num_samples += Y.shape[0]
    return errs/num_samples

def init_parameters():
    rng = np.random.RandomState(1234)
    for p in parameters:
        p.set_value(p.tag.initializer.generate(rng, p.get_value().shape))

def snapshot_parameters():
    return [p.get_value(borrow=False) for p in parameters]

def load_parameters(snapshot):
    for p, s in zip(parameters, snapshot):
        p.set_value(s, borrow=False)

# %%
i=0
e=0

init_parameters()
for v in velocities:
    v.set_value(np.zeros_like(v.get_value()))

best_valid_error_rate = np.inf
best_params = snapshot_parameters()
best_params_epoch = 0

train_erros = []
train_loss = []
train_nll = []
validation_errors = []

number_of_epochs = 3
patience_expansion = 1.5

while e<number_of_epochs:
    e += 1
    epoch_start_i = i
    
    for X_batch, Y_batch in cifar10_train_stream.get_epoch_iterator(): 
        i += 1
        
        K = 4000
        lrate = 5e-3 * K / np.maximum(K, i)
        momentum=0.9
        
        L, err_rate, nll, wdec = train_step(X_batch, Y_batch, lrate, momentum)
        
        train_loss.append((i,L))
        train_erros.append((i,err_rate))
        train_nll.append((i,nll))
        
        if i % 100 == 0:
            print "At minibatch %d, batch loss %f, batch nll %f, batch error rate %f%%" % (i, L, nll, err_rate*100)
        
    
    val_error_rate = compute_error_rate(cifar10_valid_stream)
    if val_error_rate < best_valid_error_rate:
        number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
        best_valid_error_rate = val_error_rate
        best_params = snapshot_parameters()
        best_params_epoch = e
        
    validation_errors.append((i,val_error_rate))
    print "After epoch %d: valid_err_rate: %f%% currently going to do %d epochs" %(
        e, val_error_rate*100, number_of_epochs)
    
    print "After epoch %d: averaged train_err_rate: %f%% averaged train nll: %f averaged train loss: %f" %(
        e, 
        np.mean(np.asarray(train_erros)[epoch_start_i:,1])*100, 
        np.mean(np.asarray(train_nll)[epoch_start_i:,1]),
        np.mean(np.asarray(train_loss)[epoch_start_i:,1])
    )
# Out:
# At minibatch 100, batch loss 11.790413, batch nll 1.951650, batch error rate 68.000000%
# At minibatch 200, batch loss 10.902366, batch nll 1.624198, batch error rate 60.000000%
# At minibatch 300, batch loss 10.186733, batch nll 1.437143, batch error rate 52.000000%
# At minibatch 400, batch loss 9.781893, batch nll 1.531207, batch error rate 53.000000%
# After epoch 1: valid_err_rate: 49.910000% currently going to do 3 epochs
# After epoch 1: averaged train_err_rate: 61.397500% averaged train nll: 1.686746 averaged train loss: 10.982826
# At minibatch 500, batch loss 9.284522, batch nll 1.504026, batch error rate 53.000000%
# At minibatch 600, batch loss 8.637237, batch nll 1.298344, batch error rate 43.000000%
# At minibatch 700, batch loss 8.248223, batch nll 1.325273, batch error rate 44.000000%
# At minibatch 800, batch loss 7.977102, batch nll 1.445444, batch error rate 46.000000%
# After epoch 2: valid_err_rate: 47.520000% currently going to do 4 epochs
# After epoch 2: averaged train_err_rate: 46.640000% averaged train nll: 1.308454 averaged train loss: 8.662630
# At minibatch 900, batch loss 7.325785, batch nll 1.160339, batch error rate 36.000000%
# At minibatch 1000, batch loss 6.924829, batch nll 1.104715, batch error rate 37.000000%
# At minibatch 1100, batch loss 6.534805, batch nll 1.040560, batch error rate 33.000000%
# At minibatch 1200, batch loss 6.287887, batch nll 1.099425, batch error rate 39.000000%
# After epoch 3: valid_err_rate: 39.250000% currently going to do 5 epochs
# After epoch 3: averaged train_err_rate: 41.447500% averaged train nll: 1.167134 averaged train loss: 6.998669
# At minibatch 1300, batch loss 5.866169, batch nll 0.963297, batch error rate 31.000000%
# At minibatch 1400, batch loss 5.640871, batch nll 1.008260, batch error rate 36.000000%
# At minibatch 1500, batch loss 5.346400, batch nll 0.968651, batch error rate 36.000000%
# At minibatch 1600, batch loss 5.102915, batch nll 0.965278, batch error rate 39.000000%
# After epoch 4: valid_err_rate: 36.670000% currently going to do 7 epochs
# After epoch 4: averaged train_err_rate: 37.712500% averaged train nll: 1.070095 averaged train loss: 5.711475
# At minibatch 1700, batch loss 4.857420, batch nll 0.942279, batch error rate 36.000000%
# At minibatch 1800, batch loss 4.694302, batch nll 0.991344, batch error rate 36.000000%
# At minibatch 1900, batch loss 4.423740, batch nll 0.919335, batch error rate 36.000000%
# At minibatch 2000, batch loss 4.123215, batch nll 0.805802, batch error rate 36.000000%
# After epoch 5: valid_err_rate: 34.990000% currently going to do 8 epochs
# After epoch 5: averaged train_err_rate: 35.647500% averaged train nll: 1.010304 averaged train loss: 4.720762
# At minibatch 2100, batch loss 4.273570, batch nll 1.132076, batch error rate 41.000000%
# At minibatch 2200, batch loss 4.024004, batch nll 1.048211, batch error rate 36.000000%
# At minibatch 2300, batch loss 3.809738, batch nll 0.988925, batch error rate 38.000000%
# At minibatch 2400, batch loss 3.742694, batch nll 1.069068, batch error rate 39.000000%
# After epoch 6: valid_err_rate: 33.000000% currently going to do 10 epochs
# After epoch 6: averaged train_err_rate: 33.047500% averaged train nll: 0.943536 averaged train loss: 3.925319
# At minibatch 2500, batch loss 3.388044, batch nll 0.851537, batch error rate 30.000000%
# At minibatch 2600, batch loss 3.297933, batch nll 0.889800, batch error rate 36.000000%
# At minibatch 2700, batch loss 2.983002, batch nll 0.698409, batch error rate 20.000000%
# At minibatch 2800, batch loss 3.100245, batch nll 0.929959, batch error rate 35.000000%
# After epoch 7: valid_err_rate: 33.720000% currently going to do 10 epochs
# After epoch 7: averaged train_err_rate: 31.627500% averaged train nll: 0.900820 averaged train loss: 3.312310
# At minibatch 2900, batch loss 3.057747, batch nll 0.994042, batch error rate 36.000000%
# At minibatch 3000, batch loss 3.122980, batch nll 1.160544, batch error rate 38.000000%
# At minibatch 3100, batch loss 2.730164, batch nll 0.863657, batch error rate 27.000000%
# At minibatch 3200, batch loss 2.815161, batch nll 1.039365, batch error rate 35.000000%
# After epoch 8: valid_err_rate: 34.060000% currently going to do 10 epochs
# After epoch 8: averaged train_err_rate: 30.240000% averaged train nll: 0.867364 averaged train loss: 2.832699
# At minibatch 3300, batch loss 2.693332, batch nll 1.001108, batch error rate 32.000000%
# At minibatch 3400, batch loss 2.522984, batch nll 0.910191, batch error rate 31.000000%
# At minibatch 3500, batch loss 2.318341, batch nll 0.780559, batch error rate 25.000000%
# At minibatch 3600, batch loss 2.171677, batch nll 0.703482, batch error rate 22.000000%
# After epoch 9: valid_err_rate: 31.740000% currently going to do 14 epochs
# After epoch 9: averaged train_err_rate: 29.180000% averaged train nll: 0.835905 averaged train loss: 2.451244
# At minibatch 3700, batch loss 2.037607, batch nll 0.635209, batch error rate 19.000000%
# At minibatch 3800, batch loss 2.144351, batch nll 0.803537, batch error rate 31.000000%
# At minibatch 3900, batch loss 2.026839, batch nll 0.744692, batch error rate 27.000000%
# At minibatch 4000, batch loss 1.989575, batch nll 0.763074, batch error rate 25.000000%
# After epoch 10: valid_err_rate: 29.770000% currently going to do 16 epochs
# After epoch 10: averaged train_err_rate: 28.267500% averaged train nll: 0.812594 averaged train loss: 2.155293
# At minibatch 4100, batch loss 2.050672, batch nll 0.874566, batch error rate 29.000000%
# At minibatch 4200, batch loss 1.862098, batch nll 0.732613, batch error rate 24.000000%
# At minibatch 4300, batch loss 1.658021, batch nll 0.570768, batch error rate 20.000000%
# At minibatch 4400, batch loss 1.839132, batch nll 0.793265, batch error rate 27.000000%
# After epoch 11: valid_err_rate: 30.660000% currently going to do 16 epochs
# After epoch 11: averaged train_err_rate: 27.280000% averaged train nll: 0.784793 averaged train loss: 1.916360
# At minibatch 4500, batch loss 1.753922, batch nll 0.742738, batch error rate 27.000000%
# At minibatch 4600, batch loss 1.716053, batch nll 0.737847, batch error rate 27.000000%
# At minibatch 4700, batch loss 1.647936, batch nll 0.702538, batch error rate 24.000000%
# At minibatch 4800, batch loss 1.805483, batch nll 0.889563, batch error rate 29.000000%
# After epoch 12: valid_err_rate: 30.710000% currently going to do 16 epochs
# After epoch 12: averaged train_err_rate: 26.762500% averaged train nll: 0.767644 averaged train loss: 1.746018
# At minibatch 4900, batch loss 1.626228, batch nll 0.735983, batch error rate 21.000000%
# At minibatch 5000, batch loss 1.480211, batch nll 0.615102, batch error rate 21.000000%
# At minibatch 5100, batch loss 1.512804, batch nll 0.672286, batch error rate 26.000000%
# At minibatch 5200, batch loss 1.403090, batch nll 0.584573, batch error rate 23.000000%
# After epoch 13: valid_err_rate: 28.360000% currently going to do 20 epochs
# After epoch 13: averaged train_err_rate: 25.812500% averaged train nll: 0.741522 averaged train loss: 1.606946
# At minibatch 5300, batch loss 1.553075, batch nll 0.753107, batch error rate 27.000000%
# At minibatch 5400, batch loss 1.349576, batch nll 0.568656, batch error rate 23.000000%
# At minibatch 5500, batch loss 1.570356, batch nll 0.807807, batch error rate 23.000000%
# At minibatch 5600, batch loss 1.445772, batch nll 0.700988, batch error rate 26.000000%
# After epoch 14: valid_err_rate: 27.070000% currently going to do 22 epochs
# After epoch 14: averaged train_err_rate: 24.685000% averaged train nll: 0.713834 averaged train loss: 1.494829
# At minibatch 5700, batch loss 1.472388, batch nll 0.742055, batch error rate 28.000000%
# At minibatch 5800, batch loss 1.480853, batch nll 0.765717, batch error rate 29.000000%
# At minibatch 5900, batch loss 1.389162, batch nll 0.688768, batch error rate 23.000000%
# At minibatch 6000, batch loss 1.375198, batch nll 0.687757, batch error rate 26.000000%
# After epoch 15: valid_err_rate: 28.000000% currently going to do 22 epochs
# After epoch 15: averaged train_err_rate: 23.992500% averaged train nll: 0.696503 averaged train loss: 1.411926
# At minibatch 6100, batch loss 1.209150, batch nll 0.533565, batch error rate 14.000000%
# At minibatch 6200, batch loss 1.257437, batch nll 0.593009, batch error rate 22.000000%
# At minibatch 6300, batch loss 1.270697, batch nll 0.617730, batch error rate 22.000000%
# At minibatch 6400, batch loss 1.356424, batch nll 0.713828, batch error rate 28.000000%
# After epoch 16: valid_err_rate: 28.950000% currently going to do 22 epochs
# After epoch 16: averaged train_err_rate: 23.745000% averaged train nll: 0.685898 averaged train loss: 1.350228
# At minibatch 6500, batch loss 1.265528, batch nll 0.632188, batch error rate 19.000000%
# At minibatch 6600, batch loss 1.311707, batch nll 0.687218, batch error rate 24.000000%
# At minibatch 6700, batch loss 1.220419, batch nll 0.604749, batch error rate 18.000000%
# At minibatch 6800, batch loss 1.349012, batch nll 0.742236, batch error rate 23.000000%
# After epoch 17: valid_err_rate: 26.340000% currently going to do 26 epochs
# After epoch 17: averaged train_err_rate: 22.920000% averaged train nll: 0.664567 averaged train loss: 1.289150
# At minibatch 6900, batch loss 1.340290, batch nll 0.739961, batch error rate 24.000000%
# At minibatch 7000, batch loss 1.258744, batch nll 0.665968, batch error rate 23.000000%
# At minibatch 7100, batch loss 1.217408, batch nll 0.632273, batch error rate 20.000000%
# At minibatch 7200, batch loss 1.272768, batch nll 0.694963, batch error rate 25.000000%
# After epoch 18: valid_err_rate: 26.850000% currently going to do 26 epochs
# After epoch 18: averaged train_err_rate: 22.522500% averaged train nll: 0.653680 averaged train loss: 1.246173
# At minibatch 7300, batch loss 1.156844, batch nll 0.584485, batch error rate 24.000000%
# At minibatch 7400, batch loss 1.316369, batch nll 0.749944, batch error rate 23.000000%
# At minibatch 7500, batch loss 1.299947, batch nll 0.739341, batch error rate 26.000000%
# At minibatch 7600, batch loss 1.203561, batch nll 0.649102, batch error rate 24.000000%
# After epoch 19: valid_err_rate: 27.200000% currently going to do 26 epochs
# After epoch 19: averaged train_err_rate: 22.205000% averaged train nll: 0.643226 averaged train loss: 1.209605
# At minibatch 7700, batch loss 1.132041, batch nll 0.581785, batch error rate 22.000000%
# At minibatch 7800, batch loss 1.149464, batch nll 0.603899, batch error rate 21.000000%
# At minibatch 7900, batch loss 1.284492, batch nll 0.743931, batch error rate 25.000000%
# At minibatch 8000, batch loss 1.112140, batch nll 0.576149, batch error rate 21.000000%
# After epoch 20: valid_err_rate: 26.240000% currently going to do 31 epochs
# After epoch 20: averaged train_err_rate: 21.547500% averaged train nll: 0.628289 averaged train loss: 1.173745
# At minibatch 8100, batch loss 1.040941, batch nll 0.508133, batch error rate 20.000000%
# At minibatch 8200, batch loss 1.137497, batch nll 0.608520, batch error rate 22.000000%
# At minibatch 8300, batch loss 1.037364, batch nll 0.512697, batch error rate 14.000000%
# At minibatch 8400, batch loss 1.071488, batch nll 0.551320, batch error rate 17.000000%
# After epoch 21: valid_err_rate: 26.270000% currently going to do 31 epochs
# After epoch 21: averaged train_err_rate: 21.410000% averaged train nll: 0.618245 averaged train loss: 1.146827
# At minibatch 8500, batch loss 1.022070, batch nll 0.505136, batch error rate 18.000000%
# At minibatch 8600, batch loss 1.253918, batch nll 0.739676, batch error rate 27.000000%
# At minibatch 8700, batch loss 0.981209, batch nll 0.469702, batch error rate 14.000000%
# At minibatch 8800, batch loss 1.138561, batch nll 0.631128, batch error rate 22.000000%
# After epoch 22: valid_err_rate: 26.730000% currently going to do 31 epochs
# After epoch 22: averaged train_err_rate: 20.837500% averaged train nll: 0.608510 averaged train loss: 1.122625
# At minibatch 8900, batch loss 1.083114, batch nll 0.577566, batch error rate 22.000000%
# At minibatch 9000, batch loss 1.028246, batch nll 0.525301, batch error rate 16.000000%
# At minibatch 9100, batch loss 1.108349, batch nll 0.608087, batch error rate 19.000000%
# At minibatch 9200, batch loss 1.109711, batch nll 0.612834, batch error rate 21.000000%
# After epoch 23: valid_err_rate: 25.790000% currently going to do 35 epochs
# After epoch 23: averaged train_err_rate: 20.697500% averaged train nll: 0.601463 averaged train loss: 1.104200
# At minibatch 9300, batch loss 0.925736, batch nll 0.430862, batch error rate 13.000000%
# At minibatch 9400, batch loss 1.086936, batch nll 0.593870, batch error rate 18.000000%
# At minibatch 9500, batch loss 1.302213, batch nll 0.811404, batch error rate 24.000000%
# At minibatch 9600, batch loss 1.105094, batch nll 0.617131, batch error rate 25.000000%
# After epoch 24: valid_err_rate: 25.480000% currently going to do 37 epochs
# After epoch 24: averaged train_err_rate: 20.092500% averaged train nll: 0.589167 averaged train loss: 1.082016
# At minibatch 9700, batch loss 1.061485, batch nll 0.574242, batch error rate 24.000000%
# At minibatch 9800, batch loss 1.030170, batch nll 0.546154, batch error rate 20.000000%
# At minibatch 9900, batch loss 1.145571, batch nll 0.663180, batch error rate 23.000000%
# At minibatch 10000, batch loss 1.110802, batch nll 0.630198, batch error rate 24.000000%
# After epoch 25: valid_err_rate: 25.780000% currently going to do 37 epochs
# After epoch 25: averaged train_err_rate: 19.795000% averaged train nll: 0.577790 averaged train loss: 1.062394
# At minibatch 10100, batch loss 0.951079, batch nll 0.471524, batch error rate 15.000000%
# At minibatch 10200, batch loss 1.180574, batch nll 0.703013, batch error rate 26.000000%
# At minibatch 10300, batch loss 0.891746, batch nll 0.416107, batch error rate 16.000000%
# At minibatch 10400, batch loss 1.075922, batch nll 0.602395, batch error rate 24.000000%
# After epoch 26: valid_err_rate: 26.090000% currently going to do 37 epochs
# After epoch 26: averaged train_err_rate: 19.587500% averaged train nll: 0.570166 averaged train loss: 1.047629
# At minibatch 10500, batch loss 1.057648, batch nll 0.584687, batch error rate 18.000000%
# At minibatch 10600, batch loss 0.940288, batch nll 0.468712, batch error rate 20.000000%
# At minibatch 10700, batch loss 1.006216, batch nll 0.536359, batch error rate 17.000000%
# At minibatch 10800, batch loss 0.988075, batch nll 0.519186, batch error rate 20.000000%
# After epoch 27: valid_err_rate: 27.610000% currently going to do 37 epochs
# After epoch 27: averaged train_err_rate: 19.352500% averaged train nll: 0.566284 averaged train loss: 1.037653
# At minibatch 10900, batch loss 0.920982, batch nll 0.452842, batch error rate 12.000000%
# At minibatch 11000, batch loss 1.038393, batch nll 0.571604, batch error rate 24.000000%
# At minibatch 11100, batch loss 1.026189, batch nll 0.560501, batch error rate 20.000000%
# At minibatch 11200, batch loss 1.085867, batch nll 0.621409, batch error rate 20.000000%
# After epoch 28: valid_err_rate: 25.660000% currently going to do 37 epochs
# After epoch 28: averaged train_err_rate: 18.992500% averaged train nll: 0.556010 averaged train loss: 1.022832
# At minibatch 11300, batch loss 1.010127, batch nll 0.546245, batch error rate 18.000000%
# At minibatch 11400, batch loss 0.947715, batch nll 0.485031, batch error rate 14.000000%
# At minibatch 11500, batch loss 1.091849, batch nll 0.629624, batch error rate 25.000000%
# At minibatch 11600, batch loss 1.079180, batch nll 0.618306, batch error rate 24.000000%
# After epoch 29: valid_err_rate: 25.710000% currently going to do 37 epochs
# After epoch 29: averaged train_err_rate: 18.810000% averaged train nll: 0.552980 averaged train loss: 1.015833
# At minibatch 11700, batch loss 0.933037, batch nll 0.472427, batch error rate 16.000000%
# At minibatch 11800, batch loss 0.997392, batch nll 0.537477, batch error rate 20.000000%
# At minibatch 11900, batch loss 1.044510, batch nll 0.585822, batch error rate 21.000000%
# At minibatch 12000, batch loss 1.014402, batch nll 0.556427, batch error rate 17.000000%
# After epoch 30: valid_err_rate: 25.400000% currently going to do 46 epochs
# After epoch 30: averaged train_err_rate: 18.542500% averaged train nll: 0.541978 averaged train loss: 1.001641
# At minibatch 12100, batch loss 0.899721, batch nll 0.441884, batch error rate 16.000000%
# At minibatch 12200, batch loss 0.997025, batch nll 0.539769, batch error rate 16.000000%
# At minibatch 12300, batch loss 0.845034, batch nll 0.388756, batch error rate 12.000000%
# At minibatch 12400, batch loss 1.020544, batch nll 0.565589, batch error rate 22.000000%
# After epoch 31: valid_err_rate: 25.460000% currently going to do 46 epochs
# After epoch 31: averaged train_err_rate: 18.315000% averaged train nll: 0.537988 averaged train loss: 0.994961
# At minibatch 12500, batch loss 1.009764, batch nll 0.554249, batch error rate 21.000000%
# At minibatch 12600, batch loss 0.919474, batch nll 0.464392, batch error rate 18.000000%
# At minibatch 12700, batch loss 1.182039, batch nll 0.728082, batch error rate 26.000000%
# At minibatch 12800, batch loss 1.073910, batch nll 0.620856, batch error rate 17.000000%
# After epoch 32: valid_err_rate: 24.890000% currently going to do 49 epochs
# After epoch 32: averaged train_err_rate: 17.830000% averaged train nll: 0.530367 averaged train loss: 0.985001
# At minibatch 12900, batch loss 1.015655, batch nll 0.562884, batch error rate 20.000000%
# At minibatch 13000, batch loss 1.079364, batch nll 0.626974, batch error rate 18.000000%
# At minibatch 13100, batch loss 0.982324, batch nll 0.530324, batch error rate 17.000000%
# At minibatch 13200, batch loss 0.942620, batch nll 0.491080, batch error rate 18.000000%
# After epoch 33: valid_err_rate: 26.630000% currently going to do 49 epochs
# After epoch 33: averaged train_err_rate: 17.575000% averaged train nll: 0.524088 averaged train loss: 0.976461
# At minibatch 13300, batch loss 0.819960, batch nll 0.368613, batch error rate 14.000000%
# At minibatch 13400, batch loss 1.042152, batch nll 0.591283, batch error rate 20.000000%
# At minibatch 13500, batch loss 0.961369, batch nll 0.510729, batch error rate 19.000000%
# At minibatch 13600, batch loss 1.005374, batch nll 0.555214, batch error rate 20.000000%
# After epoch 34: valid_err_rate: 24.760000% currently going to do 52 epochs
# After epoch 34: averaged train_err_rate: 17.782500% averaged train nll: 0.518799 averaged train loss: 0.969745
# At minibatch 13700, batch loss 1.002026, batch nll 0.551588, batch error rate 20.000000%
# At minibatch 13800, batch loss 0.894705, batch nll 0.444468, batch error rate 16.000000%
# At minibatch 13900, batch loss 0.928384, batch nll 0.478623, batch error rate 19.000000%
# At minibatch 14000, batch loss 0.957739, batch nll 0.508799, batch error rate 19.000000%
# After epoch 35: valid_err_rate: 25.010000% currently going to do 52 epochs
# After epoch 35: averaged train_err_rate: 17.195000% averaged train nll: 0.509276 averaged train loss: 0.959284
# At minibatch 14100, batch loss 0.941145, batch nll 0.491965, batch error rate 14.000000%
# At minibatch 14200, batch loss 0.943822, batch nll 0.494876, batch error rate 18.000000%
# At minibatch 14300, batch loss 0.883231, batch nll 0.434513, batch error rate 13.000000%
# At minibatch 14400, batch loss 0.936891, batch nll 0.488916, batch error rate 14.000000%
# After epoch 36: valid_err_rate: 24.960000% currently going to do 52 epochs
# After epoch 36: averaged train_err_rate: 17.130000% averaged train nll: 0.503509 averaged train loss: 0.952346
# At minibatch 14500, batch loss 0.852961, batch nll 0.404874, batch error rate 16.000000%
# At minibatch 14600, batch loss 1.064979, batch nll 0.617020, batch error rate 22.000000%
# At minibatch 14700, batch loss 0.995889, batch nll 0.548257, batch error rate 19.000000%
# At minibatch 14800, batch loss 0.925680, batch nll 0.478421, batch error rate 16.000000%
# After epoch 37: valid_err_rate: 25.340000% currently going to do 52 epochs
# After epoch 37: averaged train_err_rate: 16.852500% averaged train nll: 0.500224 averaged train loss: 0.948014
# At minibatch 14900, batch loss 0.859728, batch nll 0.411979, batch error rate 10.000000%
# At minibatch 15000, batch loss 0.963421, batch nll 0.515518, batch error rate 21.000000%
# At minibatch 15100, batch loss 0.988117, batch nll 0.540838, batch error rate 19.000000%
# At minibatch 15200, batch loss 0.964886, batch nll 0.518110, batch error rate 21.000000%
# After epoch 38: valid_err_rate: 24.920000% currently going to do 52 epochs
# After epoch 38: averaged train_err_rate: 16.765000% averaged train nll: 0.494735 averaged train loss: 0.942187
# At minibatch 15300, batch loss 1.020281, batch nll 0.573032, batch error rate 14.000000%
# At minibatch 15400, batch loss 0.931912, batch nll 0.484852, batch error rate 15.000000%
# At minibatch 15500, batch loss 0.970136, batch nll 0.523365, batch error rate 16.000000%
# At minibatch 15600, batch loss 0.983781, batch nll 0.537238, batch error rate 17.000000%
# After epoch 39: valid_err_rate: 24.650000% currently going to do 59 epochs
# After epoch 39: averaged train_err_rate: 16.477500% averaged train nll: 0.488730 averaged train loss: 0.935685
# At minibatch 15700, batch loss 1.020491, batch nll 0.573713, batch error rate 21.000000%
# At minibatch 15800, batch loss 0.853014, batch nll 0.406348, batch error rate 14.000000%
# At minibatch 15900, batch loss 0.846243, batch nll 0.399950, batch error rate 13.000000%
# At minibatch 16000, batch loss 0.952644, batch nll 0.506385, batch error rate 17.000000%
# After epoch 40: valid_err_rate: 24.830000% currently going to do 59 epochs
# After epoch 40: averaged train_err_rate: 16.430000% averaged train nll: 0.486649 averaged train loss: 0.933186
# At minibatch 16100, batch loss 0.879351, batch nll 0.433112, batch error rate 13.000000%
# At minibatch 16200, batch loss 1.015783, batch nll 0.569409, batch error rate 18.000000%
# At minibatch 16300, batch loss 0.937660, batch nll 0.491499, batch error rate 17.000000%
# At minibatch 16400, batch loss 0.919596, batch nll 0.473423, batch error rate 15.000000%
# After epoch 41: valid_err_rate: 24.800000% currently going to do 59 epochs
# After epoch 41: averaged train_err_rate: 16.120000% averaged train nll: 0.480719 averaged train loss: 0.927007
# At minibatch 16500, batch loss 0.957732, batch nll 0.511187, batch error rate 19.000000%
# At minibatch 16600, batch loss 0.806230, batch nll 0.359541, batch error rate 11.000000%
# At minibatch 16700, batch loss 1.010607, batch nll 0.563972, batch error rate 19.000000%
# At minibatch 16800, batch loss 0.896754, batch nll 0.450420, batch error rate 16.000000%
# After epoch 42: valid_err_rate: 24.400000% currently going to do 64 epochs
# After epoch 42: averaged train_err_rate: 15.922500% averaged train nll: 0.474876 averaged train loss: 0.921406
# At minibatch 16900, batch loss 0.978332, batch nll 0.531776, batch error rate 19.000000%
# At minibatch 17000, batch loss 0.901526, batch nll 0.454888, batch error rate 18.000000%
# At minibatch 17100, batch loss 0.843292, batch nll 0.396935, batch error rate 11.000000%
# At minibatch 17200, batch loss 0.936666, batch nll 0.490449, batch error rate 18.000000%
# After epoch 43: valid_err_rate: 24.560000% currently going to do 64 epochs
# After epoch 43: averaged train_err_rate: 15.792500% averaged train nll: 0.470849 averaged train loss: 0.917335
# At minibatch 17300, batch loss 0.911766, batch nll 0.465062, batch error rate 14.000000%
# At minibatch 17400, batch loss 0.890102, batch nll 0.443219, batch error rate 16.000000%
# At minibatch 17500, batch loss 0.966560, batch nll 0.520060, batch error rate 21.000000%
# At minibatch 17600, batch loss 0.878617, batch nll 0.432120, batch error rate 15.000000%
# After epoch 44: valid_err_rate: 25.120000% currently going to do 64 epochs
# After epoch 44: averaged train_err_rate: 15.627500% averaged train nll: 0.466516 averaged train loss: 0.913135
# At minibatch 17700, batch loss 0.846839, batch nll 0.399930, batch error rate 14.000000%
# At minibatch 17800, batch loss 0.970047, batch nll 0.523164, batch error rate 17.000000%
# At minibatch 17900, batch loss 1.038691, batch nll 0.592061, batch error rate 21.000000%
# At minibatch 18000, batch loss 1.003278, batch nll 0.556510, batch error rate 21.000000%
# After epoch 45: valid_err_rate: 24.520000% currently going to do 64 epochs
# After epoch 45: averaged train_err_rate: 15.532500% averaged train nll: 0.460208 averaged train loss: 0.906934
# At minibatch 18100, batch loss 0.900583, batch nll 0.453409, batch error rate 16.000000%
# At minibatch 18200, batch loss 0.920303, batch nll 0.472985, batch error rate 20.000000%
# At minibatch 18300, batch loss 0.942297, batch nll 0.494623, batch error rate 16.000000%
# At minibatch 18400, batch loss 0.936889, batch nll 0.489605, batch error rate 15.000000%
# After epoch 46: valid_err_rate: 24.520000% currently going to do 64 epochs
# After epoch 46: averaged train_err_rate: 15.317500% averaged train nll: 0.456605 averaged train loss: 0.903953
# At minibatch 18500, batch loss 0.848350, batch nll 0.400757, batch error rate 13.000000%
# At minibatch 18600, batch loss 0.874367, batch nll 0.426727, batch error rate 17.000000%
# At minibatch 18700, batch loss 0.962628, batch nll 0.514892, batch error rate 20.000000%
# At minibatch 18800, batch loss 0.927057, batch nll 0.479615, batch error rate 20.000000%
# After epoch 47: valid_err_rate: 24.510000% currently going to do 64 epochs
# After epoch 47: averaged train_err_rate: 15.247500% averaged train nll: 0.454189 averaged train loss: 0.901786
# At minibatch 18900, batch loss 0.900175, batch nll 0.452365, batch error rate 15.000000%
# At minibatch 19000, batch loss 0.962508, batch nll 0.514564, batch error rate 19.000000%
# At minibatch 19100, batch loss 0.902955, batch nll 0.454687, batch error rate 14.000000%
# At minibatch 19200, batch loss 0.845203, batch nll 0.397213, batch error rate 15.000000%
# After epoch 48: valid_err_rate: 25.050000% currently going to do 64 epochs
# After epoch 48: averaged train_err_rate: 15.125000% averaged train nll: 0.452157 averaged train loss: 0.900071
# At minibatch 19300, batch loss 0.889763, batch nll 0.441160, batch error rate 16.000000%
# At minibatch 19400, batch loss 1.005347, batch nll 0.556756, batch error rate 23.000000%
# At minibatch 19500, batch loss 0.901827, batch nll 0.453234, batch error rate 17.000000%
# At minibatch 19600, batch loss 0.959978, batch nll 0.511562, batch error rate 17.000000%
# After epoch 49: valid_err_rate: 24.890000% currently going to do 64 epochs
# After epoch 49: averaged train_err_rate: 14.920000% averaged train nll: 0.447214 averaged train loss: 0.895745
# At minibatch 19700, batch loss 0.954242, batch nll 0.505459, batch error rate 22.000000%
# At minibatch 19800, batch loss 0.928564, batch nll 0.479485, batch error rate 15.000000%
# At minibatch 19900, batch loss 0.937420, batch nll 0.488244, batch error rate 19.000000%
# At minibatch 20000, batch loss 0.892638, batch nll 0.443658, batch error rate 11.000000%
# After epoch 50: valid_err_rate: 24.870000% currently going to do 64 epochs
# After epoch 50: averaged train_err_rate: 14.685000% averaged train nll: 0.443094 averaged train loss: 0.891999
# At minibatch 20100, batch loss 0.989145, batch nll 0.539760, batch error rate 20.000000%
# At minibatch 20200, batch loss 0.878646, batch nll 0.429038, batch error rate 15.000000%
# At minibatch 20300, batch loss 0.825395, batch nll 0.375675, batch error rate 8.000000%
# At minibatch 20400, batch loss 0.865046, batch nll 0.415485, batch error rate 12.000000%
# After epoch 51: valid_err_rate: 24.480000% currently going to do 64 epochs
# After epoch 51: averaged train_err_rate: 14.805000% averaged train nll: 0.442408 averaged train loss: 0.891950
# At minibatch 20500, batch loss 0.907854, batch nll 0.457748, batch error rate 18.000000%
# At minibatch 20600, batch loss 0.940761, batch nll 0.490472, batch error rate 16.000000%
# At minibatch 20700, batch loss 0.788203, batch nll 0.337966, batch error rate 12.000000%
# At minibatch 20800, batch loss 0.932968, batch nll 0.482900, batch error rate 16.000000%
# After epoch 52: valid_err_rate: 23.970000% currently going to do 79 epochs
# After epoch 52: averaged train_err_rate: 14.522500% averaged train nll: 0.436050 averaged train loss: 0.886212
# At minibatch 20900, batch loss 0.899014, batch nll 0.448550, batch error rate 15.000000%
# At minibatch 21000, batch loss 0.895870, batch nll 0.444964, batch error rate 14.000000%
# At minibatch 21100, batch loss 0.871112, batch nll 0.420206, batch error rate 14.000000%
# At minibatch 21200, batch loss 0.788244, batch nll 0.337531, batch error rate 11.000000%
# After epoch 53: valid_err_rate: 24.200000% currently going to do 79 epochs
# After epoch 53: averaged train_err_rate: 14.347500% averaged train nll: 0.434490 averaged train loss: 0.885160
# At minibatch 21300, batch loss 0.912168, batch nll 0.461076, batch error rate 17.000000%
# At minibatch 21400, batch loss 0.945391, batch nll 0.494483, batch error rate 19.000000%
# At minibatch 21500, batch loss 0.886329, batch nll 0.435191, batch error rate 16.000000%
# At minibatch 21600, batch loss 0.944128, batch nll 0.492676, batch error rate 18.000000%
# After epoch 54: valid_err_rate: 24.710000% currently going to do 79 epochs
# After epoch 54: averaged train_err_rate: 14.165000% averaged train nll: 0.430200 averaged train loss: 0.881285
# At minibatch 21700, batch loss 0.879361, batch nll 0.427608, batch error rate 13.000000%
# At minibatch 21800, batch loss 0.823150, batch nll 0.371264, batch error rate 11.000000%
# At minibatch 21900, batch loss 0.891405, batch nll 0.439470, batch error rate 15.000000%
# At minibatch 22000, batch loss 0.914368, batch nll 0.462267, batch error rate 17.000000%
# After epoch 55: valid_err_rate: 24.420000% currently going to do 79 epochs
# After epoch 55: averaged train_err_rate: 13.972500% averaged train nll: 0.424705 averaged train loss: 0.876581
# At minibatch 22100, batch loss 0.861054, batch nll 0.408566, batch error rate 10.000000%
# At minibatch 22200, batch loss 0.937732, batch nll 0.485342, batch error rate 17.000000%
# At minibatch 22300, batch loss 0.813496, batch nll 0.360976, batch error rate 13.000000%
# At minibatch 22400, batch loss 0.842527, batch nll 0.389699, batch error rate 12.000000%
# After epoch 56: valid_err_rate: 24.720000% currently going to do 79 epochs
# After epoch 56: averaged train_err_rate: 13.935000% averaged train nll: 0.421588 averaged train loss: 0.874110
# At minibatch 22500, batch loss 1.000157, batch nll 0.546743, batch error rate 18.000000%
# At minibatch 22600, batch loss 0.884899, batch nll 0.431331, batch error rate 16.000000%
# At minibatch 22700, batch loss 0.806120, batch nll 0.352560, batch error rate 12.000000%
# At minibatch 22800, batch loss 0.861821, batch nll 0.408319, batch error rate 15.000000%
# After epoch 57: valid_err_rate: 24.220000% currently going to do 79 epochs
# After epoch 57: averaged train_err_rate: 14.050000% averaged train nll: 0.422022 averaged train loss: 0.875439
# At minibatch 22900, batch loss 0.727571, batch nll 0.273639, batch error rate 10.000000%
# At minibatch 23000, batch loss 0.780503, batch nll 0.326204, batch error rate 8.000000%
# At minibatch 23100, batch loss 0.929324, batch nll 0.475037, batch error rate 19.000000%
# At minibatch 23200, batch loss 0.841389, batch nll 0.387271, batch error rate 12.000000%
# After epoch 58: valid_err_rate: 24.200000% currently going to do 79 epochs
# After epoch 58: averaged train_err_rate: 13.697500% averaged train nll: 0.416143 averaged train loss: 0.870266
# At minibatch 23300, batch loss 0.870067, batch nll 0.415310, batch error rate 10.000000%
# At minibatch 23400, batch loss 0.858146, batch nll 0.403283, batch error rate 9.000000%
# At minibatch 23500, batch loss 0.815247, batch nll 0.360332, batch error rate 10.000000%
# At minibatch 23600, batch loss 0.983131, batch nll 0.528143, batch error rate 23.000000%
# After epoch 59: valid_err_rate: 24.820000% currently going to do 79 epochs
# After epoch 59: averaged train_err_rate: 13.392500% averaged train nll: 0.409994 averaged train loss: 0.864753
# At minibatch 23700, batch loss 0.825787, batch nll 0.370458, batch error rate 11.000000%
# At minibatch 23800, batch loss 0.843694, batch nll 0.387945, batch error rate 15.000000%
# At minibatch 23900, batch loss 0.989105, batch nll 0.533227, batch error rate 19.000000%
# At minibatch 24000, batch loss 0.832790, batch nll 0.376997, batch error rate 13.000000%
# After epoch 60: valid_err_rate: 24.410000% currently going to do 79 epochs
# After epoch 60: averaged train_err_rate: 13.417500% averaged train nll: 0.408762 averaged train loss: 0.864373
# At minibatch 24100, batch loss 0.865602, batch nll 0.409356, batch error rate 12.000000%
# At minibatch 24200, batch loss 0.763917, batch nll 0.307490, batch error rate 11.000000%
# At minibatch 24300, batch loss 0.796315, batch nll 0.339699, batch error rate 9.000000%
# At minibatch 24400, batch loss 0.987314, batch nll 0.530678, batch error rate 18.000000%
# After epoch 61: valid_err_rate: 24.230000% currently going to do 79 epochs
# After epoch 61: averaged train_err_rate: 13.390000% averaged train nll: 0.406788 averaged train loss: 0.863165
# At minibatch 24500, batch loss 0.828409, batch nll 0.371580, batch error rate 11.000000%
# At minibatch 24600, batch loss 1.034781, batch nll 0.577451, batch error rate 20.000000%
# At minibatch 24700, batch loss 0.931216, batch nll 0.473718, batch error rate 16.000000%
# At minibatch 24800, batch loss 0.843027, batch nll 0.385553, batch error rate 15.000000%
# After epoch 62: valid_err_rate: 25.150000% currently going to do 79 epochs
# After epoch 62: averaged train_err_rate: 13.405000% averaged train nll: 0.403865 averaged train loss: 0.861057
# At minibatch 24900, batch loss 0.910351, batch nll 0.452616, batch error rate 17.000000%
# At minibatch 25000, batch loss 0.799087, batch nll 0.341284, batch error rate 12.000000%
# At minibatch 25100, batch loss 0.817367, batch nll 0.359488, batch error rate 12.000000%
# At minibatch 25200, batch loss 0.720544, batch nll 0.262398, batch error rate 6.000000%
# After epoch 63: valid_err_rate: 24.030000% currently going to do 79 epochs
# After epoch 63: averaged train_err_rate: 13.317500% averaged train nll: 0.402805 averaged train loss: 0.860626
# At minibatch 25300, batch loss 0.903683, batch nll 0.445208, batch error rate 14.000000%
# At minibatch 25400, batch loss 0.903684, batch nll 0.444787, batch error rate 16.000000%
# At minibatch 25500, batch loss 0.766300, batch nll 0.307470, batch error rate 9.000000%
# At minibatch 25600, batch loss 0.878480, batch nll 0.419619, batch error rate 14.000000%
# After epoch 64: valid_err_rate: 24.330000% currently going to do 79 epochs
# After epoch 64: averaged train_err_rate: 13.197500% averaged train nll: 0.398659 averaged train loss: 0.857341
# At minibatch 25700, batch loss 0.946116, batch nll 0.486871, batch error rate 20.000000%
# At minibatch 25800, batch loss 0.845905, batch nll 0.386521, batch error rate 14.000000%
# At minibatch 25900, batch loss 0.863433, batch nll 0.403835, batch error rate 12.000000%
# At minibatch 26000, batch loss 0.946374, batch nll 0.486564, batch error rate 17.000000%
# After epoch 65: valid_err_rate: 24.410000% currently going to do 79 epochs
# After epoch 65: averaged train_err_rate: 12.867500% averaged train nll: 0.392063 averaged train loss: 0.851460
# At minibatch 26100, batch loss 0.893031, batch nll 0.433052, batch error rate 18.000000%
# At minibatch 26200, batch loss 0.973593, batch nll 0.513428, batch error rate 15.000000%
# At minibatch 26300, batch loss 0.920553, batch nll 0.460010, batch error rate 19.000000%
# At minibatch 26400, batch loss 0.858055, batch nll 0.397372, batch error rate 14.000000%
# After epoch 66: valid_err_rate: 24.070000% currently going to do 79 epochs
# After epoch 66: averaged train_err_rate: 12.907500% averaged train nll: 0.390199 averaged train loss: 0.850439
# At minibatch 26500, batch loss 0.853629, batch nll 0.392772, batch error rate 11.000000%
# At minibatch 26600, batch loss 0.930360, batch nll 0.469303, batch error rate 14.000000%
# At minibatch 26700, batch loss 0.897125, batch nll 0.435903, batch error rate 18.000000%
# At minibatch 26800, batch loss 0.818339, batch nll 0.357034, batch error rate 12.000000%
# After epoch 67: valid_err_rate: 24.070000% currently going to do 79 epochs
# After epoch 67: averaged train_err_rate: 12.832500% averaged train nll: 0.390414 averaged train loss: 0.851457
# At minibatch 26900, batch loss 0.923978, batch nll 0.462290, batch error rate 15.000000%
# At minibatch 27000, batch loss 0.916177, batch nll 0.454500, batch error rate 13.000000%
# At minibatch 27100, batch loss 0.970190, batch nll 0.508311, batch error rate 17.000000%
# At minibatch 27200, batch loss 0.765916, batch nll 0.303967, batch error rate 9.000000%
# After epoch 68: valid_err_rate: 24.220000% currently going to do 79 epochs
# After epoch 68: averaged train_err_rate: 12.685000% averaged train nll: 0.389093 averaged train loss: 0.850828
# At minibatch 27300, batch loss 0.830939, batch nll 0.368665, batch error rate 15.000000%
# At minibatch 27400, batch loss 0.898394, batch nll 0.435810, batch error rate 15.000000%
# At minibatch 27500, batch loss 0.855277, batch nll 0.392593, batch error rate 11.000000%
# At minibatch 27600, batch loss 0.799263, batch nll 0.336509, batch error rate 13.000000%
# After epoch 69: valid_err_rate: 24.110000% currently going to do 79 epochs
# After epoch 69: averaged train_err_rate: 12.555000% averaged train nll: 0.385911 averaged train loss: 0.848399
# At minibatch 27700, batch loss 0.870080, batch nll 0.407068, batch error rate 11.000000%
# At minibatch 27800, batch loss 0.726686, batch nll 0.263425, batch error rate 6.000000%
# At minibatch 27900, batch loss 0.754063, batch nll 0.290692, batch error rate 8.000000%
# At minibatch 28000, batch loss 0.870736, batch nll 0.407268, batch error rate 12.000000%
# After epoch 70: valid_err_rate: 24.560000% currently going to do 79 epochs
# After epoch 70: averaged train_err_rate: 12.132500% averaged train nll: 0.381029 averaged train loss: 0.844224
# At minibatch 28100, batch loss 0.860842, batch nll 0.397174, batch error rate 13.000000%
# At minibatch 28200, batch loss 0.805014, batch nll 0.340983, batch error rate 10.000000%
# At minibatch 28300, batch loss 0.811123, batch nll 0.346915, batch error rate 6.000000%
# At minibatch 28400, batch loss 0.897718, batch nll 0.433381, batch error rate 11.000000%
# After epoch 71: valid_err_rate: 24.410000% currently going to do 79 epochs
# After epoch 71: averaged train_err_rate: 12.385000% averaged train nll: 0.379852 averaged train loss: 0.843842
# At minibatch 28500, batch loss 0.802610, batch nll 0.337918, batch error rate 12.000000%
# At minibatch 28600, batch loss 0.867085, batch nll 0.402121, batch error rate 15.000000%
# At minibatch 28700, batch loss 0.886830, batch nll 0.421752, batch error rate 19.000000%
# At minibatch 28800, batch loss 0.948958, batch nll 0.483810, batch error rate 18.000000%
# After epoch 72: valid_err_rate: 24.550000% currently going to do 79 epochs
# After epoch 72: averaged train_err_rate: 11.997500% averaged train nll: 0.375935 averaged train loss: 0.840814
# At minibatch 28900, batch loss 0.766705, batch nll 0.301284, batch error rate 9.000000%
# At minibatch 29000, batch loss 0.752039, batch nll 0.286390, batch error rate 5.000000%
# At minibatch 29100, batch loss 0.950191, batch nll 0.484613, batch error rate 12.000000%
# At minibatch 29200, batch loss 0.851367, batch nll 0.385742, batch error rate 9.000000%
# After epoch 73: valid_err_rate: 24.240000% currently going to do 79 epochs
# After epoch 73: averaged train_err_rate: 12.160000% averaged train nll: 0.375529 averaged train loss: 0.841032
# At minibatch 29300, batch loss 0.731148, batch nll 0.265119, batch error rate 5.000000%
# At minibatch 29400, batch loss 0.814742, batch nll 0.348484, batch error rate 13.000000%
# At minibatch 29500, batch loss 0.918775, batch nll 0.452486, batch error rate 18.000000%
# At minibatch 29600, batch loss 0.865159, batch nll 0.398610, batch error rate 14.000000%
# After epoch 74: valid_err_rate: 25.190000% currently going to do 79 epochs
# After epoch 74: averaged train_err_rate: 11.860000% averaged train nll: 0.372405 averaged train loss: 0.838562
# At minibatch 29700, batch loss 0.768862, batch nll 0.301958, batch error rate 11.000000%
# At minibatch 29800, batch loss 0.845953, batch nll 0.378951, batch error rate 11.000000%
# At minibatch 29900, batch loss 0.758471, batch nll 0.291400, batch error rate 8.000000%
# At minibatch 30000, batch loss 0.729925, batch nll 0.262649, batch error rate 5.000000%
# After epoch 75: valid_err_rate: 24.270000% currently going to do 79 epochs
# After epoch 75: averaged train_err_rate: 11.957500% averaged train nll: 0.372376 averaged train loss: 0.839346
# At minibatch 30100, batch loss 0.962110, batch nll 0.494544, batch error rate 13.000000%
# At minibatch 30200, batch loss 0.927451, batch nll 0.459609, batch error rate 17.000000%
# At minibatch 30300, batch loss 0.889947, batch nll 0.421860, batch error rate 13.000000%
# At minibatch 30400, batch loss 0.760612, batch nll 0.292502, batch error rate 11.000000%
# After epoch 76: valid_err_rate: 24.460000% currently going to do 79 epochs
# After epoch 76: averaged train_err_rate: 11.827500% averaged train nll: 0.368007 averaged train loss: 0.835809
# At minibatch 30500, batch loss 0.772244, batch nll 0.303822, batch error rate 6.000000%
# At minibatch 30600, batch loss 0.825322, batch nll 0.356755, batch error rate 12.000000%
# At minibatch 30700, batch loss 0.838298, batch nll 0.369475, batch error rate 14.000000%
# At minibatch 30800, batch loss 0.832747, batch nll 0.363800, batch error rate 10.000000%
# After epoch 77: valid_err_rate: 24.000000% currently going to do 79 epochs
# After epoch 77: averaged train_err_rate: 11.650000% averaged train nll: 0.364883 averaged train loss: 0.833473
# At minibatch 30900, batch loss 0.901409, batch nll 0.432189, batch error rate 12.000000%
# At minibatch 31000, batch loss 0.774534, batch nll 0.305037, batch error rate 8.000000%
# At minibatch 31100, batch loss 0.883990, batch nll 0.414351, batch error rate 15.000000%
# At minibatch 31200, batch loss 0.867403, batch nll 0.397764, batch error rate 13.000000%
# After epoch 78: valid_err_rate: 24.570000% currently going to do 79 epochs
# After epoch 78: averaged train_err_rate: 11.645000% averaged train nll: 0.362409 averaged train loss: 0.831800
# At minibatch 31300, batch loss 0.886425, batch nll 0.416431, batch error rate 13.000000%
# At minibatch 31400, batch loss 0.794947, batch nll 0.324882, batch error rate 8.000000%
# At minibatch 31500, batch loss 0.962488, batch nll 0.492284, batch error rate 15.000000%
# At minibatch 31600, batch loss 0.862761, batch nll 0.392376, batch error rate 11.000000%
# After epoch 79: valid_err_rate: 24.100000% currently going to do 79 epochs
# After epoch 79: averaged train_err_rate: 11.485000% averaged train nll: 0.361731 averaged train loss: 0.831808

# %%
print "Setting network parameters from after epoch %d" %(best_params_epoch)
load_parameters(best_params)

print "Success rate is %f%%" %(100.0-compute_error_rate(cifar10_testt_stream)*100.0,)
print "Error rate is %f%%" %(compute_error_rate(cifar10_testt_stream)*100.0,)

figure(figsize=(16,14))

subplot(2,1,1)
train_nll_a = np.array(train_nll)
semilogy(train_nll_a[:,0], train_nll_a[:,1], label='batch train nll')
legend()

subplot(2,1,2)
train_erros_a = np.array(train_erros)
plot(train_erros_a[:,0], train_erros_a[:,1], label='batch train error rate')
validation_errors_a = np.array(validation_errors)
plot(validation_errors_a[:,0], validation_errors_a[:,1], label='validation error rate', color='r')
ylim(0,0.8)
legend()
# Out:
# Setting network parameters from after epoch 52
# Success rate is 75.070000%
# Error rate is 24.930000%

# %%
middle_layers_computer = theano.function([X], network.model_layers)

img_num=11

middle_layers = middle_layers_computer(X_test_value[img_num:img_num+1])
print middle_layers[0].shape
print middle_layers[1].shape
print middle_layers[2].shape
print middle_layers[3].shape
print middle_layers[4].shape


plot_mat(middle_layers[0])
title(network.model_names[0])
show()

for ml, name in zip(middle_layers[1:], network.model_names[1:]):
    try:
        #print ml#.transpose(1,0,2,3).shape
        plot_mat(ml.transpose(1,0,2,3), cmap='gray')
        title(name)
        show()
    except ValueError:
        pass
# Out:
# (1, 3, 32, 32)
# (1, 10, 28, 28)
# (1, 10, 14, 14)
# (1, 25, 10, 10)
# (1, 25, 5, 5)
