# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import theano
import theano.tensor.signal.downsample
import skimage.io
from scipy.ndimage.filters import convolve

#note: this requires the starter code for the assignments!
from common.plotting import plot_mat

#theano.config.floatX = 'float32'
print theano.config.floatX
# Out:
# float32

# %%
from fuel.datasets.cifar10 import CIFAR10
from common.plotting import plot_mat

cifar10_train = CIFAR10(("train",))
cifar10_test = CIFAR10(("test",))

print "We have %d training, and %d test examples" % (
    cifar10_train.num_examples, cifar10_test.num_examples)
print "The examples are pairs of %s:" % (cifar10_train.sources,)
for i, source in enumerate(cifar10_train.sources):
    labels = cifar10_train.axis_labels[source]
    print 'The source #%d named "%s" is a %dd array with axis: %s' % (
        i, source, len(labels), labels)
    
#Note that for larger datasets that are loaded into mameory the data_sources field may not exist!
plot_mat(cifar10_train.data_sources[0][:20], cmap='gray')
print cifar10_train.data_sources[0].shape
print cifar10_test.data_sources[0].shape
print cifar10_train.data_sources[1].shape
print cifar10_test.data_sources[1].shape
# Out:
# We have 50000 training, and 10000 test examples
# The examples are pairs of (u'features', u'targets'):
# The source #0 named "features" is a 4d array with axis: (u'batch', u'channel', u'height', u'width')
# The source #1 named "targets" is a 2d array with axis: (u'batch', u'index')
# (50000, 3, 32, 32)
# (10000, 3, 32, 32)
# (50000, 1)
# (10000, 1)

# %%
cifar10_train_X = (cifar10_train.data_sources[0].reshape(cifar10_train.num_examples, -1) / 255.0).astype(np.single)
cifar10_train_Y = cifar10_train.data_sources[1].ravel()

cifar10_test_X = (cifar10_test.data_sources[0].reshape(cifar10_test.num_examples, -1) / 255.0).astype(np.single)
cifar10_test_Y = cifar10_test.data_sources[1].ravel()

print cifar10_train_X.shape
print cifar10_train_Y.shape
# Out:
# (50000, 3072)
# (50000,)

# %%
from fuel.datasets.cifar10 import CIFAR10
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme
from common.plotting import plot_mat

CIFAR10.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'}))

cifar10_train = CIFAR10(("train",), subset=slice(None,40000))
#this stream will shuffle the MNIST set and return us batches of 100 examples
cifar10_train_stream = DataStream.default_stream(
    cifar10_train,
    iteration_scheme=ShuffledScheme(cifar10_train.num_examples, 25))
                                               
cifar10_validation = CIFAR10(("train",), subset=slice(40000, None))

# We will use larger portions for testing and validation
# as these dont do a backward pass and reauire less RAM.
cifar10_validation_stream = DataStream.default_stream(
    cifar10_validation, iteration_scheme=SequentialScheme(cifar10_validation.num_examples, 100))
cifar10_test = CIFAR10(("test",))
cifar10_test_stream = DataStream.default_stream(
    cifar10_test, iteration_scheme=SequentialScheme(cifar10_test.num_examples, 100))

# %%
print "The streams return batches containing %s" % (cifar10_train_stream.sources,)

print "Each trainin batch consits of a tuple containing:"
for element in next(cifar10_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(cifar10_test_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
# Out:
# The streams return batches containing (u'features', u'targets')
# Each trainin batch consits of a tuple containing:
#  - an array of size (25, 3, 32, 32) containing float32
#  - an array of size (25, 1) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (100, 3, 32, 32) containing float32
#  - an array of size (100, 1) containing uint8

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
# A theano variable is an entry to the cmputational graph
# We will need to provide its value during function call
# X is batch_size x num_channels x img_rows x img_columns
X = theano.tensor.tensor4('X')

# Y is 1D, it lists the targets for all examples
Y = theano.tensor.matrix('Y', dtype='uint8')

#The tag values are useful during debugging the creation of Theano graphs

X_test_value, Y_test_value = next(cifar10_train_stream.get_epoch_iterator())
#
# Unfortunately, test tags don't work with convolutions with newest Theano :(
#
theano.config.compute_test_value = 'off' # Enable the computation of test values


X.tag.test_value = X_test_value[:3]
Y.tag.test_value = Y_test_value[:3]

print "X shape: %s" % (X.tag.test_value.shape,)

# this list will hold all parameters of the network
model_parameters = []

#The first convolutional layer
#The shape is: num_out_filters x num_in_filters x filter_height x filter_width
num_filters_1 = 10 #we will apply that many convolution filters in the first layer
CW1 = theano.shared(np.zeros((num_filters_1,3,5,5), dtype='float32'), name='CW1')
#please note - this is somewhat non-standard
CW1.tag.initializer = IsotropicGaussian(0.05)

CB1 = theano.shared(np.zeros((num_filters_1,), dtype='float32'), name='CB1')
CB1.tag.initializer = Constant(0.0)
model_parameters += [CW1, CB1]

after_C1 = theano.tensor.maximum(
    0.0,
    theano.tensor.nnet.conv2d(X, CW1) + CB1.dimshuffle('x',0,'x','x'))
#print "after_C1 shape: %s" % (after_C1.tag.test_value.shape,)
after_P1 = theano.tensor.signal.downsample.max_pool_2d(after_C1, (2,2), ignore_border=True)
#print "after_P1 shape: %s" % (after_P1.tag.test_value.shape,)


num_filters_2 = 25 #we will compute ten convolution filters in the first layer
CW2 = theano.shared(np.zeros((num_filters_2,num_filters_1,5,5), dtype='float32'), name='CW2')
CW2.tag.initializer = IsotropicGaussian(0.05)

CB2 = theano.shared(np.zeros((num_filters_2,), dtype='float32'), name='CB2')
CB2.tag.initializer = Constant(0.0)
model_parameters += [CW2, CB2]

after_C2 = theano.tensor.maximum(
    0.0,
    theano.tensor.nnet.conv2d(after_P1, CW2) + CB2.dimshuffle('x',0,'x','x'))
#print "after_C2 shape: %s" % (after_C2.tag.test_value.shape,)
after_P2 = theano.tensor.signal.downsample.max_pool_2d(after_C2, (2,2), ignore_border=True)
#print "after_P2 shape: %s" % (after_P2.tag.test_value.shape,)

#Fully connected layers - we just flatten all filter maps
num_fw3_hidden=500
FW3 = theano.shared(np.zeros((num_filters_2 * 5 * 5, num_fw3_hidden), dtype='float32'), name='FW3')
#FW3 = theano.shared(np.zeros(( num_fw3_hidden,num_filters_2), dtype='float32'), name='FW3')
FW3.tag.initializer = IsotropicGaussian(0.05)

FB3 = theano.shared(np.zeros((num_fw3_hidden,), dtype='float32'), name='FB3')
FB3.tag.initializer = Constant(0.0)
model_parameters += [FW3, FB3]

after_F3 = theano.tensor.maximum(
    0.0, 
    theano.tensor.dot(after_P2.flatten(2), FW3) + FB3.dimshuffle('x',0))
#print "after_F3 shape: %s" % (after_F3.tag.test_value.shape,)


num_fw4_hidden=10
FW4 = theano.shared(np.zeros((num_fw3_hidden, num_fw4_hidden), dtype='float32'), name='FW4')
FW4.tag.initializer = IsotropicGaussian(0.05)

FB4 = theano.shared(np.zeros((num_fw4_hidden,), dtype='float32'), name='FB4')
FB4.tag.initializer = Constant(0.0)
model_parameters += [FW4, FB4]

after_F4 = theano.tensor.dot(after_F3, FW4) + FB4.dimshuffle('x',0)
#print "after_F4 shape: %s" % (after_F4.tag.test_value.shape,)

log_probs = theano.tensor.nnet.softmax(after_F4)

predictions = theano.tensor.argmax(log_probs, axis=1)

error_rate = theano.tensor.neq(predictions,Y.ravel()).mean()
nll = - theano.tensor.log(log_probs[theano.tensor.arange(Y.shape[0]), Y.ravel()]).mean()

weight_decay = 0.0
for p in model_parameters:
    if p.name[1]=='W':
        weight_decay = weight_decay + 1e-3 * (p**2).sum()

cost = nll + weight_decay

#At this point stop computing test values
theano.config.compute_test_value = 'off' # Enable the computation of test values
# Out:
# X shape: (3, 3, 32, 32)

# %%
updates = []

lrate = theano.tensor.scalar('lrate',dtype='float32')
momentum = theano.tensor.scalar('momentum',dtype='float32')

# Theano will compute the gradients for us
gradients = theano.grad(cost, model_parameters)

#initialize storage for momentum
velocities = [theano.shared(np.zeros_like(p.get_value()), name='V_%s' %(p.name, )) for p in model_parameters]

for p,g,v in zip(model_parameters, gradients, velocities):
    v_new = momentum * v - lrate * g
    p_new = p + v_new
    updates += [(v,v_new), (p, p_new)]
    
updates
# Out:
# [(V_CW1, Elemwise{sub,no_inplace}.0),
#  (CW1, Elemwise{add,no_inplace}.0),
#  (V_CB1, Elemwise{sub,no_inplace}.0),
#  (CB1, Elemwise{add,no_inplace}.0),
#  (V_CW2, Elemwise{sub,no_inplace}.0),
#  (CW2, Elemwise{add,no_inplace}.0),
#  (V_CB2, Elemwise{sub,no_inplace}.0),
#  (CB2, Elemwise{add,no_inplace}.0),
#  (V_FW3, Elemwise{sub,no_inplace}.0),
#  (FW3, Elemwise{add,no_inplace}.0),
#  (V_FB3, Elemwise{sub,no_inplace}.0),
#  (FB3, Elemwise{add,no_inplace}.0),
#  (V_FW4, Elemwise{sub,no_inplace}.0),
#  (FW4, Elemwise{add,no_inplace}.0),
#  (V_FB4, Elemwise{sub,no_inplace}.0),
#  (FB4, Elemwise{add,no_inplace}.0)]

# %%
#compile theano functions

#each call to train step will make one SGD step
train_step = theano.function([X,Y,lrate,momentum],[cost, error_rate, nll, weight_decay],updates=updates)
#each call to predict will return predictions on a batch of data
predict = theano.function([X], predictions)

# %%
def compute_error_rate(stream):
    errs = 0.0
    num_samples = 0.0
    for X, Y in stream.get_epoch_iterator():
        errs += (predict(X)!=Y.ravel()).sum()
        num_samples += Y.shape[0]
    return errs/num_samples

#utilities to save values of parameters and to load them

def init_parameters():
    rng = np.random.RandomState(1234)
    for p in model_parameters:
        p.set_value(p.tag.initializer.generate(rng, p.get_value().shape))

def snapshot_parameters():
    return [p.get_value(borrow=False) for p in model_parameters]

def load_parameters(snapshot):
    for p, s in zip(model_parameters, snapshot):
        p.set_value(s, borrow=False)

# %%
# init training

i=0
e=0

init_parameters()
for v in velocities:
    v.set_value(np.zeros_like(v.get_value()))

best_valid_error_rate = np.inf
best_params = snapshot_parameters()
best_params_epoch = 0

train_erros = []
train_loss = []
train_nll = []
validation_errors = []

number_of_epochs = 3
patience_expansion = 1.5

# training loop

while e<number_of_epochs: #This loop goes over epochs
    e += 1
    #First train on all data from this batch
    epoch_start_i = i
    for X_batch, Y_batch in cifar10_train_stream.get_epoch_iterator(): 
        i += 1
        
        K = 2000
        lrate = 4e-3 * K / np.maximum(K, i)
        momentum=0.9
        #print X_batch.shape
        #print Y_batch.shape
        #print lrate
        #print momentum
        #print momentum
        L, err_rate, nll, wdec = train_step(X_batch, Y_batch, lrate, momentum)
        
        #print [p.get_value().ravel()[:10] for p in model_parameters]
        #print [p.get_value().ravel()[:10] for p in velocities]
        
        
        train_loss.append((i,L))
        train_erros.append((i,err_rate))
        train_nll.append((i,nll))
        if i % 100 == 0:
            print "At minibatch %d, batch loss %f, batch nll %f, batch error rate %f%%" % (i, L, nll, err_rate*100)
        
    # After an epoch compute validation error
    val_error_rate = compute_error_rate(cifar10_validation_stream)
    if val_error_rate < best_valid_error_rate:
        number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
        best_valid_error_rate = val_error_rate
        best_params = snapshot_parameters()
        best_params_epoch = e
    validation_errors.append((i,val_error_rate))
    print "After epoch %d: valid_err_rate: %f%% currently going to do %d epochs" %(
        e, val_error_rate*100, number_of_epochs)
    print "After epoch %d: averaged train_err_rate: %f%% averaged train nll: %f averaged train loss: %f" %(
        e, np.mean(np.asarray(train_erros)[epoch_start_i:,1])*100, 
        np.mean(np.asarray(train_nll)[epoch_start_i:,1]),
        np.mean(np.asarray(train_loss)[epoch_start_i:,1]))
# Out:
# At minibatch 100, batch loss 2.800378, batch nll 1.996853, batch error rate 72.000000%
# At minibatch 200, batch loss 2.806857, batch nll 2.014202, batch error rate 72.000000%
# At minibatch 300, batch loss 2.641975, batch nll 1.859465, batch error rate 80.000000%
# At minibatch 400, batch loss 2.631624, batch nll 1.859094, batch error rate 68.000000%
# At minibatch 500, batch loss 2.528059, batch nll 1.765648, batch error rate 52.000000%
# At minibatch 600, batch loss 2.247246, batch nll 1.494873, batch error rate 48.000000%
# At minibatch 700, batch loss 2.070450, batch nll 1.327811, batch error rate 48.000000%
# At minibatch 800, batch loss 2.262782, batch nll 1.529665, batch error rate 60.000000%
# At minibatch 900, batch loss 2.490841, batch nll 1.767501, batch error rate 60.000000%
# At minibatch 1000, batch loss 2.177501, batch nll 1.463190, batch error rate 52.000000%
# At minibatch 1100, batch loss 2.227231, batch nll 1.522023, batch error rate 52.000000%
# At minibatch 1200, batch loss 2.418119, batch nll 1.722431, batch error rate 64.000000%
# At minibatch 1300, batch loss 2.005843, batch nll 1.319495, batch error rate 36.000000%
# At minibatch 1400, batch loss 1.992099, batch nll 1.314034, batch error rate 48.000000%
# At minibatch 1500, batch loss 2.433823, batch nll 1.764454, batch error rate 64.000000%
# At minibatch 1600, batch loss 1.694266, batch nll 1.033326, batch error rate 44.000000%
# After epoch 1: valid_err_rate: 50.950000% currently going to do 3 epochs
# After epoch 1: averaged train_err_rate: 57.637500% averaged train nll: 1.590034 averaged train loss: 2.324437
# At minibatch 1700, batch loss 1.896077, batch nll 1.242990, batch error rate 36.000000%
# At minibatch 1800, batch loss 1.806708, batch nll 1.161490, batch error rate 40.000000%
# At minibatch 1900, batch loss 2.005137, batch nll 1.367774, batch error rate 36.000000%
# At minibatch 2000, batch loss 1.555933, batch nll 0.926055, batch error rate 36.000000%
# At minibatch 2100, batch loss 1.627018, batch nll 1.004682, batch error rate 36.000000%
# At minibatch 2200, batch loss 1.484217, batch nll 0.868456, batch error rate 24.000000%
# At minibatch 2300, batch loss 2.373881, batch nll 1.764959, batch error rate 68.000000%
# At minibatch 2400, batch loss 2.187176, batch nll 1.584917, batch error rate 52.000000%
# At minibatch 2500, batch loss 1.669257, batch nll 1.072761, batch error rate 32.000000%
# At minibatch 2600, batch loss 1.645665, batch nll 1.054663, batch error rate 40.000000%
# At minibatch 2700, batch loss 2.175536, batch nll 1.589871, batch error rate 56.000000%
# At minibatch 2800, batch loss 1.953418, batch nll 1.372871, batch error rate 48.000000%
# At minibatch 2900, batch loss 1.878733, batch nll 1.303221, batch error rate 48.000000%
# At minibatch 3000, batch loss 1.977900, batch nll 1.406767, batch error rate 40.000000%
# At minibatch 3100, batch loss 2.361461, batch nll 1.795096, batch error rate 68.000000%
# At minibatch 3200, batch loss 1.446359, batch nll 0.884389, batch error rate 20.000000%
# After epoch 2: valid_err_rate: 41.990000% currently going to do 4 epochs
# After epoch 2: averaged train_err_rate: 44.180000% averaged train nll: 1.245149 averaged train loss: 1.850918
# At minibatch 3300, batch loss 1.530873, batch nll 0.972363, batch error rate 32.000000%
# At minibatch 3400, batch loss 1.423025, batch nll 0.867938, batch error rate 44.000000%
# At minibatch 3500, batch loss 1.629048, batch nll 1.077498, batch error rate 36.000000%
# At minibatch 3600, batch loss 1.665208, batch nll 1.117295, batch error rate 48.000000%
# At minibatch 3700, batch loss 1.123727, batch nll 0.578859, batch error rate 28.000000%
# At minibatch 3800, batch loss 1.581187, batch nll 1.039565, batch error rate 28.000000%
# At minibatch 3900, batch loss 1.870287, batch nll 1.331778, batch error rate 52.000000%
# At minibatch 4000, batch loss 1.793090, batch nll 1.257598, batch error rate 44.000000%
# At minibatch 4100, batch loss 1.307434, batch nll 0.775118, batch error rate 32.000000%
# At minibatch 4200, batch loss 1.583192, batch nll 1.053558, batch error rate 32.000000%
# At minibatch 4300, batch loss 1.852540, batch nll 1.325629, batch error rate 52.000000%
# At minibatch 4400, batch loss 1.463926, batch nll 0.939855, batch error rate 44.000000%
# At minibatch 4500, batch loss 1.906154, batch nll 1.384506, batch error rate 48.000000%
# At minibatch 4600, batch loss 1.779397, batch nll 1.260298, batch error rate 52.000000%
# At minibatch 4700, batch loss 1.474109, batch nll 0.957616, batch error rate 28.000000%
# At minibatch 4800, batch loss 1.474237, batch nll 0.960123, batch error rate 44.000000%
# After epoch 3: valid_err_rate: 38.440000% currently going to do 5 epochs
# After epoch 3: averaged train_err_rate: 37.597500% averaged train nll: 1.077408 averaged train loss: 1.613744
# At minibatch 4900, batch loss 1.580325, batch nll 1.068159, batch error rate 44.000000%
# At minibatch 5000, batch loss 1.620423, batch nll 1.110116, batch error rate 36.000000%
# At minibatch 5100, batch loss 1.382775, batch nll 0.874396, batch error rate 36.000000%
# At minibatch 5200, batch loss 1.369639, batch nll 0.863030, batch error rate 24.000000%
# At minibatch 5300, batch loss 1.366044, batch nll 0.861474, batch error rate 36.000000%
# At minibatch 5400, batch loss 1.698671, batch nll 1.195969, batch error rate 32.000000%
# At minibatch 5500, batch loss 1.234030, batch nll 0.733018, batch error rate 36.000000%
# At minibatch 5600, batch loss 1.451482, batch nll 0.952484, batch error rate 40.000000%
# At minibatch 5700, batch loss 1.724872, batch nll 1.227654, batch error rate 48.000000%
# At minibatch 5800, batch loss 1.242458, batch nll 0.746872, batch error rate 24.000000%
# At minibatch 5900, batch loss 1.592309, batch nll 1.098577, batch error rate 36.000000%
# At minibatch 6000, batch loss 1.096442, batch nll 0.604437, batch error rate 24.000000%
# At minibatch 6100, batch loss 1.244315, batch nll 0.754080, batch error rate 28.000000%
# At minibatch 6200, batch loss 1.401037, batch nll 0.912367, batch error rate 44.000000%
# At minibatch 6300, batch loss 1.653376, batch nll 1.166305, batch error rate 48.000000%
# At minibatch 6400, batch loss 1.328245, batch nll 0.842839, batch error rate 24.000000%
# After epoch 4: valid_err_rate: 36.690000% currently going to do 7 epochs
# After epoch 4: averaged train_err_rate: 33.930000% averaged train nll: 0.969729 averaged train loss: 1.469033
# At minibatch 6500, batch loss 1.675815, batch nll 1.191581, batch error rate 36.000000%
# At minibatch 6600, batch loss 1.662645, batch nll 1.179658, batch error rate 52.000000%
# At minibatch 6700, batch loss 0.984666, batch nll 0.502939, batch error rate 12.000000%
# At minibatch 6800, batch loss 1.551260, batch nll 1.070645, batch error rate 40.000000%
# At minibatch 6900, batch loss 2.106750, batch nll 1.627407, batch error rate 48.000000%
# At minibatch 7000, batch loss 1.347902, batch nll 0.869800, batch error rate 44.000000%
# At minibatch 7100, batch loss 1.233923, batch nll 0.757015, batch error rate 28.000000%
# At minibatch 7200, batch loss 1.329185, batch nll 0.853458, batch error rate 36.000000%
# At minibatch 7300, batch loss 1.485306, batch nll 1.010898, batch error rate 32.000000%
# At minibatch 7400, batch loss 1.053128, batch nll 0.579938, batch error rate 16.000000%
# At minibatch 7500, batch loss 1.035645, batch nll 0.563646, batch error rate 20.000000%
# At minibatch 7600, batch loss 1.619480, batch nll 1.148755, batch error rate 48.000000%
# At minibatch 7700, batch loss 1.431371, batch nll 0.961874, batch error rate 36.000000%
# At minibatch 7800, batch loss 1.688406, batch nll 1.219893, batch error rate 36.000000%
# At minibatch 7900, batch loss 1.084648, batch nll 0.617571, batch error rate 24.000000%
# At minibatch 8000, batch loss 0.979714, batch nll 0.513744, batch error rate 20.000000%
# After epoch 5: valid_err_rate: 35.440000% currently going to do 8 epochs
# After epoch 5: averaged train_err_rate: 31.225000% averaged train nll: 0.895775 averaged train loss: 1.371432
# At minibatch 8100, batch loss 1.278098, batch nll 0.812832, batch error rate 32.000000%
# At minibatch 8200, batch loss 1.303380, batch nll 0.839122, batch error rate 24.000000%
# At minibatch 8300, batch loss 1.324840, batch nll 0.861394, batch error rate 40.000000%
# At minibatch 8400, batch loss 1.537638, batch nll 1.074962, batch error rate 48.000000%
# At minibatch 8500, batch loss 1.455174, batch nll 0.993380, batch error rate 32.000000%
# At minibatch 8600, batch loss 0.932390, batch nll 0.471673, batch error rate 16.000000%
# At minibatch 8700, batch loss 1.319890, batch nll 0.859975, batch error rate 32.000000%
# At minibatch 8800, batch loss 1.356458, batch nll 0.897560, batch error rate 36.000000%
# At minibatch 8900, batch loss 1.146327, batch nll 0.688321, batch error rate 16.000000%
# At minibatch 9000, batch loss 1.452022, batch nll 0.994994, batch error rate 28.000000%
# At minibatch 9100, batch loss 1.753052, batch nll 1.296823, batch error rate 48.000000%
# At minibatch 9200, batch loss 1.232114, batch nll 0.776608, batch error rate 24.000000%
# At minibatch 9300, batch loss 1.337106, batch nll 0.882290, batch error rate 32.000000%
# At minibatch 9400, batch loss 1.203680, batch nll 0.749803, batch error rate 32.000000%
# At minibatch 9500, batch loss 1.115490, batch nll 0.662522, batch error rate 28.000000%
# At minibatch 9600, batch loss 1.630917, batch nll 1.178772, batch error rate 32.000000%
# After epoch 6: valid_err_rate: 35.020000% currently going to do 10 epochs
# After epoch 6: averaged train_err_rate: 28.860000% averaged train nll: 0.839159 averaged train loss: 1.298190
# At minibatch 9700, batch loss 1.708680, batch nll 1.257236, batch error rate 36.000000%
# At minibatch 9800, batch loss 1.325104, batch nll 0.874280, batch error rate 32.000000%
# At minibatch 9900, batch loss 1.179748, batch nll 0.729425, batch error rate 20.000000%
# At minibatch 10000, batch loss 1.193690, batch nll 0.744100, batch error rate 28.000000%
# At minibatch 10100, batch loss 1.271268, batch nll 0.822169, batch error rate 24.000000%
# At minibatch 10200, batch loss 1.099447, batch nll 0.651036, batch error rate 8.000000%
# At minibatch 10300, batch loss 1.171819, batch nll 0.724118, batch error rate 16.000000%
# At minibatch 10400, batch loss 1.100991, batch nll 0.653963, batch error rate 20.000000%
# At minibatch 10500, batch loss 1.592178, batch nll 1.145868, batch error rate 32.000000%
# At minibatch 10600, batch loss 1.258745, batch nll 0.813178, batch error rate 32.000000%
# At minibatch 10700, batch loss 1.360412, batch nll 0.915349, batch error rate 28.000000%
# At minibatch 10800, batch loss 1.330701, batch nll 0.886268, batch error rate 36.000000%
# At minibatch 10900, batch loss 1.349756, batch nll 0.905876, batch error rate 40.000000%
# At minibatch 11000, batch loss 1.216724, batch nll 0.773413, batch error rate 24.000000%
# At minibatch 11100, batch loss 1.146712, batch nll 0.703995, batch error rate 28.000000%
# At minibatch 11200, batch loss 1.265965, batch nll 0.823934, batch error rate 36.000000%
# After epoch 7: valid_err_rate: 34.720000% currently going to do 11 epochs
# After epoch 7: averaged train_err_rate: 27.277500% averaged train nll: 0.786353 averaged train loss: 1.233405
# At minibatch 11300, batch loss 1.110849, batch nll 0.669225, batch error rate 16.000000%
# At minibatch 11400, batch loss 1.222290, batch nll 0.781167, batch error rate 20.000000%
# At minibatch 11500, batch loss 1.502216, batch nll 1.061449, batch error rate 48.000000%
# At minibatch 11600, batch loss 1.403427, batch nll 0.963140, batch error rate 32.000000%
# At minibatch 11700, batch loss 1.210220, batch nll 0.770518, batch error rate 24.000000%
# At minibatch 11800, batch loss 1.290974, batch nll 0.851631, batch error rate 28.000000%
# At minibatch 11900, batch loss 1.026110, batch nll 0.587298, batch error rate 20.000000%
# At minibatch 12000, batch loss 1.014457, batch nll 0.576195, batch error rate 24.000000%
# At minibatch 12100, batch loss 1.213673, batch nll 0.775954, batch error rate 32.000000%
# At minibatch 12200, batch loss 1.250475, batch nll 0.813222, batch error rate 24.000000%
# At minibatch 12300, batch loss 1.433868, batch nll 0.997149, batch error rate 36.000000%
# At minibatch 12400, batch loss 1.095652, batch nll 0.659485, batch error rate 28.000000%
# At minibatch 12500, batch loss 1.251656, batch nll 0.815918, batch error rate 24.000000%
# At minibatch 12600, batch loss 1.254697, batch nll 0.819468, batch error rate 32.000000%
# At minibatch 12700, batch loss 1.191759, batch nll 0.757096, batch error rate 24.000000%
# At minibatch 12800, batch loss 1.134032, batch nll 0.699915, batch error rate 20.000000%
# After epoch 8: valid_err_rate: 33.370000% currently going to do 13 epochs
# After epoch 8: averaged train_err_rate: 25.400000% averaged train nll: 0.741081 averaged train loss: 1.179298
# At minibatch 12900, batch loss 1.348627, batch nll 0.914812, batch error rate 36.000000%
# At minibatch 13000, batch loss 1.097962, batch nll 0.664499, batch error rate 20.000000%
# At minibatch 13100, batch loss 1.371533, batch nll 0.938317, batch error rate 36.000000%
# At minibatch 13200, batch loss 1.109023, batch nll 0.676198, batch error rate 28.000000%
# At minibatch 13300, batch loss 1.195448, batch nll 0.762918, batch error rate 32.000000%
# At minibatch 13400, batch loss 1.189926, batch nll 0.757858, batch error rate 20.000000%
# At minibatch 13500, batch loss 1.191001, batch nll 0.759257, batch error rate 32.000000%
# At minibatch 13600, batch loss 1.047568, batch nll 0.616277, batch error rate 12.000000%
# At minibatch 13700, batch loss 1.383876, batch nll 0.953071, batch error rate 28.000000%
# At minibatch 13800, batch loss 1.280684, batch nll 0.850298, batch error rate 28.000000%
# At minibatch 13900, batch loss 1.187832, batch nll 0.757815, batch error rate 20.000000%
# At minibatch 14000, batch loss 1.276034, batch nll 0.846372, batch error rate 28.000000%
# At minibatch 14100, batch loss 1.243384, batch nll 0.814113, batch error rate 24.000000%
# At minibatch 14200, batch loss 1.035580, batch nll 0.606756, batch error rate 20.000000%
# At minibatch 14300, batch loss 0.976804, batch nll 0.548349, batch error rate 24.000000%
# At minibatch 14400, batch loss 1.100682, batch nll 0.672654, batch error rate 24.000000%
# After epoch 9: valid_err_rate: 33.520000% currently going to do 13 epochs
# After epoch 9: averaged train_err_rate: 23.940000% averaged train nll: 0.699234 averaged train loss: 1.130447
# At minibatch 14500, batch loss 0.770163, batch nll 0.342330, batch error rate 8.000000%
# At minibatch 14600, batch loss 1.190173, batch nll 0.762585, batch error rate 28.000000%
# At minibatch 14700, batch loss 1.441884, batch nll 1.014562, batch error rate 28.000000%
# At minibatch 14800, batch loss 0.878964, batch nll 0.451967, batch error rate 20.000000%
# At minibatch 14900, batch loss 0.893385, batch nll 0.466669, batch error rate 12.000000%
# At minibatch 15000, batch loss 1.169537, batch nll 0.743205, batch error rate 20.000000%
# At minibatch 15100, batch loss 1.442305, batch nll 1.016330, batch error rate 36.000000%
# At minibatch 15200, batch loss 1.283983, batch nll 0.858280, batch error rate 32.000000%
# At minibatch 15300, batch loss 1.141152, batch nll 0.715784, batch error rate 28.000000%
# At minibatch 15400, batch loss 0.981649, batch nll 0.556614, batch error rate 24.000000%
# At minibatch 15500, batch loss 0.941073, batch nll 0.516304, batch error rate 20.000000%
# At minibatch 15600, batch loss 1.235597, batch nll 0.811073, batch error rate 40.000000%
# At minibatch 15700, batch loss 1.043614, batch nll 0.619505, batch error rate 28.000000%
# At minibatch 15800, batch loss 1.099669, batch nll 0.675890, batch error rate 28.000000%
# At minibatch 15900, batch loss 1.141812, batch nll 0.718290, batch error rate 32.000000%
# At minibatch 16000, batch loss 1.213195, batch nll 0.789992, batch error rate 24.000000%
# After epoch 10: valid_err_rate: 33.610000% currently going to do 13 epochs
# After epoch 10: averaged train_err_rate: 22.630000% averaged train nll: 0.661939 averaged train loss: 1.087636
# At minibatch 16100, batch loss 0.946490, batch nll 0.523438, batch error rate 12.000000%
# At minibatch 16200, batch loss 0.879958, batch nll 0.457127, batch error rate 20.000000%
# At minibatch 16300, batch loss 1.048085, batch nll 0.625470, batch error rate 32.000000%
# At minibatch 16400, batch loss 0.912463, batch nll 0.490039, batch error rate 12.000000%
# At minibatch 16500, batch loss 0.943311, batch nll 0.521111, batch error rate 24.000000%
# At minibatch 16600, batch loss 0.980359, batch nll 0.558412, batch error rate 28.000000%
# At minibatch 16700, batch loss 0.893085, batch nll 0.471376, batch error rate 12.000000%
# At minibatch 16800, batch loss 0.902445, batch nll 0.480999, batch error rate 8.000000%
# At minibatch 16900, batch loss 1.188839, batch nll 0.767609, batch error rate 24.000000%
# At minibatch 17000, batch loss 1.103247, batch nll 0.682367, batch error rate 20.000000%
# At minibatch 17100, batch loss 1.072349, batch nll 0.651701, batch error rate 20.000000%
# At minibatch 17200, batch loss 1.018796, batch nll 0.598384, batch error rate 20.000000%
# At minibatch 17300, batch loss 0.917138, batch nll 0.496969, batch error rate 24.000000%
# At minibatch 17400, batch loss 1.006500, batch nll 0.586559, batch error rate 24.000000%
# At minibatch 17500, batch loss 0.977864, batch nll 0.558313, batch error rate 12.000000%
# At minibatch 17600, batch loss 1.295674, batch nll 0.876325, batch error rate 32.000000%
# After epoch 11: valid_err_rate: 33.340000% currently going to do 17 epochs
# After epoch 11: averaged train_err_rate: 21.217500% averaged train nll: 0.628681 averaged train loss: 1.050077
# At minibatch 17700, batch loss 1.108722, batch nll 0.689570, batch error rate 28.000000%
# At minibatch 17800, batch loss 1.097609, batch nll 0.678559, batch error rate 20.000000%
# At minibatch 17900, batch loss 0.931243, batch nll 0.512434, batch error rate 8.000000%
# At minibatch 18000, batch loss 1.160485, batch nll 0.741843, batch error rate 20.000000%
# At minibatch 18100, batch loss 0.833571, batch nll 0.415128, batch error rate 8.000000%
# At minibatch 18200, batch loss 0.950847, batch nll 0.532479, batch error rate 16.000000%
# At minibatch 18300, batch loss 1.069419, batch nll 0.651289, batch error rate 12.000000%
# At minibatch 18400, batch loss 1.258756, batch nll 0.840889, batch error rate 16.000000%
# At minibatch 18500, batch loss 0.925779, batch nll 0.508129, batch error rate 12.000000%
# At minibatch 18600, batch loss 0.935539, batch nll 0.518087, batch error rate 16.000000%
# At minibatch 18700, batch loss 1.022085, batch nll 0.604890, batch error rate 24.000000%
# At minibatch 18800, batch loss 1.197636, batch nll 0.780601, batch error rate 24.000000%
# At minibatch 18900, batch loss 1.098564, batch nll 0.681731, batch error rate 32.000000%
# At minibatch 19000, batch loss 1.002362, batch nll 0.585734, batch error rate 24.000000%
# At minibatch 19100, batch loss 1.394575, batch nll 0.978089, batch error rate 36.000000%
# At minibatch 19200, batch loss 1.006876, batch nll 0.590580, batch error rate 16.000000%
# After epoch 12: valid_err_rate: 33.370000% currently going to do 17 epochs
# After epoch 12: averaged train_err_rate: 19.777500% averaged train nll: 0.594889 averaged train loss: 1.012736
# At minibatch 19300, batch loss 1.015762, batch nll 0.599661, batch error rate 28.000000%
# At minibatch 19400, batch loss 1.372906, batch nll 0.956885, batch error rate 40.000000%
# At minibatch 19500, batch loss 0.852012, batch nll 0.436101, batch error rate 16.000000%
# At minibatch 19600, batch loss 0.935555, batch nll 0.519779, batch error rate 20.000000%
# At minibatch 19700, batch loss 0.873561, batch nll 0.457868, batch error rate 8.000000%
# At minibatch 19800, batch loss 1.007174, batch nll 0.591645, batch error rate 24.000000%
# At minibatch 19900, batch loss 1.076748, batch nll 0.661376, batch error rate 24.000000%
# At minibatch 20000, batch loss 0.925199, batch nll 0.510029, batch error rate 16.000000%
# At minibatch 20100, batch loss 0.712955, batch nll 0.297960, batch error rate 4.000000%
# At minibatch 20200, batch loss 0.933609, batch nll 0.518821, batch error rate 12.000000%
# At minibatch 20300, batch loss 0.776445, batch nll 0.361811, batch error rate 12.000000%
# At minibatch 20400, batch loss 0.870341, batch nll 0.455881, batch error rate 12.000000%
# At minibatch 20500, batch loss 1.408002, batch nll 0.993738, batch error rate 28.000000%
# At minibatch 20600, batch loss 0.910127, batch nll 0.496030, batch error rate 16.000000%
# At minibatch 20700, batch loss 1.341953, batch nll 0.927975, batch error rate 40.000000%
# At minibatch 20800, batch loss 0.776868, batch nll 0.363098, batch error rate 8.000000%
# After epoch 13: valid_err_rate: 33.440000% currently going to do 17 epochs
# After epoch 13: averaged train_err_rate: 18.892500% averaged train nll: 0.565218 averaged train loss: 0.980331
# At minibatch 20900, batch loss 0.926973, batch nll 0.513256, batch error rate 12.000000%
# At minibatch 21000, batch loss 0.855232, batch nll 0.441598, batch error rate 12.000000%
# At minibatch 21100, batch loss 0.850338, batch nll 0.436784, batch error rate 20.000000%
# At minibatch 21200, batch loss 0.951309, batch nll 0.537864, batch error rate 28.000000%
# At minibatch 21300, batch loss 0.790549, batch nll 0.377237, batch error rate 16.000000%
# At minibatch 21400, batch loss 0.947270, batch nll 0.534063, batch error rate 24.000000%
# At minibatch 21500, batch loss 0.868052, batch nll 0.454973, batch error rate 4.000000%
# At minibatch 21600, batch loss 1.039395, batch nll 0.626465, batch error rate 20.000000%
# At minibatch 21700, batch loss 0.918601, batch nll 0.505800, batch error rate 12.000000%
# At minibatch 21800, batch loss 0.844242, batch nll 0.431599, batch error rate 8.000000%
# At minibatch 21900, batch loss 1.051025, batch nll 0.638521, batch error rate 20.000000%
# At minibatch 22000, batch loss 0.810217, batch nll 0.397873, batch error rate 8.000000%
# At minibatch 22100, batch loss 1.109265, batch nll 0.697068, batch error rate 24.000000%
# At minibatch 22200, batch loss 0.787250, batch nll 0.375148, batch error rate 12.000000%
# At minibatch 22300, batch loss 0.901205, batch nll 0.489237, batch error rate 16.000000%
# At minibatch 22400, batch loss 1.008128, batch nll 0.596306, batch error rate 24.000000%
# After epoch 14: valid_err_rate: 33.140000% currently going to do 22 epochs
# After epoch 14: averaged train_err_rate: 17.750000% averaged train nll: 0.536836 averaged train loss: 0.949724
# At minibatch 22500, batch loss 0.883209, batch nll 0.471444, batch error rate 16.000000%
# At minibatch 22600, batch loss 1.063756, batch nll 0.652011, batch error rate 32.000000%
# At minibatch 22700, batch loss 0.795483, batch nll 0.383852, batch error rate 12.000000%
# At minibatch 22800, batch loss 0.991057, batch nll 0.579504, batch error rate 24.000000%
# At minibatch 22900, batch loss 0.864423, batch nll 0.452992, batch error rate 16.000000%
# At minibatch 23000, batch loss 1.008677, batch nll 0.597302, batch error rate 24.000000%
# At minibatch 23100, batch loss 0.798225, batch nll 0.386999, batch error rate 16.000000%
# At minibatch 23200, batch loss 0.906084, batch nll 0.494901, batch error rate 16.000000%
# At minibatch 23300, batch loss 1.172540, batch nll 0.761457, batch error rate 32.000000%
# At minibatch 23400, batch loss 1.089808, batch nll 0.678877, batch error rate 28.000000%
# At minibatch 23500, batch loss 0.965050, batch nll 0.554231, batch error rate 20.000000%
# At minibatch 23600, batch loss 1.136348, batch nll 0.725640, batch error rate 28.000000%
# At minibatch 23700, batch loss 0.745290, batch nll 0.334734, batch error rate 8.000000%
# At minibatch 23800, batch loss 0.886543, batch nll 0.476138, batch error rate 12.000000%
# At minibatch 23900, batch loss 0.894627, batch nll 0.484359, batch error rate 20.000000%
# At minibatch 24000, batch loss 0.961946, batch nll 0.551785, batch error rate 24.000000%
# After epoch 15: valid_err_rate: 33.080000% currently going to do 23 epochs
# After epoch 15: averaged train_err_rate: 16.795000% averaged train nll: 0.510706 averaged train loss: 0.921808
# At minibatch 24100, batch loss 1.169473, batch nll 0.759349, batch error rate 28.000000%
# At minibatch 24200, batch loss 1.113204, batch nll 0.703074, batch error rate 24.000000%
# At minibatch 24300, batch loss 0.903203, batch nll 0.493130, batch error rate 16.000000%
# At minibatch 24400, batch loss 0.902569, batch nll 0.492584, batch error rate 16.000000%
# At minibatch 24500, batch loss 0.721858, batch nll 0.311908, batch error rate 4.000000%
# At minibatch 24600, batch loss 0.802283, batch nll 0.392399, batch error rate 16.000000%
# At minibatch 24700, batch loss 0.969193, batch nll 0.559462, batch error rate 16.000000%
# At minibatch 24800, batch loss 0.826813, batch nll 0.417154, batch error rate 16.000000%
# At minibatch 24900, batch loss 0.952462, batch nll 0.542933, batch error rate 24.000000%
# At minibatch 25000, batch loss 1.067937, batch nll 0.658486, batch error rate 16.000000%
# At minibatch 25100, batch loss 0.752992, batch nll 0.343626, batch error rate 8.000000%
# At minibatch 25200, batch loss 0.753767, batch nll 0.344486, batch error rate 12.000000%
# At minibatch 25300, batch loss 0.963637, batch nll 0.554430, batch error rate 20.000000%
# At minibatch 25400, batch loss 1.182498, batch nll 0.773367, batch error rate 20.000000%
# At minibatch 25500, batch loss 1.010079, batch nll 0.601043, batch error rate 24.000000%
# At minibatch 25600, batch loss 0.803237, batch nll 0.394309, batch error rate 16.000000%
# After epoch 16: valid_err_rate: 33.380000% currently going to do 23 epochs
# After epoch 16: averaged train_err_rate: 15.605000% averaged train nll: 0.485005 averaged train loss: 0.894634
# At minibatch 25700, batch loss 1.300629, batch nll 0.891720, batch error rate 28.000000%
# At minibatch 25800, batch loss 0.821987, batch nll 0.413125, batch error rate 12.000000%
# At minibatch 25900, batch loss 0.765857, batch nll 0.357044, batch error rate 12.000000%
# At minibatch 26000, batch loss 0.825168, batch nll 0.416418, batch error rate 8.000000%
# At minibatch 26100, batch loss 0.848092, batch nll 0.439349, batch error rate 12.000000%
# At minibatch 26200, batch loss 0.625120, batch nll 0.216433, batch error rate 4.000000%
# At minibatch 26300, batch loss 0.828397, batch nll 0.419800, batch error rate 4.000000%
# At minibatch 26400, batch loss 0.752325, batch nll 0.343818, batch error rate 12.000000%
# At minibatch 26500, batch loss 0.988789, batch nll 0.580345, batch error rate 12.000000%
# At minibatch 26600, batch loss 0.912171, batch nll 0.503755, batch error rate 12.000000%
# At minibatch 26700, batch loss 0.946087, batch nll 0.537767, batch error rate 16.000000%
# At minibatch 26800, batch loss 0.919205, batch nll 0.510976, batch error rate 16.000000%
# At minibatch 26900, batch loss 0.749625, batch nll 0.341465, batch error rate 8.000000%
# At minibatch 27000, batch loss 0.748635, batch nll 0.340566, batch error rate 8.000000%
# At minibatch 27100, batch loss 0.891223, batch nll 0.483216, batch error rate 28.000000%
# At minibatch 27200, batch loss 0.726682, batch nll 0.318788, batch error rate 12.000000%
# After epoch 17: valid_err_rate: 33.240000% currently going to do 23 epochs
# After epoch 17: averaged train_err_rate: 14.782500% averaged train nll: 0.460686 averaged train loss: 0.869180
# At minibatch 27300, batch loss 0.878129, batch nll 0.470257, batch error rate 12.000000%
# At minibatch 27400, batch loss 0.823526, batch nll 0.415709, batch error rate 12.000000%
# At minibatch 27500, batch loss 0.746886, batch nll 0.339072, batch error rate 8.000000%
# At minibatch 27600, batch loss 0.740148, batch nll 0.332356, batch error rate 8.000000%
# At minibatch 27700, batch loss 0.799059, batch nll 0.391363, batch error rate 12.000000%
# At minibatch 27800, batch loss 0.607206, batch nll 0.199581, batch error rate 0.000000%
# At minibatch 27900, batch loss 0.714027, batch nll 0.306407, batch error rate 8.000000%
# At minibatch 28000, batch loss 0.970848, batch nll 0.563282, batch error rate 20.000000%
# At minibatch 28100, batch loss 0.858765, batch nll 0.451255, batch error rate 16.000000%
# At minibatch 28200, batch loss 0.699143, batch nll 0.291700, batch error rate 4.000000%
# At minibatch 28300, batch loss 0.900428, batch nll 0.493053, batch error rate 20.000000%
# At minibatch 28400, batch loss 0.966417, batch nll 0.559110, batch error rate 16.000000%
# At minibatch 28500, batch loss 0.575752, batch nll 0.168539, batch error rate 0.000000%
# At minibatch 28600, batch loss 0.813360, batch nll 0.406197, batch error rate 20.000000%
# At minibatch 28700, batch loss 0.547515, batch nll 0.140398, batch error rate 0.000000%
# At minibatch 28800, batch loss 0.719150, batch nll 0.312117, batch error rate 4.000000%
# After epoch 18: valid_err_rate: 33.470000% currently going to do 23 epochs
# After epoch 18: averaged train_err_rate: 13.922500% averaged train nll: 0.438955 averaged train loss: 0.846478
# At minibatch 28900, batch loss 0.848007, batch nll 0.440986, batch error rate 20.000000%
# At minibatch 29000, batch loss 0.998276, batch nll 0.591267, batch error rate 20.000000%
# At minibatch 29100, batch loss 0.708596, batch nll 0.301589, batch error rate 4.000000%
# At minibatch 29200, batch loss 0.965689, batch nll 0.558736, batch error rate 16.000000%
# At minibatch 29300, batch loss 0.854666, batch nll 0.447721, batch error rate 20.000000%
# At minibatch 29400, batch loss 0.718690, batch nll 0.311816, batch error rate 0.000000%
# At minibatch 29500, batch loss 1.027601, batch nll 0.620746, batch error rate 20.000000%
# At minibatch 29600, batch loss 0.614531, batch nll 0.207708, batch error rate 4.000000%
# At minibatch 29700, batch loss 0.910009, batch nll 0.503193, batch error rate 20.000000%
# At minibatch 29800, batch loss 0.740817, batch nll 0.334043, batch error rate 8.000000%
# At minibatch 29900, batch loss 0.658599, batch nll 0.251872, batch error rate 4.000000%
# At minibatch 30000, batch loss 0.877470, batch nll 0.470832, batch error rate 20.000000%
# At minibatch 30100, batch loss 0.875118, batch nll 0.468555, batch error rate 16.000000%
# At minibatch 30200, batch loss 0.959993, batch nll 0.553468, batch error rate 12.000000%
# At minibatch 30300, batch loss 0.706485, batch nll 0.299987, batch error rate 12.000000%
# At minibatch 30400, batch loss 0.620889, batch nll 0.214448, batch error rate 4.000000%
# After epoch 19: valid_err_rate: 33.350000% currently going to do 23 epochs
# After epoch 19: averaged train_err_rate: 13.137500% averaged train nll: 0.416272 averaged train loss: 0.823071
# At minibatch 30500, batch loss 0.706211, batch nll 0.299762, batch error rate 8.000000%
# At minibatch 30600, batch loss 1.071187, batch nll 0.664755, batch error rate 20.000000%
# At minibatch 30700, batch loss 0.727400, batch nll 0.320999, batch error rate 4.000000%
# At minibatch 30800, batch loss 0.755152, batch nll 0.348738, batch error rate 12.000000%
# At minibatch 30900, batch loss 0.956794, batch nll 0.550421, batch error rate 24.000000%
# At minibatch 31000, batch loss 0.785427, batch nll 0.379113, batch error rate 8.000000%
# At minibatch 31100, batch loss 0.682560, batch nll 0.276264, batch error rate 8.000000%
# At minibatch 31200, batch loss 0.936973, batch nll 0.530712, batch error rate 8.000000%
# At minibatch 31300, batch loss 0.705418, batch nll 0.299187, batch error rate 12.000000%
# At minibatch 31400, batch loss 1.187738, batch nll 0.781554, batch error rate 28.000000%
# At minibatch 31500, batch loss 0.810441, batch nll 0.404297, batch error rate 16.000000%
# At minibatch 31600, batch loss 0.989343, batch nll 0.583261, batch error rate 24.000000%
# At minibatch 31700, batch loss 0.892023, batch nll 0.485999, batch error rate 20.000000%
# At minibatch 31800, batch loss 0.657187, batch nll 0.251186, batch error rate 4.000000%
# At minibatch 31900, batch loss 0.857931, batch nll 0.451970, batch error rate 12.000000%
# At minibatch 32000, batch loss 0.716041, batch nll 0.310160, batch error rate 12.000000%
# After epoch 20: valid_err_rate: 33.490000% currently going to do 23 epochs
# After epoch 20: averaged train_err_rate: 12.260000% averaged train nll: 0.395916 averaged train loss: 0.802149
# At minibatch 32100, batch loss 0.699754, batch nll 0.293865, batch error rate 8.000000%
# At minibatch 32200, batch loss 0.562693, batch nll 0.156811, batch error rate 0.000000%
# At minibatch 32300, batch loss 0.632610, batch nll 0.226725, batch error rate 16.000000%
# At minibatch 32400, batch loss 0.717892, batch nll 0.312048, batch error rate 12.000000%
# At minibatch 32500, batch loss 0.901553, batch nll 0.495723, batch error rate 20.000000%
# At minibatch 32600, batch loss 0.659446, batch nll 0.253643, batch error rate 12.000000%
# At minibatch 32700, batch loss 0.644735, batch nll 0.238937, batch error rate 0.000000%
# At minibatch 32800, batch loss 0.840515, batch nll 0.434736, batch error rate 12.000000%
# At minibatch 32900, batch loss 0.666865, batch nll 0.261124, batch error rate 4.000000%
# At minibatch 33000, batch loss 0.635580, batch nll 0.229859, batch error rate 4.000000%
# At minibatch 33100, batch loss 0.986131, batch nll 0.580413, batch error rate 28.000000%
# At minibatch 33200, batch loss 0.697557, batch nll 0.291861, batch error rate 4.000000%
# At minibatch 33300, batch loss 0.754562, batch nll 0.348897, batch error rate 16.000000%
# At minibatch 33400, batch loss 0.839173, batch nll 0.433549, batch error rate 12.000000%
# At minibatch 33500, batch loss 0.653163, batch nll 0.247610, batch error rate 4.000000%
# At minibatch 33600, batch loss 0.964018, batch nll 0.558527, batch error rate 28.000000%
# After epoch 21: valid_err_rate: 33.390000% currently going to do 23 epochs
# After epoch 21: averaged train_err_rate: 11.402500% averaged train nll: 0.377296 averaged train loss: 0.783054
# At minibatch 33700, batch loss 0.633296, batch nll 0.227799, batch error rate 12.000000%
# At minibatch 33800, batch loss 0.791482, batch nll 0.386004, batch error rate 16.000000%
# At minibatch 33900, batch loss 0.604640, batch nll 0.199157, batch error rate 4.000000%
# At minibatch 34000, batch loss 0.931195, batch nll 0.525733, batch error rate 8.000000%
# At minibatch 34100, batch loss 0.881433, batch nll 0.476013, batch error rate 12.000000%
# At minibatch 34200, batch loss 0.835945, batch nll 0.430539, batch error rate 12.000000%
# At minibatch 34300, batch loss 1.035584, batch nll 0.630197, batch error rate 24.000000%
# At minibatch 34400, batch loss 0.712494, batch nll 0.307122, batch error rate 4.000000%
# At minibatch 34500, batch loss 0.962224, batch nll 0.556834, batch error rate 24.000000%
# At minibatch 34600, batch loss 0.889968, batch nll 0.484586, batch error rate 20.000000%
# At minibatch 34700, batch loss 0.855979, batch nll 0.450621, batch error rate 16.000000%
# At minibatch 34800, batch loss 1.068527, batch nll 0.663179, batch error rate 24.000000%
# At minibatch 34900, batch loss 0.667137, batch nll 0.261830, batch error rate 8.000000%
# At minibatch 35000, batch loss 0.750740, batch nll 0.345473, batch error rate 12.000000%
# At minibatch 35100, batch loss 0.839789, batch nll 0.434554, batch error rate 16.000000%
# At minibatch 35200, batch loss 0.801618, batch nll 0.396397, batch error rate 16.000000%
# After epoch 22: valid_err_rate: 33.460000% currently going to do 23 epochs
# After epoch 22: averaged train_err_rate: 10.692500% averaged train nll: 0.358492 averaged train loss: 0.763876
# At minibatch 35300, batch loss 0.682792, batch nll 0.277577, batch error rate 8.000000%
# At minibatch 35400, batch loss 0.816445, batch nll 0.411228, batch error rate 12.000000%
# At minibatch 35500, batch loss 0.596799, batch nll 0.191602, batch error rate 4.000000%
# At minibatch 35600, batch loss 0.772203, batch nll 0.366972, batch error rate 8.000000%
# At minibatch 35700, batch loss 0.856911, batch nll 0.451676, batch error rate 8.000000%
# At minibatch 35800, batch loss 0.925442, batch nll 0.520237, batch error rate 16.000000%
# At minibatch 35900, batch loss 0.700338, batch nll 0.295148, batch error rate 12.000000%
# At minibatch 36000, batch loss 0.746451, batch nll 0.341270, batch error rate 16.000000%
# At minibatch 36100, batch loss 0.769472, batch nll 0.364303, batch error rate 12.000000%
# At minibatch 36200, batch loss 0.487564, batch nll 0.082428, batch error rate 0.000000%
# At minibatch 36300, batch loss 0.842679, batch nll 0.437569, batch error rate 16.000000%
# At minibatch 36400, batch loss 0.588826, batch nll 0.183738, batch error rate 0.000000%
# At minibatch 36500, batch loss 0.731482, batch nll 0.326442, batch error rate 12.000000%
# At minibatch 36600, batch loss 0.811204, batch nll 0.406201, batch error rate 16.000000%
# At minibatch 36700, batch loss 0.849357, batch nll 0.444378, batch error rate 20.000000%
# At minibatch 36800, batch loss 0.832127, batch nll 0.427167, batch error rate 20.000000%
# After epoch 23: valid_err_rate: 33.440000% currently going to do 23 epochs
# After epoch 23: averaged train_err_rate: 10.060000% averaged train nll: 0.341306 averaged train loss: 0.746449
# At minibatch 36900, batch loss 0.797386, batch nll 0.392423, batch error rate 12.000000%
# At minibatch 37000, batch loss 0.729104, batch nll 0.324130, batch error rate 12.000000%
# At minibatch 37100, batch loss 0.627509, batch nll 0.222549, batch error rate 8.000000%
# At minibatch 37200, batch loss 0.819257, batch nll 0.414321, batch error rate 20.000000%
# At minibatch 37300, batch loss 0.670603, batch nll 0.265673, batch error rate 12.000000%
# At minibatch 37400, batch loss 0.562813, batch nll 0.157866, batch error rate 4.000000%
# At minibatch 37500, batch loss 0.709119, batch nll 0.304178, batch error rate 16.000000%
# At minibatch 37600, batch loss 0.729800, batch nll 0.324864, batch error rate 12.000000%
# At minibatch 37700, batch loss 0.621207, batch nll 0.216291, batch error rate 0.000000%
# At minibatch 37800, batch loss 0.746822, batch nll 0.341907, batch error rate 8.000000%
# At minibatch 37900, batch loss 0.701441, batch nll 0.296554, batch error rate 16.000000%
# At minibatch 38000, batch loss 0.580376, batch nll 0.175515, batch error rate 4.000000%
# At minibatch 38100, batch loss 0.734410, batch nll 0.329563, batch error rate 12.000000%
# At minibatch 38200, batch loss 0.543924, batch nll 0.139101, batch error rate 0.000000%
# At minibatch 38300, batch loss 0.890648, batch nll 0.485853, batch error rate 8.000000%
# At minibatch 38400, batch loss 0.542750, batch nll 0.137997, batch error rate 4.000000%
# After epoch 24: valid_err_rate: 33.300000% currently going to do 23 epochs
# After epoch 24: averaged train_err_rate: 9.392500% averaged train nll: 0.326093 averaged train loss: 0.730998

# %%
print "Setting network parameters from after epoch %d" %(best_params_epoch)
load_parameters(best_params)

print "Test error rate is %f%%" %(compute_error_rate(cifar10_test_stream)*100.0,)

subplot(2,1,1)
train_nll_a = np.array(train_nll)
semilogy(train_nll_a[:,0], train_nll_a[:,1], label='batch train nll')
legend()

subplot(2,1,2)
train_erros_a = np.array(train_erros)
plot(train_erros_a[:,0], train_erros_a[:,1], label='batch train error rate')
validation_errors_a = np.array(validation_errors)
plot(validation_errors_a[:,0], validation_errors_a[:,1], label='validation error rate', color='r')
ylim(0,0.2)
legend()
# Out:
# Setting network parameters from after epoch 17
# Test error rate is 31.500000%

# %%
iii = predict.maker.inputs[0]
X = iii.variable

# %%
# build a function that shows how the network processes an image

middle_layers_computer = theano.function([X], [
        X,
        after_C1,
        after_P1,
        after_C2,
        after_P2
        ])

# %%
img_num=11

middle_layers = middle_layers_computer(X_test_value[img_num:img_num+1])

for ml, name in zip(middle_layers, ['X', 'C1', 'P1', 'C2', 'P2']):
    plot_mat(ml.transpose(1,0,2,3), cmap='gray')
    title(name)
    show()
