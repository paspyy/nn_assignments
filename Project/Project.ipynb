# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['convolve']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
print theano.__file__
# Out:
# /home/i258324/Dokumenty/SN/tempNN/nn_assignments/libs/Theano/theano/__init__.pyc

# %%
import theano
import theano.tensor.signal.downsample
import skimage.io
from scipy.ndimage.filters import convolve

#note: this requires the starter code for the assignments!
from common.plotting import plot_mat

theano.config.floatX = 'float32'
print theano.config.floatX
# Out:
# float32

# %%
from fuel.datasets.cifar10 import CIFAR10
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme
from common.plotting import plot_mat

CIFAR10.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'}))

cifar10_train = CIFAR10(("train",), subset=slice(None,40000))
#this stream will shuffle the MNIST set and return us batches of 100 examples
cifar10_train_stream = DataStream.default_stream(
    cifar10_train,
    iteration_scheme=ShuffledScheme(cifar10_train.num_examples, 100))
                                               
cifar10_validation = CIFAR10(("train",), subset=slice(40000, None))

# We will use larger portions for testing and validation
# as these dont do a backward pass and reauire less RAM.
cifar10_validation_stream = DataStream.default_stream(
    cifar10_validation, iteration_scheme=SequentialScheme(cifar10_validation.num_examples, 300))
cifar10_test = CIFAR10(("test",))
cifar10_test_stream = DataStream.default_stream(
    cifar10_test, iteration_scheme=SequentialScheme(cifar10_test.num_examples, 300))

# %%
print "The streams return batches containing %s" % (cifar10_train_stream.sources,)

print "Each trainin batch consits of a tuple containing:"
for element in next(cifar10_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(cifar10_test_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    

plot_mat(cifar10_train.data_sources[0][:20], cmap='gray')
# Out:
# The streams return batches containing (u'features', u'targets')
# Each trainin batch consits of a tuple containing:
#  - an array of size (100, 3, 32, 32) containing float32
#  - an array of size (100, 1) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (300, 3, 32, 32) containing float32
#  - an array of size (300, 1) containing uint8

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
# A theano variable is an entry to the cmputational graph
# We will need to provide its value during function call
# X is batch_size x num_channels x img_rows x img_columns
X = theano.tensor.tensor4('X')

# Y is 1D, it lists the targets for all examples
Y = theano.tensor.matrix('Y', dtype='uint8')

#The tag values are useful during debugging the creation of Theano graphs

X_test_value, Y_test_value = next(cifar10_train_stream.get_epoch_iterator())
#
# Unfortunately, test tags don't work with convolutions with newest Theano :(
#
theano.config.compute_test_value = 'warn' # Enable the computation of test values


X.tag.test_value = X_test_value[:3]
Y.tag.test_value = Y_test_value[:3]

print "X shape: %s" % (X.tag.test_value.shape,)

# this list will hold all parameters of the network
model_parameters = []

#The first convolutional layer
#The shape is: num_out_filters x num_in_filters x filter_height x filter_width
num_filters_1 = 10 #we will apply that many convolution filters in the first layer
CW1 = theano.shared(np.zeros((num_filters_1,3,5,5), dtype='float32'), name='CW1')
#please note - this is somewhat non-standard
CW1.tag.initializer = IsotropicGaussian(0.05)

CB1 = theano.shared(np.zeros((num_filters_1,), dtype='float32'), name='CB1')
CB1.tag.initializer = Constant(0.0)
model_parameters += [CW1, CB1]

after_C1 = theano.tensor.maximum(
    0.0,
    theano.tensor.nnet.conv2d(X, CW1) + CB1.dimshuffle('x',0,'x','x'))
print "after_C1 shape: %s" % (after_C1.tag.test_value.shape,)
after_P1 = theano.tensor.signal.downsample.max_pool_2d(after_C1, (2,2), ignore_border=True)
print "after_P1 shape: %s" % (after_P1.tag.test_value.shape,)


num_filters_2 = 25 #we will compute ten convolution filters in the first layer
CW2 = theano.shared(np.zeros((num_filters_2,num_filters_1,5,5), dtype='float32'), name='CW2')
CW2.tag.initializer = IsotropicGaussian(0.05)

CB2 = theano.shared(np.zeros((num_filters_2,), dtype='float32'), name='CB2')
CB2.tag.initializer = Constant(0.0)
model_parameters += [CW2, CB2]

after_C2 = theano.tensor.maximum(
    0.0,
    theano.tensor.nnet.conv2d(after_P1, CW2) + CB2.dimshuffle('x',0,'x','x'))
#print "after_C2 shape: %s" % (after_C2.tag.test_value.shape,)
after_P2 = theano.tensor.signal.downsample.max_pool_2d(after_C2, (2,2), ignore_border=True)
#print "after_P2 shape: %s" % (after_P2.tag.test_value.shape,)

#Fully connected layers - we just flatten all filter maps
num_fw3_hidden=500
FW3 = theano.shared(np.zeros((num_filters_2 * 5 * 5, num_fw3_hidden), dtype='float32'), name='FW3')
#FW3 = theano.shared(np.zeros(( num_fw3_hidden,num_filters_2), dtype='float32'), name='FW3')
FW3.tag.initializer = IsotropicGaussian(0.05)
    
FB3 = theano.shared(np.zeros((num_fw3_hidden,), dtype='float32'), name='FB3')
FB3.tag.initializer = Constant(0.0)
model_parameters += [FW3, FB3]

after_F3 = theano.tensor.maximum(
    0.0, 
    theano.tensor.dot(after_P2.flatten(2), FW3) + FB3.dimshuffle('x',0))
#print "after_F3 shape: %s" % (after_F3.tag.test_value.shape,)


num_fw4_hidden=10
FW4 = theano.shared(np.zeros((num_fw3_hidden, num_fw4_hidden), dtype='float32'), name='FW4')
FW4.tag.initializer = IsotropicGaussian(0.05)

FB4 = theano.shared(np.zeros((num_fw4_hidden,), dtype='float32'), name='FB4')
FB4.tag.initializer = Constant(0.0)
model_parameters += [FW4, FB4]

after_F4 = theano.tensor.dot(after_F3, FW4) + FB4.dimshuffle('x',0)
#print "after_F4 shape: %s" % (after_F4.tag.test_value.shape,)

log_probs = theano.tensor.nnet.softmax(after_F4)

predictions = theano.tensor.argmax(log_probs, axis=1)

error_rate = theano.tensor.neq(predictions,Y.ravel()).mean()
nll = - theano.tensor.log(log_probs[theano.tensor.arange(Y.shape[0]), Y.ravel()]).mean()

weight_decay = 0.0
for p in model_parameters:
    if p.name[1]=='W':
        weight_decay = weight_decay + 1e-3 * (p**2).sum()

cost = nll + weight_decay

#At this point stop computing test values
theano.config.compute_test_value = 'off' # Enable the computation of test values
# Out:
# X shape: (3, 3, 32, 32)
# after_C1 shape: (3, 10, 28, 28)
# after_P1 shape: (3, 10, 14, 14)

# %%
updates = []

lrate = theano.tensor.scalar('lrate',dtype='float32')
momentum = theano.tensor.scalar('momentum',dtype='float32')

# Theano will compute the gradients for us
gradients = theano.grad(cost, model_parameters)

#initialize storage for momentum
velocities = [theano.shared(np.zeros_like(p.get_value()), name='V_%s' %(p.name, )) for p in model_parameters]

for p,g,v in zip(model_parameters, gradients, velocities):
    v_new = momentum * v - lrate * g
    p_new = p + v_new
    updates += [(v,v_new), (p, p_new)]
    
updates
# Out:
# [(V_CW1, Elemwise{sub,no_inplace}.0),
#  (CW1, Elemwise{add,no_inplace}.0),
#  (V_CB1, Elemwise{sub,no_inplace}.0),
#  (CB1, Elemwise{add,no_inplace}.0),
#  (V_CW2, Elemwise{sub,no_inplace}.0),
#  (CW2, Elemwise{add,no_inplace}.0),
#  (V_CB2, Elemwise{sub,no_inplace}.0),
#  (CB2, Elemwise{add,no_inplace}.0),
#  (V_FW3, Elemwise{sub,no_inplace}.0),
#  (FW3, Elemwise{add,no_inplace}.0),
#  (V_FB3, Elemwise{sub,no_inplace}.0),
#  (FB3, Elemwise{add,no_inplace}.0),
#  (V_FW4, Elemwise{sub,no_inplace}.0),
#  (FW4, Elemwise{add,no_inplace}.0),
#  (V_FB4, Elemwise{sub,no_inplace}.0),
#  (FB4, Elemwise{add,no_inplace}.0)]

# %%
#compile theano functions

#each call to train step will make one SGD step
train_step = theano.function([X,Y,lrate,momentum],[cost, error_rate, nll, weight_decay],updates=updates)
#each call to predict will return predictions on a batch of data
predict = theano.function([X], predictions)

# %%
def compute_error_rate(stream):
    errs = 0.0
    num_samples = 0.0
    for X, Y in stream.get_epoch_iterator():
        errs += (predict(X)!=Y.ravel()).sum()
        num_samples += Y.shape[0]
    return errs/num_samples

#utilities to save values of parameters and to load them

def init_parameters():
    rng = np.random.RandomState(1234)
    for p in model_parameters:
        p.set_value(p.tag.initializer.generate(rng, p.get_value().shape))

def snapshot_parameters():
    return [p.get_value(borrow=False) for p in model_parameters]

def load_parameters(snapshot):
    for p, s in zip(model_parameters, snapshot):
        p.set_value(s, borrow=False)

# %%
# init training

i=0
e=0

init_parameters()
for v in velocities:
    v.set_value(np.zeros_like(v.get_value()))

best_valid_error_rate = np.inf
best_params = snapshot_parameters()
best_params_epoch = 0

train_erros = []
train_loss = []
train_nll = []
validation_errors = []

number_of_epochs = 3
patience_expansion = 1.5

# training loop

while e<number_of_epochs: #This loop goes over epochs
    e += 1
    #First train on all data from this batch
    epoch_start_i = i
    for X_batch, Y_batch in cifar10_train_stream.get_epoch_iterator(): 
        i += 1
        
        K = 2000
        lrate = 4e-3 * K / np.maximum(K, i)
        momentum=0.9
        #print X_batch.shape
        #print Y_batch.shape
        #print lrate
        #print momentum
        #print momentum
        L, err_rate, nll, wdec = train_step(X_batch, Y_batch, lrate, momentum)
        
        #print [p.get_value().ravel()[:10] for p in model_parameters]
        #print [p.get_value().ravel()[:10] for p in velocities]
        
        
        train_loss.append((i,L))
        train_erros.append((i,err_rate))
        train_nll.append((i,nll))
        if i % 100 == 0:
            print "At minibatch %d, batch loss %f, batch nll %f, batch error rate %f%%" % (i, L, nll, err_rate*100)
        
    # After an epoch compute validation error
    val_error_rate = compute_error_rate(cifar10_validation_stream)
    if val_error_rate < best_valid_error_rate:
        number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
        best_valid_error_rate = val_error_rate
        best_params = snapshot_parameters()
        best_params_epoch = e
    validation_errors.append((i,val_error_rate))
    print "After epoch %d: valid_err_rate: %f%% currently going to do %d epochs" %(
        e, val_error_rate*100, number_of_epochs)
    print "After epoch %d: averaged train_err_rate: %f%% averaged train nll: %f averaged train loss: %f" %(
        e, np.mean(np.asarray(train_erros)[epoch_start_i:,1])*100, 
        np.mean(np.asarray(train_nll)[epoch_start_i:,1]),
        np.mean(np.asarray(train_loss)[epoch_start_i:,1]))
# Out:
# At minibatch 100, batch loss 2.867633, batch nll 2.064004, batch error rate 73.000000%
# At minibatch 200, batch loss 2.639867, batch nll 1.846993, batch error rate 68.000000%
# At minibatch 300, batch loss 2.504860, batch nll 1.721970, batch error rate 62.000000%
# At minibatch 400, batch loss 2.290012, batch nll 1.517077, batch error rate 50.000000%
# After epoch 1: valid_err_rate: 57.470000% currently going to do 3 epochs
# After epoch 1: averaged train_err_rate: 66.855000% averaged train nll: 1.854063 averaged train loss: 2.647260
# At minibatch 500, batch loss 2.257500, batch nll 1.494758, batch error rate 58.000000%
# At minibatch 600, batch loss 2.239037, batch nll 1.486465, batch error rate 59.000000%
# At minibatch 700, batch loss 2.094494, batch nll 1.351962, batch error rate 43.000000%
# At minibatch 800, batch loss 2.006160, batch nll 1.273406, batch error rate 44.000000%
# After epoch 2: valid_err_rate: 50.460000% currently going to do 4 epochs
# After epoch 2: averaged train_err_rate: 52.815000% averaged train nll: 1.468355 averaged train loss: 2.220962
# At minibatch 900, batch loss 2.153338, batch nll 1.429974, batch error rate 50.000000%
# At minibatch 1000, batch loss 2.026898, batch nll 1.312918, batch error rate 49.000000%
# At minibatch 1100, batch loss 1.965009, batch nll 1.260344, batch error rate 47.000000%
# At minibatch 1200, batch loss 2.066711, batch nll 1.371133, batch error rate 51.000000%
# After epoch 3: valid_err_rate: 46.230000% currently going to do 5 epochs
# After epoch 3: averaged train_err_rate: 47.550000% averaged train nll: 1.326481 averaged train loss: 2.040474
# At minibatch 1300, batch loss 2.111397, batch nll 1.424612, batch error rate 48.000000%
# At minibatch 1400, batch loss 1.945555, batch nll 1.267274, batch error rate 41.000000%
# At minibatch 1500, batch loss 1.958390, batch nll 1.288676, batch error rate 52.000000%
# At minibatch 1600, batch loss 2.115135, batch nll 1.453915, batch error rate 43.000000%
# After epoch 4: valid_err_rate: 44.390000% currently going to do 7 epochs
# After epoch 4: averaged train_err_rate: 43.802500% averaged train nll: 1.236114 averaged train loss: 1.914415
# At minibatch 1700, batch loss 1.829258, batch nll 1.175823, batch error rate 37.000000%
# At minibatch 1800, batch loss 1.740034, batch nll 1.094539, batch error rate 40.000000%
# At minibatch 1900, batch loss 1.660558, batch nll 1.022994, batch error rate 33.000000%
# At minibatch 2000, batch loss 1.795372, batch nll 1.165537, batch error rate 41.000000%
# After epoch 5: valid_err_rate: 42.090000% currently going to do 8 epochs
# After epoch 5: averaged train_err_rate: 41.230000% averaged train nll: 1.163434 averaged train loss: 1.808875
# At minibatch 2100, batch loss 1.681072, batch nll 1.058200, batch error rate 36.000000%
# At minibatch 2200, batch loss 1.653070, batch nll 1.036937, batch error rate 35.000000%
# At minibatch 2300, batch loss 1.634413, batch nll 1.024754, batch error rate 35.000000%
# At minibatch 2400, batch loss 1.631609, batch nll 1.028319, batch error rate 40.000000%
# After epoch 6: valid_err_rate: 39.610000% currently going to do 10 epochs
# After epoch 6: averaged train_err_rate: 38.432500% averaged train nll: 1.091583 averaged train loss: 1.707815
# At minibatch 2500, batch loss 1.678431, batch nll 1.080628, batch error rate 33.000000%
# At minibatch 2600, batch loss 1.568126, batch nll 0.975702, batch error rate 32.000000%
# At minibatch 2700, batch loss 1.650880, batch nll 1.063518, batch error rate 37.000000%
# At minibatch 2800, batch loss 1.421007, batch nll 0.838521, batch error rate 31.000000%
# After epoch 7: valid_err_rate: 38.620000% currently going to do 11 epochs
# After epoch 7: averaged train_err_rate: 36.145000% averaged train nll: 1.029034 averaged train loss: 1.621632
# At minibatch 2900, batch loss 1.804533, batch nll 1.226391, batch error rate 43.000000%
# At minibatch 3000, batch loss 1.607999, batch nll 1.034299, batch error rate 38.000000%
# At minibatch 3100, batch loss 1.592163, batch nll 1.022426, batch error rate 34.000000%
# At minibatch 3200, batch loss 1.653694, batch nll 1.087880, batch error rate 42.000000%
# After epoch 8: valid_err_rate: 36.960000% currently going to do 13 epochs
# After epoch 8: averaged train_err_rate: 34.300000% averaged train nll: 0.977349 averaged train loss: 1.551244
# At minibatch 3300, batch loss 1.379327, batch nll 0.816983, batch error rate 28.000000%
# At minibatch 3400, batch loss 1.399079, batch nll 0.840166, batch error rate 30.000000%
# At minibatch 3500, batch loss 1.277645, batch nll 0.722408, batch error rate 20.000000%
# At minibatch 3600, batch loss 1.466724, batch nll 0.914847, batch error rate 32.000000%
# After epoch 9: valid_err_rate: 36.780000% currently going to do 14 epochs
# After epoch 9: averaged train_err_rate: 32.345000% averaged train nll: 0.932135 averaged train loss: 1.490919
# At minibatch 3700, batch loss 1.528071, batch nll 0.979097, batch error rate 36.000000%
# At minibatch 3800, batch loss 1.650299, batch nll 1.104190, batch error rate 37.000000%
# At minibatch 3900, batch loss 1.265018, batch nll 0.721794, batch error rate 23.000000%
# At minibatch 4000, batch loss 1.440570, batch nll 0.900307, batch error rate 33.000000%
# After epoch 10: valid_err_rate: 36.820000% currently going to do 14 epochs
# After epoch 10: averaged train_err_rate: 31.230000% averaged train nll: 0.896217 averaged train loss: 1.442254
# At minibatch 4100, batch loss 1.593027, batch nll 1.055071, batch error rate 33.000000%
# At minibatch 4200, batch loss 1.451609, batch nll 0.916276, batch error rate 31.000000%
# At minibatch 4300, batch loss 1.345086, batch nll 0.812283, batch error rate 29.000000%
# At minibatch 4400, batch loss 1.395889, batch nll 0.865508, batch error rate 25.000000%
# After epoch 11: valid_err_rate: 34.980000% currently going to do 17 epochs
# After epoch 11: averaged train_err_rate: 29.830000% averaged train nll: 0.859560 averaged train loss: 1.394881
# At minibatch 4500, batch loss 1.225282, batch nll 0.697050, batch error rate 22.000000%
# At minibatch 4600, batch loss 1.340091, batch nll 0.814031, batch error rate 30.000000%
# At minibatch 4700, batch loss 1.207136, batch nll 0.683306, batch error rate 26.000000%
# At minibatch 4800, batch loss 1.351141, batch nll 0.829396, batch error rate 29.000000%
# After epoch 12: valid_err_rate: 35.360000% currently going to do 17 epochs
# After epoch 12: averaged train_err_rate: 28.687500% averaged train nll: 0.827459 averaged train loss: 1.353501
# At minibatch 4900, batch loss 1.263697, batch nll 0.743812, batch error rate 24.000000%
# At minibatch 5000, batch loss 1.217625, batch nll 0.699571, batch error rate 23.000000%
# At minibatch 5100, batch loss 1.144970, batch nll 0.628829, batch error rate 22.000000%
# At minibatch 5200, batch loss 1.299654, batch nll 0.785390, batch error rate 23.000000%
# After epoch 13: valid_err_rate: 34.110000% currently going to do 20 epochs
# After epoch 13: averaged train_err_rate: 28.040000% averaged train nll: 0.804921 averaged train loss: 1.322932
# At minibatch 5300, batch loss 1.290767, batch nll 0.778073, batch error rate 31.000000%
# At minibatch 5400, batch loss 1.441190, batch nll 0.930094, batch error rate 33.000000%
# At minibatch 5500, batch loss 1.363421, batch nll 0.854180, batch error rate 28.000000%
# At minibatch 5600, batch loss 1.317808, batch nll 0.810137, batch error rate 25.000000%
# After epoch 14: valid_err_rate: 34.770000% currently going to do 20 epochs
# After epoch 14: averaged train_err_rate: 26.810000% averaged train nll: 0.776494 averaged train loss: 1.287496
# At minibatch 5700, batch loss 1.339268, batch nll 0.833019, batch error rate 27.000000%
# At minibatch 5800, batch loss 1.129122, batch nll 0.624292, batch error rate 22.000000%
# At minibatch 5900, batch loss 1.188457, batch nll 0.685206, batch error rate 27.000000%
# At minibatch 6000, batch loss 1.163730, batch nll 0.661957, batch error rate 23.000000%
# After epoch 15: valid_err_rate: 33.390000% currently going to do 23 epochs
# After epoch 15: averaged train_err_rate: 25.867500% averaged train nll: 0.750208 averaged train loss: 1.254950
# At minibatch 6100, batch loss 1.287508, batch nll 0.786961, batch error rate 30.000000%
# At minibatch 6200, batch loss 1.127295, batch nll 0.627964, batch error rate 25.000000%
# At minibatch 6300, batch loss 1.222940, batch nll 0.725067, batch error rate 29.000000%
# At minibatch 6400, batch loss 1.220569, batch nll 0.724066, batch error rate 25.000000%
# After epoch 16: valid_err_rate: 33.260000% currently going to do 25 epochs
# After epoch 16: averaged train_err_rate: 25.057500% averaged train nll: 0.728810 averaged train loss: 1.228025
# At minibatch 6500, batch loss 1.282397, batch nll 0.787033, batch error rate 30.000000%
# At minibatch 6600, batch loss 1.331743, batch nll 0.837475, batch error rate 27.000000%
# At minibatch 6700, batch loss 1.075636, batch nll 0.582572, batch error rate 19.000000%
# At minibatch 6800, batch loss 1.208586, batch nll 0.716735, batch error rate 25.000000%
# After epoch 17: valid_err_rate: 33.490000% currently going to do 25 epochs
# After epoch 17: averaged train_err_rate: 24.182500% averaged train nll: 0.706448 averaged train loss: 1.200659
# At minibatch 6900, batch loss 1.192177, batch nll 0.701281, batch error rate 22.000000%
# At minibatch 7000, batch loss 1.046184, batch nll 0.556404, batch error rate 15.000000%
# At minibatch 7100, batch loss 1.147710, batch nll 0.658982, batch error rate 25.000000%
# At minibatch 7200, batch loss 1.037347, batch nll 0.549696, batch error rate 22.000000%
# After epoch 18: valid_err_rate: 33.080000% currently going to do 28 epochs
# After epoch 18: averaged train_err_rate: 23.607500% averaged train nll: 0.688965 averaged train loss: 1.178753
# At minibatch 7300, batch loss 1.195648, batch nll 0.708948, batch error rate 22.000000%
# At minibatch 7400, batch loss 1.187797, batch nll 0.702019, batch error rate 24.000000%
# At minibatch 7500, batch loss 1.100549, batch nll 0.615709, batch error rate 21.000000%
# At minibatch 7600, batch loss 1.175966, batch nll 0.692189, batch error rate 22.000000%
# After epoch 19: valid_err_rate: 32.700000% currently going to do 29 epochs
# After epoch 19: averaged train_err_rate: 22.835000% averaged train nll: 0.666592 averaged train loss: 1.152349
# At minibatch 7700, batch loss 1.263999, batch nll 0.780997, batch error rate 32.000000%
# At minibatch 7800, batch loss 1.172092, batch nll 0.689964, batch error rate 24.000000%
# At minibatch 7900, batch loss 1.152553, batch nll 0.671311, batch error rate 28.000000%
# At minibatch 8000, batch loss 0.989695, batch nll 0.509422, batch error rate 19.000000%
# After epoch 20: valid_err_rate: 32.460000% currently going to do 31 epochs
# After epoch 20: averaged train_err_rate: 22.112500% averaged train nll: 0.648147 averaged train loss: 1.130242
# At minibatch 8100, batch loss 1.106045, batch nll 0.626515, batch error rate 22.000000%
# At minibatch 8200, batch loss 1.114082, batch nll 0.635296, batch error rate 18.000000%
# At minibatch 8300, batch loss 1.187150, batch nll 0.709168, batch error rate 26.000000%
# At minibatch 8400, batch loss 1.042341, batch nll 0.565215, batch error rate 19.000000%
# After epoch 21: valid_err_rate: 33.230000% currently going to do 31 epochs
# After epoch 21: averaged train_err_rate: 21.427500% averaged train nll: 0.633085 averaged train loss: 1.111842
# At minibatch 8500, batch loss 1.043413, batch nll 0.566995, batch error rate 20.000000%
# At minibatch 8600, batch loss 0.973094, batch nll 0.497371, batch error rate 17.000000%
# At minibatch 8700, batch loss 1.175772, batch nll 0.700749, batch error rate 26.000000%
# At minibatch 8800, batch loss 1.115049, batch nll 0.640778, batch error rate 26.000000%
# After epoch 22: valid_err_rate: 32.360000% currently going to do 34 epochs
# After epoch 22: averaged train_err_rate: 20.880000% averaged train nll: 0.615089 averaged train loss: 1.090812
# At minibatch 8900, batch loss 1.070462, batch nll 0.596816, batch error rate 20.000000%
# At minibatch 9000, batch loss 1.156839, batch nll 0.683818, batch error rate 28.000000%
# At minibatch 9100, batch loss 1.116048, batch nll 0.643688, batch error rate 20.000000%
# At minibatch 9200, batch loss 0.977677, batch nll 0.506082, batch error rate 15.000000%
# After epoch 23: valid_err_rate: 32.490000% currently going to do 34 epochs
# After epoch 23: averaged train_err_rate: 20.255000% averaged train nll: 0.598870 averaged train loss: 1.071855
# At minibatch 9300, batch loss 1.130037, batch nll 0.658995, batch error rate 22.000000%
# At minibatch 9400, batch loss 1.261027, batch nll 0.790594, batch error rate 30.000000%
# At minibatch 9500, batch loss 0.949761, batch nll 0.479894, batch error rate 13.000000%
# At minibatch 9600, batch loss 1.069130, batch nll 0.599901, batch error rate 20.000000%
# After epoch 24: valid_err_rate: 32.430000% currently going to do 34 epochs
# After epoch 24: averaged train_err_rate: 19.482500% averaged train nll: 0.580290 averaged train loss: 1.050722
# At minibatch 9700, batch loss 1.019942, batch nll 0.551226, batch error rate 21.000000%
# At minibatch 9800, batch loss 1.139736, batch nll 0.671618, batch error rate 17.000000%
# At minibatch 9900, batch loss 0.938284, batch nll 0.470741, batch error rate 13.000000%
# At minibatch 10000, batch loss 1.080951, batch nll 0.613967, batch error rate 18.000000%
# After epoch 25: valid_err_rate: 32.170000% currently going to do 38 epochs
# After epoch 25: averaged train_err_rate: 19.220000% averaged train nll: 0.568752 averaged train loss: 1.036872
# At minibatch 10100, batch loss 0.912437, batch nll 0.445939, batch error rate 15.000000%
# At minibatch 10200, batch loss 1.108937, batch nll 0.642932, batch error rate 22.000000%
# At minibatch 10300, batch loss 1.165145, batch nll 0.699643, batch error rate 24.000000%
# At minibatch 10400, batch loss 0.973529, batch nll 0.508576, batch error rate 17.000000%
# After epoch 26: valid_err_rate: 31.940000% currently going to do 40 epochs
# After epoch 26: averaged train_err_rate: 18.585000% averaged train nll: 0.553596 averaged train loss: 1.019588
# At minibatch 10500, batch loss 0.940400, batch nll 0.475788, batch error rate 16.000000%
# At minibatch 10600, batch loss 0.959522, batch nll 0.495425, batch error rate 17.000000%
# At minibatch 10700, batch loss 1.081584, batch nll 0.617953, batch error rate 22.000000%
# At minibatch 10800, batch loss 0.986884, batch nll 0.523786, batch error rate 17.000000%
# After epoch 27: valid_err_rate: 31.880000% currently going to do 41 epochs
# After epoch 27: averaged train_err_rate: 17.900000% averaged train nll: 0.540026 averaged train loss: 1.004115
# At minibatch 10900, batch loss 1.020394, batch nll 0.557663, batch error rate 20.000000%
# At minibatch 11000, batch loss 1.114912, batch nll 0.652602, batch error rate 24.000000%
# At minibatch 11100, batch loss 0.891382, batch nll 0.429538, batch error rate 13.000000%
# At minibatch 11200, batch loss 1.007188, batch nll 0.545857, batch error rate 20.000000%
# After epoch 28: valid_err_rate: 32.300000% currently going to do 41 epochs
# After epoch 28: averaged train_err_rate: 17.295000% averaged train nll: 0.524105 averaged train loss: 0.986380
# At minibatch 11300, batch loss 1.058385, batch nll 0.597428, batch error rate 19.000000%
# At minibatch 11400, batch loss 1.022540, batch nll 0.561955, batch error rate 22.000000%
# At minibatch 11500, batch loss 1.023876, batch nll 0.563759, batch error rate 23.000000%
# At minibatch 11600, batch loss 0.965131, batch nll 0.505413, batch error rate 20.000000%
# After epoch 29: valid_err_rate: 32.620000% currently going to do 41 epochs
# After epoch 29: averaged train_err_rate: 17.005000% averaged train nll: 0.512334 averaged train loss: 0.972876
# At minibatch 11700, batch loss 0.896645, batch nll 0.437283, batch error rate 11.000000%
# At minibatch 11800, batch loss 1.167458, batch nll 0.708482, batch error rate 24.000000%
# At minibatch 11900, batch loss 0.888147, batch nll 0.429587, batch error rate 13.000000%
# At minibatch 12000, batch loss 0.890735, batch nll 0.432537, batch error rate 11.000000%
# After epoch 30: valid_err_rate: 31.970000% currently going to do 41 epochs
# After epoch 30: averaged train_err_rate: 16.615000% averaged train nll: 0.502780 averaged train loss: 0.961742
# At minibatch 12100, batch loss 0.916433, batch nll 0.458515, batch error rate 18.000000%
# At minibatch 12200, batch loss 0.835680, batch nll 0.378132, batch error rate 10.000000%
# At minibatch 12300, batch loss 0.874911, batch nll 0.417716, batch error rate 13.000000%
# At minibatch 12400, batch loss 0.874850, batch nll 0.418015, batch error rate 15.000000%
# After epoch 31: valid_err_rate: 32.240000% currently going to do 41 epochs
# After epoch 31: averaged train_err_rate: 15.860000% averaged train nll: 0.486757 averaged train loss: 0.944306
# At minibatch 12500, batch loss 0.902326, batch nll 0.445756, batch error rate 12.000000%
# At minibatch 12600, batch loss 0.920818, batch nll 0.464576, batch error rate 17.000000%
# At minibatch 12700, batch loss 0.968180, batch nll 0.512259, batch error rate 18.000000%
# At minibatch 12800, batch loss 1.105621, batch nll 0.650049, batch error rate 20.000000%
# After epoch 32: valid_err_rate: 32.140000% currently going to do 41 epochs
# After epoch 32: averaged train_err_rate: 15.482500% averaged train nll: 0.473885 averaged train loss: 0.930117
# At minibatch 12900, batch loss 0.847255, batch nll 0.391954, batch error rate 14.000000%
# At minibatch 13000, batch loss 0.899989, batch nll 0.444972, batch error rate 15.000000%
# At minibatch 13100, batch loss 0.818002, batch nll 0.363310, batch error rate 9.000000%
# At minibatch 13200, batch loss 0.940229, batch nll 0.485883, batch error rate 14.000000%
# After epoch 33: valid_err_rate: 32.580000% currently going to do 41 epochs
# After epoch 33: averaged train_err_rate: 15.125000% averaged train nll: 0.464892 averaged train loss: 0.919878
# At minibatch 13300, batch loss 0.864192, batch nll 0.410050, batch error rate 13.000000%
# At minibatch 13400, batch loss 0.864141, batch nll 0.410249, batch error rate 11.000000%
# At minibatch 13500, batch loss 0.935816, batch nll 0.482222, batch error rate 17.000000%
# At minibatch 13600, batch loss 1.037260, batch nll 0.583995, batch error rate 19.000000%
# After epoch 34: valid_err_rate: 31.990000% currently going to do 41 epochs
# After epoch 34: averaged train_err_rate: 14.440000% averaged train nll: 0.451936 averaged train loss: 0.905797
# At minibatch 13700, batch loss 0.965065, batch nll 0.512073, batch error rate 17.000000%
# At minibatch 13800, batch loss 0.996274, batch nll 0.543531, batch error rate 15.000000%
# At minibatch 13900, batch loss 0.928755, batch nll 0.476266, batch error rate 16.000000%
# At minibatch 14000, batch loss 0.890495, batch nll 0.438251, batch error rate 12.000000%
# After epoch 35: valid_err_rate: 31.680000% currently going to do 53 epochs
# After epoch 35: averaged train_err_rate: 14.140000% averaged train nll: 0.440927 averaged train loss: 0.893669
# At minibatch 14100, batch loss 0.747773, batch nll 0.295762, batch error rate 7.000000%
# At minibatch 14200, batch loss 0.913527, batch nll 0.461747, batch error rate 12.000000%
# At minibatch 14300, batch loss 0.802795, batch nll 0.351253, batch error rate 12.000000%
# At minibatch 14400, batch loss 0.910482, batch nll 0.459194, batch error rate 15.000000%
# After epoch 36: valid_err_rate: 31.540000% currently going to do 55 epochs
# After epoch 36: averaged train_err_rate: 13.700000% averaged train nll: 0.430779 averaged train loss: 0.882549
# At minibatch 14500, batch loss 0.914175, batch nll 0.463073, batch error rate 17.000000%
# At minibatch 14600, batch loss 0.883061, batch nll 0.432166, batch error rate 16.000000%
# At minibatch 14700, batch loss 0.917885, batch nll 0.467228, batch error rate 17.000000%
# At minibatch 14800, batch loss 0.887001, batch nll 0.436591, batch error rate 16.000000%
# After epoch 37: valid_err_rate: 31.950000% currently going to do 55 epochs
# After epoch 37: averaged train_err_rate: 13.317500% averaged train nll: 0.419902 averaged train loss: 0.870777
# At minibatch 14900, batch loss 0.858004, batch nll 0.407780, batch error rate 15.000000%
# At minibatch 15000, batch loss 0.824193, batch nll 0.374166, batch error rate 12.000000%
# At minibatch 15100, batch loss 0.782447, batch nll 0.332642, batch error rate 11.000000%
# At minibatch 15200, batch loss 0.851187, batch nll 0.401598, batch error rate 13.000000%
# After epoch 38: valid_err_rate: 31.740000% currently going to do 55 epochs
# After epoch 38: averaged train_err_rate: 12.842500% averaged train nll: 0.410411 averaged train loss: 0.860423
# At minibatch 15300, batch loss 0.734910, batch nll 0.285516, batch error rate 9.000000%
# At minibatch 15400, batch loss 0.992227, batch nll 0.543038, batch error rate 17.000000%
# At minibatch 15500, batch loss 0.955972, batch nll 0.506974, batch error rate 18.000000%
# At minibatch 15600, batch loss 0.920674, batch nll 0.471889, batch error rate 15.000000%
# After epoch 39: valid_err_rate: 31.510000% currently going to do 59 epochs
# After epoch 39: averaged train_err_rate: 12.585000% averaged train nll: 0.401163 averaged train loss: 0.850353
# At minibatch 15700, batch loss 0.770243, batch nll 0.321625, batch error rate 9.000000%
# At minibatch 15800, batch loss 0.748924, batch nll 0.300486, batch error rate 9.000000%
# At minibatch 15900, batch loss 0.821766, batch nll 0.373538, batch error rate 10.000000%
# At minibatch 16000, batch loss 0.862751, batch nll 0.414740, batch error rate 15.000000%
# After epoch 40: valid_err_rate: 31.850000% currently going to do 59 epochs
# After epoch 40: averaged train_err_rate: 12.285000% averaged train nll: 0.392798 averaged train loss: 0.841223
# At minibatch 16100, batch loss 0.888911, batch nll 0.441039, batch error rate 8.000000%
# At minibatch 16200, batch loss 0.865875, batch nll 0.418158, batch error rate 13.000000%
# At minibatch 16300, batch loss 0.826357, batch nll 0.378836, batch error rate 9.000000%
# At minibatch 16400, batch loss 0.823700, batch nll 0.376361, batch error rate 13.000000%
# After epoch 41: valid_err_rate: 31.810000% currently going to do 59 epochs
# After epoch 41: averaged train_err_rate: 11.695000% averaged train nll: 0.380785 averaged train loss: 0.828481
# At minibatch 16500, batch loss 0.756203, batch nll 0.309027, batch error rate 10.000000%
# At minibatch 16600, batch loss 0.860706, batch nll 0.413694, batch error rate 16.000000%
# At minibatch 16700, batch loss 0.739568, batch nll 0.292715, batch error rate 8.000000%
# At minibatch 16800, batch loss 0.767005, batch nll 0.320337, batch error rate 9.000000%
# After epoch 42: valid_err_rate: 32.310000% currently going to do 59 epochs
# After epoch 42: averaged train_err_rate: 11.310000% averaged train nll: 0.373123 averaged train loss: 0.820131
# At minibatch 16900, batch loss 0.752196, batch nll 0.305656, batch error rate 12.000000%
# At minibatch 17000, batch loss 0.878869, batch nll 0.432486, batch error rate 15.000000%
# At minibatch 17100, batch loss 0.824123, batch nll 0.377914, batch error rate 14.000000%
# At minibatch 17200, batch loss 0.785055, batch nll 0.339000, batch error rate 13.000000%
# After epoch 43: valid_err_rate: 32.320000% currently going to do 59 epochs
# After epoch 43: averaged train_err_rate: 11.042500% averaged train nll: 0.365127 averaged train loss: 0.811499
# At minibatch 17300, batch loss 0.797315, batch nll 0.351397, batch error rate 9.000000%
# At minibatch 17400, batch loss 0.793024, batch nll 0.347240, batch error rate 12.000000%
# At minibatch 17500, batch loss 0.881306, batch nll 0.435674, batch error rate 14.000000%
# At minibatch 17600, batch loss 0.796258, batch nll 0.350803, batch error rate 7.000000%
# After epoch 44: valid_err_rate: 32.270000% currently going to do 59 epochs
# After epoch 44: averaged train_err_rate: 10.925000% averaged train nll: 0.358438 averaged train loss: 0.804208
# At minibatch 17700, batch loss 0.825258, batch nll 0.379908, batch error rate 12.000000%
# At minibatch 17800, batch loss 0.756462, batch nll 0.311270, batch error rate 6.000000%
# At minibatch 17900, batch loss 0.731801, batch nll 0.286756, batch error rate 8.000000%
# At minibatch 18000, batch loss 0.771451, batch nll 0.326549, batch error rate 10.000000%
# After epoch 45: valid_err_rate: 32.220000% currently going to do 59 epochs
# After epoch 45: averaged train_err_rate: 10.377500% averaged train nll: 0.347991 averaged train loss: 0.793184
# At minibatch 18100, batch loss 0.842842, batch nll 0.398047, batch error rate 13.000000%
# At minibatch 18200, batch loss 0.785628, batch nll 0.340965, batch error rate 11.000000%
# At minibatch 18300, batch loss 0.801954, batch nll 0.357432, batch error rate 8.000000%
# At minibatch 18400, batch loss 0.772235, batch nll 0.327847, batch error rate 9.000000%
# After epoch 46: valid_err_rate: 32.630000% currently going to do 59 epochs
# After epoch 46: averaged train_err_rate: 10.145000% averaged train nll: 0.339913 averaged train loss: 0.784572
# At minibatch 18500, batch loss 0.734882, batch nll 0.290591, batch error rate 10.000000%
# At minibatch 18600, batch loss 0.752131, batch nll 0.307961, batch error rate 9.000000%
# At minibatch 18700, batch loss 0.922242, batch nll 0.478203, batch error rate 14.000000%
# At minibatch 18800, batch loss 0.877645, batch nll 0.433746, batch error rate 11.000000%
# After epoch 47: valid_err_rate: 31.980000% currently going to do 59 epochs
# After epoch 47: averaged train_err_rate: 9.850000% averaged train nll: 0.333727 averaged train loss: 0.777885
# At minibatch 18900, batch loss 0.698902, batch nll 0.255105, batch error rate 4.000000%
# At minibatch 19000, batch loss 0.673643, batch nll 0.229968, batch error rate 6.000000%
# At minibatch 19100, batch loss 0.686755, batch nll 0.243204, batch error rate 7.000000%
# At minibatch 19200, batch loss 0.769034, batch nll 0.325609, batch error rate 8.000000%
# After epoch 48: valid_err_rate: 32.060000% currently going to do 59 epochs
# After epoch 48: averaged train_err_rate: 9.412500% averaged train nll: 0.325634 averaged train loss: 0.769307
# At minibatch 19300, batch loss 0.731302, batch nll 0.287949, batch error rate 7.000000%
# At minibatch 19400, batch loss 0.851922, batch nll 0.408678, batch error rate 10.000000%
# At minibatch 19500, batch loss 0.828599, batch nll 0.385477, batch error rate 10.000000%
# At minibatch 19600, batch loss 0.743591, batch nll 0.300603, batch error rate 8.000000%
# After epoch 49: valid_err_rate: 32.230000% currently going to do 59 epochs
# After epoch 49: averaged train_err_rate: 9.025000% averaged train nll: 0.315929 averaged train loss: 0.759160
# At minibatch 19700, batch loss 0.694189, batch nll 0.251313, batch error rate 7.000000%
# At minibatch 19800, batch loss 0.822411, batch nll 0.379628, batch error rate 14.000000%
# At minibatch 19900, batch loss 0.803925, batch nll 0.361244, batch error rate 12.000000%
# At minibatch 20000, batch loss 0.765135, batch nll 0.322575, batch error rate 8.000000%
# After epoch 50: valid_err_rate: 32.090000% currently going to do 59 epochs
# After epoch 50: averaged train_err_rate: 8.742500% averaged train nll: 0.308846 averaged train loss: 0.751624
# At minibatch 20100, batch loss 0.724033, batch nll 0.281554, batch error rate 6.000000%
# At minibatch 20200, batch loss 0.714208, batch nll 0.271852, batch error rate 7.000000%
# At minibatch 20300, batch loss 0.746593, batch nll 0.304321, batch error rate 9.000000%
# At minibatch 20400, batch loss 0.778102, batch nll 0.335952, batch error rate 9.000000%
# After epoch 51: valid_err_rate: 32.520000% currently going to do 59 epochs
# After epoch 51: averaged train_err_rate: 8.465000% averaged train nll: 0.302995 averaged train loss: 0.745358
# At minibatch 20500, batch loss 0.769327, batch nll 0.327253, batch error rate 10.000000%
# At minibatch 20600, batch loss 0.684124, batch nll 0.242159, batch error rate 9.000000%
# At minibatch 20700, batch loss 0.731091, batch nll 0.289231, batch error rate 10.000000%
# At minibatch 20800, batch loss 0.770972, batch nll 0.329214, batch error rate 9.000000%
# After epoch 52: valid_err_rate: 32.370000% currently going to do 59 epochs
# After epoch 52: averaged train_err_rate: 8.262500% averaged train nll: 0.296494 averaged train loss: 0.738457
# At minibatch 20900, batch loss 0.728813, batch nll 0.287134, batch error rate 8.000000%
# At minibatch 21000, batch loss 0.771462, batch nll 0.329869, batch error rate 8.000000%
# At minibatch 21100, batch loss 0.790697, batch nll 0.349204, batch error rate 9.000000%
# At minibatch 21200, batch loss 0.714817, batch nll 0.273442, batch error rate 7.000000%
# After epoch 53: valid_err_rate: 32.380000% currently going to do 59 epochs
# After epoch 53: averaged train_err_rate: 8.027500% averaged train nll: 0.290106 averaged train loss: 0.731693
# At minibatch 21300, batch loss 0.733920, batch nll 0.292617, batch error rate 9.000000%
# At minibatch 21400, batch loss 0.821603, batch nll 0.380377, batch error rate 12.000000%
# At minibatch 21500, batch loss 0.751224, batch nll 0.310093, batch error rate 9.000000%
# At minibatch 21600, batch loss 0.806903, batch nll 0.365884, batch error rate 8.000000%
# After epoch 54: valid_err_rate: 32.090000% currently going to do 59 epochs
# After epoch 54: averaged train_err_rate: 7.650000% averaged train nll: 0.282498 averaged train loss: 0.723712
# At minibatch 21700, batch loss 0.741634, batch nll 0.300679, batch error rate 6.000000%
# At minibatch 21800, batch loss 0.711356, batch nll 0.270478, batch error rate 7.000000%
# At minibatch 21900, batch loss 0.711554, batch nll 0.270774, batch error rate 10.000000%
# At minibatch 22000, batch loss 0.647273, batch nll 0.206589, batch error rate 6.000000%
# After epoch 55: valid_err_rate: 32.890000% currently going to do 59 epochs
# After epoch 55: averaged train_err_rate: 7.372500% averaged train nll: 0.276847 averaged train loss: 0.717713
# At minibatch 22100, batch loss 0.784166, batch nll 0.343560, batch error rate 12.000000%
# At minibatch 22200, batch loss 0.829349, batch nll 0.388827, batch error rate 11.000000%
# At minibatch 22300, batch loss 0.777893, batch nll 0.337448, batch error rate 9.000000%
# At minibatch 22400, batch loss 0.714178, batch nll 0.273832, batch error rate 8.000000%
# After epoch 56: valid_err_rate: 32.190000% currently going to do 59 epochs
# After epoch 56: averaged train_err_rate: 7.022500% averaged train nll: 0.270252 averaged train loss: 0.710775
# At minibatch 22500, batch loss 0.664687, batch nll 0.224412, batch error rate 7.000000%
# At minibatch 22600, batch loss 0.677142, batch nll 0.236941, batch error rate 4.000000%
# At minibatch 22700, batch loss 0.782684, batch nll 0.342576, batch error rate 8.000000%
# At minibatch 22800, batch loss 0.686046, batch nll 0.246025, batch error rate 8.000000%
# After epoch 57: valid_err_rate: 32.420000% currently going to do 59 epochs
# After epoch 57: averaged train_err_rate: 6.935000% averaged train nll: 0.264050 averaged train loss: 0.704242
# At minibatch 22900, batch loss 0.749012, batch nll 0.309055, batch error rate 8.000000%
# At minibatch 23000, batch loss 0.738519, batch nll 0.298632, batch error rate 8.000000%
# At minibatch 23100, batch loss 0.806524, batch nll 0.366725, batch error rate 12.000000%
# At minibatch 23200, batch loss 0.711802, batch nll 0.272086, batch error rate 9.000000%
# After epoch 58: valid_err_rate: 32.240000% currently going to do 59 epochs
# After epoch 58: averaged train_err_rate: 6.592500% averaged train nll: 0.258685 averaged train loss: 0.698562
# At minibatch 23300, batch loss 0.681780, batch nll 0.242134, batch error rate 4.000000%
# At minibatch 23400, batch loss 0.715640, batch nll 0.276059, batch error rate 9.000000%
# At minibatch 23500, batch loss 0.703367, batch nll 0.263860, batch error rate 7.000000%
# At minibatch 23600, batch loss 0.710742, batch nll 0.271329, batch error rate 6.000000%
# After epoch 59: valid_err_rate: 32.490000% currently going to do 59 epochs
# After epoch 59: averaged train_err_rate: 6.480000% averaged train nll: 0.254180 averaged train loss: 0.693752
# At minibatch 23700, batch loss 0.672621, batch nll 0.233267, batch error rate 7.000000%
# At minibatch 23800, batch loss 0.647557, batch nll 0.208280, batch error rate 6.000000%
# At minibatch 23900, batch loss 0.756269, batch nll 0.317058, batch error rate 11.000000%
# At minibatch 24000, batch loss 0.694505, batch nll 0.255398, batch error rate 7.000000%
# After epoch 60: valid_err_rate: 32.940000% currently going to do 59 epochs
# After epoch 60: averaged train_err_rate: 6.250000% averaged train nll: 0.247774 averaged train loss: 0.687050

# %%
print "Setting network parameters from after epoch %d" %(best_params_epoch)
load_parameters(best_params)

print "Test error rate is %f%%" %(compute_error_rate(cifar10_test_stream)*100.0,)

figure(figsize=(16,14))

subplot(2,1,1)
train_nll_a = np.array(train_nll)
semilogy(train_nll_a[:,0], train_nll_a[:,1], label='batch train nll')
legend()

subplot(2,1,2)
train_erros_a = np.array(train_erros)
plot(train_erros_a[:,0], train_erros_a[:,1], label='batch train error rate')
validation_errors_a = np.array(validation_errors)
plot(validation_errors_a[:,0], validation_errors_a[:,1], label='validation error rate', color='r')
ylim(0,0.8)
legend()
# Out:
# Setting network parameters from after epoch 39
# Test error rate is 33.110000%

# %%
iii = predict.maker.inputs[0]
X = iii.variable

# %%
# build a function that shows how the network processes an image

middle_layers_computer = theano.function([X], [
        X,
        after_C1,
        after_P1,
        after_C2,
        after_P2
        ])

# %%
img_num=11

middle_layers = middle_layers_computer(X_test_value[img_num:img_num+1])
print middle_layers[0].transpose(1,0,2,3).shape
print middle_layers[1].shape
print middle_layers[2].shape
print middle_layers[3].shape
print middle_layers[4].shape

for ml, name in zip(middle_layers, ['X', 'C1', 'P1', 'C2', 'P2']):
    plot_mat(ml.transpose(1,0,2,3), cmap='gray')
    title(name)
    show()
# Out:
# (3, 1, 32, 32)
# (1, 10, 28, 28)
# (1, 10, 14, 14)
# (1, 25, 10, 10)
# (1, 25, 5, 5)
