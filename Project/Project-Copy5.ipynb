# %%
# %pylab inline

from scipy.ndimage.filters import convolve

import theano
import theano.tensor.signal.downsample
import skimage.io
print theano.config.floatX

from common.plotting import plot_mat

from fuel.datasets.cifar10 import CIFAR10
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme
# Out:
# Populating the interactive namespace from numpy and matplotlib
# float32
# Using gpu device 0: GeForce GTX 780 (CNMeM is enabled)

# %%
CIFAR10.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'})
)

cifar10_train = CIFAR10(("train",), subset=slice(None,40000))
cifar10_valid = CIFAR10(("train",), subset=slice(40000, None))
cifar10_testt  = CIFAR10(("test",))

minibatch_train = 125
minibatch_valid = 100
minibatch_testt = 100

cifar10_train_stream = DataStream.default_stream(
    cifar10_train,
    iteration_scheme=ShuffledScheme(cifar10_train.num_examples, minibatch_train)
)
cifar10_valid_stream = DataStream.default_stream(
    cifar10_valid, 
    iteration_scheme=SequentialScheme(cifar10_valid.num_examples, minibatch_valid)
)
cifar10_testt_stream = DataStream.default_stream(
    cifar10_testt, 
    iteration_scheme=SequentialScheme(cifar10_testt.num_examples, minibatch_testt)
)

print "Each trainin batch consits of a tuple containing:"
for element in next(cifar10_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(cifar10_testt_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    

plot_mat(cifar10_train.data_sources[0][:20], cmap='gray')

asd = 0
for x,y in cifar10_train_stream.get_epoch_iterator():
    asd += 1
print asd
# Out:
# Each trainin batch consits of a tuple containing:
#  - an array of size (125, 3, 32, 32) containing float32
#  - an array of size (125, 1) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (100, 3, 32, 32) containing float32
#  - an array of size (100, 1) containing uint8
# 320

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
def print_warn(s, X):
    print "after_%s shape: %s" % (s, X.tag.test_value.shape,)

class Layer_Conv():
    def __init__(self, in_chan, out_chan, size):
        self.in_chan = in_chan
        self.out_chan = out_chan
        self.size = size
    def make(self, X, n):
        CWn = theano.shared(np.zeros((self.out_chan, self.in_chan, self.size, self.size), dtype='float32'), name=('CW%d'%n))
        CBn = theano.shared(np.zeros((self.out_chan,), dtype='float32'), name=('CB%d'%n))
        
        CWn.tag.initializer = IsotropicGaussian(0.05)
        CBn.tag.initializer = Constant(0.0)
        
        after_Cn = theano.tensor.maximum(
            0.0,
            theano.tensor.nnet.conv2d(X, CWn) + CBn.dimshuffle('x',0,'x','x')
        )
        print_warn(("C%d"%n), after_Cn)
        
        return after_Cn, [CWn, CBn], [("C%d"%n)]
    
class Layer_Pool():
    def __init__(self, size):
        self.size = size        
    def make(self, X, n):
        after_Pn = theano.tensor.signal.downsample.max_pool_2d(X, (self.size, self.size), ignore_border=True)
        print_warn(("P%d"%n), after_Pn)
        
        return after_Pn, [], [("P%d"%n)]
    
class Layer_Filt():
    def __init__(self, in_chan, out_chan):
        self.in_chan = in_chan
        self.out_chan = out_chan
    def make(self, X, n):
        FWn = theano.shared(np.zeros((self.in_chan, self.out_chan), dtype='float32'), name=('FW%d'%n))
        FBn = theano.shared(np.zeros((self.out_chan,), dtype='float32'), name=('FB%d'%n))
        
        FWn.tag.initializer = IsotropicGaussian(0.05)
        FBn.tag.initializer = Constant(0.0)

        after_Fn = theano.tensor.dot(X.flatten(2), FWn) + FBn.dimshuffle('x',0)
        print_warn(("F%d"%n), after_Fn)
        
        return after_Fn, [FWn, FBn], [("F%d"%n)]
    
class Layer_Soft():
    def __init__(self):
        pass
    def make(self, X, n):
        after_Sn = theano.tensor.nnet.softmax(X)
        print_warn(("S%d"%n), after_Sn)
        
        return after_Sn, [], [("S%d"%n)]

# %%
class NetworkBuilder():
    def __init__(self, layerlist):
        self.layers = layerlist
    def make(self, X):
        model_parameters = []
        self.model_names = ["X"]
        self.model_layers = [X] 
        i = 1
        after = X
        for layer in self.layers:
            after, param, name = layer.make(after, i)
            self.model_layers += [after]
            model_parameters += param
            self.model_names += name
            i += 1
            
        return after, model_parameters

# %%
theano.config.compute_test_value = 'warn'
X_test_value, Y_test_value = next(cifar10_train_stream.get_epoch_iterator())

X = theano.tensor.tensor4('X')
Y = theano.tensor.matrix('Y', dtype='uint8')
X.tag.test_value = X_test_value[:3]
Y.tag.test_value = Y_test_value[:3]
print "X shape: %s" % (X.tag.test_value.shape,)

network = NetworkBuilder([
        Layer_Conv(3, 40, 3),
        Layer_Pool(2),
        Layer_Conv(40, 60, 4),
        Layer_Pool(2),
        Layer_Conv(60, 90, 3),
        Layer_Filt(90*4*4, 1500),
        Layer_Filt(1500, 600),
        Layer_Filt(600, 10),
        Layer_Soft()
    ])

output, parameters = network.make(X)

predictions = theano.tensor.argmax(output, axis=1)

error_rate = theano.tensor.neq(predictions,Y.ravel()).mean()

nll = - theano.tensor.log(output[theano.tensor.arange(Y.shape[0]), Y.ravel()]).mean()

alpha = 3e-3
weight_decay = 0.0
for p in parameters:
    if p.name[1]=='W':
        weight_decay = weight_decay + alpha * (p**2).sum()

cost = nll + weight_decay

theano.config.compute_test_value = 'off'
# Out:
# X shape: (3, 3, 32, 32)
# after_C1 shape: (3, 40, 30, 30)
# after_P2 shape: (3, 40, 15, 15)
# after_C3 shape: (3, 60, 12, 12)
# after_P4 shape: (3, 60, 6, 6)
# after_C5 shape: (3, 90, 4, 4)
# after_F6 shape: (3, 1500)
# after_F7 shape: (3, 600)
# after_F8 shape: (3, 10)
# after_S9 shape: (3, 10)

# %%
updates = []

lrate = theano.tensor.scalar('lrate',dtype='float32')
momentum = theano.tensor.scalar('momentum',dtype='float32')
gradients = theano.grad(cost, parameters)
velocities = [theano.shared(np.zeros_like(p.get_value()), name='V_%s' %(p.name, )) for p in parameters]

for p,g,v in zip(parameters, gradients, velocities):
    v_new = momentum * v - lrate * g
    p_new = p + v_new
    updates += [(v,v_new), (p, p_new)]

# %%
train_step = theano.function(
    [X, Y, lrate, momentum],
    [cost, error_rate, nll, weight_decay],
    updates=updates
)

predict = theano.function(
    [X], 
    predictions
)

# %%
def compute_error_rate(stream):
    errs = 0.0
    num_samples = 0.0
    for X, Y in stream.get_epoch_iterator():
        errs += (predict(X)!=Y.ravel()).sum()
        num_samples += Y.shape[0]
    return errs/num_samples

def compute_error_rate_with_write(stream, fo):
    errs = 0.0
    num_samples = 0.0
    for X, Y in stream.get_epoch_iterator():
        tempX = predict(X)
        tempY = Y.ravel()
        errs += (tempX!=tempY).sum()
        for xx,yy in zip(tempX, tempY):
            fo.write(str(xx)+' '+str(yy)+'\n')
        num_samples += Y.shape[0]
    return errs/num_samples

def init_parameters():
    rng = np.random.RandomState(1234)
    for p in parameters:
        p.set_value(p.tag.initializer.generate(rng, p.get_value().shape))

def snapshot_parameters():
    return [p.get_value(borrow=False) for p in parameters]

def load_parameters(snapshot):
    for p, s in zip(parameters, snapshot):
        p.set_value(s, borrow=False)

# %%
import time

i=0
e=0
startTotal = time.time()
init_parameters()
for v in velocities:
    v.set_value(np.zeros_like(v.get_value()))

best_valid_error_rate = np.inf
best_params = snapshot_parameters()
best_params_epoch = 0

train_erros = []
train_loss = []
train_nll = []
validation_errors = []

number_of_epochs = 3
patience_expansion = 1.5

while e<number_of_epochs:
    e += 1
    epoch_start_i = i
    
    startPart = time.time()
    for X_batch, Y_batch in cifar10_train_stream.get_epoch_iterator(): 
        i += 1
        
        K = 3200
        lrate = 7e-3 * K / np.maximum(K, i)
        momentum=0.9
        
        L, err_rate, nll, wdec = train_step(X_batch, Y_batch, lrate, momentum)
        
        train_loss.append((i,L))
        train_erros.append((i,err_rate))
        train_nll.append((i,nll))
        
        if i % 100 == 0:
            print "At minibatch %d, batch loss %f, batch nll %f, batch error rate %f%%" % (i, L, nll, err_rate*100)
    print "Epoch time:",(time.time()-startPart),"s"
        
    
    val_error_rate = compute_error_rate(cifar10_valid_stream)
    if val_error_rate < best_valid_error_rate:
        number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
        best_valid_error_rate = val_error_rate
        best_params = snapshot_parameters()
        best_params_epoch = e
        
    validation_errors.append((i,val_error_rate))
    print "After epoch %d: valid_err_rate: %f%% currently going to do %d epochs" %(
        e, val_error_rate*100, number_of_epochs)
    
    print "After epoch %d: averaged train_err_rate: %f%% averaged train nll: %f averaged train loss: %f" %(
        e, 
        np.mean(np.asarray(train_erros)[epoch_start_i:,1])*100, 
        np.mean(np.asarray(train_nll)[epoch_start_i:,1]),
        np.mean(np.asarray(train_loss)[epoch_start_i:,1])
    )
    
print "Total time:",(time.time()-startTotal)/60.0,"min"
# Out:
# At minibatch 100, batch loss 23.650711, batch nll 1.658561, batch error rate 62.400000%
# At minibatch 200, batch loss 21.653788, batch nll 1.424583, batch error rate 47.200000%
# At minibatch 300, batch loss 19.968576, batch nll 1.359861, batch error rate 46.400000%
# Epoch time: 19.2855529785 s
# After epoch 1: valid_err_rate: 47.810000% currently going to do 3 epochs
# After epoch 1: averaged train_err_rate: 56.125000% averaged train nll: 1.559477 averaged train loss: 22.524395
# At minibatch 400, batch loss 18.430855, batch nll 1.309561, batch error rate 48.800000%
# At minibatch 500, batch loss 16.940626, batch nll 1.184673, batch error rate 47.200000%
# At minibatch 600, batch loss 15.653082, batch nll 1.151541, batch error rate 42.400000%
# Epoch time: 19.2659578323 s
# After epoch 2: valid_err_rate: 40.010000% currently going to do 4 epochs
# After epoch 2: averaged train_err_rate: 42.955000% averaged train nll: 1.208255 averaged train loss: 17.269444
# At minibatch 700, batch loss 14.309499, batch nll 0.957977, batch error rate 35.200000%
# At minibatch 800, batch loss 13.356301, batch nll 1.061894, batch error rate 36.800000%
# At minibatch 900, batch loss 12.333797, batch nll 1.010914, batch error rate 35.200000%
# Epoch time: 19.3348891735 s
# After epoch 3: valid_err_rate: 38.070000% currently going to do 5 epochs
# After epoch 3: averaged train_err_rate: 37.347500% averaged train nll: 1.066649 averaged train loss: 13.392499
# At minibatch 1000, batch loss 11.541275, batch nll 1.109895, batch error rate 40.800000%
# At minibatch 1100, batch loss 10.768010, batch nll 1.154903, batch error rate 40.800000%
# At minibatch 1200, batch loss 9.734364, batch nll 0.873304, batch error rate 32.000000%
# Epoch time: 19.2650232315 s
# After epoch 4: valid_err_rate: 33.680000% currently going to do 7 epochs
# After epoch 4: averaged train_err_rate: 33.995000% averaged train nll: 0.969615 averaged train loss: 10.450822
# At minibatch 1300, batch loss 9.117495, batch nll 0.948646, batch error rate 34.400000%
# At minibatch 1400, batch loss 8.324772, batch nll 0.788674, batch error rate 24.800000%
# At minibatch 1500, batch loss 7.918906, batch nll 0.965152, batch error rate 33.600000%
# At minibatch 1600, batch loss 7.235094, batch nll 0.817627, batch error rate 30.400000%
# Epoch time: 19.2911250591 s
# After epoch 5: valid_err_rate: 31.380000% currently going to do 8 epochs
# After epoch 5: averaged train_err_rate: 31.600000% averaged train nll: 0.903479 averaged train loss: 8.218552
# At minibatch 1700, batch loss 6.681123, batch nll 0.751628, batch error rate 27.200000%
# At minibatch 1800, batch loss 6.352446, batch nll 0.875444, batch error rate 29.600000%
# At minibatch 1900, batch loss 5.841177, batch nll 0.779310, batch error rate 26.400000%
# Epoch time: 19.257750988 s
# After epoch 6: valid_err_rate: 31.140000% currently going to do 10 epochs
# After epoch 6: averaged train_err_rate: 29.720000% averaged train nll: 0.857739 averaged train loss: 6.524473
# At minibatch 2000, batch loss 5.604623, batch nll 0.922572, batch error rate 33.600000%
# At minibatch 2100, batch loss 5.125028, batch nll 0.792953, batch error rate 26.400000%
# At minibatch 2200, batch loss 4.734263, batch nll 0.723361, batch error rate 23.200000%
# Epoch time: 33.035118103 s
# After epoch 7: valid_err_rate: 30.190000% currently going to do 11 epochs
# After epoch 7: averaged train_err_rate: 28.655000% averaged train nll: 0.820719 averaged train loss: 5.230961
# At minibatch 2300, batch loss 4.515355, batch nll 0.799137, batch error rate 28.000000%
# At minibatch 2400, batch loss 4.173318, batch nll 0.726667, batch error rate 29.600000%
# At minibatch 2500, batch loss 3.895928, batch nll 0.698939, batch error rate 26.400000%
# Epoch time: 39.38803792 s
# After epoch 8: valid_err_rate: 29.270000% currently going to do 13 epochs
# After epoch 8: averaged train_err_rate: 27.007500% averaged train nll: 0.782888 averaged train loss: 4.236598
# At minibatch 2600, batch loss 3.680353, batch nll 0.711844, batch error rate 23.200000%
# At minibatch 2700, batch loss 3.556453, batch nll 0.795798, batch error rate 30.400000%
# At minibatch 2800, batch loss 3.220642, batch nll 0.652101, batch error rate 20.000000%
# Epoch time: 41.1819000244 s
# After epoch 9: valid_err_rate: 28.480000% currently going to do 14 epochs
# After epoch 9: averaged train_err_rate: 26.407500% averaged train nll: 0.763297 averaged train loss: 3.489799
# At minibatch 2900, batch loss 3.079077, batch nll 0.688260, batch error rate 26.400000%
# At minibatch 3000, batch loss 2.854359, batch nll 0.624214, batch error rate 20.800000%
# At minibatch 3100, batch loss 2.852006, batch nll 0.769640, batch error rate 26.400000%
# At minibatch 3200, batch loss 2.571827, batch nll 0.628088, batch error rate 21.600000%
# Epoch time: 39.4041531086 s
# After epoch 10: valid_err_rate: 29.180000% currently going to do 14 epochs
# After epoch 10: averaged train_err_rate: 25.357500% averaged train nll: 0.729860 averaged train loss: 2.903483
# At minibatch 3300, batch loss 2.616970, batch nll 0.795912, batch error rate 22.400000%
# At minibatch 3400, batch loss 2.496218, batch nll 0.785637, batch error rate 27.200000%
# At minibatch 3500, batch loss 2.306514, batch nll 0.696175, batch error rate 20.000000%
# Epoch time: 39.4087259769 s
# After epoch 11: valid_err_rate: 27.970000% currently going to do 17 epochs
# After epoch 11: averaged train_err_rate: 24.720000% averaged train nll: 0.715254 averaged train loss: 2.472703
# At minibatch 3600, batch loss 2.255226, batch nll 0.731695, batch error rate 24.000000%
# At minibatch 3700, batch loss 2.131966, batch nll 0.688977, batch error rate 24.800000%
# At minibatch 3800, batch loss 2.064739, batch nll 0.694602, batch error rate 17.600000%
# Epoch time: 39.4207930565 s
# After epoch 12: valid_err_rate: 27.630000% currently going to do 19 epochs
# After epoch 12: averaged train_err_rate: 23.605000% averaged train nll: 0.682636 averaged train loss: 2.144128
# At minibatch 3900, batch loss 1.920226, batch nll 0.614239, batch error rate 24.800000%
# At minibatch 4000, batch loss 1.899496, batch nll 0.651608, batch error rate 24.000000%
# At minibatch 4100, batch loss 1.886498, batch nll 0.694469, batch error rate 24.800000%
# Epoch time: 39.4103219509 s
# After epoch 13: valid_err_rate: 27.270000% currently going to do 20 epochs
# After epoch 13: averaged train_err_rate: 22.852500% averaged train nll: 0.662962 averaged train loss: 1.911866
# At minibatch 4200, batch loss 1.662684, batch nll 0.519118, batch error rate 14.400000%
# At minibatch 4300, batch loss 1.646591, batch nll 0.546969, batch error rate 19.200000%
# At minibatch 4400, batch loss 1.660699, batch nll 0.603280, batch error rate 21.600000%
# Epoch time: 39.4164478779 s
# After epoch 14: valid_err_rate: 26.330000% currently going to do 22 epochs
# After epoch 14: averaged train_err_rate: 22.185000% averaged train nll: 0.637140 averaged train loss: 1.728842
# At minibatch 4500, batch loss 1.648519, batch nll 0.628400, batch error rate 19.200000%
# At minibatch 4600, batch loss 1.567932, batch nll 0.581725, batch error rate 21.600000%
# At minibatch 4700, batch loss 1.770713, batch nll 0.816670, batch error rate 22.400000%
# At minibatch 4800, batch loss 1.479787, batch nll 0.555998, batch error rate 22.400000%
# Epoch time: 39.4519209862 s
# After epoch 15: valid_err_rate: 25.480000% currently going to do 23 epochs
# After epoch 15: averaged train_err_rate: 21.222500% averaged train nll: 0.616544 averaged train loss: 1.590275
# At minibatch 4900, batch loss 1.515035, batch nll 0.616457, batch error rate 24.000000%
# At minibatch 5000, batch loss 1.521656, batch nll 0.648988, batch error rate 21.600000%
# At minibatch 5100, batch loss 1.445540, batch nll 0.596910, batch error rate 12.800000%
# Epoch time: 39.3937709332 s
# After epoch 16: valid_err_rate: 26.730000% currently going to do 23 epochs
# After epoch 16: averaged train_err_rate: 20.427500% averaged train nll: 0.594007 averaged train loss: 1.477256
# At minibatch 5200, batch loss 1.330245, batch nll 0.501564, batch error rate 20.000000%
# At minibatch 5300, batch loss 1.396652, batch nll 0.587919, batch error rate 18.400000%
# At minibatch 5400, batch loss 1.258939, batch nll 0.468890, batch error rate 16.800000%
# Epoch time: 39.4000711441 s
# After epoch 17: valid_err_rate: 26.810000% currently going to do 23 epochs
# After epoch 17: averaged train_err_rate: 20.182500% averaged train nll: 0.585597 averaged train loss: 1.398595
# At minibatch 5500, batch loss 1.449626, batch nll 0.676329, batch error rate 24.000000%
# At minibatch 5600, batch loss 1.230258, batch nll 0.472807, batch error rate 16.000000%
# At minibatch 5700, batch loss 1.308529, batch nll 0.566202, batch error rate 22.400000%
# Epoch time: 39.4307610989 s
# After epoch 18: valid_err_rate: 25.230000% currently going to do 28 epochs
# After epoch 18: averaged train_err_rate: 19.400000% averaged train nll: 0.565788 averaged train loss: 1.323311
# At minibatch 5800, batch loss 1.375007, batch nll 0.646762, batch error rate 20.000000%
# At minibatch 5900, batch loss 1.209374, batch nll 0.493117, batch error rate 12.800000%
# At minibatch 6000, batch loss 1.288626, batch nll 0.585712, batch error rate 18.400000%
# Epoch time: 39.41157794 s
# After epoch 19: valid_err_rate: 24.370000% currently going to do 29 epochs
# After epoch 19: averaged train_err_rate: 18.920000% averaged train nll: 0.554042 averaged train loss: 1.267314
# At minibatch 6100, batch loss 1.256545, batch nll 0.565191, batch error rate 20.800000%
# At minibatch 6200, batch loss 1.114183, batch nll 0.432399, batch error rate 13.600000%
# At minibatch 6300, batch loss 1.292329, batch nll 0.620752, batch error rate 19.200000%
# At minibatch 6400, batch loss 1.226286, batch nll 0.564424, batch error rate 21.600000%
# Epoch time: 39.4521751404 s
# After epoch 20: valid_err_rate: 25.390000% currently going to do 29 epochs
# After epoch 20: averaged train_err_rate: 18.530000% averaged train nll: 0.541342 averaged train loss: 1.218899
# At minibatch 6500, batch loss 1.209703, batch nll 0.555404, batch error rate 16.800000%
# At minibatch 6600, batch loss 1.146762, batch nll 0.500848, batch error rate 14.400000%
# At minibatch 6700, batch loss 1.040329, batch nll 0.402785, batch error rate 13.600000%
# Epoch time: 39.4339010715 s
# After epoch 21: valid_err_rate: 24.590000% currently going to do 29 epochs
# After epoch 21: averaged train_err_rate: 17.845000% averaged train nll: 0.529139 averaged train loss: 1.178246
# At minibatch 6800, batch loss 1.076294, batch nll 0.445074, batch error rate 14.400000%
# At minibatch 6900, batch loss 1.153777, batch nll 0.529507, batch error rate 20.000000%
# At minibatch 7000, batch loss 1.185501, batch nll 0.567682, batch error rate 23.200000%
# Epoch time: 39.4241449833 s
# After epoch 22: valid_err_rate: 24.340000% currently going to do 34 epochs
# After epoch 22: averaged train_err_rate: 17.850000% averaged train nll: 0.517752 averaged train loss: 1.143325
# At minibatch 7100, batch loss 1.184342, batch nll 0.572500, batch error rate 19.200000%
# At minibatch 7200, batch loss 1.187717, batch nll 0.581181, batch error rate 20.800000%
# At minibatch 7300, batch loss 1.081280, batch nll 0.479593, batch error rate 14.400000%
# Epoch time: 39.4512140751 s
# After epoch 23: valid_err_rate: 25.420000% currently going to do 34 epochs
# After epoch 23: averaged train_err_rate: 16.945000% averaged train nll: 0.500821 averaged train loss: 1.107376
# At minibatch 7400, batch loss 1.113530, batch nll 0.517731, batch error rate 20.000000%
# At minibatch 7500, batch loss 1.063263, batch nll 0.471730, batch error rate 16.000000%
# At minibatch 7600, batch loss 1.123272, batch nll 0.536739, batch error rate 16.000000%
# Epoch time: 39.4719970226 s
# After epoch 24: valid_err_rate: 24.380000% currently going to do 34 epochs
# After epoch 24: averaged train_err_rate: 16.670000% averaged train nll: 0.495246 averaged train loss: 1.085617
# At minibatch 7700, batch loss 0.937606, batch nll 0.355655, batch error rate 12.000000%
# At minibatch 7800, batch loss 0.961608, batch nll 0.382712, batch error rate 14.400000%
# At minibatch 7900, batch loss 1.040885, batch nll 0.465804, batch error rate 10.400000%
# At minibatch 8000, batch loss 1.057250, batch nll 0.486151, batch error rate 18.400000%
# Epoch time: 39.4331729412 s
# After epoch 25: valid_err_rate: 23.830000% currently going to do 38 epochs
# After epoch 25: averaged train_err_rate: 16.512500% averaged train nll: 0.488833 averaged train loss: 1.066061
# At minibatch 8100, batch loss 1.050081, batch nll 0.481369, batch error rate 14.400000%
# At minibatch 8200, batch loss 1.027341, batch nll 0.462192, batch error rate 16.000000%
# At minibatch 8300, batch loss 1.113636, batch nll 0.552129, batch error rate 17.600000%
# Epoch time: 39.3942089081 s
# After epoch 26: valid_err_rate: 23.730000% currently going to do 40 epochs
# After epoch 26: averaged train_err_rate: 16.047500% averaged train nll: 0.474448 averaged train loss: 1.040800
# At minibatch 8400, batch loss 0.997756, batch nll 0.438469, batch error rate 19.200000%
# At minibatch 8500, batch loss 1.130032, batch nll 0.573356, batch error rate 18.400000%
# At minibatch 8600, batch loss 1.029798, batch nll 0.476564, batch error rate 13.600000%
# Epoch time: 39.4157738686 s
# After epoch 27: valid_err_rate: 24.540000% currently going to do 40 epochs
# After epoch 27: averaged train_err_rate: 15.640000% averaged train nll: 0.465135 averaged train loss: 1.022047
# At minibatch 8700, batch loss 0.962964, batch nll 0.412006, batch error rate 11.200000%
# At minibatch 8800, batch loss 0.931155, batch nll 0.381978, batch error rate 14.400000%
# At minibatch 8900, batch loss 0.900326, batch nll 0.353618, batch error rate 13.600000%
# Epoch time: 50.7014381886 s
# After epoch 28: valid_err_rate: 26.320000% currently going to do 40 epochs
# After epoch 28: averaged train_err_rate: 15.185000% averaged train nll: 0.453767 averaged train loss: 1.002721
# At minibatch 9000, batch loss 1.013655, batch nll 0.468444, batch error rate 16.000000%
# At minibatch 9100, batch loss 1.052246, batch nll 0.508633, batch error rate 16.000000%
# At minibatch 9200, batch loss 0.880831, batch nll 0.339119, batch error rate 5.600000%
# Epoch time: 57.4961280823 s
# After epoch 29: valid_err_rate: 23.910000% currently going to do 40 epochs
# After epoch 29: averaged train_err_rate: 14.837500% averaged train nll: 0.445746 averaged train loss: 0.988929
# At minibatch 9300, batch loss 1.098980, batch nll 0.559006, batch error rate 20.000000%
# At minibatch 9400, batch loss 1.048125, batch nll 0.509339, batch error rate 16.000000%
# At minibatch 9500, batch loss 0.872501, batch nll 0.335220, batch error rate 12.000000%
# At minibatch 9600, batch loss 0.975634, batch nll 0.440597, batch error rate 13.600000%
# Epoch time: 57.2053358555 s
# After epoch 30: valid_err_rate: 24.270000% currently going to do 40 epochs
# After epoch 30: averaged train_err_rate: 14.817500% averaged train nll: 0.439914 averaged train loss: 0.977907
# At minibatch 9700, batch loss 1.043752, batch nll 0.509255, batch error rate 16.000000%
# At minibatch 9800, batch loss 0.957245, batch nll 0.423775, batch error rate 16.000000%
# At minibatch 9900, batch loss 1.082170, batch nll 0.550328, batch error rate 19.200000%
# Epoch time: 57.5286130905 s
# After epoch 31: valid_err_rate: 23.430000% currently going to do 47 epochs
# After epoch 31: averaged train_err_rate: 14.387500% averaged train nll: 0.429105 averaged train loss: 0.962765
# At minibatch 10000, batch loss 0.884820, batch nll 0.353533, batch error rate 11.200000%
# At minibatch 10100, batch loss 0.917080, batch nll 0.386875, batch error rate 12.800000%
# At minibatch 10200, batch loss 0.925701, batch nll 0.397001, batch error rate 12.800000%
# Epoch time: 57.4688358307 s
# After epoch 32: valid_err_rate: 24.110000% currently going to do 47 epochs
# After epoch 32: averaged train_err_rate: 14.055000% averaged train nll: 0.423025 averaged train loss: 0.953218
# At minibatch 10300, batch loss 0.920684, batch nll 0.392463, batch error rate 14.400000%
# At minibatch 10400, batch loss 0.890188, batch nll 0.362607, batch error rate 12.800000%
# At minibatch 10500, batch loss 0.946087, batch nll 0.419996, batch error rate 16.000000%
# Epoch time: 57.4911961555 s
# After epoch 33: valid_err_rate: 23.780000% currently going to do 47 epochs
# After epoch 33: averaged train_err_rate: 13.750000% averaged train nll: 0.415221 averaged train loss: 0.942461
# At minibatch 10600, batch loss 0.965435, batch nll 0.440356, batch error rate 16.000000%
# At minibatch 10700, batch loss 0.917387, batch nll 0.392806, batch error rate 12.800000%
# At minibatch 10800, batch loss 0.966000, batch nll 0.442178, batch error rate 15.200000%
# Epoch time: 57.2306530476 s
# After epoch 34: valid_err_rate: 24.110000% currently going to do 47 epochs
# After epoch 34: averaged train_err_rate: 13.500000% averaged train nll: 0.409070 averaged train loss: 0.933399
# At minibatch 10900, batch loss 0.964471, batch nll 0.441387, batch error rate 14.400000%
# At minibatch 11000, batch loss 0.938692, batch nll 0.416024, batch error rate 14.400000%
# At minibatch 11100, batch loss 0.922404, batch nll 0.400117, batch error rate 14.400000%
# At minibatch 11200, batch loss 0.995261, batch nll 0.473574, batch error rate 14.400000%
# Epoch time: 57.5296800137 s
# After epoch 35: valid_err_rate: 23.720000% currently going to do 47 epochs
# After epoch 35: averaged train_err_rate: 13.250000% averaged train nll: 0.401436 averaged train loss: 0.924004
# At minibatch 11300, batch loss 0.941091, batch nll 0.419262, batch error rate 8.800000%
# At minibatch 11400, batch loss 0.887599, batch nll 0.366616, batch error rate 13.600000%
# At minibatch 11500, batch loss 0.917620, batch nll 0.397213, batch error rate 12.000000%
# Epoch time: 57.4889359474 s
# After epoch 36: valid_err_rate: 23.530000% currently going to do 47 epochs
# After epoch 36: averaged train_err_rate: 12.797500% averaged train nll: 0.391909 averaged train loss: 0.913151
# At minibatch 11600, batch loss 0.911914, batch nll 0.391482, batch error rate 11.200000%
# At minibatch 11700, batch loss 0.960834, batch nll 0.440921, batch error rate 16.000000%
# At minibatch 11800, batch loss 0.983133, batch nll 0.463616, batch error rate 14.400000%
# Epoch time: 57.3345310688 s
# After epoch 37: valid_err_rate: 23.620000% currently going to do 47 epochs
# After epoch 37: averaged train_err_rate: 12.467500% averaged train nll: 0.385376 averaged train loss: 0.905344
# At minibatch 11900, batch loss 0.917824, batch nll 0.398692, batch error rate 10.400000%
# At minibatch 12000, batch loss 0.966499, batch nll 0.447680, batch error rate 15.200000%
# At minibatch 12100, batch loss 0.825420, batch nll 0.307056, batch error rate 7.200000%
# Epoch time: 57.1799731255 s
# After epoch 38: valid_err_rate: 24.480000% currently going to do 47 epochs
# After epoch 38: averaged train_err_rate: 12.297500% averaged train nll: 0.381288 averaged train loss: 0.900028
# At minibatch 12200, batch loss 0.870030, batch nll 0.351715, batch error rate 11.200000%
# At minibatch 12300, batch loss 0.826126, batch nll 0.307799, batch error rate 10.400000%
# At minibatch 12400, batch loss 0.933681, batch nll 0.415810, batch error rate 11.200000%
# Epoch time: 57.5253109932 s
# After epoch 39: valid_err_rate: 23.460000% currently going to do 47 epochs
# After epoch 39: averaged train_err_rate: 12.267500% averaged train nll: 0.379673 averaged train loss: 0.897830
# At minibatch 12500, batch loss 0.855030, batch nll 0.337460, batch error rate 9.600000%
# At minibatch 12600, batch loss 0.917655, batch nll 0.399840, batch error rate 14.400000%
# At minibatch 12700, batch loss 0.925203, batch nll 0.407788, batch error rate 13.600000%
# At minibatch 12800, batch loss 0.903425, batch nll 0.386136, batch error rate 9.600000%
# Epoch time: 57.5259730816 s
# After epoch 40: valid_err_rate: 23.830000% currently going to do 47 epochs
# After epoch 40: averaged train_err_rate: 11.822500% averaged train nll: 0.370775 averaged train loss: 0.888273
# At minibatch 12900, batch loss 0.929185, batch nll 0.411424, batch error rate 11.200000%
# At minibatch 13000, batch loss 0.941654, batch nll 0.424175, batch error rate 12.800000%
# At minibatch 13100, batch loss 0.909753, batch nll 0.392566, batch error rate 14.400000%
# Epoch time: 57.1904559135 s
# After epoch 41: valid_err_rate: 23.830000% currently going to do 47 epochs
# After epoch 41: averaged train_err_rate: 11.995000% averaged train nll: 0.368781 averaged train loss: 0.886301
# At minibatch 13200, batch loss 0.903015, batch nll 0.385544, batch error rate 13.600000%
# At minibatch 13300, batch loss 0.902501, batch nll 0.385175, batch error rate 10.400000%
# At minibatch 13400, batch loss 0.863458, batch nll 0.346286, batch error rate 10.400000%
# Epoch time: 57.4930651188 s
# After epoch 42: valid_err_rate: 23.780000% currently going to do 47 epochs
# After epoch 42: averaged train_err_rate: 11.360000% averaged train nll: 0.356589 averaged train loss: 0.873889
# At minibatch 13500, batch loss 0.854649, batch nll 0.336977, batch error rate 12.000000%
# At minibatch 13600, batch loss 0.802396, batch nll 0.284786, batch error rate 12.800000%
# At minibatch 13700, batch loss 0.882361, batch nll 0.365072, batch error rate 12.000000%
# Epoch time: 57.5122258663 s
# After epoch 43: valid_err_rate: 23.770000% currently going to do 47 epochs
# After epoch 43: averaged train_err_rate: 11.607500% averaged train nll: 0.358089 averaged train loss: 0.875561
# At minibatch 13800, batch loss 0.875224, batch nll 0.358038, batch error rate 11.200000%
# At minibatch 13900, batch loss 0.834321, batch nll 0.316754, batch error rate 12.000000%
# At minibatch 14000, batch loss 0.764737, batch nll 0.247495, batch error rate 7.200000%
# Epoch time: 57.5156919956 s
# After epoch 44: valid_err_rate: 23.810000% currently going to do 47 epochs
# After epoch 44: averaged train_err_rate: 10.940000% averaged train nll: 0.347181 averaged train loss: 0.864499
# At minibatch 14100, batch loss 0.863209, batch nll 0.346065, batch error rate 13.600000%
# At minibatch 14200, batch loss 0.741465, batch nll 0.223648, batch error rate 4.800000%
# At minibatch 14300, batch loss 0.918158, batch nll 0.400453, batch error rate 12.800000%
# At minibatch 14400, batch loss 0.868407, batch nll 0.350682, batch error rate 9.600000%
# Epoch time: 57.1868810654 s
# After epoch 45: valid_err_rate: 24.320000% currently going to do 47 epochs
# After epoch 45: averaged train_err_rate: 10.900000% averaged train nll: 0.343330 averaged train loss: 0.860964
# At minibatch 14500, batch loss 0.913665, batch nll 0.395637, batch error rate 15.200000%
# At minibatch 14600, batch loss 0.785518, batch nll 0.267761, batch error rate 6.400000%
# At minibatch 14700, batch loss 0.786814, batch nll 0.268921, batch error rate 8.000000%
# Epoch time: 57.5161709785 s
# After epoch 46: valid_err_rate: 23.270000% currently going to do 70 epochs
# After epoch 46: averaged train_err_rate: 10.655000% averaged train nll: 0.338143 averaged train loss: 0.855985
# At minibatch 14800, batch loss 0.857825, batch nll 0.339662, batch error rate 8.800000%
# At minibatch 14900, batch loss 0.887554, batch nll 0.368890, batch error rate 10.400000%
# At minibatch 15000, batch loss 0.904908, batch nll 0.386419, batch error rate 14.400000%
# Epoch time: 57.4904150963 s
# After epoch 47: valid_err_rate: 24.110000% currently going to do 70 epochs
# After epoch 47: averaged train_err_rate: 10.472500% averaged train nll: 0.333934 averaged train loss: 0.852344
# At minibatch 15100, batch loss 0.750622, batch nll 0.231834, batch error rate 5.600000%
# At minibatch 15200, batch loss 0.897390, batch nll 0.378465, batch error rate 13.600000%
# At minibatch 15300, batch loss 0.855352, batch nll 0.336391, batch error rate 12.800000%
# Epoch time: 57.3033201694 s
# After epoch 48: valid_err_rate: 23.810000% currently going to do 70 epochs
# After epoch 48: averaged train_err_rate: 10.315000% averaged train nll: 0.328456 averaged train loss: 0.847344
# At minibatch 15400, batch loss 0.858593, batch nll 0.339597, batch error rate 12.000000%
# At minibatch 15500, batch loss 0.766146, batch nll 0.246756, batch error rate 4.800000%
# At minibatch 15600, batch loss 0.835988, batch nll 0.316326, batch error rate 9.600000%
# Epoch time: 57.3540520668 s
# After epoch 49: valid_err_rate: 23.400000% currently going to do 70 epochs
# After epoch 49: averaged train_err_rate: 9.887500% averaged train nll: 0.322588 averaged train loss: 0.841961
# At minibatch 15700, batch loss 0.812645, batch nll 0.292898, batch error rate 9.600000%
# At minibatch 15800, batch loss 0.729430, batch nll 0.209280, batch error rate 5.600000%
# At minibatch 15900, batch loss 0.815446, batch nll 0.295262, batch error rate 10.400000%
# At minibatch 16000, batch loss 0.933847, batch nll 0.413661, batch error rate 12.800000%
# Epoch time: 57.3850929737 s
# After epoch 50: valid_err_rate: 23.830000% currently going to do 70 epochs
# After epoch 50: averaged train_err_rate: 9.727500% averaged train nll: 0.316838 averaged train loss: 0.836955
# At minibatch 16100, batch loss 0.781468, batch nll 0.260829, batch error rate 7.200000%
# At minibatch 16200, batch loss 0.824643, batch nll 0.303675, batch error rate 6.400000%
# At minibatch 16300, batch loss 0.818215, batch nll 0.297374, batch error rate 7.200000%
# Epoch time: 57.6045839787 s
# After epoch 51: valid_err_rate: 23.370000% currently going to do 70 epochs
# After epoch 51: averaged train_err_rate: 9.600000% averaged train nll: 0.313828 averaged train loss: 0.834558
# At minibatch 16400, batch loss 0.902165, batch nll 0.380829, batch error rate 13.600000%
# At minibatch 16500, batch loss 0.875136, batch nll 0.353360, batch error rate 11.200000%
# At minibatch 16600, batch loss 0.834154, batch nll 0.312434, batch error rate 12.000000%
# Epoch time: 57.3715171814 s
# After epoch 52: valid_err_rate: 23.500000% currently going to do 70 epochs
# After epoch 52: averaged train_err_rate: 9.572500% averaged train nll: 0.311608 averaged train loss: 0.833132
# At minibatch 16700, batch loss 0.812402, batch nll 0.290566, batch error rate 7.200000%
# At minibatch 16800, batch loss 0.915385, batch nll 0.393008, batch error rate 12.800000%
# At minibatch 16900, batch loss 0.844771, batch nll 0.322500, batch error rate 11.200000%
# Epoch time: 57.5553529263 s
# After epoch 53: valid_err_rate: 23.560000% currently going to do 70 epochs
# After epoch 53: averaged train_err_rate: 9.567500% averaged train nll: 0.308730 averaged train loss: 0.830855
# At minibatch 17000, batch loss 0.807367, batch nll 0.285002, batch error rate 7.200000%
# At minibatch 17100, batch loss 0.837377, batch nll 0.314369, batch error rate 10.400000%
# At minibatch 17200, batch loss 0.808392, batch nll 0.285322, batch error rate 11.200000%
# Epoch time: 57.4406588078 s
# After epoch 54: valid_err_rate: 23.040000% currently going to do 82 epochs
# After epoch 54: averaged train_err_rate: 8.940000% averaged train nll: 0.300188 averaged train loss: 0.823054
# At minibatch 17300, batch loss 0.880171, batch nll 0.356962, batch error rate 12.800000%
# At minibatch 17400, batch loss 0.847027, batch nll 0.323538, batch error rate 12.000000%
# At minibatch 17500, batch loss 0.835536, batch nll 0.311711, batch error rate 9.600000%
# At minibatch 17600, batch loss 0.906905, batch nll 0.382843, batch error rate 15.200000%
# Epoch time: 57.4522080421 s
# After epoch 55: valid_err_rate: 23.710000% currently going to do 82 epochs
# After epoch 55: averaged train_err_rate: 9.130000% averaged train nll: 0.298609 averaged train loss: 0.822244
# At minibatch 17700, batch loss 0.801126, batch nll 0.276697, batch error rate 8.000000%
# At minibatch 17800, batch loss 0.825618, batch nll 0.301006, batch error rate 10.400000%
# At minibatch 17900, batch loss 0.901816, batch nll 0.377083, batch error rate 10.400000%
# Epoch time: 57.1192729473 s
# After epoch 56: valid_err_rate: 23.400000% currently going to do 82 epochs
# After epoch 56: averaged train_err_rate: 8.840000% averaged train nll: 0.293531 averaged train loss: 0.818041
# At minibatch 18000, batch loss 0.912005, batch nll 0.386678, batch error rate 11.200000%
# At minibatch 18100, batch loss 0.924984, batch nll 0.399426, batch error rate 12.800000%
# At minibatch 18200, batch loss 0.820339, batch nll 0.294652, batch error rate 6.400000%
# Epoch time: 57.4498369694 s
# After epoch 57: valid_err_rate: 24.250000% currently going to do 82 epochs
# After epoch 57: averaged train_err_rate: 8.645000% averaged train nll: 0.288885 averaged train loss: 0.814313
# At minibatch 18300, batch loss 0.755139, batch nll 0.228975, batch error rate 4.800000%
# At minibatch 18400, batch loss 0.788553, batch nll 0.261948, batch error rate 8.000000%
# At minibatch 18500, batch loss 0.893899, batch nll 0.367294, batch error rate 9.600000%
# Epoch time: 57.4200799465 s
# After epoch 58: valid_err_rate: 23.090000% currently going to do 82 epochs
# After epoch 58: averaged train_err_rate: 8.375000% averaged train nll: 0.284635 averaged train loss: 0.811084
# At minibatch 18600, batch loss 0.758865, batch nll 0.231965, batch error rate 6.400000%
# At minibatch 18700, batch loss 0.735843, batch nll 0.208563, batch error rate 4.000000%
# At minibatch 18800, batch loss 0.818589, batch nll 0.291192, batch error rate 7.200000%
# Epoch time: 57.2164099216 s
# After epoch 59: valid_err_rate: 23.180000% currently going to do 82 epochs
# After epoch 59: averaged train_err_rate: 8.182500% averaged train nll: 0.280993 averaged train loss: 0.808212
# At minibatch 18900, batch loss 0.819761, batch nll 0.292311, batch error rate 8.800000%
# At minibatch 19000, batch loss 0.814451, batch nll 0.286513, batch error rate 6.400000%
# At minibatch 19100, batch loss 0.712890, batch nll 0.184861, batch error rate 1.600000%
# At minibatch 19200, batch loss 0.815692, batch nll 0.287313, batch error rate 8.000000%
# Epoch time: 57.1513288021 s
# After epoch 60: valid_err_rate: 23.510000% currently going to do 82 epochs
# After epoch 60: averaged train_err_rate: 8.022500% averaged train nll: 0.276426 averaged train loss: 0.804355
# At minibatch 19300, batch loss 0.791708, batch nll 0.262850, batch error rate 8.800000%
# At minibatch 19400, batch loss 0.875960, batch nll 0.346831, batch error rate 11.200000%
# At minibatch 19500, batch loss 0.815152, batch nll 0.285897, batch error rate 8.800000%
# Epoch time: 57.4939248562 s
# After epoch 61: valid_err_rate: 23.530000% currently going to do 82 epochs
# After epoch 61: averaged train_err_rate: 7.910000% averaged train nll: 0.272078 averaged train loss: 0.801036
# At minibatch 19600, batch loss 0.794439, batch nll 0.264830, batch error rate 9.600000%
# At minibatch 19700, batch loss 0.767195, batch nll 0.237540, batch error rate 7.200000%
# At minibatch 19800, batch loss 0.816826, batch nll 0.286921, batch error rate 7.200000%
# Epoch time: 57.4626269341 s
# After epoch 62: valid_err_rate: 23.950000% currently going to do 82 epochs
# After epoch 62: averaged train_err_rate: 8.030000% averaged train nll: 0.274286 averaged train loss: 0.803956
# At minibatch 19900, batch loss 0.770004, batch nll 0.240016, batch error rate 5.600000%
# At minibatch 20000, batch loss 0.928568, batch nll 0.398136, batch error rate 12.800000%
# At minibatch 20100, batch loss 0.821376, batch nll 0.290666, batch error rate 8.000000%
# Epoch time: 57.1813340187 s
# After epoch 63: valid_err_rate: 23.990000% currently going to do 82 epochs
# After epoch 63: averaged train_err_rate: 7.717500% averaged train nll: 0.267401 averaged train loss: 0.797759
# At minibatch 20200, batch loss 0.745362, batch nll 0.214511, batch error rate 5.600000%
# At minibatch 20300, batch loss 0.786268, batch nll 0.255053, batch error rate 10.400000%
# At minibatch 20400, batch loss 0.755238, batch nll 0.223707, batch error rate 4.000000%
# Epoch time: 57.4200479984 s
# After epoch 64: valid_err_rate: 23.240000% currently going to do 82 epochs
# After epoch 64: averaged train_err_rate: 7.777500% averaged train nll: 0.266702 averaged train loss: 0.797968
# At minibatch 20500, batch loss 0.783739, batch nll 0.252051, batch error rate 8.000000%
# At minibatch 20600, batch loss 0.707809, batch nll 0.175669, batch error rate 3.200000%
# At minibatch 20700, batch loss 0.786729, batch nll 0.254311, batch error rate 10.400000%
# At minibatch 20800, batch loss 0.845981, batch nll 0.313570, batch error rate 13.600000%
# Epoch time: 57.4324481487 s
# After epoch 65: valid_err_rate: 24.010000% currently going to do 82 epochs
# After epoch 65: averaged train_err_rate: 7.432500% averaged train nll: 0.260077 averaged train loss: 0.792258
# At minibatch 20900, batch loss 0.811707, batch nll 0.278940, batch error rate 8.000000%
# At minibatch 21000, batch loss 0.751399, batch nll 0.218377, batch error rate 5.600000%
# At minibatch 21100, batch loss 0.678211, batch nll 0.144927, batch error rate 1.600000%
# Epoch time: 57.4203140736 s
# After epoch 66: valid_err_rate: 23.820000% currently going to do 82 epochs
# After epoch 66: averaged train_err_rate: 7.037500% averaged train nll: 0.255258 averaged train loss: 0.788183
# At minibatch 21200, batch loss 0.757791, batch nll 0.224316, batch error rate 6.400000%
# At minibatch 21300, batch loss 0.729871, batch nll 0.196112, batch error rate 4.800000%
# At minibatch 21400, batch loss 0.868364, batch nll 0.334293, batch error rate 10.400000%
# Epoch time: 57.1743240356 s
# After epoch 67: valid_err_rate: 23.430000% currently going to do 82 epochs
# After epoch 67: averaged train_err_rate: 6.982500% averaged train nll: 0.253264 averaged train loss: 0.786982
# At minibatch 21500, batch loss 0.796701, batch nll 0.262419, batch error rate 9.600000%
# At minibatch 21600, batch loss 0.796251, batch nll 0.261575, batch error rate 7.200000%
# At minibatch 21700, batch loss 0.759496, batch nll 0.224666, batch error rate 6.400000%
# Epoch time: 57.3925340176 s
# After epoch 68: valid_err_rate: 23.560000% currently going to do 82 epochs
# After epoch 68: averaged train_err_rate: 6.985000% averaged train nll: 0.251631 averaged train loss: 0.786239
# At minibatch 21800, batch loss 0.754032, batch nll 0.218828, batch error rate 3.200000%
# At minibatch 21900, batch loss 0.719296, batch nll 0.183944, batch error rate 4.800000%
# At minibatch 22000, batch loss 0.847704, batch nll 0.312080, batch error rate 12.800000%
# Epoch time: 57.4585809708 s
# After epoch 69: valid_err_rate: 23.560000% currently going to do 82 epochs
# After epoch 69: averaged train_err_rate: 7.015000% averaged train nll: 0.252182 averaged train loss: 0.787634
# At minibatch 22100, batch loss 0.756338, batch nll 0.220493, batch error rate 6.400000%
# At minibatch 22200, batch loss 0.756998, batch nll 0.220796, batch error rate 6.400000%
# At minibatch 22300, batch loss 0.794658, batch nll 0.258283, batch error rate 7.200000%
# At minibatch 22400, batch loss 0.769689, batch nll 0.233099, batch error rate 7.200000%
# Epoch time: 57.1978309155 s
# After epoch 70: valid_err_rate: 23.450000% currently going to do 82 epochs
# After epoch 70: averaged train_err_rate: 6.700000% averaged train nll: 0.245706 averaged train loss: 0.781930
# At minibatch 22500, batch loss 0.801207, batch nll 0.264294, batch error rate 9.600000%
# At minibatch 22600, batch loss 0.870882, batch nll 0.333820, batch error rate 10.400000%
# At minibatch 22700, batch loss 0.840906, batch nll 0.303672, batch error rate 11.200000%
# Epoch time: 57.1509239674 s
# After epoch 71: valid_err_rate: 23.510000% currently going to do 82 epochs
# After epoch 71: averaged train_err_rate: 6.580000% averaged train nll: 0.241864 averaged train loss: 0.778871
# At minibatch 22800, batch loss 0.780071, batch nll 0.242496, batch error rate 8.800000%
# At minibatch 22900, batch loss 0.794402, batch nll 0.256610, batch error rate 8.000000%
# At minibatch 23000, batch loss 0.754310, batch nll 0.216214, batch error rate 4.800000%
# Epoch time: 57.4713149071 s
# After epoch 72: valid_err_rate: 23.570000% currently going to do 82 epochs
# After epoch 72: averaged train_err_rate: 6.560000% averaged train nll: 0.239460 averaged train loss: 0.777236
# At minibatch 23100, batch loss 0.710412, batch nll 0.172179, batch error rate 2.400000%
# At minibatch 23200, batch loss 0.781880, batch nll 0.243246, batch error rate 8.000000%
# At minibatch 23300, batch loss 0.769012, batch nll 0.230171, batch error rate 9.600000%
# Epoch time: 57.40843606 s
# After epoch 73: valid_err_rate: 24.060000% currently going to do 82 epochs
# After epoch 73: averaged train_err_rate: 6.390000% averaged train nll: 0.237957 averaged train loss: 0.776507
# At minibatch 23400, batch loss 0.766758, batch nll 0.227893, batch error rate 3.200000%
# At minibatch 23500, batch loss 0.809416, batch nll 0.270169, batch error rate 8.000000%
# At minibatch 23600, batch loss 0.805106, batch nll 0.265803, batch error rate 7.200000%
# Epoch time: 57.1565060616 s
# After epoch 74: valid_err_rate: 23.750000% currently going to do 82 epochs
# After epoch 74: averaged train_err_rate: 6.435000% averaged train nll: 0.238112 averaged train loss: 0.777284
# At minibatch 23700, batch loss 0.832341, batch nll 0.292914, batch error rate 10.400000%
# At minibatch 23800, batch loss 0.738990, batch nll 0.199282, batch error rate 4.800000%
# At minibatch 23900, batch loss 0.717546, batch nll 0.177524, batch error rate 6.400000%
# At minibatch 24000, batch loss 0.774812, batch nll 0.234692, batch error rate 8.000000%
# Epoch time: 57.4080851078 s
# After epoch 75: valid_err_rate: 24.510000% currently going to do 82 epochs
# After epoch 75: averaged train_err_rate: 6.170000% averaged train nll: 0.234092 averaged train loss: 0.773906
# At minibatch 24100, batch loss 0.755837, batch nll 0.215280, batch error rate 5.600000%
# At minibatch 24200, batch loss 0.800902, batch nll 0.260170, batch error rate 11.200000%
# At minibatch 24300, batch loss 0.803060, batch nll 0.262220, batch error rate 9.600000%
# Epoch time: 57.4305598736 s
# After epoch 76: valid_err_rate: 23.210000% currently going to do 82 epochs
# After epoch 76: averaged train_err_rate: 6.247500% averaged train nll: 0.233037 averaged train loss: 0.773668
# At minibatch 24400, batch loss 0.807982, batch nll 0.266901, batch error rate 7.200000%
# At minibatch 24500, batch loss 0.732288, batch nll 0.190884, batch error rate 6.400000%
# At minibatch 24600, batch loss 0.781991, batch nll 0.240472, batch error rate 4.800000%
# Epoch time: 57.433658123 s
# After epoch 77: valid_err_rate: 24.210000% currently going to do 82 epochs
# After epoch 77: averaged train_err_rate: 6.057500% averaged train nll: 0.228685 averaged train loss: 0.769961
# At minibatch 24700, batch loss 0.750471, batch nll 0.208758, batch error rate 4.000000%
# At minibatch 24800, batch loss 0.807149, batch nll 0.265166, batch error rate 8.000000%
# At minibatch 24900, batch loss 0.887639, batch nll 0.345474, batch error rate 11.200000%
# Epoch time: 57.1561961174 s
# After epoch 78: valid_err_rate: 23.650000% currently going to do 82 epochs
# After epoch 78: averaged train_err_rate: 6.010000% averaged train nll: 0.227016 averaged train loss: 0.768980
# At minibatch 25000, batch loss 0.736995, batch nll 0.194645, batch error rate 4.800000%
# At minibatch 25100, batch loss 0.723536, batch nll 0.180867, batch error rate 4.800000%
# At minibatch 25200, batch loss 0.825258, batch nll 0.282426, batch error rate 8.000000%
# Epoch time: 57.4454879761 s
# After epoch 79: valid_err_rate: 23.880000% currently going to do 82 epochs
# After epoch 79: averaged train_err_rate: 5.657500% averaged train nll: 0.221187 averaged train loss: 0.763861
# At minibatch 25300, batch loss 0.742228, batch nll 0.199164, batch error rate 3.200000%
# At minibatch 25400, batch loss 0.757104, batch nll 0.213735, batch error rate 4.000000%
# At minibatch 25500, batch loss 0.750993, batch nll 0.207501, batch error rate 4.000000%
# At minibatch 25600, batch loss 0.791331, batch nll 0.247633, batch error rate 4.800000%
# Epoch time: 57.4252588749 s
# After epoch 80: valid_err_rate: 23.830000% currently going to do 82 epochs
# After epoch 80: averaged train_err_rate: 5.672500% averaged train nll: 0.220510 averaged train loss: 0.763899
# At minibatch 25700, batch loss 0.744359, batch nll 0.200424, batch error rate 7.200000%
# At minibatch 25800, batch loss 0.807931, batch nll 0.263687, batch error rate 6.400000%
# At minibatch 25900, batch loss 0.752425, batch nll 0.208124, batch error rate 4.000000%
# Epoch time: 57.1499137878 s
# After epoch 81: valid_err_rate: 23.310000% currently going to do 82 epochs
# After epoch 81: averaged train_err_rate: 5.605000% averaged train nll: 0.217892 averaged train loss: 0.761976
# At minibatch 26000, batch loss 0.750754, batch nll 0.206355, batch error rate 4.800000%
# At minibatch 26100, batch loss 0.737752, batch nll 0.193204, batch error rate 4.000000%
# At minibatch 26200, batch loss 0.766775, batch nll 0.221987, batch error rate 4.800000%
# Epoch time: 57.1062347889 s
# After epoch 82: valid_err_rate: 23.460000% currently going to do 82 epochs
# After epoch 82: averaged train_err_rate: 5.490000% averaged train nll: 0.215556 averaged train loss: 0.760107
# Total time: 73.8984836857 min

# %%
fo = open('results1', 'w')

print "Setting network parameters from after epoch %d" %(best_params_epoch)
load_parameters(best_params)

countError = compute_error_rate_with_write(cifar10_testt_stream, fo)
print "Success rate is %f%%" %(100.0-countError*100.0,)
print "Error rate is %f%%" %(countError*100.0,)

figure(figsize=(16,14))

subplot(2,1,1)
train_nll_a = np.array(train_nll)
semilogy(train_nll_a[:,0], train_nll_a[:,1], label='batch train nll')
legend()

subplot(2,1,2)
train_erros_a = np.array(train_erros)
plot(train_erros_a[:,0], train_erros_a[:,1], label='batch train error rate')
validation_errors_a = np.array(validation_errors)
plot(validation_errors_a[:,0], validation_errors_a[:,1], label='validation error rate', color='r')
ylim(0,1.2)
legend()

fo.close()
# Out:
# Setting network parameters from after epoch 54
# Success rate is 75.990000%
# Error rate is 24.010000%
