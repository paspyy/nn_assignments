# %%
# %pylab inline

from scipy.ndimage.filters import convolve

import theano
import theano.tensor.signal.downsample
import skimage.io
print theano.config.floatX

from common.plotting import plot_mat

from fuel.datasets.cifar10 import CIFAR10
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme
# Out:
# Populating the interactive namespace from numpy and matplotlib
# float32
# Using gpu device 0: GeForce GTX 780 (CNMeM is enabled)

# %%
CIFAR10.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'})
)

cifar10_train = CIFAR10(("train",), subset=slice(None,40000))
cifar10_valid = CIFAR10(("train",), subset=slice(40000, None))
cifar10_testt  = CIFAR10(("test",))

minibatch_train = 100
minibatch_valid = 100
minibatch_testt = 100

cifar10_train_stream = DataStream.default_stream(
    cifar10_train,
    iteration_scheme=ShuffledScheme(cifar10_train.num_examples, minibatch_train)
)
cifar10_valid_stream = DataStream.default_stream(
    cifar10_valid, 
    iteration_scheme=SequentialScheme(cifar10_valid.num_examples, minibatch_valid)
)
cifar10_testt_stream = DataStream.default_stream(
    cifar10_testt, 
    iteration_scheme=SequentialScheme(cifar10_testt.num_examples, minibatch_testt)
)

print "Each trainin batch consits of a tuple containing:"
for element in next(cifar10_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(cifar10_testt_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    

plot_mat(cifar10_train.data_sources[0][:20], cmap='gray')

asd = 0
for x in cifar10_train_stream.get_epoch_iterator():
    asd += 1
print asd
# Out:
# Each trainin batch consits of a tuple containing:
#  - an array of size (100, 3, 32, 32) containing float32
#  - an array of size (100, 1) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (100, 3, 32, 32) containing float32
#  - an array of size (100, 1) containing uint8
# 400

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
def print_warn(s, X):
    print "after_%s shape: %s" % (s, X.tag.test_value.shape,)

class Layer_Conv():
    def __init__(self, in_chan, out_chan, size):
        self.in_chan = in_chan
        self.out_chan = out_chan
        self.size = size
    def make(self, X, n):
        CWn = theano.shared(np.zeros((self.out_chan, self.in_chan, self.size, self.size), dtype='float32'), name=('CW%d'%n))
        CBn = theano.shared(np.zeros((self.out_chan,), dtype='float32'), name=('CB%d'%n))
        
        CWn.tag.initializer = IsotropicGaussian(0.05)
        CBn.tag.initializer = Constant(0.0)
        
        after_Cn = theano.tensor.maximum(
            0.0,
            theano.tensor.nnet.conv2d(X, CWn) + CBn.dimshuffle('x',0,'x','x')
        )
        print_warn(("C%d"%n), after_Cn)
        
        return after_Cn, [CWn, CBn], [("C%d"%n)]
    
class Layer_Pool():
    def __init__(self, size):
        self.size = size        
    def make(self, X, n):
        after_Pn = theano.tensor.signal.downsample.max_pool_2d(X, (self.size, self.size), ignore_border=True)
        print_warn(("P%d"%n), after_Pn)
        
        return after_Pn, [], [("P%d"%n)]
    
class Layer_Filt():
    def __init__(self, in_chan, out_chan):
        self.in_chan = in_chan
        self.out_chan = out_chan
    def make(self, X, n):
        num_fw4_hidden=10
        FWn = theano.shared(np.zeros((self.in_chan, self.out_chan), dtype='float32'), name=('FW%d'%n))
        FBn = theano.shared(np.zeros((self.out_chan,), dtype='float32'), name=('FB%d'%n))
        
        FWn.tag.initializer = IsotropicGaussian(0.05)
        FBn.tag.initializer = Constant(0.0)

        after_Fn = theano.tensor.dot(X.flatten(2), FWn) + FBn.dimshuffle('x',0)
        print_warn(("F%d"%n), after_Fn)
        
        return after_Fn, [FWn, FBn], [("F%d"%n)]
    
class Layer_Soft():
    def __init__(self):
        pass
    def make(self, X, n):
        after_Sn = theano.tensor.nnet.softmax(X)
        print_warn(("S%d"%n), after_Sn)
        
        return after_Sn, [], [("S%d"%n)]

# %%
class NetworkBuilder():
    def __init__(self, layerlist):
        self.layers = layerlist
    def make(self, X):
        model_parameters = []
        self.model_names = ["X"]
        self.model_layers = [X] 
        i = 1
        after = X
        for layer in self.layers:
            after, param, name = layer.make(after, i)
            self.model_layers += [after]
            model_parameters += param
            self.model_names += name
            i += 1
            
        return after, model_parameters

# %%
theano.config.compute_test_value = 'warn'
X_test_value, Y_test_value = next(cifar10_train_stream.get_epoch_iterator())

X = theano.tensor.tensor4('X')
Y = theano.tensor.matrix('Y', dtype='uint8')
X.tag.test_value = X_test_value[:3]
Y.tag.test_value = Y_test_value[:3]
print "X shape: %s" % (X.tag.test_value.shape,)

network = NetworkBuilder([
        Layer_Conv(3, 16, 3),
        Layer_Pool(2),
        Layer_Conv(16, 25, 4),
        Layer_Pool(2),
        Layer_Conv(25, 32, 3),
        Layer_Filt(32*4*4, 1000),
        Layer_Filt(1000, 300),
        Layer_Filt(300, 10),
        Layer_Soft()
    ])

output, parameters = network.make(X)

predictions = theano.tensor.argmax(output, axis=1)

error_rate = theano.tensor.neq(predictions,Y.ravel()).mean()

nll = - theano.tensor.log(output[theano.tensor.arange(Y.shape[0]), Y.ravel()]).mean()

alpha = 3e-3
weight_decay = 0.0
for p in parameters:
    if p.name[1]=='W':
        weight_decay = weight_decay + alpha * (p**2).sum()

cost = nll + weight_decay

theano.config.compute_test_value = 'off'
# Out:
# X shape: (3, 3, 32, 32)
# after_C1 shape: (3, 16, 30, 30)
# after_P2 shape: (3, 16, 15, 15)
# after_C3 shape: (3, 25, 12, 12)
# after_P4 shape: (3, 25, 6, 6)
# after_C5 shape: (3, 32, 4, 4)
# after_F6 shape: (3, 1000)
# after_F7 shape: (3, 300)
# after_F8 shape: (3, 10)
# after_S9 shape: (3, 10)

# %%
updates = []

lrate = theano.tensor.scalar('lrate',dtype='float32')
momentum = theano.tensor.scalar('momentum',dtype='float32')
gradients = theano.grad(cost, parameters)
velocities = [theano.shared(np.zeros_like(p.get_value()), name='V_%s' %(p.name, )) for p in parameters]

for p,g,v in zip(parameters, gradients, velocities):
    v_new = momentum * v - lrate * g
    p_new = p + v_new
    updates += [(v,v_new), (p, p_new)]

# %%
train_step = theano.function(
    [X, Y, lrate, momentum],
    [cost, error_rate, nll, weight_decay],
    updates=updates
)

predict = theano.function(
    [X], 
    predictions
)

# %%
def compute_error_rate(stream):
    errs = 0.0
    num_samples = 0.0
    for X, Y in stream.get_epoch_iterator():
        errs += (predict(X)!=Y.ravel()).sum()
        num_samples += Y.shape[0]
    return errs/num_samples

def init_parameters():
    rng = np.random.RandomState(1234)
    for p in parameters:
        p.set_value(p.tag.initializer.generate(rng, p.get_value().shape))

def snapshot_parameters():
    return [p.get_value(borrow=False) for p in parameters]

def load_parameters(snapshot):
    for p, s in zip(parameters, snapshot):
        p.set_value(s, borrow=False)

# %%
i=0
e=0

init_parameters()
for v in velocities:
    v.set_value(np.zeros_like(v.get_value()))

best_valid_error_rate = np.inf
best_params = snapshot_parameters()
best_params_epoch = 0

train_erros = []
train_loss = []
train_nll = []
validation_errors = []

number_of_epochs = 3
patience_expansion = 1.5

while e<number_of_epochs:
    e += 1
    epoch_start_i = i
    
    for X_batch, Y_batch in cifar10_train_stream.get_epoch_iterator(): 
        i += 1
        
        K = 4000
        lrate = 8e-3 * K / np.maximum(K, i)
        momentum=0.9
        
        L, err_rate, nll, wdec = train_step(X_batch, Y_batch, lrate, momentum)
        
        train_loss.append((i,L))
        train_erros.append((i,err_rate))
        train_nll.append((i,nll))
        
        if i % 100 == 0:
            print "At minibatch %d, batch loss %f, batch nll %f, batch error rate %f%%" % (i, L, nll, err_rate*100)
        
    
    val_error_rate = compute_error_rate(cifar10_valid_stream)
    if val_error_rate < best_valid_error_rate:
        number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
        best_valid_error_rate = val_error_rate
        best_params = snapshot_parameters()
        best_params_epoch = e
        
    validation_errors.append((i,val_error_rate))
    print "After epoch %d: valid_err_rate: %f%% currently going to do %d epochs" %(
        e, val_error_rate*100, number_of_epochs)
    
    print "After epoch %d: averaged train_err_rate: %f%% averaged train nll: %f averaged train loss: %f" %(
        e, 
        np.mean(np.asarray(train_erros)[epoch_start_i:,1])*100, 
        np.mean(np.asarray(train_nll)[epoch_start_i:,1]),
        np.mean(np.asarray(train_loss)[epoch_start_i:,1])
    )
# Out:
# At minibatch 100, batch loss 7.660357, batch nll 1.939183, batch error rate 65.000000%
# At minibatch 200, batch loss 6.904273, batch nll 1.692686, batch error rate 58.000000%
# At minibatch 300, batch loss 6.294778, batch nll 1.546527, batch error rate 60.000000%
# At minibatch 400, batch loss 5.710951, batch nll 1.384625, batch error rate 49.000000%
# After epoch 1: valid_err_rate: 53.390000% currently going to do 3 epochs
# After epoch 1: averaged train_err_rate: 63.300000% averaged train nll: 1.735332 averaged train loss: 6.974287
# At minibatch 500, batch loss 5.463983, batch nll 1.518863, batch error rate 53.000000%
# At minibatch 600, batch loss 5.060654, batch nll 1.463202, batch error rate 57.000000%
# At minibatch 700, batch loss 4.659332, batch nll 1.376767, batch error rate 48.000000%
# At minibatch 800, batch loss 4.464179, batch nll 1.467066, batch error rate 53.000000%
# After epoch 2: valid_err_rate: 47.740000% currently going to do 4 epochs
# After epoch 2: averaged train_err_rate: 50.085000% averaged train nll: 1.386805 averaged train loss: 5.003876
# At minibatch 900, batch loss 4.062167, batch nll 1.322565, batch error rate 41.000000%
# At minibatch 1000, batch loss 3.857168, batch nll 1.350994, batch error rate 42.000000%
# At minibatch 1100, batch loss 3.653813, batch nll 1.359609, batch error rate 49.000000%
# At minibatch 1200, batch loss 3.502937, batch nll 1.399677, batch error rate 47.000000%
# After epoch 3: valid_err_rate: 46.210000% currently going to do 5 epochs
# After epoch 3: averaged train_err_rate: 45.407500% averaged train nll: 1.269390 averaged train loss: 3.789206
# At minibatch 1300, batch loss 3.095303, batch nll 1.164701, batch error rate 39.000000%
# At minibatch 1400, batch loss 2.934235, batch nll 1.159508, batch error rate 39.000000%
# At minibatch 1500, batch loss 2.630083, batch nll 0.997546, batch error rate 34.000000%
# At minibatch 1600, batch loss 2.629347, batch nll 1.126350, batch error rate 37.000000%
# After epoch 4: valid_err_rate: 40.350000% currently going to do 7 epochs
# After epoch 4: averaged train_err_rate: 42.312500% averaged train nll: 1.185730 averaged train loss: 2.968919
# At minibatch 1700, batch loss 2.421907, batch nll 1.033698, batch error rate 35.000000%
# At minibatch 1800, batch loss 2.328110, batch nll 1.044327, batch error rate 37.000000%
# At minibatch 1900, batch loss 2.260046, batch nll 1.071324, batch error rate 39.000000%
# At minibatch 2000, batch loss 2.191940, batch nll 1.091548, batch error rate 42.000000%
# After epoch 5: valid_err_rate: 39.420000% currently going to do 8 epochs
# After epoch 5: averaged train_err_rate: 40.275000% averaged train nll: 1.125026 averaged train loss: 2.414096
# At minibatch 2100, batch loss 2.112171, batch nll 1.087678, batch error rate 39.000000%
# At minibatch 2200, batch loss 2.068233, batch nll 1.117118, batch error rate 43.000000%
# At minibatch 2300, batch loss 1.984025, batch nll 1.096420, batch error rate 43.000000%
# At minibatch 2400, batch loss 1.711264, batch nll 0.879193, batch error rate 35.000000%
# After epoch 6: valid_err_rate: 37.700000% currently going to do 10 epochs
# After epoch 6: averaged train_err_rate: 38.595000% averaged train nll: 1.089393 averaged train loss: 2.046083
# At minibatch 2500, batch loss 2.047071, batch nll 1.267967, batch error rate 48.000000%
# At minibatch 2600, batch loss 1.826864, batch nll 1.095797, batch error rate 39.000000%
# At minibatch 2700, batch loss 1.788012, batch nll 1.099793, batch error rate 43.000000%
# At minibatch 2800, batch loss 1.889918, batch nll 1.241272, batch error rate 42.000000%
# After epoch 7: valid_err_rate: 38.840000% currently going to do 10 epochs
# After epoch 7: averaged train_err_rate: 36.790000% averaged train nll: 1.040495 averaged train loss: 1.774803
# At minibatch 2900, batch loss 1.562777, batch nll 0.947970, batch error rate 39.000000%
# At minibatch 3000, batch loss 1.496522, batch nll 0.911435, batch error rate 35.000000%
# At minibatch 3100, batch loss 1.321971, batch nll 0.767644, batch error rate 23.000000%
# At minibatch 3200, batch loss 1.541643, batch nll 1.012843, batch error rate 33.000000%
# After epoch 8: valid_err_rate: 35.980000% currently going to do 13 epochs
# After epoch 8: averaged train_err_rate: 35.397500% averaged train nll: 1.011913 averaged train loss: 1.597764
# At minibatch 3300, batch loss 1.605107, batch nll 1.098099, batch error rate 40.000000%
# At minibatch 3400, batch loss 1.756785, batch nll 1.270813, batch error rate 46.000000%
# At minibatch 3500, batch loss 1.329128, batch nll 0.861657, batch error rate 35.000000%
# At minibatch 3600, batch loss 1.545931, batch nll 1.095633, batch error rate 37.000000%
# After epoch 9: valid_err_rate: 36.550000% currently going to do 13 epochs
# After epoch 9: averaged train_err_rate: 35.077500% averaged train nll: 0.991407 averaged train loss: 1.478705
# At minibatch 3700, batch loss 1.594618, batch nll 1.157343, batch error rate 41.000000%
# At minibatch 3800, batch loss 1.353538, batch nll 0.931632, batch error rate 32.000000%
# At minibatch 3900, batch loss 1.396762, batch nll 0.986008, batch error rate 31.000000%
# At minibatch 4000, batch loss 1.304300, batch nll 0.906275, batch error rate 29.000000%
# After epoch 10: valid_err_rate: 37.700000% currently going to do 13 epochs
# After epoch 10: averaged train_err_rate: 33.570000% averaged train nll: 0.962723 averaged train loss: 1.385958
# At minibatch 4100, batch loss 1.194505, batch nll 0.806071, batch error rate 31.000000%
# At minibatch 4200, batch loss 1.233222, batch nll 0.852144, batch error rate 31.000000%
# At minibatch 4300, batch loss 1.263974, batch nll 0.890720, batch error rate 34.000000%
# At minibatch 4400, batch loss 1.240317, batch nll 0.875037, batch error rate 30.000000%
# After epoch 11: valid_err_rate: 33.420000% currently going to do 17 epochs
# After epoch 11: averaged train_err_rate: 32.682500% averaged train nll: 0.934419 averaged train loss: 1.315623
# At minibatch 4500, batch loss 1.313334, batch nll 0.952848, batch error rate 37.000000%
# At minibatch 4600, batch loss 1.205525, batch nll 0.850262, batch error rate 27.000000%
# At minibatch 4700, batch loss 1.098901, batch nll 0.748012, batch error rate 28.000000%
# At minibatch 4800, batch loss 1.198228, batch nll 0.852688, batch error rate 34.000000%
# After epoch 12: valid_err_rate: 35.280000% currently going to do 17 epochs
# After epoch 12: averaged train_err_rate: 31.422500% averaged train nll: 0.900389 averaged train loss: 1.255812
# At minibatch 4900, batch loss 1.120606, batch nll 0.775851, batch error rate 25.000000%
# At minibatch 5000, batch loss 1.207560, batch nll 0.864743, batch error rate 32.000000%
# At minibatch 5100, batch loss 1.369075, batch nll 1.031615, batch error rate 36.000000%
# At minibatch 5200, batch loss 1.259689, batch nll 0.925676, batch error rate 28.000000%
# After epoch 13: valid_err_rate: 34.440000% currently going to do 17 epochs
# After epoch 13: averaged train_err_rate: 31.402500% averaged train nll: 0.899106 averaged train loss: 1.240091
# At minibatch 5300, batch loss 1.242444, batch nll 0.908021, batch error rate 35.000000%
# At minibatch 5400, batch loss 0.996789, batch nll 0.664706, batch error rate 18.000000%
# At minibatch 5500, batch loss 1.148710, batch nll 0.820011, batch error rate 27.000000%
# At minibatch 5600, batch loss 1.037328, batch nll 0.709175, batch error rate 24.000000%
# After epoch 14: valid_err_rate: 31.320000% currently going to do 22 epochs
# After epoch 14: averaged train_err_rate: 30.370000% averaged train nll: 0.871660 averaged train loss: 1.203240
# At minibatch 5700, batch loss 1.119040, batch nll 0.790929, batch error rate 24.000000%
# At minibatch 5800, batch loss 1.016983, batch nll 0.689962, batch error rate 26.000000%
# At minibatch 5900, batch loss 1.384791, batch nll 1.060062, batch error rate 38.000000%
# At minibatch 6000, batch loss 1.123175, batch nll 0.800846, batch error rate 34.000000%
# After epoch 15: valid_err_rate: 30.080000% currently going to do 23 epochs
# After epoch 15: averaged train_err_rate: 29.777500% averaged train nll: 0.847437 averaged train loss: 1.173578
# At minibatch 6100, batch loss 1.215785, batch nll 0.893696, batch error rate 30.000000%
# At minibatch 6200, batch loss 1.228796, batch nll 0.907729, batch error rate 33.000000%
# At minibatch 6300, batch loss 1.028044, batch nll 0.708039, batch error rate 25.000000%
# At minibatch 6400, batch loss 1.221432, batch nll 0.901353, batch error rate 37.000000%
# After epoch 16: valid_err_rate: 31.780000% currently going to do 23 epochs
# After epoch 16: averaged train_err_rate: 29.017500% averaged train nll: 0.827407 averaged train loss: 1.148556
# At minibatch 6500, batch loss 1.062824, batch nll 0.741868, batch error rate 27.000000%
# At minibatch 6600, batch loss 0.979927, batch nll 0.659281, batch error rate 19.000000%
# At minibatch 6700, batch loss 1.140159, batch nll 0.820360, batch error rate 29.000000%
# At minibatch 6800, batch loss 1.217184, batch nll 0.897212, batch error rate 33.000000%
# After epoch 17: valid_err_rate: 33.910000% currently going to do 23 epochs
# After epoch 17: averaged train_err_rate: 28.702500% averaged train nll: 0.821431 averaged train loss: 1.141710
# At minibatch 6900, batch loss 1.107710, batch nll 0.786798, batch error rate 27.000000%
# At minibatch 7000, batch loss 1.144320, batch nll 0.823528, batch error rate 24.000000%
# At minibatch 7100, batch loss 1.024321, batch nll 0.704487, batch error rate 19.000000%
# At minibatch 7200, batch loss 1.200485, batch nll 0.881604, batch error rate 25.000000%
# After epoch 18: valid_err_rate: 29.610000% currently going to do 28 epochs
# After epoch 18: averaged train_err_rate: 27.955000% averaged train nll: 0.802138 averaged train loss: 1.122516
# At minibatch 7300, batch loss 1.213177, batch nll 0.893328, batch error rate 32.000000%
# At minibatch 7400, batch loss 1.075295, batch nll 0.755684, batch error rate 26.000000%
# At minibatch 7500, batch loss 1.074159, batch nll 0.754623, batch error rate 26.000000%
# At minibatch 7600, batch loss 1.109830, batch nll 0.791468, batch error rate 33.000000%
# After epoch 19: valid_err_rate: 29.450000% currently going to do 29 epochs
# After epoch 19: averaged train_err_rate: 27.297500% averaged train nll: 0.789727 averaged train loss: 1.109240
# At minibatch 7700, batch loss 1.140067, batch nll 0.820690, batch error rate 28.000000%
# At minibatch 7800, batch loss 1.239405, batch nll 0.919481, batch error rate 31.000000%
# At minibatch 7900, batch loss 1.170939, batch nll 0.851479, batch error rate 30.000000%
# At minibatch 8000, batch loss 1.107305, batch nll 0.788146, batch error rate 26.000000%
# After epoch 20: valid_err_rate: 29.830000% currently going to do 29 epochs
# After epoch 20: averaged train_err_rate: 27.507500% averaged train nll: 0.784262 averaged train loss: 1.103707
# At minibatch 8100, batch loss 1.077546, batch nll 0.756930, batch error rate 28.000000%
# At minibatch 8200, batch loss 1.068089, batch nll 0.747574, batch error rate 28.000000%
# At minibatch 8300, batch loss 1.148743, batch nll 0.828108, batch error rate 29.000000%
# At minibatch 8400, batch loss 1.008014, batch nll 0.687504, batch error rate 22.000000%
# After epoch 21: valid_err_rate: 28.650000% currently going to do 32 epochs
# After epoch 21: averaged train_err_rate: 26.820000% averaged train nll: 0.771541 averaged train loss: 1.092049
# At minibatch 8500, batch loss 0.992232, batch nll 0.670128, batch error rate 23.000000%
# At minibatch 8600, batch loss 1.081402, batch nll 0.758887, batch error rate 27.000000%
# At minibatch 8700, batch loss 1.038867, batch nll 0.717482, batch error rate 20.000000%
# At minibatch 8800, batch loss 1.002323, batch nll 0.682251, batch error rate 20.000000%
# After epoch 22: valid_err_rate: 28.770000% currently going to do 32 epochs
# After epoch 22: averaged train_err_rate: 26.697500% averaged train nll: 0.770153 averaged train loss: 1.091721
# At minibatch 8900, batch loss 1.063305, batch nll 0.741783, batch error rate 26.000000%
# At minibatch 9000, batch loss 1.243540, batch nll 0.921281, batch error rate 36.000000%
# At minibatch 9100, batch loss 0.924490, batch nll 0.600890, batch error rate 15.000000%
# At minibatch 9200, batch loss 1.172930, batch nll 0.850953, batch error rate 29.000000%
# After epoch 23: valid_err_rate: 29.330000% currently going to do 32 epochs
# After epoch 23: averaged train_err_rate: 26.117500% averaged train nll: 0.755751 averaged train loss: 1.077906
# At minibatch 9300, batch loss 0.963806, batch nll 0.640885, batch error rate 21.000000%
# At minibatch 9400, batch loss 1.158515, batch nll 0.834862, batch error rate 32.000000%
# At minibatch 9500, batch loss 1.092034, batch nll 0.768084, batch error rate 26.000000%
# At minibatch 9600, batch loss 1.134228, batch nll 0.811381, batch error rate 28.000000%
# After epoch 24: valid_err_rate: 28.720000% currently going to do 32 epochs
# After epoch 24: averaged train_err_rate: 26.047500% averaged train nll: 0.752575 averaged train loss: 1.075809
# At minibatch 9700, batch loss 0.932909, batch nll 0.609013, batch error rate 20.000000%
# At minibatch 9800, batch loss 1.049091, batch nll 0.724542, batch error rate 20.000000%
# At minibatch 9900, batch loss 1.186946, batch nll 0.862359, batch error rate 30.000000%
# At minibatch 10000, batch loss 1.057018, batch nll 0.732746, batch error rate 32.000000%
# After epoch 25: valid_err_rate: 28.400000% currently going to do 38 epochs
# After epoch 25: averaged train_err_rate: 25.525000% averaged train nll: 0.741854 averaged train loss: 1.066138
# At minibatch 10100, batch loss 1.063575, batch nll 0.737594, batch error rate 25.000000%
# At minibatch 10200, batch loss 0.975007, batch nll 0.649725, batch error rate 23.000000%
# At minibatch 10300, batch loss 1.168067, batch nll 0.842369, batch error rate 32.000000%
# At minibatch 10400, batch loss 1.173377, batch nll 0.847862, batch error rate 31.000000%
# After epoch 26: valid_err_rate: 28.650000% currently going to do 38 epochs
# After epoch 26: averaged train_err_rate: 25.327500% averaged train nll: 0.733457 averaged train loss: 1.059094
# At minibatch 10500, batch loss 0.890755, batch nll 0.564719, batch error rate 17.000000%
# At minibatch 10600, batch loss 1.167318, batch nll 0.840763, batch error rate 33.000000%
# At minibatch 10700, batch loss 0.885480, batch nll 0.558903, batch error rate 21.000000%
# At minibatch 10800, batch loss 1.049004, batch nll 0.722664, batch error rate 26.000000%
# After epoch 27: valid_err_rate: 28.250000% currently going to do 41 epochs
# After epoch 27: averaged train_err_rate: 25.172500% averaged train nll: 0.728604 averaged train loss: 1.054901
# At minibatch 10900, batch loss 1.087829, batch nll 0.760036, batch error rate 23.000000%
# At minibatch 11000, batch loss 1.046248, batch nll 0.718825, batch error rate 19.000000%
# At minibatch 11100, batch loss 1.026272, batch nll 0.699076, batch error rate 20.000000%
# At minibatch 11200, batch loss 1.076494, batch nll 0.749181, batch error rate 27.000000%
# After epoch 28: valid_err_rate: 30.070000% currently going to do 41 epochs
# After epoch 28: averaged train_err_rate: 25.040000% averaged train nll: 0.723558 averaged train loss: 1.050865
# At minibatch 11300, batch loss 0.938325, batch nll 0.610375, batch error rate 20.000000%
# At minibatch 11400, batch loss 1.046299, batch nll 0.718182, batch error rate 21.000000%
# At minibatch 11500, batch loss 1.000682, batch nll 0.672621, batch error rate 20.000000%
# At minibatch 11600, batch loss 0.981664, batch nll 0.652669, batch error rate 25.000000%
# After epoch 29: valid_err_rate: 29.250000% currently going to do 41 epochs
# After epoch 29: averaged train_err_rate: 24.790000% averaged train nll: 0.717489 averaged train loss: 1.045575
# At minibatch 11700, batch loss 1.010272, batch nll 0.680333, batch error rate 23.000000%
# At minibatch 11800, batch loss 1.001155, batch nll 0.671626, batch error rate 18.000000%
# At minibatch 11900, batch loss 1.149897, batch nll 0.819622, batch error rate 29.000000%
# At minibatch 12000, batch loss 1.132552, batch nll 0.802344, batch error rate 27.000000%
# After epoch 30: valid_err_rate: 27.840000% currently going to do 46 epochs
# After epoch 30: averaged train_err_rate: 24.542500% averaged train nll: 0.714214 averaged train loss: 1.043990
# At minibatch 12100, batch loss 0.970438, batch nll 0.639373, batch error rate 21.000000%
# At minibatch 12200, batch loss 1.041525, batch nll 0.710477, batch error rate 28.000000%
# At minibatch 12300, batch loss 1.057053, batch nll 0.725944, batch error rate 25.000000%
# At minibatch 12400, batch loss 1.076158, batch nll 0.745064, batch error rate 27.000000%
# After epoch 31: valid_err_rate: 28.320000% currently going to do 46 epochs
# After epoch 31: averaged train_err_rate: 24.282500% averaged train nll: 0.704011 averaged train loss: 1.035111
# At minibatch 12500, batch loss 0.946275, batch nll 0.614134, batch error rate 24.000000%
# At minibatch 12600, batch loss 0.973737, batch nll 0.641094, batch error rate 20.000000%
# At minibatch 12700, batch loss 0.875818, batch nll 0.543174, batch error rate 21.000000%
# At minibatch 12800, batch loss 1.068668, batch nll 0.737025, batch error rate 27.000000%
# After epoch 32: valid_err_rate: 27.670000% currently going to do 49 epochs
# After epoch 32: averaged train_err_rate: 24.265000% averaged train nll: 0.703802 averaged train loss: 1.035906
# At minibatch 12900, batch loss 0.967757, batch nll 0.634797, batch error rate 18.000000%
# At minibatch 13000, batch loss 0.989212, batch nll 0.655443, batch error rate 22.000000%
# At minibatch 13100, batch loss 1.196752, batch nll 0.864023, batch error rate 33.000000%
# At minibatch 13200, batch loss 1.007229, batch nll 0.674328, batch error rate 24.000000%
# After epoch 33: valid_err_rate: 27.460000% currently going to do 50 epochs
# After epoch 33: averaged train_err_rate: 24.050000% averaged train nll: 0.696867 averaged train loss: 1.029815
# At minibatch 13300, batch loss 1.041290, batch nll 0.707947, batch error rate 23.000000%
# At minibatch 13400, batch loss 1.131644, batch nll 0.797986, batch error rate 29.000000%
# At minibatch 13500, batch loss 1.015398, batch nll 0.681259, batch error rate 18.000000%
# At minibatch 13600, batch loss 1.129453, batch nll 0.795378, batch error rate 24.000000%
# After epoch 34: valid_err_rate: 28.080000% currently going to do 50 epochs
# After epoch 34: averaged train_err_rate: 24.197500% averaged train nll: 0.700641 averaged train loss: 1.034350
# At minibatch 13700, batch loss 0.832708, batch nll 0.498088, batch error rate 17.000000%
# At minibatch 13800, batch loss 1.188871, batch nll 0.854502, batch error rate 28.000000%
# At minibatch 13900, batch loss 0.957663, batch nll 0.622605, batch error rate 21.000000%
# At minibatch 14000, batch loss 1.006455, batch nll 0.671148, batch error rate 21.000000%
# After epoch 35: valid_err_rate: 27.710000% currently going to do 50 epochs
# After epoch 35: averaged train_err_rate: 23.827500% averaged train nll: 0.689976 averaged train loss: 1.024574
# At minibatch 14100, batch loss 1.043563, batch nll 0.707431, batch error rate 21.000000%
# At minibatch 14200, batch loss 0.995118, batch nll 0.658694, batch error rate 23.000000%
# At minibatch 14300, batch loss 0.962162, batch nll 0.625783, batch error rate 20.000000%
# At minibatch 14400, batch loss 1.058298, batch nll 0.721970, batch error rate 26.000000%
# After epoch 36: valid_err_rate: 27.690000% currently going to do 50 epochs
# After epoch 36: averaged train_err_rate: 23.380000% averaged train nll: 0.683926 averaged train loss: 1.020072
# At minibatch 14500, batch loss 1.057754, batch nll 0.720558, batch error rate 24.000000%
# At minibatch 14600, batch loss 1.015251, batch nll 0.678039, batch error rate 27.000000%
# At minibatch 14700, batch loss 1.023206, batch nll 0.686422, batch error rate 26.000000%
# At minibatch 14800, batch loss 0.941955, batch nll 0.605544, batch error rate 17.000000%
# After epoch 37: valid_err_rate: 26.970000% currently going to do 56 epochs
# After epoch 37: averaged train_err_rate: 23.530000% averaged train nll: 0.679464 averaged train loss: 1.016393
# At minibatch 14900, batch loss 0.856796, batch nll 0.519371, batch error rate 22.000000%
# At minibatch 15000, batch loss 1.167987, batch nll 0.830394, batch error rate 30.000000%
# At minibatch 15100, batch loss 1.087487, batch nll 0.749516, batch error rate 25.000000%
# At minibatch 15200, batch loss 0.948993, batch nll 0.611132, batch error rate 22.000000%
# After epoch 38: valid_err_rate: 28.280000% currently going to do 56 epochs
# After epoch 38: averaged train_err_rate: 23.442500% averaged train nll: 0.681764 averaged train loss: 1.019256
# At minibatch 15300, batch loss 1.003024, batch nll 0.663754, batch error rate 22.000000%
# At minibatch 15400, batch loss 0.990514, batch nll 0.651158, batch error rate 26.000000%
# At minibatch 15500, batch loss 1.098623, batch nll 0.759666, batch error rate 24.000000%
# At minibatch 15600, batch loss 1.108284, batch nll 0.769270, batch error rate 31.000000%
# After epoch 39: valid_err_rate: 27.310000% currently going to do 56 epochs
# After epoch 39: averaged train_err_rate: 23.537500% averaged train nll: 0.678406 averaged train loss: 1.017408
# At minibatch 15700, batch loss 1.027774, batch nll 0.688060, batch error rate 19.000000%
# At minibatch 15800, batch loss 1.122542, batch nll 0.783106, batch error rate 26.000000%
# At minibatch 15900, batch loss 1.028049, batch nll 0.688600, batch error rate 23.000000%
# At minibatch 16000, batch loss 0.989778, batch nll 0.649692, batch error rate 21.000000%
# After epoch 40: valid_err_rate: 26.470000% currently going to do 61 epochs
# After epoch 40: averaged train_err_rate: 23.287500% averaged train nll: 0.673274 averaged train loss: 1.012787
# At minibatch 16100, batch loss 1.034650, batch nll 0.694276, batch error rate 22.000000%
# At minibatch 16200, batch loss 0.972957, batch nll 0.632384, batch error rate 21.000000%
# At minibatch 16300, batch loss 0.936426, batch nll 0.595729, batch error rate 14.000000%
# At minibatch 16400, batch loss 0.999207, batch nll 0.658401, batch error rate 27.000000%
# After epoch 41: valid_err_rate: 27.070000% currently going to do 61 epochs
# After epoch 41: averaged train_err_rate: 23.065000% averaged train nll: 0.672102 averaged train loss: 1.012618
# At minibatch 16500, batch loss 0.936644, batch nll 0.595455, batch error rate 22.000000%
# At minibatch 16600, batch loss 1.122720, batch nll 0.781558, batch error rate 24.000000%
# At minibatch 16700, batch loss 1.019452, batch nll 0.678710, batch error rate 20.000000%
# At minibatch 16800, batch loss 0.986201, batch nll 0.644823, batch error rate 23.000000%
# After epoch 42: valid_err_rate: 27.470000% currently going to do 61 epochs
# After epoch 42: averaged train_err_rate: 22.947500% averaged train nll: 0.670419 averaged train loss: 1.011579
# At minibatch 16900, batch loss 0.998821, batch nll 0.656947, batch error rate 27.000000%
# At minibatch 17000, batch loss 0.962248, batch nll 0.620036, batch error rate 28.000000%
# At minibatch 17100, batch loss 1.127548, batch nll 0.785579, batch error rate 28.000000%
# At minibatch 17200, batch loss 0.893398, batch nll 0.551499, batch error rate 22.000000%
# After epoch 43: valid_err_rate: 26.780000% currently going to do 61 epochs
# After epoch 43: averaged train_err_rate: 22.725000% averaged train nll: 0.663141 averaged train loss: 1.005067
# At minibatch 17300, batch loss 1.124390, batch nll 0.781781, batch error rate 26.000000%
# At minibatch 17400, batch loss 0.967355, batch nll 0.624963, batch error rate 19.000000%
# At minibatch 17500, batch loss 0.896893, batch nll 0.554423, batch error rate 21.000000%
# At minibatch 17600, batch loss 1.010166, batch nll 0.667482, batch error rate 27.000000%
# After epoch 44: valid_err_rate: 27.290000% currently going to do 61 epochs
# After epoch 44: averaged train_err_rate: 22.577500% averaged train nll: 0.660736 averaged train loss: 1.003229
# At minibatch 17700, batch loss 1.069070, batch nll 0.725213, batch error rate 20.000000%
# At minibatch 17800, batch loss 0.951849, batch nll 0.608019, batch error rate 21.000000%
# At minibatch 17900, batch loss 1.150700, batch nll 0.807533, batch error rate 28.000000%
# At minibatch 18000, batch loss 0.994503, batch nll 0.651000, batch error rate 21.000000%
# After epoch 45: valid_err_rate: 28.520000% currently going to do 61 epochs
# After epoch 45: averaged train_err_rate: 22.612500% averaged train nll: 0.658161 averaged train loss: 1.001720
# At minibatch 18100, batch loss 0.982037, batch nll 0.637819, batch error rate 20.000000%
# At minibatch 18200, batch loss 0.966823, batch nll 0.622393, batch error rate 18.000000%
# At minibatch 18300, batch loss 1.190238, batch nll 0.845884, batch error rate 35.000000%
# At minibatch 18400, batch loss 1.168798, batch nll 0.824641, batch error rate 29.000000%
# After epoch 46: valid_err_rate: 27.410000% currently going to do 61 epochs
# After epoch 46: averaged train_err_rate: 22.580000% averaged train nll: 0.655703 averaged train loss: 0.999839
# At minibatch 18500, batch loss 1.021936, batch nll 0.676743, batch error rate 23.000000%
# At minibatch 18600, batch loss 0.907079, batch nll 0.562026, batch error rate 19.000000%
# At minibatch 18700, batch loss 0.937885, batch nll 0.592471, batch error rate 19.000000%
# At minibatch 18800, batch loss 0.981552, batch nll 0.636805, batch error rate 22.000000%
# After epoch 47: valid_err_rate: 26.540000% currently going to do 61 epochs
# After epoch 47: averaged train_err_rate: 22.335000% averaged train nll: 0.653643 averaged train loss: 0.998692
# At minibatch 18900, batch loss 0.975696, batch nll 0.629958, batch error rate 18.000000%
# At minibatch 19000, batch loss 1.061168, batch nll 0.715674, batch error rate 29.000000%
# At minibatch 19100, batch loss 1.119820, batch nll 0.773927, batch error rate 26.000000%
# At minibatch 19200, batch loss 1.054293, batch nll 0.708662, batch error rate 28.000000%
# After epoch 48: valid_err_rate: 27.290000% currently going to do 61 epochs
# After epoch 48: averaged train_err_rate: 22.442500% averaged train nll: 0.650953 averaged train loss: 0.996580
# At minibatch 19300, batch loss 1.007414, batch nll 0.661605, batch error rate 25.000000%
# At minibatch 19400, batch loss 1.058563, batch nll 0.712233, batch error rate 22.000000%
# At minibatch 19500, batch loss 1.023661, batch nll 0.677416, batch error rate 23.000000%
# At minibatch 19600, batch loss 0.982434, batch nll 0.636232, batch error rate 25.000000%
# After epoch 49: valid_err_rate: 26.930000% currently going to do 61 epochs
# After epoch 49: averaged train_err_rate: 22.362500% averaged train nll: 0.652177 averaged train loss: 0.998207
# At minibatch 19700, batch loss 1.052280, batch nll 0.705412, batch error rate 28.000000%
# At minibatch 19800, batch loss 1.128099, batch nll 0.780948, batch error rate 27.000000%
# At minibatch 19900, batch loss 0.983482, batch nll 0.636352, batch error rate 27.000000%
# At minibatch 20000, batch loss 1.041381, batch nll 0.694464, batch error rate 25.000000%
# After epoch 50: valid_err_rate: 26.600000% currently going to do 61 epochs
# After epoch 50: averaged train_err_rate: 22.392500% averaged train nll: 0.648055 averaged train loss: 0.995002
# At minibatch 20100, batch loss 1.028784, batch nll 0.681746, batch error rate 29.000000%
# At minibatch 20200, batch loss 1.007287, batch nll 0.659562, batch error rate 24.000000%
# At minibatch 20300, batch loss 0.978388, batch nll 0.630519, batch error rate 20.000000%
# At minibatch 20400, batch loss 1.081985, batch nll 0.734247, batch error rate 26.000000%
# After epoch 51: valid_err_rate: 28.100000% currently going to do 61 epochs
# After epoch 51: averaged train_err_rate: 22.122500% averaged train nll: 0.642809 averaged train loss: 0.990231
# At minibatch 20500, batch loss 1.050444, batch nll 0.702120, batch error rate 26.000000%
# At minibatch 20600, batch loss 0.932149, batch nll 0.583776, batch error rate 23.000000%
# At minibatch 20700, batch loss 0.913105, batch nll 0.565104, batch error rate 20.000000%
# At minibatch 20800, batch loss 0.950670, batch nll 0.602403, batch error rate 24.000000%
# After epoch 52: valid_err_rate: 26.690000% currently going to do 61 epochs
# After epoch 52: averaged train_err_rate: 22.135000% averaged train nll: 0.643756 averaged train loss: 0.991981
# At minibatch 20900, batch loss 1.068933, batch nll 0.720120, batch error rate 29.000000%
# At minibatch 21000, batch loss 1.020048, batch nll 0.671123, batch error rate 22.000000%
# At minibatch 21100, batch loss 0.900840, batch nll 0.551904, batch error rate 21.000000%
# At minibatch 21200, batch loss 1.037536, batch nll 0.688525, batch error rate 30.000000%
# After epoch 53: valid_err_rate: 26.870000% currently going to do 61 epochs
# After epoch 53: averaged train_err_rate: 22.037500% averaged train nll: 0.640335 averaged train loss: 0.989173
# At minibatch 21300, batch loss 1.003628, batch nll 0.654402, batch error rate 25.000000%
# At minibatch 21400, batch loss 0.942581, batch nll 0.592926, batch error rate 18.000000%
# At minibatch 21500, batch loss 0.929239, batch nll 0.579437, batch error rate 19.000000%
# At minibatch 21600, batch loss 0.885365, batch nll 0.535499, batch error rate 12.000000%
# After epoch 54: valid_err_rate: 26.320000% currently going to do 82 epochs
# After epoch 54: averaged train_err_rate: 21.847500% averaged train nll: 0.638479 averaged train loss: 0.987987
# At minibatch 21700, batch loss 0.941320, batch nll 0.590930, batch error rate 24.000000%
# At minibatch 21800, batch loss 1.037912, batch nll 0.687763, batch error rate 24.000000%
# At minibatch 21900, batch loss 1.055649, batch nll 0.705582, batch error rate 23.000000%
# At minibatch 22000, batch loss 1.127813, batch nll 0.777415, batch error rate 31.000000%
# After epoch 55: valid_err_rate: 26.280000% currently going to do 83 epochs
# After epoch 55: averaged train_err_rate: 21.810000% averaged train nll: 0.635878 averaged train loss: 0.986094
# At minibatch 22100, batch loss 1.029090, batch nll 0.677907, batch error rate 21.000000%
# At minibatch 22200, batch loss 0.963469, batch nll 0.612543, batch error rate 19.000000%
# At minibatch 22300, batch loss 1.173146, batch nll 0.822133, batch error rate 27.000000%
# At minibatch 22400, batch loss 0.962461, batch nll 0.611542, batch error rate 19.000000%
# After epoch 56: valid_err_rate: 27.220000% currently going to do 83 epochs
# After epoch 56: averaged train_err_rate: 21.652500% averaged train nll: 0.633999 averaged train loss: 0.984965
# At minibatch 22500, batch loss 1.055786, batch nll 0.704367, batch error rate 23.000000%
# At minibatch 22600, batch loss 1.112335, batch nll 0.760766, batch error rate 22.000000%
# At minibatch 22700, batch loss 0.938030, batch nll 0.586423, batch error rate 21.000000%
# At minibatch 22800, batch loss 0.938411, batch nll 0.586873, batch error rate 20.000000%
# After epoch 57: valid_err_rate: 27.610000% currently going to do 83 epochs
# After epoch 57: averaged train_err_rate: 21.662500% averaged train nll: 0.629998 averaged train loss: 0.981416
# At minibatch 22900, batch loss 1.130229, batch nll 0.778314, batch error rate 29.000000%
# At minibatch 23000, batch loss 0.943379, batch nll 0.591340, batch error rate 19.000000%
# At minibatch 23100, batch loss 0.891625, batch nll 0.539926, batch error rate 19.000000%
# At minibatch 23200, batch loss 1.048946, batch nll 0.697043, batch error rate 27.000000%
# After epoch 58: valid_err_rate: 26.720000% currently going to do 83 epochs
# After epoch 58: averaged train_err_rate: 21.795000% averaged train nll: 0.633072 averaged train loss: 0.984900
# At minibatch 23300, batch loss 0.824046, batch nll 0.471800, batch error rate 14.000000%
# At minibatch 23400, batch loss 0.985074, batch nll 0.632258, batch error rate 23.000000%
# At minibatch 23500, batch loss 1.023185, batch nll 0.670508, batch error rate 22.000000%
# At minibatch 23600, batch loss 1.002287, batch nll 0.649827, batch error rate 22.000000%
# After epoch 59: valid_err_rate: 26.800000% currently going to do 83 epochs
# After epoch 59: averaged train_err_rate: 21.460000% averaged train nll: 0.628260 averaged train loss: 0.980763
# At minibatch 23700, batch loss 1.051590, batch nll 0.698471, batch error rate 24.000000%
# At minibatch 23800, batch loss 0.935942, batch nll 0.582619, batch error rate 21.000000%
# At minibatch 23900, batch loss 1.014071, batch nll 0.660798, batch error rate 22.000000%
# At minibatch 24000, batch loss 1.060405, batch nll 0.707338, batch error rate 26.000000%
# After epoch 60: valid_err_rate: 27.460000% currently going to do 83 epochs
# After epoch 60: averaged train_err_rate: 21.355000% averaged train nll: 0.624068 averaged train loss: 0.977168
# At minibatch 24100, batch loss 0.963735, batch nll 0.610203, batch error rate 17.000000%
# At minibatch 24200, batch loss 1.040289, batch nll 0.686553, batch error rate 26.000000%
# At minibatch 24300, batch loss 1.089077, batch nll 0.735612, batch error rate 23.000000%
# At minibatch 24400, batch loss 0.945366, batch nll 0.591817, batch error rate 20.000000%
# After epoch 61: valid_err_rate: 26.430000% currently going to do 83 epochs
# After epoch 61: averaged train_err_rate: 21.307500% averaged train nll: 0.623416 averaged train loss: 0.976954
# At minibatch 24500, batch loss 0.971022, batch nll 0.617253, batch error rate 18.000000%
# At minibatch 24600, batch loss 0.802682, batch nll 0.448854, batch error rate 17.000000%
# At minibatch 24700, batch loss 1.108172, batch nll 0.754197, batch error rate 25.000000%
# At minibatch 24800, batch loss 1.036201, batch nll 0.682158, batch error rate 23.000000%
# After epoch 62: valid_err_rate: 26.430000% currently going to do 83 epochs
# After epoch 62: averaged train_err_rate: 21.482500% averaged train nll: 0.624136 averaged train loss: 0.977998
# At minibatch 24900, batch loss 1.004694, batch nll 0.650655, batch error rate 21.000000%
# At minibatch 25000, batch loss 1.097756, batch nll 0.742727, batch error rate 23.000000%
# At minibatch 25100, batch loss 1.005448, batch nll 0.650368, batch error rate 25.000000%
# At minibatch 25200, batch loss 0.986597, batch nll 0.632199, batch error rate 24.000000%
# After epoch 63: valid_err_rate: 27.260000% currently going to do 83 epochs
# After epoch 63: averaged train_err_rate: 21.507500% averaged train nll: 0.623081 averaged train loss: 0.977707
# At minibatch 25300, batch loss 1.018970, batch nll 0.664132, batch error rate 22.000000%
# At minibatch 25400, batch loss 0.882448, batch nll 0.527625, batch error rate 15.000000%
# At minibatch 25500, batch loss 0.918043, batch nll 0.562979, batch error rate 21.000000%
# At minibatch 25600, batch loss 0.914217, batch nll 0.559047, batch error rate 17.000000%
# After epoch 64: valid_err_rate: 26.340000% currently going to do 83 epochs
# After epoch 64: averaged train_err_rate: 21.330000% averaged train nll: 0.620267 averaged train loss: 0.975172
# At minibatch 25700, batch loss 1.097090, batch nll 0.741480, batch error rate 23.000000%
# At minibatch 25800, batch loss 1.033519, batch nll 0.677821, batch error rate 27.000000%
# At minibatch 25900, batch loss 0.902344, batch nll 0.546448, batch error rate 18.000000%
# At minibatch 26000, batch loss 1.002929, batch nll 0.647364, batch error rate 23.000000%
# After epoch 65: valid_err_rate: 26.710000% currently going to do 83 epochs
# After epoch 65: averaged train_err_rate: 21.325000% averaged train nll: 0.619646 averaged train loss: 0.975307
# At minibatch 26100, batch loss 1.107260, batch nll 0.751345, batch error rate 27.000000%
# At minibatch 26200, batch loss 0.900798, batch nll 0.544724, batch error rate 20.000000%
# At minibatch 26300, batch loss 0.994505, batch nll 0.638324, batch error rate 20.000000%
# At minibatch 26400, batch loss 1.165461, batch nll 0.809163, batch error rate 34.000000%
# After epoch 66: valid_err_rate: 26.830000% currently going to do 83 epochs
# After epoch 66: averaged train_err_rate: 21.330000% averaged train nll: 0.616163 averaged train loss: 0.972203
# At minibatch 26500, batch loss 1.127951, batch nll 0.771485, batch error rate 24.000000%
# At minibatch 26600, batch loss 1.072288, batch nll 0.715681, batch error rate 25.000000%
# At minibatch 26700, batch loss 1.074655, batch nll 0.717973, batch error rate 24.000000%
# At minibatch 26800, batch loss 0.978991, batch nll 0.622242, batch error rate 21.000000%
# After epoch 67: valid_err_rate: 26.660000% currently going to do 83 epochs
# After epoch 67: averaged train_err_rate: 21.090000% averaged train nll: 0.613214 averaged train loss: 0.969727
# At minibatch 26900, batch loss 0.977824, batch nll 0.620632, batch error rate 18.000000%
# At minibatch 27000, batch loss 0.984950, batch nll 0.627810, batch error rate 23.000000%
# At minibatch 27100, batch loss 1.056704, batch nll 0.699790, batch error rate 28.000000%
# At minibatch 27200, batch loss 0.877276, batch nll 0.520090, batch error rate 17.000000%
# After epoch 68: valid_err_rate: 26.750000% currently going to do 83 epochs
# After epoch 68: averaged train_err_rate: 21.100000% averaged train nll: 0.612822 averaged train loss: 0.969912
# At minibatch 27300, batch loss 1.061011, batch nll 0.703735, batch error rate 22.000000%
# At minibatch 27400, batch loss 1.009276, batch nll 0.651898, batch error rate 20.000000%
# At minibatch 27500, batch loss 1.118431, batch nll 0.760974, batch error rate 28.000000%
# At minibatch 27600, batch loss 0.854948, batch nll 0.497492, batch error rate 18.000000%
# After epoch 69: valid_err_rate: 25.970000% currently going to do 104 epochs
# After epoch 69: averaged train_err_rate: 21.017500% averaged train nll: 0.615315 averaged train loss: 0.972721
# At minibatch 27700, batch loss 0.938407, batch nll 0.580304, batch error rate 19.000000%
# At minibatch 27800, batch loss 0.959146, batch nll 0.600977, batch error rate 21.000000%
# At minibatch 27900, batch loss 1.015972, batch nll 0.657791, batch error rate 21.000000%
# At minibatch 28000, batch loss 0.964628, batch nll 0.606671, batch error rate 19.000000%
# After epoch 70: valid_err_rate: 26.440000% currently going to do 104 epochs
# After epoch 70: averaged train_err_rate: 21.017500% averaged train nll: 0.612954 averaged train loss: 0.970974
# At minibatch 28100, batch loss 0.911135, batch nll 0.552865, batch error rate 17.000000%
# At minibatch 28200, batch loss 0.862392, batch nll 0.503934, batch error rate 20.000000%
# At minibatch 28300, batch loss 0.889152, batch nll 0.530550, batch error rate 16.000000%
# At minibatch 28400, batch loss 0.986939, batch nll 0.628379, batch error rate 21.000000%
# After epoch 71: valid_err_rate: 26.690000% currently going to do 104 epochs
# After epoch 71: averaged train_err_rate: 20.882500% averaged train nll: 0.607506 averaged train loss: 0.965930
# At minibatch 28500, batch loss 1.117736, batch nll 0.758929, batch error rate 22.000000%
# At minibatch 28600, batch loss 0.990578, batch nll 0.631605, batch error rate 19.000000%
# At minibatch 28700, batch loss 0.965000, batch nll 0.606036, batch error rate 17.000000%
# At minibatch 28800, batch loss 1.046402, batch nll 0.687407, batch error rate 20.000000%
# After epoch 72: valid_err_rate: 26.630000% currently going to do 104 epochs
# After epoch 72: averaged train_err_rate: 20.977500% averaged train nll: 0.609254 averaged train loss: 0.968152
# At minibatch 28900, batch loss 1.005579, batch nll 0.646123, batch error rate 22.000000%
# At minibatch 29000, batch loss 0.923125, batch nll 0.563735, batch error rate 18.000000%
# At minibatch 29100, batch loss 1.054044, batch nll 0.694349, batch error rate 26.000000%
# At minibatch 29200, batch loss 1.018202, batch nll 0.658479, batch error rate 25.000000%
# After epoch 73: valid_err_rate: 26.450000% currently going to do 104 epochs
# After epoch 73: averaged train_err_rate: 20.897500% averaged train nll: 0.606155 averaged train loss: 0.965657
# At minibatch 29300, batch loss 0.841460, batch nll 0.481565, batch error rate 18.000000%
# At minibatch 29400, batch loss 0.803088, batch nll 0.443134, batch error rate 15.000000%
# At minibatch 29500, batch loss 1.170385, batch nll 0.810442, batch error rate 30.000000%
# At minibatch 29600, batch loss 1.067262, batch nll 0.707474, batch error rate 24.000000%
# After epoch 74: valid_err_rate: 25.910000% currently going to do 112 epochs
# After epoch 74: averaged train_err_rate: 20.910000% averaged train nll: 0.608839 averaged train loss: 0.968717
# At minibatch 29700, batch loss 0.892581, batch nll 0.532290, batch error rate 19.000000%
# At minibatch 29800, batch loss 0.930266, batch nll 0.570300, batch error rate 23.000000%
# At minibatch 29900, batch loss 1.007876, batch nll 0.647759, batch error rate 23.000000%
# At minibatch 30000, batch loss 0.958423, batch nll 0.598178, batch error rate 21.000000%
# After epoch 75: valid_err_rate: 27.050000% currently going to do 112 epochs
# After epoch 75: averaged train_err_rate: 20.605000% averaged train nll: 0.605728 averaged train loss: 0.965815
# At minibatch 30100, batch loss 0.847551, batch nll 0.487101, batch error rate 13.000000%
# At minibatch 30200, batch loss 0.996093, batch nll 0.635491, batch error rate 20.000000%
# At minibatch 30300, batch loss 0.966351, batch nll 0.605869, batch error rate 19.000000%
# At minibatch 30400, batch loss 0.918235, batch nll 0.557604, batch error rate 22.000000%
# After epoch 76: valid_err_rate: 26.130000% currently going to do 112 epochs
# After epoch 76: averaged train_err_rate: 20.760000% averaged train nll: 0.607834 averaged train loss: 0.968316
# At minibatch 30500, batch loss 1.067447, batch nll 0.706621, batch error rate 24.000000%
# At minibatch 30600, batch loss 1.035348, batch nll 0.674366, batch error rate 22.000000%
# At minibatch 30700, batch loss 0.907734, batch nll 0.546774, batch error rate 20.000000%
# At minibatch 30800, batch loss 0.868715, batch nll 0.507713, batch error rate 16.000000%
# After epoch 77: valid_err_rate: 26.740000% currently going to do 112 epochs
# After epoch 77: averaged train_err_rate: 20.542500% averaged train nll: 0.600512 averaged train loss: 0.961416
# At minibatch 30900, batch loss 0.957475, batch nll 0.596029, batch error rate 21.000000%
# At minibatch 31000, batch loss 0.921917, batch nll 0.560453, batch error rate 19.000000%
# At minibatch 31100, batch loss 1.025193, batch nll 0.663586, batch error rate 23.000000%
# At minibatch 31200, batch loss 0.866973, batch nll 0.505331, batch error rate 14.000000%
# After epoch 78: valid_err_rate: 26.260000% currently going to do 112 epochs
# After epoch 78: averaged train_err_rate: 20.360000% averaged train nll: 0.598985 averaged train loss: 0.960466
# At minibatch 31300, batch loss 1.076171, batch nll 0.714319, batch error rate 24.000000%
# At minibatch 31400, batch loss 0.936496, batch nll 0.574348, batch error rate 19.000000%
# At minibatch 31500, batch loss 1.007739, batch nll 0.645476, batch error rate 25.000000%
# At minibatch 31600, batch loss 1.014665, batch nll 0.652644, batch error rate 24.000000%
# After epoch 79: valid_err_rate: 26.700000% currently going to do 112 epochs
# After epoch 79: averaged train_err_rate: 20.432500% averaged train nll: 0.597811 averaged train loss: 0.959824
# At minibatch 31700, batch loss 1.065436, batch nll 0.703164, batch error rate 23.000000%
# At minibatch 31800, batch loss 1.006100, batch nll 0.643911, batch error rate 20.000000%
# At minibatch 31900, batch loss 1.040561, batch nll 0.678374, batch error rate 19.000000%
# At minibatch 32000, batch loss 0.974841, batch nll 0.612493, batch error rate 23.000000%
# After epoch 80: valid_err_rate: 26.580000% currently going to do 112 epochs
# After epoch 80: averaged train_err_rate: 20.662500% averaged train nll: 0.599288 averaged train loss: 0.961507
# At minibatch 32100, batch loss 0.979438, batch nll 0.616853, batch error rate 21.000000%
# At minibatch 32200, batch loss 0.950473, batch nll 0.587782, batch error rate 21.000000%
# At minibatch 32300, batch loss 0.886608, batch nll 0.523645, batch error rate 20.000000%
# At minibatch 32400, batch loss 0.996545, batch nll 0.633824, batch error rate 23.000000%
# After epoch 81: valid_err_rate: 26.300000% currently going to do 112 epochs
# After epoch 81: averaged train_err_rate: 20.472500% averaged train nll: 0.595656 averaged train loss: 0.958365
# At minibatch 32500, batch loss 1.039175, batch nll 0.676181, batch error rate 25.000000%
# At minibatch 32600, batch loss 0.882516, batch nll 0.519560, batch error rate 15.000000%
# At minibatch 32700, batch loss 0.917720, batch nll 0.554702, batch error rate 13.000000%
# At minibatch 32800, batch loss 1.164105, batch nll 0.801196, batch error rate 24.000000%
# After epoch 82: valid_err_rate: 26.280000% currently going to do 112 epochs
# After epoch 82: averaged train_err_rate: 20.445000% averaged train nll: 0.597834 averaged train loss: 0.960803
# At minibatch 32900, batch loss 0.912026, batch nll 0.548930, batch error rate 14.000000%
# At minibatch 33000, batch loss 1.100346, batch nll 0.736992, batch error rate 29.000000%
# At minibatch 33100, batch loss 0.954049, batch nll 0.590631, batch error rate 21.000000%
# At minibatch 33200, batch loss 0.992452, batch nll 0.629073, batch error rate 25.000000%
# After epoch 83: valid_err_rate: 26.170000% currently going to do 112 epochs
# After epoch 83: averaged train_err_rate: 20.167500% averaged train nll: 0.594862 averaged train loss: 0.958088
# At minibatch 33300, batch loss 1.014578, batch nll 0.650795, batch error rate 22.000000%
# At minibatch 33400, batch loss 1.149422, batch nll 0.785317, batch error rate 29.000000%
# At minibatch 33500, batch loss 0.986813, batch nll 0.622943, batch error rate 20.000000%
# At minibatch 33600, batch loss 0.915400, batch nll 0.551669, batch error rate 21.000000%
# After epoch 84: valid_err_rate: 26.100000% currently going to do 112 epochs
# After epoch 84: averaged train_err_rate: 20.310000% averaged train nll: 0.592740 averaged train loss: 0.956625
# At minibatch 33700, batch loss 0.893253, batch nll 0.529203, batch error rate 17.000000%
# At minibatch 33800, batch loss 1.119664, batch nll 0.755579, batch error rate 27.000000%
# At minibatch 33900, batch loss 0.855524, batch nll 0.491388, batch error rate 16.000000%
# At minibatch 34000, batch loss 1.092842, batch nll 0.728747, batch error rate 27.000000%
# After epoch 85: valid_err_rate: 26.370000% currently going to do 112 epochs
# After epoch 85: averaged train_err_rate: 20.270000% averaged train nll: 0.591076 averaged train loss: 0.955132
# At minibatch 34100, batch loss 1.050366, batch nll 0.686056, batch error rate 22.000000%
# At minibatch 34200, batch loss 0.991317, batch nll 0.626823, batch error rate 17.000000%
# At minibatch 34300, batch loss 0.787471, batch nll 0.422974, batch error rate 12.000000%
# At minibatch 34400, batch loss 0.940528, batch nll 0.575968, batch error rate 20.000000%
# After epoch 86: valid_err_rate: 26.560000% currently going to do 112 epochs
# After epoch 86: averaged train_err_rate: 20.197500% averaged train nll: 0.592117 averaged train loss: 0.956517
# At minibatch 34500, batch loss 0.843474, batch nll 0.478512, batch error rate 20.000000%
# At minibatch 34600, batch loss 1.204380, batch nll 0.839500, batch error rate 30.000000%
# At minibatch 34700, batch loss 1.043576, batch nll 0.678553, batch error rate 26.000000%
# At minibatch 34800, batch loss 0.975183, batch nll 0.610337, batch error rate 19.000000%
# After epoch 87: valid_err_rate: 26.780000% currently going to do 112 epochs
# After epoch 87: averaged train_err_rate: 20.417500% averaged train nll: 0.590970 averaged train loss: 0.955890
# At minibatch 34900, batch loss 0.928660, batch nll 0.563669, batch error rate 19.000000%
# At minibatch 35000, batch loss 0.913001, batch nll 0.547843, batch error rate 19.000000%
# At minibatch 35100, batch loss 0.894145, batch nll 0.528943, batch error rate 15.000000%
# At minibatch 35200, batch loss 0.871790, batch nll 0.506458, batch error rate 19.000000%
# After epoch 88: valid_err_rate: 26.420000% currently going to do 112 epochs
# After epoch 88: averaged train_err_rate: 20.097500% averaged train nll: 0.591928 averaged train loss: 0.957034
# At minibatch 35300, batch loss 0.981651, batch nll 0.616244, batch error rate 23.000000%
# At minibatch 35400, batch loss 0.898067, batch nll 0.532374, batch error rate 23.000000%
# At minibatch 35500, batch loss 0.938816, batch nll 0.573089, batch error rate 18.000000%
# At minibatch 35600, batch loss 0.870609, batch nll 0.504904, batch error rate 21.000000%
# ...
# At minibatch 138900, batch loss 0.815773, batch nll 0.413081, batch error rate 12.000000%
# At minibatch 139000, batch loss 0.877441, batch nll 0.474761, batch error rate 17.000000%
# At minibatch 139100, batch loss 0.876126, batch nll 0.473445, batch error rate 19.000000%
# At minibatch 139200, batch loss 0.953737, batch nll 0.551067, batch error rate 17.000000%
# After epoch 348: valid_err_rate: 25.940000% currently going to do 376 epochs
# After epoch 348: averaged train_err_rate: 16.655000% averaged train nll: 0.495646 averaged train loss: 0.898313
# At minibatch 139300, batch loss 1.016923, batch nll 0.614197, batch error rate 21.000000%
# At minibatch 139400, batch loss 1.005902, batch nll 0.603123, batch error rate 22.000000%
# At minibatch 139500, batch loss 0.820750, batch nll 0.417973, batch error rate 13.000000%
# At minibatch 139600, batch loss 0.998516, batch nll 0.595763, batch error rate 23.000000%
# After epoch 349: valid_err_rate: 25.440000% currently going to do 376 epochs
# After epoch 349: averaged train_err_rate: 16.600000% averaged train nll: 0.496462 averaged train loss: 0.899210
# At minibatch 139700, batch loss 0.896166, batch nll 0.493427, batch error rate 19.000000%
# At minibatch 139800, batch loss 0.823918, batch nll 0.421148, batch error rate 15.000000%
# At minibatch 139900, batch loss 0.834683, batch nll 0.431867, batch error rate 16.000000%
# At minibatch 140000, batch loss 0.890064, batch nll 0.487250, batch error rate 17.000000%
# After epoch 350: valid_err_rate: 25.990000% currently going to do 376 epochs
# After epoch 350: averaged train_err_rate: 16.522500% averaged train nll: 0.496922 averaged train loss: 0.899701
# At minibatch 140100, batch loss 0.802038, batch nll 0.399211, batch error rate 12.000000%
# At minibatch 140200, batch loss 1.036217, batch nll 0.633347, batch error rate 19.000000%
# At minibatch 140300, batch loss 0.977313, batch nll 0.574404, batch error rate 23.000000%
# At minibatch 140400, batch loss 0.877682, batch nll 0.474801, batch error rate 16.000000%
# After epoch 351: valid_err_rate: 25.520000% currently going to do 376 epochs
# After epoch 351: averaged train_err_rate: 16.522500% averaged train nll: 0.495804 averaged train loss: 0.898664
# At minibatch 140500, batch loss 0.852283, batch nll 0.449374, batch error rate 18.000000%
# At minibatch 140600, batch loss 0.962510, batch nll 0.559590, batch error rate 20.000000%
# At minibatch 140700, batch loss 0.956467, batch nll 0.553567, batch error rate 22.000000%
# At minibatch 140800, batch loss 0.913841, batch nll 0.510929, batch error rate 17.000000%
# After epoch 352: valid_err_rate: 25.770000% currently going to do 376 epochs
# After epoch 352: averaged train_err_rate: 16.767500% averaged train nll: 0.496929 averaged train loss: 0.899838
# At minibatch 140900, batch loss 1.001834, batch nll 0.598825, batch error rate 21.000000%
# At minibatch 141000, batch loss 0.821936, batch nll 0.418919, batch error rate 11.000000%
# At minibatch 141100, batch loss 0.901562, batch nll 0.498620, batch error rate 19.000000%
# At minibatch 141200, batch loss 0.974574, batch nll 0.571622, batch error rate 17.000000%
# After epoch 353: valid_err_rate: 25.840000% currently going to do 376 epochs
# After epoch 353: averaged train_err_rate: 16.597500% averaged train nll: 0.496485 averaged train loss: 0.899458
# At minibatch 141300, batch loss 0.858357, batch nll 0.455341, batch error rate 9.000000%
# At minibatch 141400, batch loss 0.829123, batch nll 0.426057, batch error rate 15.000000%
# At minibatch 141500, batch loss 0.923285, batch nll 0.520216, batch error rate 18.000000%
# At minibatch 141600, batch loss 0.949275, batch nll 0.546281, batch error rate 23.000000%
# After epoch 354: valid_err_rate: 25.640000% currently going to do 376 epochs
# After epoch 354: averaged train_err_rate: 16.647500% averaged train nll: 0.497308 averaged train loss: 0.900343
# At minibatch 141700, batch loss 0.858628, batch nll 0.455526, batch error rate 17.000000%
# At minibatch 141800, batch loss 0.971238, batch nll 0.568153, batch error rate 15.000000%
# At minibatch 141900, batch loss 0.764173, batch nll 0.361089, batch error rate 9.000000%
# At minibatch 142000, batch loss 0.827496, batch nll 0.424408, batch error rate 12.000000%
# After epoch 355: valid_err_rate: 25.450000% currently going to do 376 epochs
# After epoch 355: averaged train_err_rate: 16.505000% averaged train nll: 0.494870 averaged train loss: 0.897951
# At minibatch 142100, batch loss 0.752280, batch nll 0.349142, batch error rate 10.000000%
# At minibatch 142200, batch loss 0.859000, batch nll 0.455851, batch error rate 13.000000%
# At minibatch 142300, batch loss 0.915456, batch nll 0.512327, batch error rate 16.000000%
# At minibatch 142400, batch loss 0.786453, batch nll 0.383287, batch error rate 15.000000%
# After epoch 356: valid_err_rate: 25.690000% currently going to do 376 epochs
# After epoch 356: averaged train_err_rate: 16.462500% averaged train nll: 0.495287 averaged train loss: 0.898431
# At minibatch 142500, batch loss 0.888319, batch nll 0.485096, batch error rate 17.000000%
# At minibatch 142600, batch loss 1.044961, batch nll 0.641696, batch error rate 22.000000%
# At minibatch 142700, batch loss 0.880888, batch nll 0.477625, batch error rate 14.000000%
# At minibatch 142800, batch loss 0.757827, batch nll 0.354584, batch error rate 10.000000%
# After epoch 357: valid_err_rate: 25.780000% currently going to do 376 epochs
# After epoch 357: averaged train_err_rate: 16.602500% averaged train nll: 0.495450 averaged train loss: 0.898699
# At minibatch 142900, batch loss 0.836867, batch nll 0.433569, batch error rate 13.000000%
# At minibatch 143000, batch loss 1.011657, batch nll 0.608316, batch error rate 20.000000%
# At minibatch 143100, batch loss 0.857521, batch nll 0.454225, batch error rate 17.000000%
# At minibatch 143200, batch loss 0.889767, batch nll 0.486488, batch error rate 16.000000%
# After epoch 358: valid_err_rate: 25.360000% currently going to do 376 epochs
# After epoch 358: averaged train_err_rate: 16.560000% averaged train nll: 0.497193 averaged train loss: 0.900500
# At minibatch 143300, batch loss 0.828049, batch nll 0.424708, batch error rate 15.000000%
# At minibatch 143400, batch loss 0.888904, batch nll 0.485519, batch error rate 17.000000%
# At minibatch 143500, batch loss 0.909252, batch nll 0.505925, batch error rate 18.000000%
# At minibatch 143600, batch loss 0.796072, batch nll 0.392719, batch error rate 13.000000%
# After epoch 359: valid_err_rate: 25.540000% currently going to do 376 epochs
# After epoch 359: averaged train_err_rate: 16.502500% averaged train nll: 0.495560 averaged train loss: 0.898893
# At minibatch 143700, batch loss 0.876054, batch nll 0.472690, batch error rate 15.000000%
# At minibatch 143800, batch loss 0.885406, batch nll 0.482038, batch error rate 12.000000%
# At minibatch 143900, batch loss 0.980860, batch nll 0.577419, batch error rate 18.000000%
# At minibatch 144000, batch loss 0.847179, batch nll 0.443754, batch error rate 13.000000%
# After epoch 360: valid_err_rate: 25.410000% currently going to do 376 epochs
# After epoch 360: averaged train_err_rate: 16.442500% averaged train nll: 0.494964 averaged train loss: 0.898356
# At minibatch 144100, batch loss 0.868057, batch nll 0.464613, batch error rate 18.000000%
# At minibatch 144200, batch loss 0.859521, batch nll 0.456022, batch error rate 20.000000%
# At minibatch 144300, batch loss 0.865551, batch nll 0.462065, batch error rate 13.000000%
# At minibatch 144400, batch loss 0.985901, batch nll 0.582428, batch error rate 21.000000%
# After epoch 361: valid_err_rate: 25.440000% currently going to do 376 epochs
# After epoch 361: averaged train_err_rate: 16.655000% averaged train nll: 0.495484 averaged train loss: 0.898959
# At minibatch 144500, batch loss 0.933511, batch nll 0.529976, batch error rate 19.000000%
# At minibatch 144600, batch loss 1.085397, batch nll 0.681825, batch error rate 23.000000%
# At minibatch 144700, batch loss 0.895545, batch nll 0.492015, batch error rate 19.000000%
# At minibatch 144800, batch loss 0.908856, batch nll 0.505335, batch error rate 18.000000%
# After epoch 362: valid_err_rate: 25.400000% currently going to do 376 epochs
# After epoch 362: averaged train_err_rate: 16.525000% averaged train nll: 0.494916 averaged train loss: 0.898443
# At minibatch 144900, batch loss 0.865654, batch nll 0.462080, batch error rate 17.000000%
# At minibatch 145000, batch loss 0.880922, batch nll 0.477306, batch error rate 14.000000%
# At minibatch 145100, batch loss 0.914824, batch nll 0.511227, batch error rate 19.000000%
# At minibatch 145200, batch loss 0.819313, batch nll 0.415657, batch error rate 15.000000%
# After epoch 363: valid_err_rate: 25.860000% currently going to do 376 epochs
# After epoch 363: averaged train_err_rate: 16.605000% averaged train nll: 0.496134 averaged train loss: 0.899724
# At minibatch 145300, batch loss 0.796134, batch nll 0.392521, batch error rate 14.000000%
# At minibatch 145400, batch loss 0.856773, batch nll 0.453067, batch error rate 14.000000%
# At minibatch 145500, batch loss 1.101999, batch nll 0.698282, batch error rate 21.000000%
# At minibatch 145600, batch loss 0.761850, batch nll 0.358174, batch error rate 7.000000%
# After epoch 364: valid_err_rate: 25.490000% currently going to do 376 epochs
# After epoch 364: averaged train_err_rate: 16.512500% averaged train nll: 0.494694 averaged train loss: 0.898363
# At minibatch 145700, batch loss 0.924701, batch nll 0.520968, batch error rate 20.000000%
# At minibatch 145800, batch loss 0.955660, batch nll 0.551847, batch error rate 18.000000%
# At minibatch 145900, batch loss 0.839930, batch nll 0.436148, batch error rate 14.000000%
# At minibatch 146000, batch loss 0.866293, batch nll 0.462574, batch error rate 15.000000%
# After epoch 365: valid_err_rate: 25.380000% currently going to do 376 epochs
# After epoch 365: averaged train_err_rate: 16.530000% averaged train nll: 0.494119 averaged train loss: 0.897867
# At minibatch 146100, batch loss 0.808943, batch nll 0.405138, batch error rate 12.000000%
# At minibatch 146200, batch loss 0.832728, batch nll 0.428911, batch error rate 14.000000%
# At minibatch 146300, batch loss 0.837870, batch nll 0.434066, batch error rate 17.000000%
# At minibatch 146400, batch loss 1.021830, batch nll 0.618064, batch error rate 20.000000%
# After epoch 366: valid_err_rate: 25.220000% currently going to do 376 epochs
# After epoch 366: averaged train_err_rate: 16.482500% averaged train nll: 0.495273 averaged train loss: 0.899071
# At minibatch 146500, batch loss 0.783335, batch nll 0.379476, batch error rate 14.000000%
# At minibatch 146600, batch loss 0.917825, batch nll 0.513945, batch error rate 17.000000%
# At minibatch 146700, batch loss 0.803219, batch nll 0.399405, batch error rate 15.000000%
# At minibatch 146800, batch loss 0.957054, batch nll 0.553230, batch error rate 22.000000%
# After epoch 367: valid_err_rate: 25.710000% currently going to do 376 epochs
# After epoch 367: averaged train_err_rate: 16.522500% averaged train nll: 0.494836 averaged train loss: 0.898668
# At minibatch 146900, batch loss 0.830765, batch nll 0.426959, batch error rate 16.000000%
# At minibatch 147000, batch loss 1.015357, batch nll 0.611476, batch error rate 22.000000%
# At minibatch 147100, batch loss 0.922556, batch nll 0.518684, batch error rate 14.000000%
# At minibatch 147200, batch loss 0.847133, batch nll 0.443286, batch error rate 14.000000%
# After epoch 368: valid_err_rate: 25.370000% currently going to do 376 epochs
# After epoch 368: averaged train_err_rate: 16.482500% averaged train nll: 0.495451 averaged train loss: 0.899292
# At minibatch 147300, batch loss 0.798620, batch nll 0.394757, batch error rate 12.000000%
# At minibatch 147400, batch loss 0.888900, batch nll 0.485010, batch error rate 17.000000%
# At minibatch 147500, batch loss 0.837927, batch nll 0.434015, batch error rate 15.000000%
# At minibatch 147600, batch loss 0.926451, batch nll 0.522523, batch error rate 17.000000%
# After epoch 369: valid_err_rate: 26.310000% currently going to do 376 epochs
# After epoch 369: averaged train_err_rate: 16.497500% averaged train nll: 0.495072 averaged train loss: 0.898960
# At minibatch 147700, batch loss 0.957886, batch nll 0.553982, batch error rate 17.000000%
# At minibatch 147800, batch loss 0.952889, batch nll 0.548912, batch error rate 17.000000%
# At minibatch 147900, batch loss 0.884413, batch nll 0.480415, batch error rate 16.000000%
# At minibatch 148000, batch loss 0.817617, batch nll 0.413616, batch error rate 13.000000%
# After epoch 370: valid_err_rate: 25.430000% currently going to do 376 epochs
# After epoch 370: averaged train_err_rate: 16.492500% averaged train nll: 0.493874 averaged train loss: 0.897833
# At minibatch 148100, batch loss 0.770917, batch nll 0.366955, batch error rate 9.000000%
# At minibatch 148200, batch loss 0.953606, batch nll 0.549629, batch error rate 19.000000%
# At minibatch 148300, batch loss 0.967597, batch nll 0.563605, batch error rate 19.000000%
# At minibatch 148400, batch loss 0.901339, batch nll 0.497265, batch error rate 17.000000%
# After epoch 371: valid_err_rate: 25.180000% currently going to do 376 epochs
# After epoch 371: averaged train_err_rate: 16.375000% averaged train nll: 0.493278 averaged train loss: 0.897279
# At minibatch 148500, batch loss 0.771904, batch nll 0.367784, batch error rate 12.000000%
# At minibatch 148600, batch loss 0.836407, batch nll 0.432298, batch error rate 15.000000%
# At minibatch 148700, batch loss 0.855505, batch nll 0.451381, batch error rate 12.000000%
# At minibatch 148800, batch loss 0.870369, batch nll 0.466257, batch error rate 18.000000%
# After epoch 372: valid_err_rate: 25.850000% currently going to do 376 epochs
# After epoch 372: averaged train_err_rate: 16.600000% averaged train nll: 0.494437 averaged train loss: 0.898552
# At minibatch 148900, batch loss 0.943753, batch nll 0.539601, batch error rate 21.000000%
# At minibatch 149000, batch loss 0.990535, batch nll 0.586351, batch error rate 19.000000%
# At minibatch 149100, batch loss 0.928432, batch nll 0.524262, batch error rate 19.000000%
# At minibatch 149200, batch loss 0.925762, batch nll 0.521613, batch error rate 19.000000%
# After epoch 373: valid_err_rate: 25.370000% currently going to do 376 epochs
# After epoch 373: averaged train_err_rate: 16.432500% averaged train nll: 0.494284 averaged train loss: 0.898441
# At minibatch 149300, batch loss 0.886524, batch nll 0.482339, batch error rate 14.000000%
# At minibatch 149400, batch loss 0.822805, batch nll 0.418637, batch error rate 13.000000%
# At minibatch 149500, batch loss 0.830636, batch nll 0.426507, batch error rate 9.000000%
# At minibatch 149600, batch loss 0.809235, batch nll 0.405036, batch error rate 15.000000%
# After epoch 374: valid_err_rate: 25.750000% currently going to do 376 epochs
# After epoch 374: averaged train_err_rate: 16.537500% averaged train nll: 0.494003 averaged train loss: 0.898165
# At minibatch 149700, batch loss 0.849502, batch nll 0.445274, batch error rate 14.000000%
# At minibatch 149800, batch loss 0.975809, batch nll 0.571563, batch error rate 19.000000%
# At minibatch 149900, batch loss 0.808835, batch nll 0.404551, batch error rate 14.000000%
# At minibatch 150000, batch loss 0.792008, batch nll 0.387708, batch error rate 13.000000%
# After epoch 375: valid_err_rate: 25.310000% currently going to do 376 epochs
# After epoch 375: averaged train_err_rate: 16.357500% averaged train nll: 0.492168 averaged train loss: 0.896421
# At minibatch 150100, batch loss 0.845144, batch nll 0.440788, batch error rate 13.000000%
# At minibatch 150200, batch loss 0.911305, batch nll 0.506980, batch error rate 17.000000%
# At minibatch 150300, batch loss 0.964472, batch nll 0.560116, batch error rate 18.000000%
# At minibatch 150400, batch loss 0.903912, batch nll 0.499577, batch error rate 17.000000%
# After epoch 376: valid_err_rate: 25.530000% currently going to do 376 epochs
# After epoch 376: averaged train_err_rate: 16.427500% averaged train nll: 0.492739 averaged train loss: 0.897068

# %%
print "Setting network parameters from after epoch %d" %(best_params_epoch)
load_parameters(best_params)

print "Success rate is %f%%" %(100.0-compute_error_rate(cifar10_testt_stream)*100.0,)
print "Error rate is %f%%" %(compute_error_rate(cifar10_testt_stream)*100.0,)

figure(figsize=(16,14))

subplot(2,1,1)
train_nll_a = np.array(train_nll)
semilogy(train_nll_a[:,0], train_nll_a[:,1], label='batch train nll')
legend()

subplot(2,1,2)
train_erros_a = np.array(train_erros)
plot(train_erros_a[:,0], train_erros_a[:,1], label='batch train error rate')
validation_errors_a = np.array(validation_errors)
plot(validation_errors_a[:,0], validation_errors_a[:,1], label='validation error rate', color='r')
ylim(0,0.8)
legend()
# Out:
# Setting network parameters from after epoch 250
# Success rate is 73.790000%
# Error rate is 26.210000%

# %%
middle_layers_computer = theano.function([X], network.model_layers)

img_num=11

middle_layers = middle_layers_computer(X_test_value[img_num:img_num+1])
print middle_layers[0].shape
print middle_layers[1].shape
print middle_layers[2].shape
print middle_layers[3].shape
print middle_layers[4].shape


plot_mat(middle_layers[0])
title(network.model_names[0])
show()

for ml, name in zip(middle_layers[1:], network.model_names[1:]):
    try:
        #print ml#.transpose(1,0,2,3).shape
        plot_mat(ml.transpose(1,0,2,3), cmap='gray')
        title(name)
        show()
    except ValueError:
        pass
# Out:
# (1, 3, 32, 32)
# (1, 10, 28, 28)
# (1, 10, 14, 14)
# (1, 25, 10, 10)
# (1, 25, 5, 5)
