# %%
# %pylab inline

from scipy.ndimage.filters import convolve

import theano
import theano.tensor.signal.downsample
import skimage.io
print theano.config.floatX

from common.plotting import plot_mat

from fuel.datasets.cifar10 import CIFAR10
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme
# Out:
# Populating the interactive namespace from numpy and matplotlib
# float32
# Using gpu device 0: GeForce GTX 780 (CNMeM is enabled)

# %%
CIFAR10.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'})
)

cifar10_train = CIFAR10(("train",), subset=slice(None,40000))
cifar10_valid = CIFAR10(("train",), subset=slice(40000, None))
cifar10_testt  = CIFAR10(("test",))

minibatch_train = 100
minibatch_valid = 100
minibatch_testt = 100

cifar10_train_stream = DataStream.default_stream(
    cifar10_train,
    iteration_scheme=ShuffledScheme(cifar10_train.num_examples, minibatch_train)
)
cifar10_valid_stream = DataStream.default_stream(
    cifar10_valid, 
    iteration_scheme=SequentialScheme(cifar10_valid.num_examples, minibatch_valid)
)
cifar10_testt_stream = DataStream.default_stream(
    cifar10_testt, 
    iteration_scheme=SequentialScheme(cifar10_testt.num_examples, minibatch_testt)
)

print "Each trainin batch consits of a tuple containing:"
for element in next(cifar10_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(cifar10_testt_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    

plot_mat(cifar10_train.data_sources[0][:20], cmap='gray')

asd = 0
for x in cifar10_train_stream.get_epoch_iterator():
    asd += 1
print asd
# Out:
# Each trainin batch consits of a tuple containing:
#  - an array of size (100, 3, 32, 32) containing float32
#  - an array of size (100, 1) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (100, 3, 32, 32) containing float32
#  - an array of size (100, 1) containing uint8
# 400

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
def print_warn(s, X):
    print "after_%s shape: %s" % (s, X.tag.test_value.shape,)

class Layer_Conv():
    def __init__(self, in_chan, out_chan, size):
        self.in_chan = in_chan
        self.out_chan = out_chan
        self.size = size
    def make(self, X, n):
        CWn = theano.shared(np.zeros((self.out_chan, self.in_chan, self.size, self.size), dtype='float32'), name=('CW%d'%n))
        CBn = theano.shared(np.zeros((self.out_chan,), dtype='float32'), name=('CB%d'%n))
        
        CWn.tag.initializer = IsotropicGaussian(0.05)
        CBn.tag.initializer = Constant(0.0)
        
        after_Cn = theano.tensor.maximum(
            0.0,
            theano.tensor.nnet.conv2d(X, CWn) + CBn.dimshuffle('x',0,'x','x')
        )
        print_warn(("C%d"%n), after_Cn)
        
        return after_Cn, [CWn, CBn], [("C%d"%n)]
    
class Layer_Pool():
    def __init__(self, size):
        self.size = size        
    def make(self, X, n):
        after_Pn = theano.tensor.signal.downsample.max_pool_2d(X, (self.size, self.size), ignore_border=True)
        print_warn(("P%d"%n), after_Pn)
        
        return after_Pn, [], [("P%d"%n)]
    
class Layer_Filt():
    def __init__(self, in_chan, out_chan):
        self.in_chan = in_chan
        self.out_chan = out_chan
    def make(self, X, n):
        num_fw4_hidden=10
        FWn = theano.shared(np.zeros((self.in_chan, self.out_chan), dtype='float32'), name=('FW%d'%n))
        FBn = theano.shared(np.zeros((self.out_chan,), dtype='float32'), name=('FB%d'%n))
        
        FWn.tag.initializer = IsotropicGaussian(0.05)
        FBn.tag.initializer = Constant(0.0)

        after_Fn = theano.tensor.dot(X.flatten(2), FWn) + FBn.dimshuffle('x',0)
        print_warn(("F%d"%n), after_Fn)
        
        return after_Fn, [FWn, FBn], [("F%d"%n)]
    
class Layer_Soft():
    def __init__(self):
        pass
    def make(self, X, n):
        after_Sn = theano.tensor.nnet.softmax(X)
        print_warn(("S%d"%n), after_Sn)
        
        return after_Sn, [], [("S%d"%n)]

# %%
class NetworkBuilder():
    def __init__(self, layerlist):
        self.layers = layerlist
    def make(self, X):
        model_parameters = []
        self.model_names = ["X"]
        self.model_layers = [X] 
        i = 1
        after = X
        for layer in self.layers:
            after, param, name = layer.make(after, i)
            self.model_layers += [after]
            model_parameters += param
            self.model_names += name
            i += 1
            
        return after, model_parameters

# %%
theano.config.compute_test_value = 'warn'
X_test_value, Y_test_value = next(cifar10_train_stream.get_epoch_iterator())

X = theano.tensor.tensor4('X')
Y = theano.tensor.matrix('Y', dtype='uint8')
X.tag.test_value = X_test_value[:3]
Y.tag.test_value = Y_test_value[:3]
print "X shape: %s" % (X.tag.test_value.shape,)

network = NetworkBuilder([
        Layer_Conv(3, 16, 3),
        Layer_Pool(2),
        Layer_Conv(16, 25, 4),
        Layer_Pool(2),
        Layer_Conv(25, 32, 3),
        Layer_Filt(32*4*4, 1000),
        Layer_Filt(1000, 300),
        Layer_Filt(300, 10),
        Layer_Soft()
    ])

output, parameters = network.make(X)

predictions = theano.tensor.argmax(output, axis=1)

error_rate = theano.tensor.neq(predictions,Y.ravel()).mean()

nll = - theano.tensor.log(output[theano.tensor.arange(Y.shape[0]), Y.ravel()]).mean()

alpha = 3e-3
weight_decay = 0.0
for p in parameters:
    if p.name[1]=='W':
        weight_decay = weight_decay + alpha * (p**2).sum()

cost = nll + weight_decay

theano.config.compute_test_value = 'off'
# Out:
# X shape: (3, 3, 32, 32)
# after_C1 shape: (3, 16, 30, 30)
# after_P2 shape: (3, 16, 15, 15)
# after_C3 shape: (3, 25, 12, 12)
# after_P4 shape: (3, 25, 6, 6)
# after_C5 shape: (3, 32, 4, 4)
# after_F6 shape: (3, 1000)
# after_F7 shape: (3, 300)
# after_F8 shape: (3, 10)
# after_S9 shape: (3, 10)

# %%
updates = []

lrate = theano.tensor.scalar('lrate',dtype='float32')
momentum = theano.tensor.scalar('momentum',dtype='float32')
gradients = theano.grad(cost, parameters)
velocities = [theano.shared(np.zeros_like(p.get_value()), name='V_%s' %(p.name, )) for p in parameters]

for p,g,v in zip(parameters, gradients, velocities):
    v_new = momentum * v - lrate * g
    p_new = p + v_new
    updates += [(v,v_new), (p, p_new)]

# %%
train_step = theano.function(
    [X, Y, lrate, momentum],
    [cost, error_rate, nll, weight_decay],
    updates=updates
)

predict = theano.function(
    [X], 
    predictions
)

# %%
def compute_error_rate(stream):
    errs = 0.0
    num_samples = 0.0
    for X, Y in stream.get_epoch_iterator():
        errs += (predict(X)!=Y.ravel()).sum()
        num_samples += Y.shape[0]
    return errs/num_samples

def init_parameters():
    rng = np.random.RandomState(1234)
    for p in parameters:
        p.set_value(p.tag.initializer.generate(rng, p.get_value().shape))

def snapshot_parameters():
    return [p.get_value(borrow=False) for p in parameters]

def load_parameters(snapshot):
    for p, s in zip(parameters, snapshot):
        p.set_value(s, borrow=False)

# %%
i=0
e=0

init_parameters()
for v in velocities:
    v.set_value(np.zeros_like(v.get_value()))

best_valid_error_rate = np.inf
best_params = snapshot_parameters()
best_params_epoch = 0

train_erros = []
train_loss = []
train_nll = []
validation_errors = []

number_of_epochs = 3
patience_expansion = 1.5

while e<number_of_epochs:
    e += 1
    epoch_start_i = i
    
    for X_batch, Y_batch in cifar10_train_stream.get_epoch_iterator(): 
        i += 1
        
        K = 4000
        lrate = 5e-3 * K / np.maximum(K, i)
        momentum=0.9
        
        L, err_rate, nll, wdec = train_step(X_batch, Y_batch, lrate, momentum)
        
        train_loss.append((i,L))
        train_erros.append((i,err_rate))
        train_nll.append((i,nll))
        
        if i % 100 == 0:
            print "At minibatch %d, batch loss %f, batch nll %f, batch error rate %f%%" % (i, L, nll, err_rate*100)
        
    
    val_error_rate = compute_error_rate(cifar10_valid_stream)
    if val_error_rate < best_valid_error_rate:
        number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
        best_valid_error_rate = val_error_rate
        best_params = snapshot_parameters()
        best_params_epoch = e
        
    validation_errors.append((i,val_error_rate))
    print "After epoch %d: valid_err_rate: %f%% currently going to do %d epochs" %(
        e, val_error_rate*100, number_of_epochs)
    
    print "After epoch %d: averaged train_err_rate: %f%% averaged train nll: %f averaged train loss: %f" %(
        e, 
        np.mean(np.asarray(train_erros)[epoch_start_i:,1])*100, 
        np.mean(np.asarray(train_nll)[epoch_start_i:,1]),
        np.mean(np.asarray(train_loss)[epoch_start_i:,1])
    )
# Out:
# At minibatch 100, batch loss 7.923643, batch nll 2.016683, batch error rate 75.000000%
# At minibatch 200, batch loss 7.392081, batch nll 1.820128, batch error rate 64.000000%
# At minibatch 300, batch loss 6.919276, batch nll 1.660894, batch error rate 61.000000%
# At minibatch 400, batch loss 6.427878, batch nll 1.466739, batch error rate 53.000000%
# After epoch 1: valid_err_rate: 55.740000% currently going to do 3 epochs
# After epoch 1: averaged train_err_rate: 66.710000% averaged train nll: 1.820435 averaged train loss: 7.403751
# At minibatch 500, batch loss 6.265445, batch nll 1.583621, batch error rate 56.000000%
# At minibatch 600, batch loss 5.894906, batch nll 1.477359, batch error rate 54.000000%
# At minibatch 700, batch loss 5.582300, batch nll 1.413286, batch error rate 49.000000%
# At minibatch 800, batch loss 5.416505, batch nll 1.481704, batch error rate 54.000000%
# After epoch 2: valid_err_rate: 49.520000% currently going to do 4 epochs
# After epoch 2: averaged train_err_rate: 51.810000% averaged train nll: 1.435376 averaged train loss: 5.861853
# At minibatch 900, batch loss 5.103746, batch nll 1.388643, batch error rate 46.000000%
# At minibatch 1000, batch loss 4.948655, batch nll 1.440124, batch error rate 45.000000%
# At minibatch 1100, batch loss 4.702124, batch nll 1.388136, batch error rate 52.000000%
# At minibatch 1200, batch loss 4.555612, batch nll 1.424612, batch error rate 54.000000%
# After epoch 3: valid_err_rate: 49.090000% currently going to do 5 epochs
# After epoch 3: averaged train_err_rate: 47.812500% averaged train nll: 1.329189 averaged train loss: 4.844858
# At minibatch 1300, batch loss 4.230900, batch nll 1.270184, batch error rate 45.000000%
# At minibatch 1400, batch loss 3.967503, batch nll 1.167663, batch error rate 40.000000%
# At minibatch 1500, batch loss 3.782487, batch nll 1.134601, batch error rate 35.000000%
# At minibatch 1600, batch loss 3.745418, batch nll 1.240551, batch error rate 41.000000%
# After epoch 4: valid_err_rate: 43.030000% currently going to do 7 epochs
# After epoch 4: averaged train_err_rate: 44.747500% averaged train nll: 1.254471 averaged train loss: 4.059297
# At minibatch 1700, batch loss 3.489649, batch nll 1.118262, batch error rate 44.000000%
# At minibatch 1800, batch loss 3.377414, batch nll 1.130864, batch error rate 39.000000%
# At minibatch 1900, batch loss 3.308542, batch nll 1.180104, batch error rate 41.000000%
# At minibatch 2000, batch loss 3.160986, batch nll 1.145382, batch error rate 46.000000%
# After epoch 5: valid_err_rate: 41.470000% currently going to do 8 epochs
# After epoch 5: averaged train_err_rate: 42.482500% averaged train nll: 1.191434 averaged train loss: 3.441643
# At minibatch 2100, batch loss 3.106253, batch nll 1.193548, batch error rate 41.000000%
# At minibatch 2200, batch loss 2.870721, batch nll 1.057553, batch error rate 37.000000%
# At minibatch 2300, batch loss 2.843008, batch nll 1.121465, batch error rate 45.000000%
# At minibatch 2400, batch loss 2.511924, batch nll 0.875765, batch error rate 29.000000%
# After epoch 6: valid_err_rate: 39.970000% currently going to do 10 epochs
# After epoch 6: averaged train_err_rate: 41.105000% averaged train nll: 1.155494 averaged train loss: 2.972863
# At minibatch 2500, batch loss 2.865665, batch nll 1.311122, batch error rate 48.000000%
# At minibatch 2600, batch loss 2.608343, batch nll 1.131212, batch error rate 43.000000%
# At minibatch 2700, batch loss 2.556107, batch nll 1.150278, batch error rate 45.000000%
# At minibatch 2800, batch loss 2.606644, batch nll 1.268860, batch error rate 49.000000%
# After epoch 7: valid_err_rate: 39.400000% currently going to do 11 epochs
# After epoch 7: averaged train_err_rate: 39.072500% averaged train nll: 1.100999 averaged train loss: 2.581442
# At minibatch 2900, batch loss 2.267406, batch nll 0.993013, batch error rate 38.000000%
# At minibatch 3000, batch loss 2.323821, batch nll 1.107269, batch error rate 45.000000%
# At minibatch 3100, batch loss 1.985574, batch nll 0.826185, batch error rate 23.000000%
# At minibatch 3200, batch loss 2.159960, batch nll 1.053639, batch error rate 33.000000%
# After epoch 8: valid_err_rate: 37.470000% currently going to do 13 epochs
# After epoch 8: averaged train_err_rate: 37.840000% averaged train nll: 1.068785 averaged train loss: 2.286449
# At minibatch 3300, batch loss 2.167583, batch nll 1.110318, batch error rate 41.000000%
# At minibatch 3400, batch loss 2.278550, batch nll 1.267958, batch error rate 43.000000%
# At minibatch 3500, batch loss 1.903736, batch nll 0.936190, batch error rate 35.000000%
# At minibatch 3600, batch loss 2.064990, batch nll 1.139534, batch error rate 39.000000%
# After epoch 9: valid_err_rate: 36.940000% currently going to do 14 epochs
# After epoch 9: averaged train_err_rate: 36.730000% averaged train nll: 1.041740 averaged train loss: 2.053956
# At minibatch 3700, batch loss 2.054146, batch nll 1.166700, batch error rate 40.000000%
# At minibatch 3800, batch loss 1.897697, batch nll 1.046410, batch error rate 34.000000%
# At minibatch 3900, batch loss 1.906772, batch nll 1.090573, batch error rate 34.000000%
# At minibatch 4000, batch loss 1.704648, batch nll 0.920781, batch error rate 30.000000%
# After epoch 10: valid_err_rate: 36.320000% currently going to do 16 epochs
# After epoch 10: averaged train_err_rate: 35.282500% averaged train nll: 1.008743 averaged train loss: 1.860794
# At minibatch 4100, batch loss 1.546937, batch nll 0.793442, batch error rate 26.000000%
# At minibatch 4200, batch loss 1.732272, batch nll 1.004676, batch error rate 42.000000%
# At minibatch 4300, batch loss 1.584940, batch nll 0.882065, batch error rate 34.000000%
# At minibatch 4400, batch loss 1.537874, batch nll 0.859611, batch error rate 31.000000%
# After epoch 11: valid_err_rate: 34.040000% currently going to do 17 epochs
# After epoch 11: averaged train_err_rate: 34.687500% averaged train nll: 0.985150 averaged train loss: 1.713829
# At minibatch 4500, batch loss 1.681062, batch nll 1.023690, batch error rate 37.000000%
# At minibatch 4600, batch loss 1.613136, batch nll 0.975336, batch error rate 30.000000%
# At minibatch 4700, batch loss 1.458900, batch nll 0.839463, batch error rate 28.000000%
# At minibatch 4800, batch loss 1.566830, batch nll 0.964441, batch error rate 38.000000%
# After epoch 12: valid_err_rate: 34.790000% currently going to do 17 epochs
# After epoch 12: averaged train_err_rate: 33.447500% averaged train nll: 0.953840 averaged train loss: 1.592279
# At minibatch 4900, batch loss 1.490145, batch nll 0.903231, batch error rate 31.000000%
# At minibatch 5000, batch loss 1.532445, batch nll 0.958349, batch error rate 33.000000%
# At minibatch 5100, batch loss 1.520049, batch nll 0.961030, batch error rate 32.000000%
# At minibatch 5200, batch loss 1.510529, batch nll 0.964726, batch error rate 31.000000%
# After epoch 13: valid_err_rate: 35.420000% currently going to do 17 epochs
# After epoch 13: averaged train_err_rate: 33.145000% averaged train nll: 0.946360 averaged train loss: 1.519702
# At minibatch 5300, batch loss 1.551938, batch nll 1.016362, batch error rate 39.000000%
# At minibatch 5400, batch loss 1.268441, batch nll 0.744068, batch error rate 25.000000%
# At minibatch 5500, batch loss 1.416637, batch nll 0.903377, batch error rate 33.000000%
# At minibatch 5600, batch loss 1.302238, batch nll 0.798952, batch error rate 28.000000%
# After epoch 14: valid_err_rate: 33.820000% currently going to do 22 epochs
# After epoch 14: averaged train_err_rate: 31.970000% averaged train nll: 0.920355 averaged train loss: 1.444654
# At minibatch 5700, batch loss 1.398346, batch nll 0.903043, batch error rate 33.000000%
# At minibatch 5800, batch loss 1.218998, batch nll 0.732315, batch error rate 27.000000%
# At minibatch 5900, batch loss 1.436284, batch nll 0.958171, batch error rate 30.000000%
# At minibatch 6000, batch loss 1.336933, batch nll 0.867015, batch error rate 33.000000%
# After epoch 15: valid_err_rate: 32.550000% currently going to do 23 epochs
# After epoch 15: averaged train_err_rate: 31.415000% averaged train nll: 0.897775 averaged train loss: 1.384293
# At minibatch 6100, batch loss 1.441000, batch nll 0.977971, batch error rate 36.000000%
# At minibatch 6200, batch loss 1.401603, batch nll 0.945157, batch error rate 33.000000%
# At minibatch 6300, batch loss 1.301709, batch nll 0.851779, batch error rate 27.000000%
# At minibatch 6400, batch loss 1.394067, batch nll 0.949375, batch error rate 35.000000%
# After epoch 16: valid_err_rate: 33.420000% currently going to do 23 epochs
# After epoch 16: averaged train_err_rate: 30.390000% averaged train nll: 0.880402 averaged train loss: 1.337149
# At minibatch 6500, batch loss 1.248029, batch nll 0.808253, batch error rate 26.000000%
# At minibatch 6600, batch loss 1.153925, batch nll 0.720149, batch error rate 22.000000%
# At minibatch 6700, batch loss 1.320487, batch nll 0.891508, batch error rate 35.000000%
# At minibatch 6800, batch loss 1.330317, batch nll 0.905731, batch error rate 33.000000%
# After epoch 17: valid_err_rate: 33.980000% currently going to do 23 epochs
# After epoch 17: averaged train_err_rate: 30.675000% averaged train nll: 0.875423 averaged train loss: 1.309610
# At minibatch 6900, batch loss 1.227395, batch nll 0.807084, batch error rate 27.000000%
# At minibatch 7000, batch loss 1.328208, batch nll 0.912296, batch error rate 30.000000%
# At minibatch 7100, batch loss 1.154776, batch nll 0.743080, batch error rate 20.000000%
# At minibatch 7200, batch loss 1.291155, batch nll 0.884032, batch error rate 30.000000%
# After epoch 18: valid_err_rate: 31.290000% currently going to do 28 epochs
# After epoch 18: averaged train_err_rate: 29.857500% averaged train nll: 0.855735 averaged train loss: 1.271824
# At minibatch 7300, batch loss 1.426164, batch nll 1.022402, batch error rate 39.000000%
# At minibatch 7400, batch loss 1.270913, batch nll 0.870881, batch error rate 30.000000%
# At minibatch 7500, batch loss 1.132187, batch nll 0.734435, batch error rate 27.000000%
# At minibatch 7600, batch loss 1.196905, batch nll 0.802728, batch error rate 30.000000%
# After epoch 19: valid_err_rate: 30.110000% currently going to do 29 epochs
# After epoch 19: averaged train_err_rate: 29.200000% averaged train nll: 0.846593 averaged train loss: 1.247167
# At minibatch 7700, batch loss 1.245381, batch nll 0.853827, batch error rate 32.000000%
# At minibatch 7800, batch loss 1.392013, batch nll 1.003373, batch error rate 35.000000%
# At minibatch 7900, batch loss 1.279469, batch nll 0.893709, batch error rate 33.000000%
# At minibatch 8000, batch loss 1.260977, batch nll 0.877976, batch error rate 32.000000%
# After epoch 20: valid_err_rate: 31.690000% currently going to do 29 epochs
# After epoch 20: averaged train_err_rate: 29.140000% averaged train nll: 0.841653 averaged train loss: 1.230341
# At minibatch 8100, batch loss 1.197212, batch nll 0.816327, batch error rate 32.000000%
# At minibatch 8200, batch loss 1.203135, batch nll 0.824480, batch error rate 31.000000%
# At minibatch 8300, batch loss 1.258176, batch nll 0.881924, batch error rate 31.000000%
# At minibatch 8400, batch loss 1.159977, batch nll 0.785641, batch error rate 24.000000%
# After epoch 21: valid_err_rate: 30.200000% currently going to do 29 epochs
# After epoch 21: averaged train_err_rate: 28.572500% averaged train nll: 0.825450 averaged train loss: 1.204141
# At minibatch 8500, batch loss 1.111783, batch nll 0.738701, batch error rate 25.000000%
# At minibatch 8600, batch loss 1.238766, batch nll 0.867286, batch error rate 29.000000%
# At minibatch 8700, batch loss 1.086586, batch nll 0.717816, batch error rate 26.000000%
# At minibatch 8800, batch loss 1.154671, batch nll 0.788296, batch error rate 24.000000%
# After epoch 22: valid_err_rate: 30.240000% currently going to do 29 epochs
# After epoch 22: averaged train_err_rate: 28.267500% averaged train nll: 0.820070 averaged train loss: 1.190932
# At minibatch 8900, batch loss 1.097383, batch nll 0.732319, batch error rate 22.000000%
# At minibatch 9000, batch loss 1.317299, batch nll 0.953533, batch error rate 36.000000%
# At minibatch 9100, batch loss 0.996680, batch nll 0.634325, batch error rate 19.000000%
# At minibatch 9200, batch loss 1.211704, batch nll 0.851065, batch error rate 32.000000%
# After epoch 23: valid_err_rate: 31.060000% currently going to do 29 epochs
# After epoch 23: averaged train_err_rate: 27.852500% averaged train nll: 0.811291 averaged train loss: 1.174979
# At minibatch 9300, batch loss 1.056563, batch nll 0.696824, batch error rate 31.000000%
# At minibatch 9400, batch loss 1.215469, batch nll 0.856996, batch error rate 29.000000%
# At minibatch 9500, batch loss 1.154678, batch nll 0.797157, batch error rate 25.000000%
# At minibatch 9600, batch loss 1.190173, batch nll 0.834682, batch error rate 32.000000%
# After epoch 24: valid_err_rate: 30.110000% currently going to do 29 epochs
# After epoch 24: averaged train_err_rate: 28.017500% averaged train nll: 0.806867 averaged train loss: 1.165333
# At minibatch 9700, batch loss 1.071351, batch nll 0.717131, batch error rate 25.000000%
# At minibatch 9800, batch loss 1.154434, batch nll 0.800946, batch error rate 28.000000%
# At minibatch 9900, batch loss 1.348289, batch nll 0.995609, batch error rate 35.000000%
# At minibatch 10000, batch loss 1.170378, batch nll 0.818975, batch error rate 28.000000%
# After epoch 25: valid_err_rate: 29.900000% currently going to do 38 epochs
# After epoch 25: averaged train_err_rate: 27.507500% averaged train nll: 0.795250 averaged train loss: 1.148791
# At minibatch 10100, batch loss 1.168650, batch nll 0.817375, batch error rate 30.000000%
# At minibatch 10200, batch loss 1.076563, batch nll 0.726969, batch error rate 25.000000%
# At minibatch 10300, batch loss 1.177807, batch nll 0.829443, batch error rate 28.000000%
# At minibatch 10400, batch loss 1.326876, batch nll 0.979317, batch error rate 34.000000%
# After epoch 26: valid_err_rate: 30.040000% currently going to do 38 epochs
# After epoch 26: averaged train_err_rate: 27.120000% averaged train nll: 0.787268 averaged train loss: 1.137022
# At minibatch 10500, batch loss 0.949652, batch nll 0.602558, batch error rate 20.000000%
# At minibatch 10600, batch loss 1.228569, batch nll 0.882186, batch error rate 34.000000%
# At minibatch 10700, batch loss 0.938373, batch nll 0.592618, batch error rate 20.000000%
# At minibatch 10800, batch loss 1.151054, batch nll 0.806956, batch error rate 29.000000%
# After epoch 27: valid_err_rate: 31.030000% currently going to do 38 epochs
# After epoch 27: averaged train_err_rate: 26.860000% averaged train nll: 0.780671 averaged train loss: 1.126952
# At minibatch 10900, batch loss 1.171009, batch nll 0.826966, batch error rate 26.000000%
# At minibatch 11000, batch loss 1.100827, batch nll 0.757353, batch error rate 29.000000%
# At minibatch 11100, batch loss 1.144063, batch nll 0.801873, batch error rate 26.000000%
# At minibatch 11200, batch loss 1.071672, batch nll 0.729841, batch error rate 24.000000%
# After epoch 28: valid_err_rate: 31.190000% currently going to do 38 epochs
# After epoch 28: averaged train_err_rate: 26.810000% averaged train nll: 0.779178 averaged train loss: 1.122329
# At minibatch 11300, batch loss 0.998023, batch nll 0.656506, batch error rate 24.000000%
# At minibatch 11400, batch loss 1.207627, batch nll 0.866435, batch error rate 32.000000%
# At minibatch 11500, batch loss 1.088862, batch nll 0.748573, batch error rate 28.000000%
# At minibatch 11600, batch loss 1.063616, batch nll 0.723639, batch error rate 30.000000%
# After epoch 29: valid_err_rate: 30.890000% currently going to do 38 epochs
# After epoch 29: averaged train_err_rate: 26.450000% averaged train nll: 0.770324 averaged train loss: 1.111372
# At minibatch 11700, batch loss 1.072698, batch nll 0.732579, batch error rate 25.000000%
# At minibatch 11800, batch loss 1.121446, batch nll 0.782032, batch error rate 24.000000%
# At minibatch 11900, batch loss 1.227708, batch nll 0.889021, batch error rate 28.000000%
# At minibatch 12000, batch loss 1.174198, batch nll 0.836201, batch error rate 31.000000%
# After epoch 30: valid_err_rate: 29.320000% currently going to do 46 epochs
# After epoch 30: averaged train_err_rate: 26.472500% averaged train nll: 0.768999 averaged train loss: 1.108290
# At minibatch 12100, batch loss 1.041558, batch nll 0.703759, batch error rate 26.000000%
# At minibatch 12200, batch loss 1.088995, batch nll 0.751155, batch error rate 28.000000%
# At minibatch 12300, batch loss 1.108911, batch nll 0.771406, batch error rate 30.000000%
# At minibatch 12400, batch loss 1.157044, batch nll 0.820223, batch error rate 28.000000%
# After epoch 31: valid_err_rate: 29.340000% currently going to do 46 epochs
# After epoch 31: averaged train_err_rate: 26.320000% averaged train nll: 0.761827 averaged train loss: 1.099528
# At minibatch 12500, batch loss 0.995747, batch nll 0.658728, batch error rate 24.000000%
# At minibatch 12600, batch loss 1.066138, batch nll 0.729610, batch error rate 24.000000%
# At minibatch 12700, batch loss 0.939711, batch nll 0.603394, batch error rate 22.000000%
# At minibatch 12800, batch loss 1.144078, batch nll 0.808820, batch error rate 28.000000%
# After epoch 32: valid_err_rate: 30.340000% currently going to do 46 epochs
# After epoch 32: averaged train_err_rate: 26.102500% averaged train nll: 0.761960 averaged train loss: 1.098354
# At minibatch 12900, batch loss 1.026821, batch nll 0.691190, batch error rate 23.000000%
# At minibatch 13000, batch loss 1.030094, batch nll 0.694371, batch error rate 24.000000%
# At minibatch 13100, batch loss 1.289728, batch nll 0.955058, batch error rate 36.000000%
# At minibatch 13200, batch loss 1.051236, batch nll 0.717136, batch error rate 21.000000%
# After epoch 33: valid_err_rate: 29.030000% currently going to do 50 epochs
# After epoch 33: averaged train_err_rate: 25.810000% averaged train nll: 0.751583 averaged train loss: 1.086781
# At minibatch 13300, batch loss 1.079621, batch nll 0.745486, batch error rate 27.000000%
# At minibatch 13400, batch loss 1.238662, batch nll 0.904948, batch error rate 29.000000%
# At minibatch 13500, batch loss 1.065682, batch nll 0.731862, batch error rate 21.000000%
# At minibatch 13600, batch loss 1.101979, batch nll 0.768472, batch error rate 26.000000%
# After epoch 34: valid_err_rate: 29.370000% currently going to do 50 epochs
# After epoch 34: averaged train_err_rate: 25.732500% averaged train nll: 0.749091 averaged train loss: 1.082998
# At minibatch 13700, batch loss 0.851519, batch nll 0.518170, batch error rate 18.000000%
# At minibatch 13800, batch loss 1.189864, batch nll 0.856592, batch error rate 33.000000%
# At minibatch 13900, batch loss 1.107534, batch nll 0.774661, batch error rate 27.000000%
# At minibatch 14000, batch loss 1.063763, batch nll 0.730857, batch error rate 23.000000%
# After epoch 35: valid_err_rate: 28.860000% currently going to do 53 epochs
# After epoch 35: averaged train_err_rate: 25.755000% averaged train nll: 0.747427 averaged train loss: 1.080602
# At minibatch 14100, batch loss 1.047910, batch nll 0.714731, batch error rate 24.000000%
# At minibatch 14200, batch loss 1.042667, batch nll 0.709669, batch error rate 25.000000%
# At minibatch 14300, batch loss 0.986190, batch nll 0.653404, batch error rate 22.000000%
# At minibatch 14400, batch loss 1.114184, batch nll 0.781637, batch error rate 25.000000%
# After epoch 36: valid_err_rate: 29.320000% currently going to do 53 epochs
# After epoch 36: averaged train_err_rate: 25.247500% averaged train nll: 0.738229 averaged train loss: 1.071140
# At minibatch 14500, batch loss 1.154194, batch nll 0.821389, batch error rate 34.000000%
# At minibatch 14600, batch loss 1.064127, batch nll 0.731475, batch error rate 22.000000%
# At minibatch 14700, batch loss 1.014138, batch nll 0.682041, batch error rate 24.000000%
# At minibatch 14800, batch loss 1.001384, batch nll 0.670032, batch error rate 22.000000%
# After epoch 37: valid_err_rate: 28.560000% currently going to do 56 epochs
# After epoch 37: averaged train_err_rate: 25.040000% averaged train nll: 0.732477 averaged train loss: 1.064839
# At minibatch 14900, batch loss 0.870709, batch nll 0.539211, batch error rate 19.000000%
# At minibatch 15000, batch loss 1.212057, batch nll 0.880542, batch error rate 31.000000%
# At minibatch 15100, batch loss 1.099931, batch nll 0.768241, batch error rate 26.000000%
# At minibatch 15200, batch loss 1.093194, batch nll 0.761775, batch error rate 29.000000%
# After epoch 38: valid_err_rate: 29.590000% currently going to do 56 epochs
# After epoch 38: averaged train_err_rate: 25.130000% averaged train nll: 0.732493 averaged train loss: 1.064027
# At minibatch 15300, batch loss 0.998257, batch nll 0.666712, batch error rate 24.000000%
# At minibatch 15400, batch loss 1.004408, batch nll 0.672656, batch error rate 22.000000%
# At minibatch 15500, batch loss 1.144917, batch nll 0.813426, batch error rate 30.000000%
# At minibatch 15600, batch loss 1.068450, batch nll 0.737432, batch error rate 24.000000%
# After epoch 39: valid_err_rate: 28.560000% currently going to do 56 epochs
# After epoch 39: averaged train_err_rate: 24.962500% averaged train nll: 0.727529 averaged train loss: 1.058984
# At minibatch 15700, batch loss 1.037209, batch nll 0.705577, batch error rate 20.000000%
# At minibatch 15800, batch loss 1.132661, batch nll 0.801317, batch error rate 28.000000%
# At minibatch 15900, batch loss 1.114800, batch nll 0.783792, batch error rate 28.000000%
# At minibatch 16000, batch loss 1.037699, batch nll 0.706808, batch error rate 23.000000%
# After epoch 40: valid_err_rate: 28.840000% currently going to do 56 epochs
# After epoch 40: averaged train_err_rate: 24.970000% averaged train nll: 0.726017 averaged train loss: 1.057266
# At minibatch 16100, batch loss 1.091938, batch nll 0.760865, batch error rate 24.000000%
# At minibatch 16200, batch loss 1.066195, batch nll 0.735045, batch error rate 24.000000%
# At minibatch 16300, batch loss 0.945036, batch nll 0.614227, batch error rate 18.000000%
# At minibatch 16400, batch loss 1.033735, batch nll 0.703157, batch error rate 25.000000%
# After epoch 41: valid_err_rate: 28.720000% currently going to do 56 epochs
# After epoch 41: averaged train_err_rate: 25.075000% averaged train nll: 0.726925 averaged train loss: 1.057861
# At minibatch 16500, batch loss 1.003740, batch nll 0.672948, batch error rate 21.000000%
# At minibatch 16600, batch loss 1.170136, batch nll 0.839371, batch error rate 30.000000%
# At minibatch 16700, batch loss 1.027676, batch nll 0.697547, batch error rate 25.000000%
# At minibatch 16800, batch loss 1.054955, batch nll 0.724263, batch error rate 24.000000%
# After epoch 42: valid_err_rate: 28.490000% currently going to do 64 epochs
# After epoch 42: averaged train_err_rate: 24.590000% averaged train nll: 0.718957 averaged train loss: 1.049613
# At minibatch 16900, batch loss 1.056778, batch nll 0.726168, batch error rate 28.000000%
# At minibatch 17000, batch loss 0.975095, batch nll 0.644165, batch error rate 25.000000%
# At minibatch 17100, batch loss 1.129376, batch nll 0.798456, batch error rate 27.000000%
# At minibatch 17200, batch loss 0.960323, batch nll 0.629826, batch error rate 20.000000%
# After epoch 43: valid_err_rate: 28.590000% currently going to do 64 epochs
# After epoch 43: averaged train_err_rate: 24.575000% averaged train nll: 0.716609 averaged train loss: 1.047354
# At minibatch 17300, batch loss 1.159928, batch nll 0.829026, batch error rate 26.000000%
# At minibatch 17400, batch loss 0.967412, batch nll 0.636708, batch error rate 21.000000%
# At minibatch 17500, batch loss 0.940609, batch nll 0.610081, batch error rate 18.000000%
# At minibatch 17600, batch loss 1.020602, batch nll 0.690033, batch error rate 26.000000%
# After epoch 44: valid_err_rate: 28.650000% currently going to do 64 epochs
# After epoch 44: averaged train_err_rate: 24.420000% averaged train nll: 0.713087 averaged train loss: 1.043799
# At minibatch 17700, batch loss 1.093221, batch nll 0.762513, batch error rate 24.000000%
# At minibatch 17800, batch loss 0.950780, batch nll 0.619833, batch error rate 21.000000%
# At minibatch 17900, batch loss 1.160810, batch nll 0.830291, batch error rate 27.000000%
# At minibatch 18000, batch loss 1.023581, batch nll 0.692911, batch error rate 23.000000%
# After epoch 45: valid_err_rate: 29.030000% currently going to do 64 epochs
# After epoch 45: averaged train_err_rate: 24.402500% averaged train nll: 0.709951 averaged train loss: 1.040658
# At minibatch 18100, batch loss 0.966107, batch nll 0.635020, batch error rate 19.000000%
# At minibatch 18200, batch loss 0.957686, batch nll 0.626454, batch error rate 23.000000%
# At minibatch 18300, batch loss 1.202087, batch nll 0.871171, batch error rate 31.000000%
# At minibatch 18400, batch loss 1.171012, batch nll 0.840517, batch error rate 31.000000%
# After epoch 46: valid_err_rate: 28.020000% currently going to do 70 epochs
# After epoch 46: averaged train_err_rate: 24.280000% averaged train nll: 0.707911 averaged train loss: 1.038849
# At minibatch 18500, batch loss 1.042830, batch nll 0.711819, batch error rate 23.000000%
# At minibatch 18600, batch loss 0.950136, batch nll 0.619187, batch error rate 22.000000%
# At minibatch 18700, batch loss 1.000961, batch nll 0.669734, batch error rate 23.000000%
# At minibatch 18800, batch loss 0.949788, batch nll 0.618775, batch error rate 18.000000%
# After epoch 47: valid_err_rate: 27.830000% currently going to do 71 epochs
# After epoch 47: averaged train_err_rate: 24.270000% averaged train nll: 0.706790 averaged train loss: 1.037789
# At minibatch 18900, batch loss 1.010979, batch nll 0.679719, batch error rate 25.000000%
# At minibatch 19000, batch loss 1.071244, batch nll 0.740104, batch error rate 29.000000%
# At minibatch 19100, batch loss 1.127714, batch nll 0.796334, batch error rate 28.000000%
# At minibatch 19200, batch loss 1.031669, batch nll 0.700594, batch error rate 24.000000%
# After epoch 48: valid_err_rate: 27.980000% currently going to do 71 epochs
# After epoch 48: averaged train_err_rate: 24.022500% averaged train nll: 0.702154 averaged train loss: 1.033378
# At minibatch 19300, batch loss 1.093964, batch nll 0.762507, batch error rate 25.000000%
# At minibatch 19400, batch loss 0.993634, batch nll 0.662198, batch error rate 26.000000%
# At minibatch 19500, batch loss 0.997515, batch nll 0.666092, batch error rate 24.000000%
# At minibatch 19600, batch loss 0.997890, batch nll 0.666612, batch error rate 20.000000%
# After epoch 49: valid_err_rate: 28.360000% currently going to do 71 epochs
# After epoch 49: averaged train_err_rate: 24.040000% averaged train nll: 0.700193 averaged train loss: 1.031533
# At minibatch 19700, batch loss 1.116513, batch nll 0.784888, batch error rate 28.000000%
# At minibatch 19800, batch loss 1.135868, batch nll 0.804275, batch error rate 28.000000%
# At minibatch 19900, batch loss 0.940695, batch nll 0.608951, batch error rate 21.000000%
# At minibatch 20000, batch loss 1.168802, batch nll 0.837285, batch error rate 30.000000%
# After epoch 50: valid_err_rate: 27.700000% currently going to do 76 epochs
# After epoch 50: averaged train_err_rate: 23.820000% averaged train nll: 0.695967 averaged train loss: 1.027557
# At minibatch 20100, batch loss 1.086934, batch nll 0.755397, batch error rate 27.000000%
# At minibatch 20200, batch loss 1.073325, batch nll 0.741707, batch error rate 27.000000%
# At minibatch 20300, batch loss 0.975371, batch nll 0.643627, batch error rate 25.000000%
# At minibatch 20400, batch loss 1.180333, batch nll 0.848466, batch error rate 26.000000%
# After epoch 51: valid_err_rate: 28.250000% currently going to do 76 epochs
# After epoch 51: averaged train_err_rate: 23.792500% averaged train nll: 0.692910 averaged train loss: 1.024517
# At minibatch 20500, batch loss 1.030570, batch nll 0.698549, batch error rate 25.000000%
# At minibatch 20600, batch loss 1.022555, batch nll 0.690447, batch error rate 24.000000%
# At minibatch 20700, batch loss 0.972651, batch nll 0.640837, batch error rate 19.000000%
# At minibatch 20800, batch loss 0.925249, batch nll 0.593672, batch error rate 18.000000%
# After epoch 52: valid_err_rate: 27.600000% currently going to do 79 epochs
# After epoch 52: averaged train_err_rate: 23.972500% averaged train nll: 0.694532 averaged train loss: 1.026500
# At minibatch 20900, batch loss 1.015297, batch nll 0.683463, batch error rate 29.000000%
# At minibatch 21000, batch loss 1.104865, batch nll 0.772787, batch error rate 26.000000%
# At minibatch 21100, batch loss 0.929305, batch nll 0.597175, batch error rate 19.000000%
# At minibatch 21200, batch loss 1.142614, batch nll 0.810583, batch error rate 34.000000%
# After epoch 53: valid_err_rate: 27.820000% currently going to do 79 epochs
# After epoch 53: averaged train_err_rate: 23.555000% averaged train nll: 0.691296 averaged train loss: 1.023284
# At minibatch 21300, batch loss 1.018546, batch nll 0.686395, batch error rate 25.000000%
# At minibatch 21400, batch loss 0.966430, batch nll 0.634116, batch error rate 22.000000%
# At minibatch 21500, batch loss 0.988444, batch nll 0.656050, batch error rate 25.000000%
# At minibatch 21600, batch loss 0.969857, batch nll 0.637473, batch error rate 22.000000%
# After epoch 54: valid_err_rate: 27.730000% currently going to do 79 epochs
# After epoch 54: averaged train_err_rate: 23.582500% averaged train nll: 0.688293 averaged train loss: 1.020562
# At minibatch 21700, batch loss 1.025651, batch nll 0.692904, batch error rate 27.000000%
# At minibatch 21800, batch loss 1.046742, batch nll 0.714294, batch error rate 29.000000%
# At minibatch 21900, batch loss 1.013442, batch nll 0.680888, batch error rate 23.000000%
# At minibatch 22000, batch loss 1.102741, batch nll 0.770137, batch error rate 33.000000%
# After epoch 55: valid_err_rate: 27.550000% currently going to do 83 epochs
# After epoch 55: averaged train_err_rate: 23.577500% averaged train nll: 0.685836 averaged train loss: 1.018445
# At minibatch 22100, batch loss 1.111258, batch nll 0.778283, batch error rate 30.000000%
# At minibatch 22200, batch loss 1.023779, batch nll 0.690985, batch error rate 19.000000%
# At minibatch 22300, batch loss 1.094947, batch nll 0.762133, batch error rate 30.000000%
# At minibatch 22400, batch loss 1.056788, batch nll 0.724031, batch error rate 22.000000%
# After epoch 56: valid_err_rate: 27.420000% currently going to do 85 epochs
# After epoch 56: averaged train_err_rate: 23.620000% averaged train nll: 0.686370 averaged train loss: 1.019195
# At minibatch 22500, batch loss 1.057531, batch nll 0.724498, batch error rate 24.000000%
# At minibatch 22600, batch loss 1.179163, batch nll 0.846129, batch error rate 27.000000%
# At minibatch 22700, batch loss 1.046901, batch nll 0.713739, batch error rate 29.000000%
# At minibatch 22800, batch loss 0.906814, batch nll 0.573591, batch error rate 19.000000%
# After epoch 57: valid_err_rate: 27.430000% currently going to do 85 epochs
# After epoch 57: averaged train_err_rate: 23.297500% averaged train nll: 0.680730 averaged train loss: 1.013787
# At minibatch 22900, batch loss 1.210448, batch nll 0.876921, batch error rate 28.000000%
# At minibatch 23000, batch loss 0.999174, batch nll 0.665679, batch error rate 23.000000%
# At minibatch 23100, batch loss 0.914815, batch nll 0.581342, batch error rate 18.000000%
# At minibatch 23200, batch loss 1.060679, batch nll 0.727349, batch error rate 24.000000%
# After epoch 58: valid_err_rate: 27.650000% currently going to do 85 epochs
# After epoch 58: averaged train_err_rate: 23.497500% averaged train nll: 0.682952 averaged train loss: 1.016383
# At minibatch 23300, batch loss 0.826720, batch nll 0.493052, batch error rate 16.000000%
# At minibatch 23400, batch loss 0.964801, batch nll 0.630706, batch error rate 21.000000%
# At minibatch 23500, batch loss 1.063212, batch nll 0.729275, batch error rate 22.000000%
# At minibatch 23600, batch loss 1.025957, batch nll 0.692300, batch error rate 21.000000%
# After epoch 59: valid_err_rate: 27.650000% currently going to do 85 epochs
# After epoch 59: averaged train_err_rate: 23.145000% averaged train nll: 0.679136 averaged train loss: 1.012949
# At minibatch 23700, batch loss 1.057018, batch nll 0.722908, batch error rate 23.000000%
# At minibatch 23800, batch loss 1.014402, batch nll 0.680187, batch error rate 22.000000%
# At minibatch 23900, batch loss 1.117508, batch nll 0.783359, batch error rate 27.000000%
# At minibatch 24000, batch loss 1.126367, batch nll 0.792391, batch error rate 30.000000%
# After epoch 60: valid_err_rate: 28.550000% currently going to do 85 epochs
# After epoch 60: averaged train_err_rate: 23.157500% averaged train nll: 0.675396 averaged train loss: 1.009455
# At minibatch 24100, batch loss 0.981419, batch nll 0.647324, batch error rate 19.000000%
# At minibatch 24200, batch loss 1.068008, batch nll 0.733752, batch error rate 29.000000%
# At minibatch 24300, batch loss 1.136144, batch nll 0.801823, batch error rate 28.000000%
# At minibatch 24400, batch loss 0.939426, batch nll 0.605051, batch error rate 19.000000%
# After epoch 61: valid_err_rate: 27.800000% currently going to do 85 epochs
# After epoch 61: averaged train_err_rate: 23.317500% averaged train nll: 0.676044 averaged train loss: 1.010259
# At minibatch 24500, batch loss 1.006085, batch nll 0.671669, batch error rate 22.000000%
# At minibatch 24600, batch loss 0.892509, batch nll 0.557987, batch error rate 18.000000%
# At minibatch 24700, batch loss 1.021331, batch nll 0.686725, batch error rate 22.000000%
# At minibatch 24800, batch loss 1.006644, batch nll 0.671990, batch error rate 22.000000%
# After epoch 62: valid_err_rate: 27.260000% currently going to do 94 epochs
# After epoch 62: averaged train_err_rate: 22.865000% averaged train nll: 0.674297 averaged train loss: 1.008816
# At minibatch 24900, batch loss 0.977993, batch nll 0.643193, batch error rate 21.000000%
# At minibatch 25000, batch loss 1.122841, batch nll 0.787577, batch error rate 24.000000%
# At minibatch 25100, batch loss 1.052653, batch nll 0.717371, batch error rate 24.000000%
# At minibatch 25200, batch loss 0.940902, batch nll 0.605913, batch error rate 19.000000%
# After epoch 63: valid_err_rate: 27.890000% currently going to do 94 epochs
# After epoch 63: averaged train_err_rate: 23.050000% averaged train nll: 0.671077 averaged train loss: 1.006129
# At minibatch 25300, batch loss 1.008833, batch nll 0.673634, batch error rate 27.000000%
# At minibatch 25400, batch loss 0.937513, batch nll 0.602320, batch error rate 22.000000%
# At minibatch 25500, batch loss 0.980810, batch nll 0.645618, batch error rate 21.000000%
# At minibatch 25600, batch loss 0.985333, batch nll 0.650041, batch error rate 20.000000%
# After epoch 64: valid_err_rate: 27.510000% currently going to do 94 epochs
# After epoch 64: averaged train_err_rate: 22.957500% averaged train nll: 0.669129 averaged train loss: 1.004294
# At minibatch 25700, batch loss 1.105996, batch nll 0.770337, batch error rate 20.000000%
# At minibatch 25800, batch loss 1.042579, batch nll 0.706935, batch error rate 24.000000%
# At minibatch 25900, batch loss 0.981082, batch nll 0.645382, batch error rate 23.000000%
# At minibatch 26000, batch loss 1.042361, batch nll 0.706800, batch error rate 25.000000%
# After epoch 65: valid_err_rate: 27.660000% currently going to do 94 epochs
# After epoch 65: averaged train_err_rate: 22.877500% averaged train nll: 0.668966 averaged train loss: 1.004584
# At minibatch 26100, batch loss 1.160829, batch nll 0.825174, batch error rate 25.000000%
# At minibatch 26200, batch loss 0.959347, batch nll 0.623478, batch error rate 21.000000%
# At minibatch 26300, batch loss 0.966347, batch nll 0.630375, batch error rate 21.000000%
# At minibatch 26400, batch loss 1.246592, batch nll 0.910541, batch error rate 34.000000%
# After epoch 66: valid_err_rate: 27.260000% currently going to do 94 epochs
# After epoch 66: averaged train_err_rate: 22.952500% averaged train nll: 0.666701 averaged train loss: 1.002535
# At minibatch 26500, batch loss 1.233903, batch nll 0.897892, batch error rate 33.000000%
# At minibatch 26600, batch loss 1.076779, batch nll 0.740689, batch error rate 21.000000%
# At minibatch 26700, batch loss 0.990407, batch nll 0.654132, batch error rate 24.000000%
# At minibatch 26800, batch loss 1.005413, batch nll 0.669150, batch error rate 17.000000%
# After epoch 67: valid_err_rate: 27.010000% currently going to do 101 epochs
# After epoch 67: averaged train_err_rate: 22.435000% averaged train nll: 0.661760 averaged train loss: 0.997863
# At minibatch 26900, batch loss 0.976138, batch nll 0.639608, batch error rate 19.000000%
# At minibatch 27000, batch loss 1.052167, batch nll 0.715478, batch error rate 24.000000%
# At minibatch 27100, batch loss 1.057498, batch nll 0.720928, batch error rate 25.000000%
# At minibatch 27200, batch loss 0.920967, batch nll 0.584535, batch error rate 17.000000%
# After epoch 68: valid_err_rate: 27.130000% currently going to do 101 epochs
# After epoch 68: averaged train_err_rate: 22.735000% averaged train nll: 0.661483 averaged train loss: 0.998022
# At minibatch 27300, batch loss 1.105899, batch nll 0.769367, batch error rate 29.000000%
# At minibatch 27400, batch loss 1.085106, batch nll 0.748461, batch error rate 30.000000%
# At minibatch 27500, batch loss 1.172728, batch nll 0.836028, batch error rate 26.000000%
# At minibatch 27600, batch loss 0.906085, batch nll 0.569451, batch error rate 18.000000%
# After epoch 69: valid_err_rate: 27.790000% currently going to do 101 epochs
# After epoch 69: averaged train_err_rate: 22.605000% averaged train nll: 0.662462 averaged train loss: 0.999099
# At minibatch 27700, batch loss 0.979385, batch nll 0.642461, batch error rate 24.000000%
# At minibatch 27800, batch loss 1.008121, batch nll 0.671011, batch error rate 24.000000%
# At minibatch 27900, batch loss 0.998503, batch nll 0.661190, batch error rate 23.000000%
# At minibatch 28000, batch loss 0.963357, batch nll 0.626189, batch error rate 22.000000%
# After epoch 70: valid_err_rate: 27.200000% currently going to do 101 epochs
# After epoch 70: averaged train_err_rate: 22.692500% averaged train nll: 0.660856 averaged train loss: 0.997916
# At minibatch 28100, batch loss 0.953675, batch nll 0.616510, batch error rate 20.000000%
# At minibatch 28200, batch loss 0.886727, batch nll 0.549497, batch error rate 17.000000%
# At minibatch 28300, batch loss 0.831861, batch nll 0.494371, batch error rate 15.000000%
# At minibatch 28400, batch loss 1.035088, batch nll 0.697569, batch error rate 28.000000%
# After epoch 71: valid_err_rate: 27.040000% currently going to do 101 epochs
# After epoch 71: averaged train_err_rate: 22.625000% averaged train nll: 0.658904 averaged train loss: 0.996232
# At minibatch 28500, batch loss 1.145309, batch nll 0.807623, batch error rate 27.000000%
# At minibatch 28600, batch loss 0.970624, batch nll 0.632662, batch error rate 21.000000%
# At minibatch 28700, batch loss 0.965001, batch nll 0.627085, batch error rate 16.000000%
# At minibatch 28800, batch loss 1.062585, batch nll 0.724821, batch error rate 22.000000%
# After epoch 72: valid_err_rate: 28.060000% currently going to do 101 epochs
# After epoch 72: averaged train_err_rate: 22.555000% averaged train nll: 0.658466 averaged train loss: 0.996272
# At minibatch 28900, batch loss 1.008542, batch nll 0.670473, batch error rate 25.000000%
# At minibatch 29000, batch loss 0.908161, batch nll 0.570060, batch error rate 18.000000%
# At minibatch 29100, batch loss 1.055077, batch nll 0.716901, batch error rate 29.000000%
# At minibatch 29200, batch loss 1.032374, batch nll 0.694159, batch error rate 21.000000%
# After epoch 73: valid_err_rate: 27.080000% currently going to do 101 epochs
# After epoch 73: averaged train_err_rate: 22.470000% averaged train nll: 0.655931 averaged train loss: 0.994000
# At minibatch 29300, batch loss 0.926988, batch nll 0.588521, batch error rate 22.000000%
# At minibatch 29400, batch loss 0.903969, batch nll 0.565264, batch error rate 18.000000%
# At minibatch 29500, batch loss 1.114465, batch nll 0.775967, batch error rate 26.000000%
# At minibatch 29600, batch loss 1.019786, batch nll 0.681559, batch error rate 24.000000%
# After epoch 74: valid_err_rate: 27.360000% currently going to do 101 epochs
# After epoch 74: averaged train_err_rate: 22.375000% averaged train nll: 0.655064 averaged train loss: 0.993537
# At minibatch 29700, batch loss 0.989759, batch nll 0.651291, batch error rate 20.000000%
# At minibatch 29800, batch loss 0.911877, batch nll 0.573522, batch error rate 26.000000%
# At minibatch 29900, batch loss 1.058351, batch nll 0.719882, batch error rate 22.000000%
# At minibatch 30000, batch loss 0.979798, batch nll 0.641229, batch error rate 21.000000%
# After epoch 75: valid_err_rate: 27.350000% currently going to do 101 epochs
# After epoch 75: averaged train_err_rate: 22.400000% averaged train nll: 0.654758 averaged train loss: 0.993209
# At minibatch 30100, batch loss 0.941167, batch nll 0.602457, batch error rate 19.000000%
# At minibatch 30200, batch loss 0.979893, batch nll 0.641134, batch error rate 23.000000%
# At minibatch 30300, batch loss 1.075169, batch nll 0.736419, batch error rate 18.000000%
# At minibatch 30400, batch loss 0.873093, batch nll 0.534292, batch error rate 21.000000%
# After epoch 76: valid_err_rate: 27.080000% currently going to do 101 epochs
# After epoch 76: averaged train_err_rate: 22.425000% averaged train nll: 0.654880 averaged train loss: 0.993591
# At minibatch 30500, batch loss 1.093930, batch nll 0.754856, batch error rate 24.000000%
# At minibatch 30600, batch loss 1.093755, batch nll 0.754522, batch error rate 30.000000%
# At minibatch 30700, batch loss 0.980269, batch nll 0.641010, batch error rate 20.000000%
# At minibatch 30800, batch loss 0.884974, batch nll 0.545679, batch error rate 22.000000%
# After epoch 77: valid_err_rate: 27.390000% currently going to do 101 epochs
# After epoch 77: averaged train_err_rate: 22.440000% averaged train nll: 0.651093 averaged train loss: 0.990273
# At minibatch 30900, batch loss 0.950616, batch nll 0.610938, batch error rate 16.000000%
# At minibatch 31000, batch loss 0.921653, batch nll 0.582090, batch error rate 19.000000%
# At minibatch 31100, batch loss 1.099241, batch nll 0.759491, batch error rate 31.000000%
# At minibatch 31200, batch loss 0.953674, batch nll 0.614092, batch error rate 21.000000%
# After epoch 78: valid_err_rate: 26.920000% currently going to do 118 epochs
# After epoch 78: averaged train_err_rate: 22.335000% averaged train nll: 0.650538 averaged train loss: 0.990128
# At minibatch 31300, batch loss 1.116495, batch nll 0.776626, batch error rate 28.000000%
# At minibatch 31400, batch loss 0.886314, batch nll 0.546211, batch error rate 15.000000%
# At minibatch 31500, batch loss 0.975607, batch nll 0.635451, batch error rate 25.000000%
# At minibatch 31600, batch loss 1.008620, batch nll 0.668782, batch error rate 22.000000%
# After epoch 79: valid_err_rate: 27.500000% currently going to do 118 epochs
# After epoch 79: averaged train_err_rate: 22.202500% averaged train nll: 0.647340 averaged train loss: 0.987283
# At minibatch 31700, batch loss 1.061656, batch nll 0.721628, batch error rate 25.000000%
# At minibatch 31800, batch loss 1.004407, batch nll 0.664376, batch error rate 19.000000%
# At minibatch 31900, batch loss 1.085499, batch nll 0.745432, batch error rate 22.000000%
# At minibatch 32000, batch loss 0.916324, batch nll 0.576056, batch error rate 19.000000%
# After epoch 80: valid_err_rate: 27.160000% currently going to do 118 epochs
# After epoch 80: averaged train_err_rate: 22.070000% averaged train nll: 0.647933 averaged train loss: 0.987979
# At minibatch 32100, batch loss 0.998309, batch nll 0.657845, batch error rate 18.000000%
# At minibatch 32200, batch loss 0.893198, batch nll 0.552583, batch error rate 17.000000%
# At minibatch 32300, batch loss 1.037242, batch nll 0.696420, batch error rate 21.000000%
# At minibatch 32400, batch loss 1.072073, batch nll 0.731383, batch error rate 21.000000%
# After epoch 81: valid_err_rate: 27.160000% currently going to do 118 epochs
# After epoch 81: averaged train_err_rate: 22.112500% averaged train nll: 0.645308 averaged train loss: 0.985900
# At minibatch 32500, batch loss 1.037699, batch nll 0.696834, batch error rate 22.000000%
# At minibatch 32600, batch loss 0.910643, batch nll 0.569752, batch error rate 18.000000%
# At minibatch 32700, batch loss 0.978747, batch nll 0.637793, batch error rate 17.000000%
# At minibatch 32800, batch loss 1.129820, batch nll 0.788911, batch error rate 26.000000%
# After epoch 82: valid_err_rate: 27.520000% currently going to do 118 epochs
# After epoch 82: averaged train_err_rate: 22.277500% averaged train nll: 0.645686 averaged train loss: 0.986565
# At minibatch 32900, batch loss 0.922674, batch nll 0.581818, batch error rate 21.000000%
# At minibatch 33000, batch loss 1.109194, batch nll 0.768173, batch error rate 27.000000%
# At minibatch 33100, batch loss 0.987472, batch nll 0.646205, batch error rate 20.000000%
# At minibatch 33200, batch loss 0.958451, batch nll 0.617235, batch error rate 25.000000%
# After epoch 83: valid_err_rate: 26.670000% currently going to do 125 epochs
# After epoch 83: averaged train_err_rate: 21.980000% averaged train nll: 0.643492 averaged train loss: 0.984511
# At minibatch 33300, batch loss 1.052410, batch nll 0.711004, batch error rate 24.000000%
# At minibatch 33400, batch loss 1.159721, batch nll 0.818071, batch error rate 28.000000%
# At minibatch 33500, batch loss 0.917546, batch nll 0.576006, batch error rate 17.000000%
# At minibatch 33600, batch loss 0.920367, batch nll 0.578775, batch error rate 17.000000%
# After epoch 84: valid_err_rate: 27.020000% currently going to do 125 epochs
# After epoch 84: averaged train_err_rate: 22.062500% averaged train nll: 0.642379 averaged train loss: 0.983904
# At minibatch 33700, batch loss 0.938308, batch nll 0.596557, batch error rate 18.000000%
# At minibatch 33800, batch loss 1.106742, batch nll 0.764987, batch error rate 28.000000%
# At minibatch 33900, batch loss 0.942901, batch nll 0.600928, batch error rate 21.000000%
# At minibatch 34000, batch loss 1.058365, batch nll 0.716383, batch error rate 21.000000%
# After epoch 85: valid_err_rate: 26.990000% currently going to do 125 epochs
# After epoch 85: averaged train_err_rate: 21.835000% averaged train nll: 0.638318 averaged train loss: 0.980143
# At minibatch 34100, batch loss 1.065311, batch nll 0.723131, batch error rate 21.000000%
# At minibatch 34200, batch loss 0.978979, batch nll 0.636743, batch error rate 20.000000%
# At minibatch 34300, batch loss 0.890526, batch nll 0.548363, batch error rate 18.000000%
# At minibatch 34400, batch loss 0.999062, batch nll 0.656874, batch error rate 26.000000%
# After epoch 86: valid_err_rate: 26.850000% currently going to do 125 epochs
# After epoch 86: averaged train_err_rate: 21.785000% averaged train nll: 0.639352 averaged train loss: 0.981497
# At minibatch 34500, batch loss 0.863779, batch nll 0.521424, batch error rate 18.000000%
# At minibatch 34600, batch loss 1.147758, batch nll 0.805233, batch error rate 27.000000%
# At minibatch 34700, batch loss 0.972452, batch nll 0.629943, batch error rate 17.000000%
# At minibatch 34800, batch loss 1.086752, batch nll 0.744283, batch error rate 22.000000%
# After epoch 87: valid_err_rate: 26.700000% currently going to do 125 epochs
# After epoch 87: averaged train_err_rate: 21.815000% averaged train nll: 0.637928 averaged train loss: 0.980353
# At minibatch 34900, batch loss 0.950163, batch nll 0.607523, batch error rate 24.000000%
# At minibatch 35000, batch loss 0.888376, batch nll 0.545634, batch error rate 18.000000%
# At minibatch 35100, batch loss 0.918907, batch nll 0.576240, batch error rate 17.000000%
# At minibatch 35200, batch loss 0.967108, batch nll 0.624240, batch error rate 22.000000%
# After epoch 88: valid_err_rate: 27.100000% currently going to do 125 epochs
# After epoch 88: averaged train_err_rate: 21.990000% averaged train nll: 0.640387 averaged train loss: 0.983060
# At minibatch 35300, batch loss 1.040456, batch nll 0.697524, batch error rate 21.000000%
# At minibatch 35400, batch loss 0.914371, batch nll 0.571284, batch error rate 21.000000%
# At minibatch 35500, batch loss 0.948366, batch nll 0.605301, batch error rate 19.000000%
# At minibatch 35600, batch loss 0.923343, batch nll 0.580283, batch error rate 28.000000%
# ...
# After epoch 161: valid_err_rate: 26.280000% currently going to do 190 epochs
# After epoch 161: averaged train_err_rate: 19.947500% averaged train nll: 0.587926 averaged train loss: 0.947129
# At minibatch 64500, batch loss 1.000022, batch nll 0.640774, batch error rate 21.000000%
# At minibatch 64600, batch loss 0.878961, batch nll 0.519704, batch error rate 20.000000%
# At minibatch 64700, batch loss 0.805360, batch nll 0.446005, batch error rate 15.000000%
# At minibatch 64800, batch loss 0.930205, batch nll 0.570815, batch error rate 16.000000%
# After epoch 162: valid_err_rate: 26.260000% currently going to do 190 epochs
# After epoch 162: averaged train_err_rate: 20.037500% averaged train nll: 0.588673 averaged train loss: 0.947982
# At minibatch 64900, batch loss 1.164742, batch nll 0.805296, batch error rate 32.000000%
# At minibatch 65000, batch loss 0.953545, batch nll 0.594014, batch error rate 19.000000%
# At minibatch 65100, batch loss 1.056214, batch nll 0.696620, batch error rate 27.000000%
# At minibatch 65200, batch loss 0.999504, batch nll 0.639962, batch error rate 16.000000%
# After epoch 163: valid_err_rate: 26.360000% currently going to do 190 epochs
# After epoch 163: averaged train_err_rate: 19.937500% averaged train nll: 0.587682 averaged train loss: 0.947180
# At minibatch 65300, batch loss 0.842903, batch nll 0.483216, batch error rate 13.000000%
# At minibatch 65400, batch loss 0.877673, batch nll 0.517884, batch error rate 17.000000%
# At minibatch 65500, batch loss 0.862291, batch nll 0.502542, batch error rate 20.000000%
# At minibatch 65600, batch loss 1.044865, batch nll 0.685162, batch error rate 24.000000%
# After epoch 164: valid_err_rate: 26.330000% currently going to do 190 epochs
# After epoch 164: averaged train_err_rate: 19.757500% averaged train nll: 0.585611 averaged train loss: 0.945320
# At minibatch 65700, batch loss 0.917476, batch nll 0.557773, batch error rate 23.000000%
# At minibatch 65800, batch loss 0.991785, batch nll 0.631965, batch error rate 21.000000%
# At minibatch 65900, batch loss 0.983967, batch nll 0.624108, batch error rate 25.000000%
# At minibatch 66000, batch loss 0.888827, batch nll 0.528927, batch error rate 14.000000%
# After epoch 165: valid_err_rate: 26.160000% currently going to do 190 epochs
# After epoch 165: averaged train_err_rate: 19.970000% averaged train nll: 0.586953 averaged train loss: 0.946759
# At minibatch 66100, batch loss 0.934590, batch nll 0.574583, batch error rate 19.000000%
# At minibatch 66200, batch loss 0.978421, batch nll 0.618419, batch error rate 21.000000%
# At minibatch 66300, batch loss 0.909893, batch nll 0.549826, batch error rate 19.000000%
# At minibatch 66400, batch loss 0.992363, batch nll 0.632258, batch error rate 26.000000%
# After epoch 166: valid_err_rate: 26.340000% currently going to do 190 epochs
# After epoch 166: averaged train_err_rate: 19.747500% averaged train nll: 0.585173 averaged train loss: 0.945200
# At minibatch 66500, batch loss 0.894083, batch nll 0.534008, batch error rate 20.000000%
# At minibatch 66600, batch loss 0.820319, batch nll 0.460014, batch error rate 15.000000%
# At minibatch 66700, batch loss 0.812219, batch nll 0.451864, batch error rate 17.000000%
# At minibatch 66800, batch loss 1.003788, batch nll 0.643482, batch error rate 26.000000%
# After epoch 167: valid_err_rate: 26.500000% currently going to do 190 epochs
# After epoch 167: averaged train_err_rate: 19.960000% averaged train nll: 0.585630 averaged train loss: 0.945864
# At minibatch 66900, batch loss 0.979119, batch nll 0.618693, batch error rate 20.000000%
# At minibatch 67000, batch loss 0.900168, batch nll 0.539757, batch error rate 18.000000%
# At minibatch 67100, batch loss 1.008102, batch nll 0.647693, batch error rate 28.000000%
# At minibatch 67200, batch loss 0.911963, batch nll 0.551530, batch error rate 22.000000%
# After epoch 168: valid_err_rate: 26.330000% currently going to do 190 epochs
# After epoch 168: averaged train_err_rate: 19.770000% averaged train nll: 0.584045 averaged train loss: 0.944449
# At minibatch 67300, batch loss 0.891900, batch nll 0.531413, batch error rate 16.000000%
# At minibatch 67400, batch loss 1.039472, batch nll 0.678955, batch error rate 29.000000%
# At minibatch 67500, batch loss 0.992969, batch nll 0.632449, batch error rate 25.000000%
# At minibatch 67600, batch loss 0.975906, batch nll 0.615307, batch error rate 21.000000%
# After epoch 169: valid_err_rate: 26.550000% currently going to do 190 epochs
# After epoch 169: averaged train_err_rate: 19.877500% averaged train nll: 0.585710 averaged train loss: 0.946227
# At minibatch 67700, batch loss 0.899252, batch nll 0.538656, batch error rate 16.000000%
# At minibatch 67800, batch loss 0.885557, batch nll 0.524856, batch error rate 15.000000%
# At minibatch 67900, batch loss 0.837827, batch nll 0.477115, batch error rate 15.000000%
# At minibatch 68000, batch loss 1.003933, batch nll 0.643168, batch error rate 21.000000%
# After epoch 170: valid_err_rate: 26.330000% currently going to do 190 epochs
# After epoch 170: averaged train_err_rate: 19.977500% averaged train nll: 0.584644 averaged train loss: 0.945318
# At minibatch 68100, batch loss 0.819964, batch nll 0.459147, batch error rate 18.000000%
# At minibatch 68200, batch loss 0.933937, batch nll 0.573015, batch error rate 20.000000%
# At minibatch 68300, batch loss 0.850795, batch nll 0.489832, batch error rate 16.000000%
# At minibatch 68400, batch loss 0.943579, batch nll 0.582657, batch error rate 23.000000%
# After epoch 171: valid_err_rate: 26.100000% currently going to do 190 epochs
# After epoch 171: averaged train_err_rate: 19.660000% averaged train nll: 0.582072 averaged train loss: 0.942970
# At minibatch 68500, batch loss 0.912777, batch nll 0.551729, batch error rate 17.000000%
# At minibatch 68600, batch loss 1.073978, batch nll 0.712829, batch error rate 22.000000%
# At minibatch 68700, batch loss 0.939815, batch nll 0.578663, batch error rate 21.000000%
# At minibatch 68800, batch loss 0.970176, batch nll 0.609125, batch error rate 20.000000%
# After epoch 172: valid_err_rate: 26.490000% currently going to do 190 epochs
# After epoch 172: averaged train_err_rate: 19.722500% averaged train nll: 0.583829 averaged train loss: 0.944926
# At minibatch 68900, batch loss 0.873574, batch nll 0.512370, batch error rate 14.000000%
# At minibatch 69000, batch loss 1.023607, batch nll 0.662388, batch error rate 24.000000%
# At minibatch 69100, batch loss 1.166396, batch nll 0.805213, batch error rate 26.000000%
# At minibatch 69200, batch loss 0.884708, batch nll 0.523480, batch error rate 19.000000%
# After epoch 173: valid_err_rate: 26.380000% currently going to do 190 epochs
# After epoch 173: averaged train_err_rate: 19.832500% averaged train nll: 0.582720 averaged train loss: 0.943902
# At minibatch 69300, batch loss 0.946953, batch nll 0.585556, batch error rate 21.000000%
# At minibatch 69400, batch loss 0.968968, batch nll 0.607535, batch error rate 27.000000%
# At minibatch 69500, batch loss 0.963687, batch nll 0.602271, batch error rate 24.000000%
# At minibatch 69600, batch loss 1.004536, batch nll 0.643103, batch error rate 19.000000%
# After epoch 174: valid_err_rate: 26.710000% currently going to do 190 epochs
# After epoch 174: averaged train_err_rate: 19.785000% averaged train nll: 0.581938 averaged train loss: 0.943330
# At minibatch 69700, batch loss 0.879140, batch nll 0.517676, batch error rate 16.000000%
# At minibatch 69800, batch loss 0.912329, batch nll 0.550830, batch error rate 18.000000%
# At minibatch 69900, batch loss 0.900457, batch nll 0.538942, batch error rate 21.000000%
# At minibatch 70000, batch loss 1.062198, batch nll 0.700661, batch error rate 27.000000%
# After epoch 175: valid_err_rate: 26.450000% currently going to do 190 epochs
# After epoch 175: averaged train_err_rate: 19.700000% averaged train nll: 0.581373 averaged train loss: 0.942876
# At minibatch 70100, batch loss 0.957296, batch nll 0.595737, batch error rate 18.000000%
# At minibatch 70200, batch loss 0.927396, batch nll 0.565779, batch error rate 21.000000%
# At minibatch 70300, batch loss 0.974930, batch nll 0.613259, batch error rate 21.000000%
# At minibatch 70400, batch loss 0.865007, batch nll 0.503279, batch error rate 15.000000%
# After epoch 176: valid_err_rate: 26.270000% currently going to do 190 epochs
# After epoch 176: averaged train_err_rate: 19.687500% averaged train nll: 0.582050 averaged train loss: 0.943667
# At minibatch 70500, batch loss 0.929137, batch nll 0.567365, batch error rate 20.000000%
# At minibatch 70600, batch loss 0.971161, batch nll 0.609373, batch error rate 18.000000%
# At minibatch 70700, batch loss 0.898851, batch nll 0.537024, batch error rate 17.000000%
# At minibatch 70800, batch loss 1.035457, batch nll 0.673591, batch error rate 22.000000%
# After epoch 177: valid_err_rate: 26.460000% currently going to do 190 epochs
# After epoch 177: averaged train_err_rate: 19.907500% averaged train nll: 0.582916 averaged train loss: 0.944714
# At minibatch 70900, batch loss 0.861593, batch nll 0.499640, batch error rate 18.000000%
# At minibatch 71000, batch loss 0.799666, batch nll 0.437717, batch error rate 16.000000%
# At minibatch 71100, batch loss 0.841592, batch nll 0.479612, batch error rate 11.000000%
# At minibatch 71200, batch loss 1.126033, batch nll 0.764029, batch error rate 26.000000%
# After epoch 178: valid_err_rate: 26.340000% currently going to do 190 epochs
# After epoch 178: averaged train_err_rate: 19.707500% averaged train nll: 0.580984 averaged train loss: 0.942938
# At minibatch 71300, batch loss 0.974588, batch nll 0.612596, batch error rate 16.000000%
# At minibatch 71400, batch loss 1.064587, batch nll 0.702456, batch error rate 24.000000%
# At minibatch 71500, batch loss 0.970614, batch nll 0.608415, batch error rate 22.000000%
# At minibatch 71600, batch loss 0.865161, batch nll 0.502971, batch error rate 19.000000%
# After epoch 179: valid_err_rate: 26.270000% currently going to do 190 epochs
# After epoch 179: averaged train_err_rate: 19.590000% averaged train nll: 0.581395 averaged train loss: 0.943494
# At minibatch 71700, batch loss 0.959759, batch nll 0.597517, batch error rate 17.000000%
# At minibatch 71800, batch loss 0.913421, batch nll 0.551069, batch error rate 21.000000%
# At minibatch 71900, batch loss 0.983430, batch nll 0.621126, batch error rate 20.000000%
# At minibatch 72000, batch loss 0.879911, batch nll 0.517631, batch error rate 21.000000%
# After epoch 180: valid_err_rate: 26.360000% currently going to do 190 epochs
# After epoch 180: averaged train_err_rate: 19.625000% averaged train nll: 0.580149 averaged train loss: 0.942434
# At minibatch 72100, batch loss 0.938249, batch nll 0.575786, batch error rate 17.000000%
# At minibatch 72200, batch loss 0.914295, batch nll 0.551870, batch error rate 19.000000%
# At minibatch 72300, batch loss 1.018355, batch nll 0.655921, batch error rate 22.000000%
# At minibatch 72400, batch loss 1.090793, batch nll 0.728322, batch error rate 25.000000%
# After epoch 181: valid_err_rate: 26.400000% currently going to do 190 epochs
# After epoch 181: averaged train_err_rate: 19.647500% averaged train nll: 0.579290 averaged train loss: 0.941722
# At minibatch 72500, batch loss 0.958544, batch nll 0.596007, batch error rate 25.000000%
# At minibatch 72600, batch loss 1.005040, batch nll 0.642386, batch error rate 24.000000%
# At minibatch 72700, batch loss 1.041724, batch nll 0.679026, batch error rate 20.000000%
# At minibatch 72800, batch loss 1.066055, batch nll 0.703397, batch error rate 22.000000%
# After epoch 182: valid_err_rate: 26.210000% currently going to do 190 epochs
# After epoch 182: averaged train_err_rate: 19.577500% averaged train nll: 0.578926 averaged train loss: 0.941534
# At minibatch 72900, batch loss 0.886018, batch nll 0.523377, batch error rate 20.000000%
# At minibatch 73000, batch loss 0.956845, batch nll 0.594112, batch error rate 22.000000%
# At minibatch 73100, batch loss 0.890632, batch nll 0.527888, batch error rate 20.000000%
# At minibatch 73200, batch loss 0.849662, batch nll 0.486930, batch error rate 22.000000%
# After epoch 183: valid_err_rate: 26.100000% currently going to do 190 epochs
# After epoch 183: averaged train_err_rate: 19.625000% averaged train nll: 0.580060 averaged train loss: 0.942760
# At minibatch 73300, batch loss 1.053272, batch nll 0.690444, batch error rate 27.000000%
# At minibatch 73400, batch loss 0.854266, batch nll 0.491430, batch error rate 13.000000%
# At minibatch 73500, batch loss 0.988507, batch nll 0.625612, batch error rate 22.000000%
# At minibatch 73600, batch loss 1.051757, batch nll 0.688842, batch error rate 26.000000%
# After epoch 184: valid_err_rate: 26.780000% currently going to do 190 epochs
# After epoch 184: averaged train_err_rate: 19.617500% averaged train nll: 0.577977 averaged train loss: 0.940823
# At minibatch 73700, batch loss 0.891910, batch nll 0.528931, batch error rate 20.000000%
# At minibatch 73800, batch loss 0.985234, batch nll 0.622165, batch error rate 21.000000%
# At minibatch 73900, batch loss 0.853871, batch nll 0.490837, batch error rate 17.000000%
# At minibatch 74000, batch loss 0.915888, batch nll 0.552849, batch error rate 19.000000%
# After epoch 185: valid_err_rate: 26.710000% currently going to do 190 epochs
# After epoch 185: averaged train_err_rate: 19.600000% averaged train nll: 0.578544 averaged train loss: 0.941560
# At minibatch 74100, batch loss 0.884434, batch nll 0.521330, batch error rate 18.000000%
# At minibatch 74200, batch loss 0.904515, batch nll 0.541241, batch error rate 18.000000%
# At minibatch 74300, batch loss 0.865830, batch nll 0.502612, batch error rate 17.000000%
# At minibatch 74400, batch loss 0.909046, batch nll 0.545842, batch error rate 22.000000%
# After epoch 186: valid_err_rate: 26.250000% currently going to do 190 epochs
# After epoch 186: averaged train_err_rate: 19.495000% averaged train nll: 0.576715 averaged train loss: 0.939895
# At minibatch 74500, batch loss 0.954067, batch nll 0.590896, batch error rate 24.000000%
# At minibatch 74600, batch loss 1.006317, batch nll 0.643139, batch error rate 19.000000%
# At minibatch 74700, batch loss 0.999393, batch nll 0.636099, batch error rate 20.000000%
# At minibatch 74800, batch loss 0.880110, batch nll 0.516735, batch error rate 14.000000%
# After epoch 187: valid_err_rate: 26.140000% currently going to do 190 epochs
# After epoch 187: averaged train_err_rate: 19.537500% averaged train nll: 0.578183 averaged train loss: 0.941410
# At minibatch 74900, batch loss 0.877034, batch nll 0.513574, batch error rate 20.000000%
# At minibatch 75000, batch loss 0.963045, batch nll 0.599528, batch error rate 22.000000%
# At minibatch 75100, batch loss 1.076809, batch nll 0.713301, batch error rate 28.000000%
# At minibatch 75200, batch loss 1.003925, batch nll 0.640455, batch error rate 21.000000%
# After epoch 188: valid_err_rate: 26.560000% currently going to do 190 epochs
# After epoch 188: averaged train_err_rate: 19.377500% averaged train nll: 0.575176 averaged train loss: 0.938656
# At minibatch 75300, batch loss 0.907280, batch nll 0.543747, batch error rate 17.000000%
# At minibatch 75400, batch loss 1.010835, batch nll 0.647273, batch error rate 19.000000%
# At minibatch 75500, batch loss 0.946809, batch nll 0.583194, batch error rate 19.000000%
# At minibatch 75600, batch loss 0.944455, batch nll 0.580826, batch error rate 16.000000%
# After epoch 189: valid_err_rate: 26.340000% currently going to do 190 epochs
# After epoch 189: averaged train_err_rate: 19.420000% averaged train nll: 0.575022 averaged train loss: 0.938598
# At minibatch 75700, batch loss 0.857295, batch nll 0.493604, batch error rate 19.000000%
# At minibatch 75800, batch loss 0.906428, batch nll 0.542611, batch error rate 26.000000%
# At minibatch 75900, batch loss 0.854152, batch nll 0.490385, batch error rate 16.000000%
# At minibatch 76000, batch loss 0.935601, batch nll 0.571838, batch error rate 21.000000%
# After epoch 190: valid_err_rate: 26.530000% currently going to do 190 epochs
# After epoch 190: averaged train_err_rate: 19.552500% averaged train nll: 0.576478 averaged train loss: 0.940228

# %%
print "Setting network parameters from after epoch %d" %(best_params_epoch)
load_parameters(best_params)

print "Success rate is %f%%" %(100.0-compute_error_rate(cifar10_testt_stream)*100.0,)
print "Error rate is %f%%" %(compute_error_rate(cifar10_testt_stream)*100.0,)

figure(figsize=(16,14))

subplot(2,1,1)
train_nll_a = np.array(train_nll)
semilogy(train_nll_a[:,0], train_nll_a[:,1], label='batch train nll')
legend()

subplot(2,1,2)
train_erros_a = np.array(train_erros)
plot(train_erros_a[:,0], train_erros_a[:,1], label='batch train error rate')
validation_errors_a = np.array(validation_errors)
plot(validation_errors_a[:,0], validation_errors_a[:,1], label='validation error rate', color='r')
ylim(0,0.8)
legend()
# Out:
# Setting network parameters from after epoch 126
# Success rate is 72.590000%
# Error rate is 27.410000%

# %%
middle_layers_computer = theano.function([X], network.model_layers)

img_num=11

middle_layers = middle_layers_computer(X_test_value[img_num:img_num+1])
print middle_layers[0].shape
print middle_layers[1].shape
print middle_layers[2].shape
print middle_layers[3].shape
print middle_layers[4].shape


plot_mat(middle_layers[0])
title(network.model_names[0])
show()

for ml, name in zip(middle_layers[1:], network.model_names[1:]):
    try:
        #print ml#.transpose(1,0,2,3).shape
        plot_mat(ml.transpose(1,0,2,3), cmap='gray')
        title(name)
        show()
    except ValueError:
        pass
# Out:
# (1, 3, 32, 32)
# (1, 10, 28, 28)
# (1, 10, 14, 14)
# (1, 25, 10, 10)
# (1, 25, 5, 5)
