# %%
# %pylab inline

from scipy.ndimage.filters import convolve

import theano
import theano.tensor.signal.downsample
import skimage.io
print theano.config.floatX

from common.plotting import plot_mat

from fuel.datasets.cifar10 import CIFAR10
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme
# Out:
# Populating the interactive namespace from numpy and matplotlib
# float32
# Using gpu device 0: GeForce GTX 780 (CNMeM is enabled)

# %%
CIFAR10.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'})
)

cifar10_train = CIFAR10(("train",), subset=slice(None,40000))
cifar10_valid = CIFAR10(("train",), subset=slice(40000, None))
cifar10_testt  = CIFAR10(("test",))

minibatch_train = 20
minibatch_valid = 100
minibatch_testt = 100

cifar10_train_stream = DataStream.default_stream(
    cifar10_train,
    iteration_scheme=ShuffledScheme(cifar10_train.num_examples, minibatch_train)
)
cifar10_valid_stream = DataStream.default_stream(
    cifar10_valid, 
    iteration_scheme=SequentialScheme(cifar10_valid.num_examples, minibatch_valid)
)
cifar10_testt_stream = DataStream.default_stream(
    cifar10_testt, 
    iteration_scheme=SequentialScheme(cifar10_testt.num_examples, minibatch_testt)
)

print "Each trainin batch consits of a tuple containing:"
for element in next(cifar10_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(cifar10_testt_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    

plot_mat(cifar10_train.data_sources[0][:20], cmap='gray')

asd = 0
for x in cifar10_train_stream.get_epoch_iterator():
    asd += 1
print asd
# Out:
# Each trainin batch consits of a tuple containing:
#  - an array of size (20, 3, 32, 32) containing float32
#  - an array of size (20, 1) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (100, 3, 32, 32) containing float32
#  - an array of size (100, 1) containing uint8
# 2000

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
def print_warn(s, X):
    print "after_%s shape: %s" % (s, X.tag.test_value.shape,)

class Layer_Conv():
    def __init__(self, in_chan, out_chan, size):
        self.in_chan = in_chan
        self.out_chan = out_chan
        self.size = size
    def make(self, X, n):
        CWn = theano.shared(np.zeros((self.out_chan, self.in_chan, self.size, self.size), dtype='float32'), name=('CW%d'%n))
        CBn = theano.shared(np.zeros((self.out_chan,), dtype='float32'), name=('CB%d'%n))
        
        CWn.tag.initializer = IsotropicGaussian(0.05)
        CBn.tag.initializer = Constant(0.0)
        
        after_Cn = theano.tensor.maximum(
            0.0,
            theano.tensor.nnet.conv2d(X, CWn) + CBn.dimshuffle('x',0,'x','x')
        )
        print_warn(("C%d"%n), after_Cn)
        
        return after_Cn, [CWn, CBn], [("C%d"%n)]
    
class Layer_Pool():
    def __init__(self, size):
        self.size = size        
    def make(self, X, n):
        after_Pn = theano.tensor.signal.downsample.max_pool_2d(X, (self.size, self.size), ignore_border=True)
        print_warn(("P%d"%n), after_Pn)
        
        return after_Pn, [], [("P%d"%n)]
    
class Layer_Filt():
    def __init__(self, in_chan, out_chan):
        self.in_chan = in_chan
        self.out_chan = out_chan
    def make(self, X, n):
        num_fw4_hidden=10
        FWn = theano.shared(np.zeros((self.in_chan, self.out_chan), dtype='float32'), name=('FW%d'%n))
        FBn = theano.shared(np.zeros((self.out_chan,), dtype='float32'), name=('FB%d'%n))
        
        FWn.tag.initializer = IsotropicGaussian(0.05)
        FBn.tag.initializer = Constant(0.0)

        after_Fn = theano.tensor.dot(X.flatten(2), FWn) + FBn.dimshuffle('x',0)
        print_warn(("F%d"%n), after_Fn)
        
        return after_Fn, [FWn, FBn], [("F%d"%n)]
    
class Layer_Soft():
    def __init__(self):
        pass
    def make(self, X, n):
        after_Sn = theano.tensor.nnet.softmax(X)
        print_warn(("S%d"%n), after_Sn)
        
        return after_Sn, [], [("S%d"%n)]

# %%
class NetworkBuilder():
    def __init__(self, layerlist):
        self.layers = layerlist
    def make(self, X):
        model_parameters = []
        self.model_names = ["X"]
        self.model_layers = [X] 
        i = 1
        after = X
        for layer in self.layers:
            after, param, name = layer.make(after, i)
            self.model_layers += [after]
            model_parameters += param
            self.model_names += name
            i += 1
            
        return after, model_parameters

# %%
theano.config.compute_test_value = 'warn'
X_test_value, Y_test_value = next(cifar10_train_stream.get_epoch_iterator())

X = theano.tensor.tensor4('X')
Y = theano.tensor.matrix('Y', dtype='uint8')
X.tag.test_value = X_test_value[:3]
Y.tag.test_value = Y_test_value[:3]
print "X shape: %s" % (X.tag.test_value.shape,)

network = NetworkBuilder([
        Layer_Conv(3, 16, 3),
        Layer_Pool(2),
        Layer_Conv(16, 25, 4),
        Layer_Pool(2),
        Layer_Conv(25, 32, 3),
        Layer_Filt(32*4*4, 1000),
        Layer_Filt(1000, 300),
        Layer_Filt(300, 10),
        Layer_Soft()
    ])

output, parameters = network.make(X)

predictions = theano.tensor.argmax(output, axis=1)

error_rate = theano.tensor.neq(predictions,Y.ravel()).mean()

nll = - theano.tensor.log(output[theano.tensor.arange(Y.shape[0]), Y.ravel()]).mean()

alpha = 3e-3
weight_decay = 0.0
for p in parameters:
    if p.name[1]=='W':
        weight_decay = weight_decay + alpha * (p**2).sum()

cost = nll + weight_decay

theano.config.compute_test_value = 'off'
# Out:
# X shape: (3, 3, 32, 32)
# after_C1 shape: (3, 16, 30, 30)
# after_P2 shape: (3, 16, 15, 15)
# after_C3 shape: (3, 25, 12, 12)
# after_P4 shape: (3, 25, 6, 6)
# after_C5 shape: (3, 32, 4, 4)
# after_F6 shape: (3, 1000)
# after_F7 shape: (3, 300)
# after_F8 shape: (3, 10)
# after_S9 shape: (3, 10)

# %%
updates = []

lrate = theano.tensor.scalar('lrate',dtype='float32')
momentum = theano.tensor.scalar('momentum',dtype='float32')
gradients = theano.grad(cost, parameters)
velocities = [theano.shared(np.zeros_like(p.get_value()), name='V_%s' %(p.name, )) for p in parameters]

for p,g,v in zip(parameters, gradients, velocities):
    v_new = momentum * v - lrate * g
    p_new = p + v_new
    updates += [(v,v_new), (p, p_new)]

# %%
train_step = theano.function(
    [X, Y, lrate, momentum],
    [cost, error_rate, nll, weight_decay],
    updates=updates
)

predict = theano.function(
    [X], 
    predictions
)

# %%
def compute_error_rate(stream):
    errs = 0.0
    num_samples = 0.0
    for X, Y in stream.get_epoch_iterator():
        errs += (predict(X)!=Y.ravel()).sum()
        num_samples += Y.shape[0]
    return errs/num_samples

def init_parameters():
    rng = np.random.RandomState(1234)
    for p in parameters:
        p.set_value(p.tag.initializer.generate(rng, p.get_value().shape))

def snapshot_parameters():
    return [p.get_value(borrow=False) for p in parameters]

def load_parameters(snapshot):
    for p, s in zip(parameters, snapshot):
        p.set_value(s, borrow=False)

# %%
i=0
e=0

init_parameters()
for v in velocities:
    v.set_value(np.zeros_like(v.get_value()))

best_valid_error_rate = np.inf
best_params = snapshot_parameters()
best_params_epoch = 0

train_erros = []
train_loss = []
train_nll = []
validation_errors = []

number_of_epochs = 3
patience_expansion = 1.5

while e<number_of_epochs:
    e += 1
    epoch_start_i = i
    
    for X_batch, Y_batch in cifar10_train_stream.get_epoch_iterator(): 
        i += 1
        
        K = 20000
        lrate = 1e-3 * K / np.maximum(K, i)
        momentum=0.9
        
        L, err_rate, nll, wdec = train_step(X_batch, Y_batch, lrate, momentum)
        
        train_loss.append((i,L))
        train_erros.append((i,err_rate))
        train_nll.append((i,nll))
        
        if i % 100 == 0:
            print "At minibatch %d, batch loss %f, batch nll %f, batch error rate %f%%" % (i, L, nll, err_rate*100)
        
    
    val_error_rate = compute_error_rate(cifar10_valid_stream)
    if val_error_rate < best_valid_error_rate:
        number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
        best_valid_error_rate = val_error_rate
        best_params = snapshot_parameters()
        best_params_epoch = e
        
    validation_errors.append((i,val_error_rate))
    print "After epoch %d: valid_err_rate: %f%% currently going to do %d epochs" %(
        e, val_error_rate*100, number_of_epochs)
    
    print "After epoch %d: averaged train_err_rate: %f%% averaged train nll: %f averaged train loss: %f" %(
        e, 
        np.mean(np.asarray(train_erros)[epoch_start_i:,1])*100, 
        np.mean(np.asarray(train_nll)[epoch_start_i:,1]),
        np.mean(np.asarray(train_loss)[epoch_start_i:,1])
    )
# Out:
# At minibatch 100, batch loss 8.438601, batch nll 2.276169, batch error rate 85.000000%
# At minibatch 200, batch loss 8.221470, batch nll 2.131130, batch error rate 80.000000%
# At minibatch 300, batch loss 7.986495, batch nll 1.966244, batch error rate 75.000000%
# At minibatch 400, batch loss 8.043441, batch nll 2.093325, batch error rate 90.000000%
# At minibatch 500, batch loss 8.131037, batch nll 2.249982, batch error rate 95.000000%
# At minibatch 600, batch loss 7.598313, batch nll 1.785814, batch error rate 60.000000%
# At minibatch 700, batch loss 7.711330, batch nll 1.965937, batch error rate 85.000000%
# At minibatch 800, batch loss 7.817984, batch nll 2.139318, batch error rate 70.000000%
# At minibatch 900, batch loss 7.447137, batch nll 1.833103, batch error rate 60.000000%
# At minibatch 1000, batch loss 7.272862, batch nll 1.723791, batch error rate 75.000000%
# At minibatch 1100, batch loss 7.059776, batch nll 1.574436, batch error rate 55.000000%
# At minibatch 1200, batch loss 7.073722, batch nll 1.651196, batch error rate 75.000000%
# At minibatch 1300, batch loss 7.021749, batch nll 1.661469, batch error rate 55.000000%
# At minibatch 1400, batch loss 6.980621, batch nll 1.682202, batch error rate 60.000000%
# At minibatch 1500, batch loss 6.714759, batch nll 1.476915, batch error rate 60.000000%
# At minibatch 1600, batch loss 7.403820, batch nll 2.226624, batch error rate 80.000000%
# At minibatch 1700, batch loss 6.264769, batch nll 1.147713, batch error rate 55.000000%
# At minibatch 1800, batch loss 6.614439, batch nll 1.556099, batch error rate 60.000000%
# At minibatch 1900, batch loss 6.433051, batch nll 1.433060, batch error rate 50.000000%
# At minibatch 2000, batch loss 6.486940, batch nll 1.544431, batch error rate 50.000000%
# After epoch 1: valid_err_rate: 53.420000% currently going to do 3 epochs
# After epoch 1: averaged train_err_rate: 64.850000% averaged train nll: 1.779235 averaged train loss: 7.341346
# At minibatch 2100, batch loss 6.767451, batch nll 1.882017, batch error rate 65.000000%
# At minibatch 2200, batch loss 6.544345, batch nll 1.715522, batch error rate 70.000000%
# At minibatch 2300, batch loss 6.301698, batch nll 1.528502, batch error rate 55.000000%
# At minibatch 2400, batch loss 6.168153, batch nll 1.449325, batch error rate 60.000000%
# At minibatch 2500, batch loss 6.098168, batch nll 1.434523, batch error rate 50.000000%
# At minibatch 2600, batch loss 6.064029, batch nll 1.453551, batch error rate 45.000000%
# At minibatch 2700, batch loss 5.927556, batch nll 1.370422, batch error rate 45.000000%
# At minibatch 2800, batch loss 5.912701, batch nll 1.407571, batch error rate 50.000000%
# At minibatch 2900, batch loss 5.755630, batch nll 1.302561, batch error rate 45.000000%
# At minibatch 3000, batch loss 5.569942, batch nll 1.167797, batch error rate 30.000000%
# At minibatch 3100, batch loss 5.345037, batch nll 0.993429, batch error rate 30.000000%
# At minibatch 3200, batch loss 5.869323, batch nll 1.567767, batch error rate 45.000000%
# At minibatch 3300, batch loss 5.314140, batch nll 1.062159, batch error rate 35.000000%
# At minibatch 3400, batch loss 5.633627, batch nll 1.431006, batch error rate 50.000000%
# At minibatch 3500, batch loss 5.725698, batch nll 1.570833, batch error rate 45.000000%
# At minibatch 3600, batch loss 5.600259, batch nll 1.492809, batch error rate 65.000000%
# At minibatch 3700, batch loss 5.384882, batch nll 1.323908, batch error rate 45.000000%
# At minibatch 3800, batch loss 5.323048, batch nll 1.309462, batch error rate 50.000000%
# At minibatch 3900, batch loss 5.096520, batch nll 1.128654, batch error rate 35.000000%
# At minibatch 4000, batch loss 5.027173, batch nll 1.105024, batch error rate 25.000000%
# After epoch 2: valid_err_rate: 48.640000% currently going to do 4 epochs
# After epoch 2: averaged train_err_rate: 51.040000% averaged train nll: 1.419598 averaged train loss: 5.831445
# At minibatch 4100, batch loss 5.077215, batch nll 1.199543, batch error rate 45.000000%
# At minibatch 4200, batch loss 5.343883, batch nll 1.510194, batch error rate 55.000000%
# At minibatch 4300, batch loss 5.191070, batch nll 1.400984, batch error rate 45.000000%
# At minibatch 4400, batch loss 5.091271, batch nll 1.344214, batch error rate 60.000000%
# At minibatch 4500, batch loss 5.409360, batch nll 1.704740, batch error rate 65.000000%
# At minibatch 4600, batch loss 4.980861, batch nll 1.317885, batch error rate 45.000000%
# At minibatch 4700, batch loss 4.944794, batch nll 1.323077, batch error rate 40.000000%
# At minibatch 4800, batch loss 4.517423, batch nll 0.937040, batch error rate 35.000000%
# At minibatch 4900, batch loss 4.638863, batch nll 1.099524, batch error rate 25.000000%
# At minibatch 5000, batch loss 4.978773, batch nll 1.479679, batch error rate 65.000000%
# At minibatch 5100, batch loss 4.910466, batch nll 1.449773, batch error rate 40.000000%
# At minibatch 5200, batch loss 4.927705, batch nll 1.506114, batch error rate 55.000000%
# At minibatch 5300, batch loss 4.746690, batch nll 1.363714, batch error rate 50.000000%
# At minibatch 5400, batch loss 4.703870, batch nll 1.359379, batch error rate 60.000000%
# At minibatch 5500, batch loss 4.518040, batch nll 1.210615, batch error rate 50.000000%
# At minibatch 5600, batch loss 5.142075, batch nll 1.871678, batch error rate 65.000000%
# At minibatch 5700, batch loss 4.423647, batch nll 1.190797, batch error rate 40.000000%
# At minibatch 5800, batch loss 4.292503, batch nll 1.095163, batch error rate 45.000000%
# At minibatch 5900, batch loss 4.712954, batch nll 1.551323, batch error rate 50.000000%
# At minibatch 6000, batch loss 4.712195, batch nll 1.586224, batch error rate 50.000000%
# After epoch 3: valid_err_rate: 44.680000% currently going to do 5 epochs
# After epoch 3: averaged train_err_rate: 46.962500% averaged train nll: 1.305980 averaged train loss: 4.813807
# At minibatch 6100, batch loss 4.314013, batch nll 1.222302, batch error rate 60.000000%
# At minibatch 6200, batch loss 4.079628, batch nll 1.022597, batch error rate 30.000000%
# At minibatch 6300, batch loss 4.516250, batch nll 1.493632, batch error rate 70.000000%
# At minibatch 6400, batch loss 4.041256, batch nll 1.051559, batch error rate 35.000000%
# At minibatch 6500, batch loss 4.214246, batch nll 1.257688, batch error rate 45.000000%
# At minibatch 6600, batch loss 4.424369, batch nll 1.500796, batch error rate 50.000000%
# At minibatch 6700, batch loss 3.940412, batch nll 1.049144, batch error rate 30.000000%
# At minibatch 6800, batch loss 3.939815, batch nll 1.080756, batch error rate 50.000000%
# At minibatch 6900, batch loss 4.102262, batch nll 1.274723, batch error rate 50.000000%
# At minibatch 7000, batch loss 4.127886, batch nll 1.331398, batch error rate 60.000000%
# At minibatch 7100, batch loss 3.963471, batch nll 1.198642, batch error rate 50.000000%
# At minibatch 7200, batch loss 4.080058, batch nll 1.345662, batch error rate 50.000000%
# At minibatch 7300, batch loss 4.193233, batch nll 1.488806, batch error rate 55.000000%
# At minibatch 7400, batch loss 3.888966, batch nll 1.214387, batch error rate 45.000000%
# At minibatch 7500, batch loss 3.742930, batch nll 1.097960, batch error rate 35.000000%
# At minibatch 7600, batch loss 3.981893, batch nll 1.365870, batch error rate 60.000000%
# At minibatch 7700, batch loss 4.001437, batch nll 1.412783, batch error rate 55.000000%
# At minibatch 7800, batch loss 3.474146, batch nll 0.914127, batch error rate 20.000000%
# At minibatch 7900, batch loss 4.333390, batch nll 1.801532, batch error rate 65.000000%
# At minibatch 8000, batch loss 3.731755, batch nll 1.227620, batch error rate 45.000000%
# After epoch 4: valid_err_rate: 42.840000% currently going to do 7 epochs
# After epoch 4: averaged train_err_rate: 43.457500% averaged train nll: 1.226308 averaged train loss: 4.028674
# At minibatch 8100, batch loss 4.457333, batch nll 1.979428, batch error rate 60.000000%
# At minibatch 8200, batch loss 3.416199, batch nll 0.965377, batch error rate 35.000000%
# At minibatch 8300, batch loss 3.927771, batch nll 1.503257, batch error rate 65.000000%
# At minibatch 8400, batch loss 3.752823, batch nll 1.354657, batch error rate 25.000000%
# At minibatch 8500, batch loss 3.370688, batch nll 0.997977, batch error rate 55.000000%
# At minibatch 8600, batch loss 3.607030, batch nll 1.260310, batch error rate 40.000000%
# At minibatch 8700, batch loss 3.572808, batch nll 1.251117, batch error rate 45.000000%
# At minibatch 8800, batch loss 3.264490, batch nll 0.968092, batch error rate 45.000000%
# At minibatch 8900, batch loss 3.408719, batch nll 1.137231, batch error rate 55.000000%
# At minibatch 9000, batch loss 3.289672, batch nll 1.042812, batch error rate 50.000000%
# At minibatch 9100, batch loss 3.268148, batch nll 1.045546, batch error rate 45.000000%
# At minibatch 9200, batch loss 3.512903, batch nll 1.313850, batch error rate 45.000000%
# At minibatch 9300, batch loss 3.286936, batch nll 1.111974, batch error rate 35.000000%
# At minibatch 9400, batch loss 3.255706, batch nll 1.103325, batch error rate 40.000000%
# At minibatch 9500, batch loss 3.203736, batch nll 1.074235, batch error rate 35.000000%
# At minibatch 9600, batch loss 3.030855, batch nll 0.924038, batch error rate 25.000000%
# At minibatch 9700, batch loss 3.190362, batch nll 1.106570, batch error rate 40.000000%
# At minibatch 9800, batch loss 3.290113, batch nll 1.229062, batch error rate 40.000000%
# At minibatch 9900, batch loss 2.824463, batch nll 0.784784, batch error rate 15.000000%
# At minibatch 10000, batch loss 3.419315, batch nll 1.400780, batch error rate 60.000000%
# After epoch 5: valid_err_rate: 40.830000% currently going to do 8 epochs
# After epoch 5: averaged train_err_rate: 41.230000% averaged train nll: 1.161476 averaged train loss: 3.413288
# At minibatch 10100, batch loss 2.853646, batch nll 0.856247, batch error rate 30.000000%
# At minibatch 10200, batch loss 2.802902, batch nll 0.826248, batch error rate 35.000000%
# At minibatch 10300, batch loss 3.017725, batch nll 1.060760, batch error rate 55.000000%
# At minibatch 10400, batch loss 2.595279, batch nll 0.658734, batch error rate 15.000000%
# At minibatch 10500, batch loss 3.096361, batch nll 1.180391, batch error rate 50.000000%
# At minibatch 10600, batch loss 2.790326, batch nll 0.894722, batch error rate 30.000000%
# At minibatch 10700, batch loss 3.351189, batch nll 1.474978, batch error rate 60.000000%
# At minibatch 10800, batch loss 3.074627, batch nll 1.218710, batch error rate 55.000000%
# At minibatch 10900, batch loss 2.984582, batch nll 1.147794, batch error rate 50.000000%
# At minibatch 11000, batch loss 2.732319, batch nll 0.914743, batch error rate 30.000000%
# At minibatch 11100, batch loss 2.660830, batch nll 0.861829, batch error rate 35.000000%
# At minibatch 11200, batch loss 3.266232, batch nll 1.486026, batch error rate 55.000000%
# At minibatch 11300, batch loss 2.797254, batch nll 1.036248, batch error rate 30.000000%
# At minibatch 11400, batch loss 2.587321, batch nll 0.844389, batch error rate 25.000000%
# At minibatch 11500, batch loss 2.922839, batch nll 1.197453, batch error rate 45.000000%
# At minibatch 11600, batch loss 3.026271, batch nll 1.319120, batch error rate 55.000000%
# At minibatch 11700, batch loss 2.689920, batch nll 1.000197, batch error rate 35.000000%
# At minibatch 11800, batch loss 2.831717, batch nll 1.159401, batch error rate 40.000000%
# At minibatch 11900, batch loss 2.715549, batch nll 1.060329, batch error rate 35.000000%
# At minibatch 12000, batch loss 2.913923, batch nll 1.275539, batch error rate 45.000000%
# After epoch 6: valid_err_rate: 37.830000% currently going to do 10 epochs
# After epoch 6: averaged train_err_rate: 39.212500% averaged train nll: 1.109408 averaged train loss: 2.930644
# At minibatch 12100, batch loss 2.812043, batch nll 1.189774, batch error rate 30.000000%
# At minibatch 12200, batch loss 2.611244, batch nll 1.004700, batch error rate 45.000000%
# At minibatch 12300, batch loss 2.663012, batch nll 1.073065, batch error rate 45.000000%
# At minibatch 12400, batch loss 2.668668, batch nll 1.094370, batch error rate 45.000000%
# At minibatch 12500, batch loss 2.544824, batch nll 0.986027, batch error rate 45.000000%
# At minibatch 12600, batch loss 2.741102, batch nll 1.198118, batch error rate 55.000000%
# At minibatch 12700, batch loss 2.489511, batch nll 0.961269, batch error rate 30.000000%
# At minibatch 12800, batch loss 2.478795, batch nll 0.966344, batch error rate 35.000000%
# At minibatch 12900, batch loss 2.152019, batch nll 0.654744, batch error rate 15.000000%
# At minibatch 13000, batch loss 2.864209, batch nll 1.382345, batch error rate 50.000000%
# At minibatch 13100, batch loss 2.284014, batch nll 0.817228, batch error rate 35.000000%
# At minibatch 13200, batch loss 2.547715, batch nll 1.095511, batch error rate 35.000000%
# At minibatch 13300, batch loss 2.719481, batch nll 1.281102, batch error rate 45.000000%
# At minibatch 13400, batch loss 2.093676, batch nll 0.669871, batch error rate 25.000000%
# At minibatch 13500, batch loss 2.928227, batch nll 1.518375, batch error rate 45.000000%
# At minibatch 13600, batch loss 2.426317, batch nll 1.030300, batch error rate 35.000000%
# At minibatch 13700, batch loss 2.327717, batch nll 0.946398, batch error rate 30.000000%
# At minibatch 13800, batch loss 2.782934, batch nll 1.414606, batch error rate 40.000000%
# At minibatch 13900, batch loss 2.081984, batch nll 0.727040, batch error rate 25.000000%
# At minibatch 14000, batch loss 2.160170, batch nll 0.818717, batch error rate 25.000000%
# After epoch 7: valid_err_rate: 38.180000% currently going to do 10 epochs
# After epoch 7: averaged train_err_rate: 37.922500% averaged train nll: 1.072187 averaged train loss: 2.556914
# At minibatch 14100, batch loss 2.735095, batch nll 1.406159, batch error rate 45.000000%
# At minibatch 14200, batch loss 2.740752, batch nll 1.424611, batch error rate 45.000000%
# At minibatch 14300, batch loss 2.705982, batch nll 1.403038, batch error rate 65.000000%
# At minibatch 14400, batch loss 2.334209, batch nll 1.042807, batch error rate 50.000000%
# At minibatch 14500, batch loss 2.618960, batch nll 1.339840, batch error rate 50.000000%
# At minibatch 14600, batch loss 1.975089, batch nll 0.708594, batch error rate 20.000000%
# At minibatch 14700, batch loss 2.236713, batch nll 0.982275, batch error rate 30.000000%
# At minibatch 14800, batch loss 2.327403, batch nll 1.084894, batch error rate 40.000000%
# At minibatch 14900, batch loss 2.109983, batch nll 0.878643, batch error rate 30.000000%
# At minibatch 15000, batch loss 2.342589, batch nll 1.122481, batch error rate 30.000000%
# At minibatch 15100, batch loss 1.898932, batch nll 0.690546, batch error rate 25.000000%
# At minibatch 15200, batch loss 2.269986, batch nll 1.072608, batch error rate 45.000000%
# At minibatch 15300, batch loss 2.028460, batch nll 0.843078, batch error rate 15.000000%
# At minibatch 15400, batch loss 2.186412, batch nll 1.012197, batch error rate 40.000000%
# At minibatch 15500, batch loss 1.849720, batch nll 0.686863, batch error rate 25.000000%
# At minibatch 15600, batch loss 2.505268, batch nll 1.352980, batch error rate 50.000000%
# At minibatch 15700, batch loss 1.783757, batch nll 0.642145, batch error rate 25.000000%
# At minibatch 15800, batch loss 2.349528, batch nll 1.218253, batch error rate 55.000000%
# At minibatch 15900, batch loss 2.040223, batch nll 0.919927, batch error rate 30.000000%
# At minibatch 16000, batch loss 1.827633, batch nll 0.717338, batch error rate 25.000000%
# After epoch 8: valid_err_rate: 40.470000% currently going to do 10 epochs
# After epoch 8: averaged train_err_rate: 36.625000% averaged train nll: 1.038937 averaged train loss: 2.260478
# At minibatch 16100, batch loss 2.138542, batch nll 1.037667, batch error rate 35.000000%
# At minibatch 16200, batch loss 1.732722, batch nll 0.641253, batch error rate 20.000000%
# At minibatch 16300, batch loss 2.297557, batch nll 1.216313, batch error rate 35.000000%
# At minibatch 16400, batch loss 2.147709, batch nll 1.076057, batch error rate 40.000000%
# At minibatch 16500, batch loss 1.813386, batch nll 0.751560, batch error rate 20.000000%
# At minibatch 16600, batch loss 1.913629, batch nll 0.861757, batch error rate 25.000000%
# At minibatch 16700, batch loss 2.207567, batch nll 1.165018, batch error rate 40.000000%
# At minibatch 16800, batch loss 2.247505, batch nll 1.213501, batch error rate 50.000000%
# At minibatch 16900, batch loss 2.359665, batch nll 1.334119, batch error rate 55.000000%
# At minibatch 17000, batch loss 2.021043, batch nll 1.005602, batch error rate 25.000000%
# At minibatch 17100, batch loss 2.233529, batch nll 1.227889, batch error rate 35.000000%
# At minibatch 17200, batch loss 2.379844, batch nll 1.382755, batch error rate 35.000000%
# At minibatch 17300, batch loss 2.048027, batch nll 1.059300, batch error rate 45.000000%
# At minibatch 17400, batch loss 2.587657, batch nll 1.607993, batch error rate 45.000000%
# At minibatch 17500, batch loss 1.953128, batch nll 0.982573, batch error rate 40.000000%
# At minibatch 17600, batch loss 1.817377, batch nll 0.855445, batch error rate 20.000000%
# At minibatch 17700, batch loss 1.928909, batch nll 0.975332, batch error rate 25.000000%
# At minibatch 17800, batch loss 2.140756, batch nll 1.195239, batch error rate 45.000000%
# At minibatch 17900, batch loss 2.006339, batch nll 1.069918, batch error rate 45.000000%
# At minibatch 18000, batch loss 2.021775, batch nll 1.093500, batch error rate 40.000000%
# After epoch 9: valid_err_rate: 38.600000% currently going to do 10 epochs
# After epoch 9: averaged train_err_rate: 35.770000% averaged train nll: 1.015433 averaged train loss: 2.032092
# At minibatch 18100, batch loss 1.828168, batch nll 0.906333, batch error rate 25.000000%
# At minibatch 18200, batch loss 1.771497, batch nll 0.857642, batch error rate 50.000000%
# At minibatch 18300, batch loss 1.752380, batch nll 0.845034, batch error rate 30.000000%
# At minibatch 18400, batch loss 1.982898, batch nll 1.083574, batch error rate 30.000000%
# At minibatch 18500, batch loss 1.719314, batch nll 0.827312, batch error rate 35.000000%
# At minibatch 18600, batch loss 1.861994, batch nll 0.977989, batch error rate 30.000000%
# At minibatch 18700, batch loss 1.778976, batch nll 0.901869, batch error rate 25.000000%
# At minibatch 18800, batch loss 1.544932, batch nll 0.675318, batch error rate 15.000000%
# At minibatch 18900, batch loss 2.333847, batch nll 1.470719, batch error rate 50.000000%
# At minibatch 19000, batch loss 1.872352, batch nll 1.017133, batch error rate 30.000000%
# At minibatch 19100, batch loss 1.833830, batch nll 0.985551, batch error rate 35.000000%
# At minibatch 19200, batch loss 1.758961, batch nll 0.916876, batch error rate 30.000000%
# At minibatch 19300, batch loss 1.699093, batch nll 0.864565, batch error rate 25.000000%
# At minibatch 19400, batch loss 1.533370, batch nll 0.705787, batch error rate 35.000000%
# At minibatch 19500, batch loss 1.929744, batch nll 1.109049, batch error rate 35.000000%
# At minibatch 19600, batch loss 1.724757, batch nll 0.911659, batch error rate 20.000000%
# At minibatch 19700, batch loss 2.302616, batch nll 1.495278, batch error rate 50.000000%
# At minibatch 19800, batch loss 1.533399, batch nll 0.732709, batch error rate 35.000000%
# At minibatch 19900, batch loss 1.540473, batch nll 0.745819, batch error rate 30.000000%
# At minibatch 20000, batch loss 2.094452, batch nll 1.307116, batch error rate 50.000000%
# After epoch 10: valid_err_rate: 35.320000% currently going to do 16 epochs
# After epoch 10: averaged train_err_rate: 34.715000% averaged train nll: 0.988835 averaged train loss: 1.845310
# At minibatch 20100, batch loss 2.056339, batch nll 1.274714, batch error rate 55.000000%
# At minibatch 20200, batch loss 2.193083, batch nll 1.416904, batch error rate 60.000000%
# At minibatch 20300, batch loss 1.476819, batch nll 0.706367, batch error rate 20.000000%
# At minibatch 20400, batch loss 1.597495, batch nll 0.832761, batch error rate 20.000000%
# At minibatch 20500, batch loss 1.721362, batch nll 0.962376, batch error rate 40.000000%
# At minibatch 20600, batch loss 1.444294, batch nll 0.689857, batch error rate 20.000000%
# At minibatch 20700, batch loss 1.505072, batch nll 0.756764, batch error rate 25.000000%
# At minibatch 20800, batch loss 1.374759, batch nll 0.631083, batch error rate 25.000000%
# At minibatch 20900, batch loss 1.597698, batch nll 0.859606, batch error rate 40.000000%
# At minibatch 21000, batch loss 1.744731, batch nll 1.011784, batch error rate 45.000000%
# At minibatch 21100, batch loss 1.587564, batch nll 0.860390, batch error rate 30.000000%
# At minibatch 21200, batch loss 1.709453, batch nll 0.987586, batch error rate 35.000000%
# At minibatch 21300, batch loss 1.652066, batch nll 0.935378, batch error rate 40.000000%
# At minibatch 21400, batch loss 1.930427, batch nll 1.218933, batch error rate 50.000000%
# At minibatch 21500, batch loss 1.755234, batch nll 1.048916, batch error rate 50.000000%
# At minibatch 21600, batch loss 1.651099, batch nll 0.949398, batch error rate 35.000000%
# At minibatch 21700, batch loss 1.932262, batch nll 1.235808, batch error rate 55.000000%
# At minibatch 21800, batch loss 1.605355, batch nll 0.913102, batch error rate 35.000000%
# At minibatch 21900, batch loss 1.574207, batch nll 0.886265, batch error rate 35.000000%
# At minibatch 22000, batch loss 1.715690, batch nll 1.032307, batch error rate 45.000000%
# After epoch 11: valid_err_rate: 34.530000% currently going to do 17 epochs
# After epoch 11: averaged train_err_rate: 33.957500% averaged train nll: 0.964770 averaged train loss: 1.698051
# At minibatch 22100, batch loss 1.702615, batch nll 1.022923, batch error rate 40.000000%
# At minibatch 22200, batch loss 1.824586, batch nll 1.149000, batch error rate 40.000000%
# At minibatch 22300, batch loss 1.524615, batch nll 0.853802, batch error rate 40.000000%
# At minibatch 22400, batch loss 1.199533, batch nll 0.532702, batch error rate 10.000000%
# At minibatch 22500, batch loss 1.190512, batch nll 0.527694, batch error rate 10.000000%
# At minibatch 22600, batch loss 1.441843, batch nll 0.782567, batch error rate 25.000000%
# At minibatch 22700, batch loss 1.468983, batch nll 0.813207, batch error rate 30.000000%
# At minibatch 22800, batch loss 1.511730, batch nll 0.860465, batch error rate 30.000000%
# At minibatch 22900, batch loss 1.569005, batch nll 0.921320, batch error rate 30.000000%
# At minibatch 23000, batch loss 1.716728, batch nll 1.073103, batch error rate 45.000000%
# At minibatch 23100, batch loss 1.520569, batch nll 0.880398, batch error rate 45.000000%
# At minibatch 23200, batch loss 1.727024, batch nll 1.090913, batch error rate 30.000000%
# At minibatch 23300, batch loss 1.427816, batch nll 0.795546, batch error rate 30.000000%
# At minibatch 23400, batch loss 1.747925, batch nll 1.119176, batch error rate 30.000000%
# At minibatch 23500, batch loss 1.418529, batch nll 0.793077, batch error rate 35.000000%
# At minibatch 23600, batch loss 1.343024, batch nll 0.721095, batch error rate 20.000000%
# At minibatch 23700, batch loss 1.087340, batch nll 0.468866, batch error rate 20.000000%
# At minibatch 23800, batch loss 1.509290, batch nll 0.894449, batch error rate 35.000000%
# At minibatch 23900, batch loss 1.866929, batch nll 1.255518, batch error rate 45.000000%
# At minibatch 24000, batch loss 1.449433, batch nll 0.841335, batch error rate 25.000000%
# After epoch 12: valid_err_rate: 33.780000% currently going to do 19 epochs
# After epoch 12: averaged train_err_rate: 32.965000% averaged train nll: 0.941700 averaged train loss: 1.586121
# At minibatch 24100, batch loss 1.470968, batch nll 0.865709, batch error rate 35.000000%
# At minibatch 24200, batch loss 1.658442, batch nll 1.056232, batch error rate 35.000000%
# At minibatch 24300, batch loss 1.684325, batch nll 1.085566, batch error rate 35.000000%
# At minibatch 24400, batch loss 1.497223, batch nll 0.900987, batch error rate 40.000000%
# At minibatch 24500, batch loss 1.295750, batch nll 0.703162, batch error rate 20.000000%
# At minibatch 24600, batch loss 1.940939, batch nll 1.350368, batch error rate 45.000000%
# At minibatch 24700, batch loss 1.490519, batch nll 0.902797, batch error rate 20.000000%
# At minibatch 24800, batch loss 1.228803, batch nll 0.643644, batch error rate 15.000000%
# At minibatch 24900, batch loss 1.597971, batch nll 1.015712, batch error rate 40.000000%
# At minibatch 25000, batch loss 1.370281, batch nll 0.790479, batch error rate 25.000000%
# At minibatch 25100, batch loss 1.905715, batch nll 1.330022, batch error rate 50.000000%
# At minibatch 25200, batch loss 1.424124, batch nll 0.851052, batch error rate 30.000000%
# At minibatch 25300, batch loss 1.469182, batch nll 0.898781, batch error rate 35.000000%
# At minibatch 25400, batch loss 1.916405, batch nll 1.348318, batch error rate 40.000000%
# At minibatch 25500, batch loss 1.339328, batch nll 0.774065, batch error rate 25.000000%
# At minibatch 25600, batch loss 1.491180, batch nll 0.928966, batch error rate 30.000000%
# At minibatch 25700, batch loss 1.584686, batch nll 1.024855, batch error rate 35.000000%
# At minibatch 25800, batch loss 1.627590, batch nll 1.070744, batch error rate 40.000000%
# At minibatch 25900, batch loss 1.354952, batch nll 0.801019, batch error rate 30.000000%
# At minibatch 26000, batch loss 1.475428, batch nll 0.924623, batch error rate 25.000000%
# After epoch 13: valid_err_rate: 34.720000% currently going to do 19 epochs
# After epoch 13: averaged train_err_rate: 32.442500% averaged train nll: 0.921850 averaged train loss: 1.501109
# At minibatch 26100, batch loss 1.407107, batch nll 0.858240, batch error rate 25.000000%
# At minibatch 26200, batch loss 1.644241, batch nll 1.097486, batch error rate 45.000000%
# At minibatch 26300, batch loss 1.781688, batch nll 1.236682, batch error rate 50.000000%
# At minibatch 26400, batch loss 1.865568, batch nll 1.322703, batch error rate 55.000000%
# At minibatch 26500, batch loss 1.384214, batch nll 0.843837, batch error rate 30.000000%
# At minibatch 26600, batch loss 1.469338, batch nll 0.930771, batch error rate 35.000000%
# At minibatch 26700, batch loss 1.366131, batch nll 0.830031, batch error rate 30.000000%
# At minibatch 26800, batch loss 1.403702, batch nll 0.870256, batch error rate 25.000000%
# At minibatch 26900, batch loss 1.876312, batch nll 1.344716, batch error rate 45.000000%
# At minibatch 27000, batch loss 1.232573, batch nll 0.703251, batch error rate 30.000000%
# At minibatch 27100, batch loss 1.409478, batch nll 0.882192, batch error rate 20.000000%
# At minibatch 27200, batch loss 2.024764, batch nll 1.499849, batch error rate 50.000000%
# At minibatch 27300, batch loss 1.429193, batch nll 0.906279, batch error rate 15.000000%
# At minibatch 27400, batch loss 1.158576, batch nll 0.637456, batch error rate 25.000000%
# At minibatch 27500, batch loss 1.238008, batch nll 0.718157, batch error rate 20.000000%
# At minibatch 27600, batch loss 1.538059, batch nll 1.020230, batch error rate 40.000000%
# At minibatch 27700, batch loss 1.499569, batch nll 0.983493, batch error rate 35.000000%
# At minibatch 27800, batch loss 1.169234, batch nll 0.655232, batch error rate 30.000000%
# At minibatch 27900, batch loss 1.758688, batch nll 1.247211, batch error rate 35.000000%
# At minibatch 28000, batch loss 1.514197, batch nll 1.004896, batch error rate 25.000000%
# After epoch 14: valid_err_rate: 33.200000% currently going to do 22 epochs
# After epoch 14: averaged train_err_rate: 31.367500% averaged train nll: 0.896151 averaged train loss: 1.426062
# At minibatch 28100, batch loss 1.702325, batch nll 1.194581, batch error rate 40.000000%
# At minibatch 28200, batch loss 1.384721, batch nll 0.878569, batch error rate 25.000000%
# At minibatch 28300, batch loss 1.153203, batch nll 0.648620, batch error rate 15.000000%
# At minibatch 28400, batch loss 1.100330, batch nll 0.597407, batch error rate 30.000000%
# At minibatch 28500, batch loss 1.615291, batch nll 1.113872, batch error rate 30.000000%
# At minibatch 28600, batch loss 1.369971, batch nll 0.870284, batch error rate 25.000000%
# At minibatch 28700, batch loss 1.451763, batch nll 0.954004, batch error rate 35.000000%
# At minibatch 28800, batch loss 1.013507, batch nll 0.517404, batch error rate 20.000000%
# At minibatch 28900, batch loss 1.716928, batch nll 1.222685, batch error rate 45.000000%
# At minibatch 29000, batch loss 1.343145, batch nll 0.851323, batch error rate 40.000000%
# At minibatch 29100, batch loss 1.351919, batch nll 0.861866, batch error rate 35.000000%
# At minibatch 29200, batch loss 1.825924, batch nll 1.336849, batch error rate 40.000000%
# At minibatch 29300, batch loss 1.207498, batch nll 0.719932, batch error rate 20.000000%
# At minibatch 29400, batch loss 1.257229, batch nll 0.771157, batch error rate 30.000000%
# At minibatch 29500, batch loss 1.270909, batch nll 0.786354, batch error rate 35.000000%
# At minibatch 29600, batch loss 1.643684, batch nll 1.161331, batch error rate 40.000000%
# At minibatch 29700, batch loss 1.245708, batch nll 0.765066, batch error rate 35.000000%
# At minibatch 29800, batch loss 1.251786, batch nll 0.772527, batch error rate 20.000000%
# At minibatch 29900, batch loss 1.382001, batch nll 0.904278, batch error rate 35.000000%
# At minibatch 30000, batch loss 0.844065, batch nll 0.367879, batch error rate 5.000000%
# After epoch 15: valid_err_rate: 31.930000% currently going to do 23 epochs
# After epoch 15: averaged train_err_rate: 30.695000% averaged train nll: 0.878962 averaged train loss: 1.371567
# At minibatch 30100, batch loss 1.142622, batch nll 0.667600, batch error rate 25.000000%
# At minibatch 30200, batch loss 1.365632, batch nll 0.891997, batch error rate 25.000000%
# At minibatch 30300, batch loss 1.158118, batch nll 0.685878, batch error rate 30.000000%
# At minibatch 30400, batch loss 1.297937, batch nll 0.827431, batch error rate 35.000000%
# At minibatch 30500, batch loss 1.709263, batch nll 1.239740, batch error rate 45.000000%
# At minibatch 30600, batch loss 1.360360, batch nll 0.891608, batch error rate 35.000000%
# At minibatch 30700, batch loss 1.189151, batch nll 0.721902, batch error rate 25.000000%
# At minibatch 30800, batch loss 1.321856, batch nll 0.856060, batch error rate 25.000000%
# At minibatch 30900, batch loss 1.250519, batch nll 0.785608, batch error rate 25.000000%
# At minibatch 31000, batch loss 1.318910, batch nll 0.855196, batch error rate 25.000000%
# At minibatch 31100, batch loss 1.351739, batch nll 0.889891, batch error rate 45.000000%
# At minibatch 31200, batch loss 1.430013, batch nll 0.969843, batch error rate 25.000000%
# At minibatch 31300, batch loss 1.295432, batch nll 0.836610, batch error rate 30.000000%
# At minibatch 31400, batch loss 1.175676, batch nll 0.718061, batch error rate 15.000000%
# At minibatch 31500, batch loss 1.169881, batch nll 0.713203, batch error rate 30.000000%
# At minibatch 31600, batch loss 1.594760, batch nll 1.139564, batch error rate 45.000000%
# At minibatch 31700, batch loss 1.482682, batch nll 1.028540, batch error rate 40.000000%
# At minibatch 31800, batch loss 0.890359, batch nll 0.437205, batch error rate 5.000000%
# At minibatch 31900, batch loss 1.126459, batch nll 0.674458, batch error rate 20.000000%
# At minibatch 32000, batch loss 1.867026, batch nll 1.416477, batch error rate 50.000000%
# After epoch 16: valid_err_rate: 32.520000% currently going to do 23 epochs
# After epoch 16: averaged train_err_rate: 30.105000% averaged train nll: 0.866774 averaged train loss: 1.330035
# At minibatch 32100, batch loss 1.584351, batch nll 1.134701, batch error rate 40.000000%
# At minibatch 32200, batch loss 1.629843, batch nll 1.181087, batch error rate 40.000000%
# At minibatch 32300, batch loss 1.349862, batch nll 0.902616, batch error rate 35.000000%
# At minibatch 32400, batch loss 0.936460, batch nll 0.489970, batch error rate 15.000000%
# At minibatch 32500, batch loss 1.730067, batch nll 1.284405, batch error rate 55.000000%
# At minibatch 32600, batch loss 1.320615, batch nll 0.875851, batch error rate 20.000000%
# At minibatch 32700, batch loss 1.418003, batch nll 0.974147, batch error rate 30.000000%
# At minibatch 32800, batch loss 1.406147, batch nll 0.963475, batch error rate 30.000000%
# At minibatch 32900, batch loss 1.150698, batch nll 0.709305, batch error rate 30.000000%
# At minibatch 33000, batch loss 1.527963, batch nll 1.087456, batch error rate 40.000000%
# At minibatch 33100, batch loss 1.369043, batch nll 0.929524, batch error rate 35.000000%
# At minibatch 33200, batch loss 1.142201, batch nll 0.704014, batch error rate 20.000000%
# At minibatch 33300, batch loss 1.284419, batch nll 0.846659, batch error rate 25.000000%
# At minibatch 33400, batch loss 1.311560, batch nll 0.874400, batch error rate 25.000000%
# At minibatch 33500, batch loss 1.636754, batch nll 1.200753, batch error rate 40.000000%
# At minibatch 33600, batch loss 1.127977, batch nll 0.692989, batch error rate 15.000000%
# At minibatch 33700, batch loss 1.705855, batch nll 1.272162, batch error rate 45.000000%
# At minibatch 33800, batch loss 0.940577, batch nll 0.507856, batch error rate 15.000000%
# At minibatch 33900, batch loss 1.265339, batch nll 0.833857, batch error rate 35.000000%
# At minibatch 34000, batch loss 0.957202, batch nll 0.526660, batch error rate 15.000000%
# After epoch 17: valid_err_rate: 31.080000% currently going to do 26 epochs
# After epoch 17: averaged train_err_rate: 29.700000% averaged train nll: 0.852008 averaged train loss: 1.292640
# At minibatch 34100, batch loss 1.069322, batch nll 0.639513, batch error rate 20.000000%
# At minibatch 34200, batch loss 1.354099, batch nll 0.924895, batch error rate 35.000000%
# At minibatch 34300, batch loss 1.315911, batch nll 0.887418, batch error rate 25.000000%
# At minibatch 34400, batch loss 1.554319, batch nll 1.126554, batch error rate 30.000000%
# At minibatch 34500, batch loss 1.350804, batch nll 0.923912, batch error rate 30.000000%
# At minibatch 34600, batch loss 1.318848, batch nll 0.892609, batch error rate 40.000000%
# At minibatch 34700, batch loss 1.491063, batch nll 1.065617, batch error rate 50.000000%
# At minibatch 34800, batch loss 1.395877, batch nll 0.971056, batch error rate 35.000000%
# At minibatch 34900, batch loss 0.842424, batch nll 0.418936, batch error rate 10.000000%
# At minibatch 35000, batch loss 1.512269, batch nll 1.089606, batch error rate 35.000000%
# At minibatch 35100, batch loss 1.132490, batch nll 0.710525, batch error rate 20.000000%
# At minibatch 35200, batch loss 1.275648, batch nll 0.854589, batch error rate 40.000000%
# At minibatch 35300, batch loss 1.376668, batch nll 0.956790, batch error rate 35.000000%
# At minibatch 35400, batch loss 1.535398, batch nll 1.116189, batch error rate 35.000000%
# At minibatch 35500, batch loss 0.993699, batch nll 0.575055, batch error rate 25.000000%
# At minibatch 35600, batch loss 1.078014, batch nll 0.660541, batch error rate 25.000000%
# At minibatch 35700, batch loss 1.561092, batch nll 1.144436, batch error rate 40.000000%
# At minibatch 35800, batch loss 1.205290, batch nll 0.789405, batch error rate 30.000000%
# At minibatch 35900, batch loss 1.666286, batch nll 1.251381, batch error rate 40.000000%
# At minibatch 36000, batch loss 0.921214, batch nll 0.506872, batch error rate 10.000000%
# After epoch 18: valid_err_rate: 30.700000% currently going to do 28 epochs
# After epoch 18: averaged train_err_rate: 29.100000% averaged train nll: 0.837890 averaged train loss: 1.260503
# At minibatch 36100, batch loss 1.297865, batch nll 0.884060, batch error rate 25.000000%
# At minibatch 36200, batch loss 1.080403, batch nll 0.666759, batch error rate 10.000000%
# At minibatch 36300, batch loss 1.258765, batch nll 0.845942, batch error rate 40.000000%
# At minibatch 36400, batch loss 1.071823, batch nll 0.660205, batch error rate 20.000000%
# At minibatch 36500, batch loss 1.261112, batch nll 0.850079, batch error rate 35.000000%
# At minibatch 36600, batch loss 1.445676, batch nll 1.034621, batch error rate 20.000000%
# At minibatch 36700, batch loss 1.288313, batch nll 0.877907, batch error rate 30.000000%
# At minibatch 36800, batch loss 1.148269, batch nll 0.739069, batch error rate 30.000000%
# At minibatch 36900, batch loss 1.274025, batch nll 0.865569, batch error rate 35.000000%
# At minibatch 37000, batch loss 1.606933, batch nll 1.199082, batch error rate 35.000000%
# At minibatch 37100, batch loss 1.180532, batch nll 0.773317, batch error rate 35.000000%
# At minibatch 37200, batch loss 1.325697, batch nll 0.919226, batch error rate 35.000000%
# At minibatch 37300, batch loss 0.888046, batch nll 0.482212, batch error rate 20.000000%
# At minibatch 37400, batch loss 1.098737, batch nll 0.694018, batch error rate 20.000000%
# At minibatch 37500, batch loss 1.256103, batch nll 0.852140, batch error rate 25.000000%
# At minibatch 37600, batch loss 1.074367, batch nll 0.671039, batch error rate 25.000000%
# At minibatch 37700, batch loss 1.276893, batch nll 0.874124, batch error rate 35.000000%
# At minibatch 37800, batch loss 1.201392, batch nll 0.799039, batch error rate 35.000000%
# At minibatch 37900, batch loss 1.396650, batch nll 0.995221, batch error rate 35.000000%
# At minibatch 38000, batch loss 1.052756, batch nll 0.651887, batch error rate 25.000000%
# After epoch 19: valid_err_rate: 29.920000% currently going to do 29 epochs
# After epoch 19: averaged train_err_rate: 28.692500% averaged train nll: 0.824402 averaged train loss: 1.232171
# At minibatch 38100, batch loss 1.193516, batch nll 0.792928, batch error rate 30.000000%
# At minibatch 38200, batch loss 1.357859, batch nll 0.957528, batch error rate 30.000000%
# At minibatch 38300, batch loss 1.163726, batch nll 0.763756, batch error rate 25.000000%
# At minibatch 38400, batch loss 1.053043, batch nll 0.653948, batch error rate 15.000000%
# At minibatch 38500, batch loss 1.328295, batch nll 0.929644, batch error rate 30.000000%
# At minibatch 38600, batch loss 1.410954, batch nll 1.012998, batch error rate 15.000000%
# At minibatch 38700, batch loss 0.900403, batch nll 0.503163, batch error rate 5.000000%
# At minibatch 38800, batch loss 1.198788, batch nll 0.802248, batch error rate 20.000000%
# At minibatch 38900, batch loss 1.040853, batch nll 0.644584, batch error rate 20.000000%
# At minibatch 39000, batch loss 1.844160, batch nll 1.448092, batch error rate 60.000000%
# At minibatch 39100, batch loss 1.341746, batch nll 0.946483, batch error rate 35.000000%
# At minibatch 39200, batch loss 1.023991, batch nll 0.629402, batch error rate 15.000000%
# At minibatch 39300, batch loss 1.295182, batch nll 0.900723, batch error rate 25.000000%
# At minibatch 39400, batch loss 1.180034, batch nll 0.786257, batch error rate 30.000000%
# At minibatch 39500, batch loss 1.847760, batch nll 1.454745, batch error rate 50.000000%
# At minibatch 39600, batch loss 1.067295, batch nll 0.675658, batch error rate 25.000000%
# At minibatch 39700, batch loss 0.978407, batch nll 0.586600, batch error rate 25.000000%
# At minibatch 39800, batch loss 1.081409, batch nll 0.689901, batch error rate 20.000000%
# At minibatch 39900, batch loss 1.333873, batch nll 0.943335, batch error rate 35.000000%
# At minibatch 40000, batch loss 1.082072, batch nll 0.692336, batch error rate 25.000000%
# After epoch 20: valid_err_rate: 30.210000% currently going to do 29 epochs
# After epoch 20: averaged train_err_rate: 28.227500% averaged train nll: 0.817069 averaged train loss: 1.212794
# At minibatch 40100, batch loss 1.391549, batch nll 1.002000, batch error rate 45.000000%
# At minibatch 40200, batch loss 1.103503, batch nll 0.714040, batch error rate 35.000000%
# At minibatch 40300, batch loss 0.936170, batch nll 0.546728, batch error rate 15.000000%
# At minibatch 40400, batch loss 1.251045, batch nll 0.862198, batch error rate 20.000000%
# At minibatch 40500, batch loss 1.316463, batch nll 0.928214, batch error rate 35.000000%
# At minibatch 40600, batch loss 1.131763, batch nll 0.743952, batch error rate 30.000000%
# At minibatch 40700, batch loss 1.294257, batch nll 0.907008, batch error rate 35.000000%
# At minibatch 40800, batch loss 1.482478, batch nll 1.095929, batch error rate 30.000000%
# At minibatch 40900, batch loss 1.115660, batch nll 0.729570, batch error rate 25.000000%
# At minibatch 41000, batch loss 1.026131, batch nll 0.640370, batch error rate 20.000000%
# At minibatch 41100, batch loss 1.205742, batch nll 0.820181, batch error rate 40.000000%
# At minibatch 41200, batch loss 1.230854, batch nll 0.845580, batch error rate 30.000000%
# At minibatch 41300, batch loss 1.416391, batch nll 1.031558, batch error rate 50.000000%
# At minibatch 41400, batch loss 1.161510, batch nll 0.777230, batch error rate 25.000000%
# At minibatch 41500, batch loss 1.566892, batch nll 1.183192, batch error rate 30.000000%
# At minibatch 41600, batch loss 1.262551, batch nll 0.879390, batch error rate 40.000000%
# At minibatch 41700, batch loss 1.452590, batch nll 1.070053, batch error rate 35.000000%
# At minibatch 41800, batch loss 1.081252, batch nll 0.699178, batch error rate 30.000000%
# At minibatch 41900, batch loss 1.536811, batch nll 1.155778, batch error rate 45.000000%
# At minibatch 42000, batch loss 1.279416, batch nll 0.898518, batch error rate 40.000000%
# After epoch 21: valid_err_rate: 31.140000% currently going to do 29 epochs
# After epoch 21: averaged train_err_rate: 28.047500% averaged train nll: 0.807137 averaged train loss: 1.192993
# At minibatch 42100, batch loss 1.087647, batch nll 0.706950, batch error rate 25.000000%
# At minibatch 42200, batch loss 1.282430, batch nll 0.902146, batch error rate 40.000000%
# At minibatch 42300, batch loss 0.934584, batch nll 0.555069, batch error rate 20.000000%
# At minibatch 42400, batch loss 1.440841, batch nll 1.061331, batch error rate 30.000000%
# At minibatch 42500, batch loss 1.639470, batch nll 1.259999, batch error rate 45.000000%
# At minibatch 42600, batch loss 1.061266, batch nll 0.682166, batch error rate 30.000000%
# At minibatch 42700, batch loss 1.067402, batch nll 0.688696, batch error rate 20.000000%
# At minibatch 42800, batch loss 1.594476, batch nll 1.216136, batch error rate 30.000000%
# At minibatch 42900, batch loss 0.761445, batch nll 0.383495, batch error rate 5.000000%
# At minibatch 43000, batch loss 0.976071, batch nll 0.598556, batch error rate 35.000000%
# At minibatch 43100, batch loss 1.044411, batch nll 0.666938, batch error rate 25.000000%
# At minibatch 43200, batch loss 1.548944, batch nll 1.172204, batch error rate 30.000000%
# At minibatch 43300, batch loss 1.450916, batch nll 1.074523, batch error rate 45.000000%
# At minibatch 43400, batch loss 1.807123, batch nll 1.431049, batch error rate 40.000000%
# At minibatch 43500, batch loss 1.272597, batch nll 0.896906, batch error rate 35.000000%
# At minibatch 43600, batch loss 1.337279, batch nll 0.962089, batch error rate 35.000000%
# At minibatch 43700, batch loss 1.276519, batch nll 0.902163, batch error rate 30.000000%
# At minibatch 43800, batch loss 1.026267, batch nll 0.652285, batch error rate 20.000000%
# At minibatch 43900, batch loss 1.052062, batch nll 0.678359, batch error rate 25.000000%
# At minibatch 44000, batch loss 1.288625, batch nll 0.915037, batch error rate 30.000000%
# After epoch 22: valid_err_rate: 30.440000% currently going to do 29 epochs
# After epoch 22: averaged train_err_rate: 27.847500% averaged train nll: 0.797543 averaged train loss: 1.174948
# At minibatch 44100, batch loss 1.257980, batch nll 0.884219, batch error rate 20.000000%
# At minibatch 44200, batch loss 1.066850, batch nll 0.693388, batch error rate 25.000000%
# At minibatch 44300, batch loss 1.114171, batch nll 0.741015, batch error rate 30.000000%
# At minibatch 44400, batch loss 1.167915, batch nll 0.794957, batch error rate 25.000000%
# At minibatch 44500, batch loss 1.216118, batch nll 0.843284, batch error rate 30.000000%
# At minibatch 44600, batch loss 1.884024, batch nll 1.511530, batch error rate 50.000000%
# At minibatch 44700, batch loss 1.142642, batch nll 0.771006, batch error rate 35.000000%
# At minibatch 44800, batch loss 0.911994, batch nll 0.541014, batch error rate 20.000000%
# At minibatch 44900, batch loss 1.155149, batch nll 0.784569, batch error rate 25.000000%
# At minibatch 45000, batch loss 0.798611, batch nll 0.428142, batch error rate 10.000000%
# At minibatch 45100, batch loss 1.086106, batch nll 0.715927, batch error rate 35.000000%
# At minibatch 45200, batch loss 1.018362, batch nll 0.648534, batch error rate 30.000000%
# At minibatch 45300, batch loss 1.152399, batch nll 0.782629, batch error rate 20.000000%
# At minibatch 45400, batch loss 0.647584, batch nll 0.277852, batch error rate 5.000000%
# At minibatch 45500, batch loss 1.262234, batch nll 0.893083, batch error rate 40.000000%
# At minibatch 45600, batch loss 1.019785, batch nll 0.650869, batch error rate 25.000000%
# At minibatch 45700, batch loss 0.993069, batch nll 0.624410, batch error rate 20.000000%
# At minibatch 45800, batch loss 1.047512, batch nll 0.679230, batch error rate 15.000000%
# At minibatch 45900, batch loss 1.117804, batch nll 0.749996, batch error rate 35.000000%
# At minibatch 46000, batch loss 1.068521, batch nll 0.700865, batch error rate 25.000000%
# After epoch 23: valid_err_rate: 31.020000% currently going to do 29 epochs
# After epoch 23: averaged train_err_rate: 27.385000% averaged train nll: 0.788986 averaged train loss: 1.159735
# At minibatch 46100, batch loss 1.229296, batch nll 0.861978, batch error rate 45.000000%
# At minibatch 46200, batch loss 0.957883, batch nll 0.590738, batch error rate 30.000000%
# At minibatch 46300, batch loss 1.313108, batch nll 0.946028, batch error rate 30.000000%
# At minibatch 46400, batch loss 1.033539, batch nll 0.666669, batch error rate 25.000000%
# At minibatch 46500, batch loss 0.738207, batch nll 0.371391, batch error rate 15.000000%
# At minibatch 46600, batch loss 1.374244, batch nll 1.007706, batch error rate 30.000000%
# At minibatch 46700, batch loss 1.145946, batch nll 0.779480, batch error rate 30.000000%
# At minibatch 46800, batch loss 1.161720, batch nll 0.795579, batch error rate 35.000000%
# At minibatch 46900, batch loss 1.252845, batch nll 0.887108, batch error rate 35.000000%
# At minibatch 47000, batch loss 1.088164, batch nll 0.722668, batch error rate 20.000000%
# At minibatch 47100, batch loss 1.151051, batch nll 0.785734, batch error rate 20.000000%
# At minibatch 47200, batch loss 0.976411, batch nll 0.611715, batch error rate 20.000000%
# At minibatch 47300, batch loss 1.523509, batch nll 1.159433, batch error rate 40.000000%
# At minibatch 47400, batch loss 0.930534, batch nll 0.566601, batch error rate 25.000000%
# At minibatch 47500, batch loss 1.004725, batch nll 0.641203, batch error rate 25.000000%
# At minibatch 47600, batch loss 0.979555, batch nll 0.616463, batch error rate 25.000000%
# At minibatch 47700, batch loss 0.624203, batch nll 0.261727, batch error rate 5.000000%
# At minibatch 47800, batch loss 1.336474, batch nll 0.974164, batch error rate 35.000000%
# At minibatch 47900, batch loss 1.054070, batch nll 0.692163, batch error rate 25.000000%
# At minibatch 48000, batch loss 1.317156, batch nll 0.955730, batch error rate 35.000000%
# After epoch 24: valid_err_rate: 29.610000% currently going to do 37 epochs
# After epoch 24: averaged train_err_rate: 27.220000% averaged train nll: 0.781246 averaged train loss: 1.146325
# At minibatch 48100, batch loss 1.458634, batch nll 1.096827, batch error rate 45.000000%
# At minibatch 48200, batch loss 1.123733, batch nll 0.761972, batch error rate 15.000000%
# At minibatch 48300, batch loss 0.742064, batch nll 0.380315, batch error rate 15.000000%
# At minibatch 48400, batch loss 1.072514, batch nll 0.711083, batch error rate 35.000000%
# At minibatch 48500, batch loss 1.373104, batch nll 1.012066, batch error rate 25.000000%
# At minibatch 48600, batch loss 1.343294, batch nll 0.982557, batch error rate 25.000000%
# At minibatch 48700, batch loss 0.655282, batch nll 0.295012, batch error rate 0.000000%
# At minibatch 48800, batch loss 1.110188, batch nll 0.750179, batch error rate 30.000000%
# At minibatch 48900, batch loss 1.290905, batch nll 0.931124, batch error rate 40.000000%
# At minibatch 49000, batch loss 1.149308, batch nll 0.789684, batch error rate 25.000000%
# ...
# At minibatch 424100, batch loss 0.986095, batch nll 0.614555, batch error rate 15.000000%
# At minibatch 424200, batch loss 0.887278, batch nll 0.515789, batch error rate 20.000000%
# At minibatch 424300, batch loss 1.040009, batch nll 0.668494, batch error rate 20.000000%
# At minibatch 424400, batch loss 0.962612, batch nll 0.591097, batch error rate 25.000000%
# At minibatch 424500, batch loss 0.899483, batch nll 0.527962, batch error rate 15.000000%
# At minibatch 424600, batch loss 0.870082, batch nll 0.498572, batch error rate 10.000000%
# At minibatch 424700, batch loss 0.746171, batch nll 0.374675, batch error rate 15.000000%
# At minibatch 424800, batch loss 1.028496, batch nll 0.656978, batch error rate 20.000000%
# At minibatch 424900, batch loss 0.764187, batch nll 0.392637, batch error rate 5.000000%
# At minibatch 425000, batch loss 1.042325, batch nll 0.670775, batch error rate 30.000000%
# At minibatch 425100, batch loss 0.773747, batch nll 0.402189, batch error rate 5.000000%
# At minibatch 425200, batch loss 1.044020, batch nll 0.672430, batch error rate 25.000000%
# At minibatch 425300, batch loss 1.095044, batch nll 0.723471, batch error rate 25.000000%
# At minibatch 425400, batch loss 0.898557, batch nll 0.526985, batch error rate 10.000000%
# At minibatch 425500, batch loss 0.990963, batch nll 0.619361, batch error rate 25.000000%
# At minibatch 425600, batch loss 1.035618, batch nll 0.664040, batch error rate 20.000000%
# At minibatch 425700, batch loss 0.963369, batch nll 0.591793, batch error rate 25.000000%
# At minibatch 425800, batch loss 1.024756, batch nll 0.653156, batch error rate 25.000000%
# At minibatch 425900, batch loss 1.033411, batch nll 0.661817, batch error rate 20.000000%
# At minibatch 426000, batch loss 0.912999, batch nll 0.541388, batch error rate 25.000000%
# After epoch 213: valid_err_rate: 26.190000% currently going to do 220 epochs
# After epoch 213: averaged train_err_rate: 18.802500% averaged train nll: 0.551736 averaged train loss: 0.923287
# At minibatch 426100, batch loss 0.590333, batch nll 0.218730, batch error rate 5.000000%
# At minibatch 426200, batch loss 1.114305, batch nll 0.742734, batch error rate 35.000000%
# At minibatch 426300, batch loss 1.104992, batch nll 0.733401, batch error rate 35.000000%
# At minibatch 426400, batch loss 0.992618, batch nll 0.621038, batch error rate 15.000000%
# At minibatch 426500, batch loss 0.886904, batch nll 0.515300, batch error rate 20.000000%
# At minibatch 426600, batch loss 1.106044, batch nll 0.734433, batch error rate 25.000000%
# At minibatch 426700, batch loss 0.914016, batch nll 0.542376, batch error rate 15.000000%
# At minibatch 426800, batch loss 0.853513, batch nll 0.481846, batch error rate 20.000000%
# At minibatch 426900, batch loss 0.667817, batch nll 0.296169, batch error rate 5.000000%
# At minibatch 427000, batch loss 0.817488, batch nll 0.445816, batch error rate 10.000000%
# At minibatch 427100, batch loss 0.895662, batch nll 0.523987, batch error rate 20.000000%
# At minibatch 427200, batch loss 0.801535, batch nll 0.429858, batch error rate 15.000000%
# At minibatch 427300, batch loss 0.770446, batch nll 0.398761, batch error rate 15.000000%
# At minibatch 427400, batch loss 1.101228, batch nll 0.729504, batch error rate 25.000000%
# At minibatch 427500, batch loss 0.779765, batch nll 0.408024, batch error rate 10.000000%
# At minibatch 427600, batch loss 1.131505, batch nll 0.759786, batch error rate 15.000000%
# At minibatch 427700, batch loss 1.010909, batch nll 0.639184, batch error rate 15.000000%
# At minibatch 427800, batch loss 1.081944, batch nll 0.710240, batch error rate 20.000000%
# At minibatch 427900, batch loss 0.863916, batch nll 0.492170, batch error rate 20.000000%
# At minibatch 428000, batch loss 1.111677, batch nll 0.739926, batch error rate 25.000000%
# After epoch 214: valid_err_rate: 26.190000% currently going to do 220 epochs
# After epoch 214: averaged train_err_rate: 18.725000% averaged train nll: 0.551180 averaged train loss: 0.922844
# At minibatch 428100, batch loss 0.778798, batch nll 0.407027, batch error rate 15.000000%
# At minibatch 428200, batch loss 0.641926, batch nll 0.270150, batch error rate 5.000000%
# At minibatch 428300, batch loss 0.903275, batch nll 0.531491, batch error rate 30.000000%
# At minibatch 428400, batch loss 0.683944, batch nll 0.312154, batch error rate 10.000000%
# At minibatch 428500, batch loss 0.706354, batch nll 0.334567, batch error rate 10.000000%
# At minibatch 428600, batch loss 0.863463, batch nll 0.491659, batch error rate 15.000000%
# At minibatch 428700, batch loss 0.919894, batch nll 0.548080, batch error rate 20.000000%
# At minibatch 428800, batch loss 1.183479, batch nll 0.811698, batch error rate 25.000000%
# At minibatch 428900, batch loss 1.110789, batch nll 0.738953, batch error rate 25.000000%
# At minibatch 429000, batch loss 0.723238, batch nll 0.351382, batch error rate 5.000000%
# At minibatch 429100, batch loss 0.756303, batch nll 0.384457, batch error rate 10.000000%
# At minibatch 429200, batch loss 0.997302, batch nll 0.625495, batch error rate 15.000000%
# At minibatch 429300, batch loss 0.679815, batch nll 0.307977, batch error rate 5.000000%
# At minibatch 429400, batch loss 0.856278, batch nll 0.484416, batch error rate 15.000000%
# At minibatch 429500, batch loss 0.907117, batch nll 0.535263, batch error rate 25.000000%
# At minibatch 429600, batch loss 1.220809, batch nll 0.848978, batch error rate 35.000000%
# At minibatch 429700, batch loss 0.903852, batch nll 0.532013, batch error rate 20.000000%
# At minibatch 429800, batch loss 0.692100, batch nll 0.320272, batch error rate 10.000000%
# At minibatch 429900, batch loss 0.939192, batch nll 0.567390, batch error rate 20.000000%
# At minibatch 430000, batch loss 0.759179, batch nll 0.387302, batch error rate 20.000000%
# After epoch 215: valid_err_rate: 26.270000% currently going to do 220 epochs
# After epoch 215: averaged train_err_rate: 18.812500% averaged train nll: 0.549817 averaged train loss: 0.921638
# At minibatch 430100, batch loss 0.954562, batch nll 0.582672, batch error rate 20.000000%
# At minibatch 430200, batch loss 1.087894, batch nll 0.715998, batch error rate 35.000000%
# At minibatch 430300, batch loss 0.833655, batch nll 0.461793, batch error rate 15.000000%
# At minibatch 430400, batch loss 0.887784, batch nll 0.515864, batch error rate 25.000000%
# At minibatch 430500, batch loss 0.876252, batch nll 0.504368, batch error rate 20.000000%
# At minibatch 430600, batch loss 0.903992, batch nll 0.532077, batch error rate 15.000000%
# At minibatch 430700, batch loss 0.885724, batch nll 0.513865, batch error rate 25.000000%
# At minibatch 430800, batch loss 1.061674, batch nll 0.689762, batch error rate 25.000000%
# At minibatch 430900, batch loss 1.038172, batch nll 0.666230, batch error rate 25.000000%
# At minibatch 431000, batch loss 0.663193, batch nll 0.291242, batch error rate 0.000000%
# At minibatch 431100, batch loss 0.865929, batch nll 0.493946, batch error rate 25.000000%
# At minibatch 431200, batch loss 1.281138, batch nll 0.909118, batch error rate 35.000000%
# At minibatch 431300, batch loss 0.933440, batch nll 0.561437, batch error rate 15.000000%
# At minibatch 431400, batch loss 0.653838, batch nll 0.281863, batch error rate 5.000000%
# At minibatch 431500, batch loss 0.839505, batch nll 0.467510, batch error rate 15.000000%
# At minibatch 431600, batch loss 1.019417, batch nll 0.647425, batch error rate 25.000000%
# At minibatch 431700, batch loss 0.610821, batch nll 0.238855, batch error rate 10.000000%
# At minibatch 431800, batch loss 0.637012, batch nll 0.265052, batch error rate 10.000000%
# At minibatch 431900, batch loss 0.951249, batch nll 0.579302, batch error rate 25.000000%
# At minibatch 432000, batch loss 0.979366, batch nll 0.607385, batch error rate 20.000000%
# After epoch 216: valid_err_rate: 26.640000% currently going to do 220 epochs
# After epoch 216: averaged train_err_rate: 18.827500% averaged train nll: 0.550330 averaged train loss: 0.922270
# At minibatch 432100, batch loss 1.195511, batch nll 0.823504, batch error rate 25.000000%
# At minibatch 432200, batch loss 0.678365, batch nll 0.306364, batch error rate 5.000000%
# At minibatch 432300, batch loss 1.099393, batch nll 0.727395, batch error rate 25.000000%
# At minibatch 432400, batch loss 1.024175, batch nll 0.652209, batch error rate 20.000000%
# At minibatch 432500, batch loss 0.879504, batch nll 0.507503, batch error rate 15.000000%
# At minibatch 432600, batch loss 1.125157, batch nll 0.753117, batch error rate 20.000000%
# At minibatch 432700, batch loss 1.078673, batch nll 0.706648, batch error rate 25.000000%
# At minibatch 432800, batch loss 0.763999, batch nll 0.392010, batch error rate 10.000000%
# At minibatch 432900, batch loss 0.707576, batch nll 0.335563, batch error rate 10.000000%
# At minibatch 433000, batch loss 0.812805, batch nll 0.440788, batch error rate 25.000000%
# At minibatch 433100, batch loss 0.723181, batch nll 0.351141, batch error rate 5.000000%
# At minibatch 433200, batch loss 0.767536, batch nll 0.395475, batch error rate 15.000000%
# At minibatch 433300, batch loss 1.067150, batch nll 0.695063, batch error rate 20.000000%
# At minibatch 433400, batch loss 0.864876, batch nll 0.492810, batch error rate 25.000000%
# At minibatch 433500, batch loss 0.828405, batch nll 0.456309, batch error rate 15.000000%
# At minibatch 433600, batch loss 0.704757, batch nll 0.332698, batch error rate 10.000000%
# At minibatch 433700, batch loss 0.818055, batch nll 0.445977, batch error rate 20.000000%
# At minibatch 433800, batch loss 0.736198, batch nll 0.364127, batch error rate 10.000000%
# At minibatch 433900, batch loss 0.633216, batch nll 0.261134, batch error rate 5.000000%
# At minibatch 434000, batch loss 1.248794, batch nll 0.876679, batch error rate 35.000000%
# After epoch 217: valid_err_rate: 26.070000% currently going to do 220 epochs
# After epoch 217: averaged train_err_rate: 18.595000% averaged train nll: 0.549413 averaged train loss: 0.921449
# At minibatch 434100, batch loss 0.786129, batch nll 0.413989, batch error rate 15.000000%
# At minibatch 434200, batch loss 0.731348, batch nll 0.359172, batch error rate 5.000000%
# At minibatch 434300, batch loss 0.745814, batch nll 0.373647, batch error rate 10.000000%
# At minibatch 434400, batch loss 1.076009, batch nll 0.703856, batch error rate 25.000000%
# At minibatch 434500, batch loss 0.974187, batch nll 0.602027, batch error rate 20.000000%
# At minibatch 434600, batch loss 1.111451, batch nll 0.739315, batch error rate 15.000000%
# At minibatch 434700, batch loss 0.859722, batch nll 0.487584, batch error rate 15.000000%
# At minibatch 434800, batch loss 0.894169, batch nll 0.521989, batch error rate 20.000000%
# At minibatch 434900, batch loss 0.908372, batch nll 0.536173, batch error rate 20.000000%
# At minibatch 435000, batch loss 1.033685, batch nll 0.661467, batch error rate 25.000000%
# At minibatch 435100, batch loss 0.794725, batch nll 0.422533, batch error rate 15.000000%
# At minibatch 435200, batch loss 0.646927, batch nll 0.274736, batch error rate 5.000000%
# At minibatch 435300, batch loss 0.588178, batch nll 0.215952, batch error rate 5.000000%
# At minibatch 435400, batch loss 0.966524, batch nll 0.594262, batch error rate 15.000000%
# At minibatch 435500, batch loss 0.840189, batch nll 0.467930, batch error rate 15.000000%
# At minibatch 435600, batch loss 0.972057, batch nll 0.599782, batch error rate 20.000000%
# At minibatch 435700, batch loss 0.851600, batch nll 0.479346, batch error rate 20.000000%
# At minibatch 435800, batch loss 0.905274, batch nll 0.533028, batch error rate 10.000000%
# At minibatch 435900, batch loss 0.778855, batch nll 0.406612, batch error rate 10.000000%
# At minibatch 436000, batch loss 0.985048, batch nll 0.612802, batch error rate 10.000000%
# After epoch 218: valid_err_rate: 26.660000% currently going to do 220 epochs
# After epoch 218: averaged train_err_rate: 18.630000% averaged train nll: 0.550305 averaged train loss: 0.922507
# At minibatch 436100, batch loss 0.706616, batch nll 0.334353, batch error rate 5.000000%
# At minibatch 436200, batch loss 0.817826, batch nll 0.445514, batch error rate 20.000000%
# At minibatch 436300, batch loss 0.816627, batch nll 0.444309, batch error rate 20.000000%
# At minibatch 436400, batch loss 1.469727, batch nll 1.097421, batch error rate 40.000000%
# At minibatch 436500, batch loss 0.626458, batch nll 0.254172, batch error rate 10.000000%
# At minibatch 436600, batch loss 0.672267, batch nll 0.299954, batch error rate 10.000000%
# At minibatch 436700, batch loss 0.692889, batch nll 0.320593, batch error rate 5.000000%
# At minibatch 436800, batch loss 0.875898, batch nll 0.503589, batch error rate 20.000000%
# At minibatch 436900, batch loss 0.961285, batch nll 0.588964, batch error rate 20.000000%
# At minibatch 437000, batch loss 0.848203, batch nll 0.475858, batch error rate 15.000000%
# At minibatch 437100, batch loss 0.867597, batch nll 0.495242, batch error rate 25.000000%
# At minibatch 437200, batch loss 0.762456, batch nll 0.390093, batch error rate 10.000000%
# At minibatch 437300, batch loss 1.258613, batch nll 0.886262, batch error rate 30.000000%
# At minibatch 437400, batch loss 1.023197, batch nll 0.650846, batch error rate 25.000000%
# At minibatch 437500, batch loss 0.875519, batch nll 0.503135, batch error rate 15.000000%
# At minibatch 437600, batch loss 0.997635, batch nll 0.625278, batch error rate 15.000000%
# At minibatch 437700, batch loss 1.256781, batch nll 0.884421, batch error rate 35.000000%
# At minibatch 437800, batch loss 0.722059, batch nll 0.349721, batch error rate 5.000000%
# At minibatch 437900, batch loss 0.701593, batch nll 0.329284, batch error rate 10.000000%
# At minibatch 438000, batch loss 0.749013, batch nll 0.376677, batch error rate 5.000000%
# After epoch 219: valid_err_rate: 26.640000% currently going to do 220 epochs
# After epoch 219: averaged train_err_rate: 18.610000% averaged train nll: 0.549488 averaged train loss: 0.921816
# At minibatch 438100, batch loss 0.804295, batch nll 0.431936, batch error rate 25.000000%
# At minibatch 438200, batch loss 0.856554, batch nll 0.484186, batch error rate 15.000000%
# At minibatch 438300, batch loss 1.119090, batch nll 0.746691, batch error rate 25.000000%
# At minibatch 438400, batch loss 1.378337, batch nll 1.005926, batch error rate 40.000000%
# At minibatch 438500, batch loss 0.851025, batch nll 0.478632, batch error rate 10.000000%
# At minibatch 438600, batch loss 0.862111, batch nll 0.489682, batch error rate 15.000000%
# At minibatch 438700, batch loss 1.025602, batch nll 0.653158, batch error rate 30.000000%
# At minibatch 438800, batch loss 0.984174, batch nll 0.611705, batch error rate 10.000000%
# At minibatch 438900, batch loss 0.820611, batch nll 0.448152, batch error rate 5.000000%
# At minibatch 439000, batch loss 1.249402, batch nll 0.876922, batch error rate 25.000000%
# At minibatch 439100, batch loss 0.851333, batch nll 0.478869, batch error rate 15.000000%
# At minibatch 439200, batch loss 1.052576, batch nll 0.680109, batch error rate 30.000000%
# At minibatch 439300, batch loss 0.927750, batch nll 0.555256, batch error rate 20.000000%
# At minibatch 439400, batch loss 0.909384, batch nll 0.536900, batch error rate 20.000000%
# At minibatch 439500, batch loss 0.682583, batch nll 0.310091, batch error rate 5.000000%
# At minibatch 439600, batch loss 0.595619, batch nll 0.223129, batch error rate 0.000000%
# At minibatch 439700, batch loss 0.868962, batch nll 0.496499, batch error rate 20.000000%
# At minibatch 439800, batch loss 0.765662, batch nll 0.393204, batch error rate 15.000000%
# At minibatch 439900, batch loss 1.048656, batch nll 0.676175, batch error rate 30.000000%
# At minibatch 440000, batch loss 1.230127, batch nll 0.857669, batch error rate 35.000000%
# After epoch 220: valid_err_rate: 26.830000% currently going to do 220 epochs
# After epoch 220: averaged train_err_rate: 18.625000% averaged train nll: 0.548760 averaged train loss: 0.921206

# %%
print "Setting network parameters from after epoch %d" %(best_params_epoch)
load_parameters(best_params)

print "Success rate is %f%%" %(100.0-compute_error_rate(cifar10_testt_stream)*100.0,)
print "Error rate is %f%%" %(compute_error_rate(cifar10_testt_stream)*100.0,)

figure(figsize=(16,14))

subplot(2,1,1)
train_nll_a = np.array(train_nll)
semilogy(train_nll_a[:,0], train_nll_a[:,1], label='batch train nll')
legend()

subplot(2,1,2)
train_erros_a = np.array(train_erros)
plot(train_erros_a[:,0], train_erros_a[:,1], label='batch train error rate')
validation_errors_a = np.array(validation_errors)
plot(validation_errors_a[:,0], validation_errors_a[:,1], label='validation error rate', color='r')
ylim(0,0.8)
legend()
# Out:
# Setting network parameters from after epoch 146
# Success rate is 73.060000%
# Error rate is 26.940000%

# %%
middle_layers_computer = theano.function([X], network.model_layers)

img_num=11

middle_layers = middle_layers_computer(X_test_value[img_num:img_num+1])
print middle_layers[0].shape
print middle_layers[1].shape
print middle_layers[2].shape
print middle_layers[3].shape
print middle_layers[4].shape


plot_mat(middle_layers[0])
title(network.model_names[0])
show()

for ml, name in zip(middle_layers[1:], network.model_names[1:]):
    try:
        #print ml#.transpose(1,0,2,3).shape
        plot_mat(ml.transpose(1,0,2,3), cmap='gray')
        title(name)
        show()
    except ValueError:
        pass
# Out:
# (1, 3, 32, 32)
# (1, 10, 28, 28)
# (1, 10, 14, 14)
# (1, 25, 10, 10)
# (1, 25, 5, 5)
